# %%
# Include Libraries
import numpy as np
import tensorflow as tf
import gym
import tensorflow.contrib.layers as layers
from mujoco_py import load_model_from_xml, MjSim, MjViewer
import policies
import value_functions as vfuncs
import utils_pg as utils

# Environment setup
#env = "CartPole-v0"
#env="InvertedPendulum-v2"
env = "HalfCheetah-v2"

# discrete = isinstance(env.action_space, gym.spaces.Discrete)
# observation_dim = env.observation_space.shape[0]
# action_dim = env.action_space.n if discrete else env.action_space.shape[0]
max_ep_len = 1000
num_traj = 20
#traj_length = max_ep_len*(observation_dim + 2)
latent_size = 100
use_baseline = True

# %%
# Feed forward network (multi-layer-perceptron, or mlp)

def build_mlp(mlp_input,output_size,scope,n_layers,size,output_activation=None):
    '''
    Build a feed forward network
    '''
    Input = mlp_input
    with tf.variable_scope(scope):
        # Dense Layers
        for i in range(n_layers-1):
            dense = tf.layers.dense(inputs = Input, units = size, activation = tf.nn.relu, bias_initializer=tf.constant_initializer(1.0))
            Input = dense
        # Fully Connected Layer
        out = layers.fully_connected(inputs = Input, num_outputs = output_size, activation_fn=output_activation)
    return out

# %%
class MetaLearner():
    def __init__(self, env, max_ep_len, num_traj,latent_size ):
        self.env = gym.make(env)
        self.discrete = isinstance(self.env.action_space, gym.spaces.Discrete)
        self.observation_dim = self.env.observation_space.shape[0]
        self.action_dim = self.env.action_space.n if self.discrete else self.env.action_space.shape[0]
        self.max_ep_len = max_ep_len
        self.num_traj = num_traj
        self.traj_length = self.max_ep_len*(self.observation_dim + 2) # TO Change
        self.use_baseline = True
        self.latent_size = latent_size
        self.feature_size = self.observation_dim + 1 + self.env.action_space.shape[0] # HC
        self.lr = 3e-3
        self.num_layers = 2
        self.layers_size = 32
        self.num_mdps = 10
        self.model = self.env.env.model
        self.sim = MjSim(self.model)
        self.gamma = 0.95
        self.decoder_len = 32

        # build model
        self.ConstructGraph()
    
    def add_placeholders(self):
        self.observation_placeholder_explore = tf.placeholder(tf.float32, shape=(None,self.observation_dim))
        if(self.discrete):
            self.action_placeholder_explore = tf.placeholder(tf.int32, shape=(None))
            self.action_placeholder_exploit = tf.placeholder(tf.int32, shape=(None))
        else:
            self.action_placeholder_explore = tf.placeholder(tf.float32, shape=(None,self.action_dim))
            self.action_placeholder_exploit= tf.placeholder(tf.float32, shape=(None,self.action_dim))

        self.baseline_target_placeholder = tf.placeholder(tf.float32, shape= None)
        self.advantage_placeholder_explore = tf.placeholder(tf.float32, shape=(None))
        
        #self.encoder_input_placeholder = tf.placeholder(tf.float32, shape= (self.num_traj,self.traj_length))
        self.encoder_input_placeholder = tf.placeholder(tf.float32, [None, None, self.feature_size])
        self.decoder_input_placeholder = tf.placeholder(tf.float32, shape= (1,self.latent_size))
        self.sequence_length_placeholder = tf.placeholder(tf.int32, [None, ])
        
        self.observation_placeholder_exploit = tf.placeholder(tf.float32, shape=(None,self.observation_dim))
        #TODO
        self.advantage_placeholder_exploit = tf.placeholder(tf.float32, shape=(None))
        
        
    def build_policy_explore(self, scope = "policy_explore"):
        if (self.discrete):
            self.action_logits = build_mlp(self.observation_placeholder_explore,self.action_dim,scope = scope,n_layers=self.num_layers,size = self.layers_size,output_activation=None)
            self.explore_action = tf.multinomial(self.action_logits,1)
            self.explore_action = tf.squeeze(self.explore_action, axis=1)
            self.explore_logprob = -tf.nn.sparse_softmax_cross_entropy_with_logits(logits = self.action_logits, labels = self.action_placeholder_explore)

        else:   
            action_means = build_mlp(self.observation_placeholder_explore,self.action_dim,scope,n_layers=self.num_layers, size = self.layers_size,output_activation=None)
            init = tf.constant(np.random.rand(1, 2))
            #log_std = tf.get_variable("log_std", [self.action_dim])
            log_std = tf.get_variable(
                'log_std',
                shape=[1, self.action_dim],
                dtype=tf.float32,
                initializer=tf.zeros_initializer(),
                trainable=True
            )
            log_std = tf.log(tf.exp(log_std) + 1.)
            log_std = tf.tile(log_std,
                                   [tf.shape(action_means)[0], 1])
            self.explore_action = tf.random_normal((1,),
                                                   action_means,
                                                   log_std)
            dist = tf.contrib.distributions.MultivariateNormalDiag(action_means, log_std)
            self.explore_logprob = dist.prob(self.action_placeholder_explore, name = 'log_prob')
            #self.explore_action =   action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
            #mvn = tf.contrib.distributions.MultivariateNormalDiag(action_means, tf.exp(log_std))
            #self.explore_logprob =  mvn.log_prob(value = self.action_placeholder_explore, name='log_prob')

    
    
    def build_policy_exploit(self, scope = "policy_exploit"):
        if(self.discrete):
            #self.exploit_action_logits = (tf.matmul(tf.nn.relu(tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W1) + self.d_B1), self.d_W2) + self.d_B2),self.d_W3) + self.d_B3)
            #self.exploit_action_logits = tf.matmul(self.observation_placeholder_exploit,self.d_W3) + self.d_B3
            self.exploit_action_logits = tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W2) + self.d_B2), self.d_W3) + self.d_B3
            self.exploit_action = tf.multinomial(self.exploit_action_logits,1)
            self.exploit_action = tf.squeeze(self.exploit_action, axis=1)
            self.exploit_logprob = -tf.nn.sparse_softmax_cross_entropy_with_logits(logits = self.exploit_action_logits, labels = self.action_placeholder_exploit)
        else:
            action_means = tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W2) + self.d_B2), self.d_W3) + self.d_B3
            init = tf.constant(np.random.rand(1, 2))
            log_std = tf.get_variable("exploit_log_prob", [self.action_dim])
            self.exploit_action = action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
            self.exploit_logprob = utils.gauss_log_prob(mu=action_means, logstd=log_std, x=self.action_placeholder_exploit)
            
#             init = tf.constant(np.random.rand(1, 2))
#             log_std = tf.get_variable("exploit_log_prob", [self.action_dim])
#             self.exploit_action =   action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
#             mvn = tf.contrib.distributions.MultivariateNormalDiag(action_means, tf.exp(log_std))
#             self.exploit_logprob =  mvn.log_prob(value = self.action_placeholder_exploit, name='exploit_log_prob')

        #self.loss_grads_exploit = self.exploit_logprob * self.advantage_placeholder_exploit
        
    def NNEncoder(self, scope = "NNEncoder"):
        self.Z = build_mlp(self.encoder_input_placeholder,self.latent_size,scope = scope,n_layers=3,size = 60,output_activation=None)
    
 

    # input [num_traj, length, features (obs + action + reward) ]
    def LSTMEncoder(self, scope = "LSTMEncoder"):
        self.hidden_size = 64
        initializer = tf.random_uniform_initializer(-1, 1)
        cell = tf.nn.rnn_cell.LSTMCell(self.hidden_size, self.feature_size, initializer=initializer)
        cell_out = tf.contrib.rnn.OutputProjectionWrapper(cell, self.latent_size)
        self.output, _ = tf.nn.dynamic_rnn(cell_out,self.encoder_input_placeholder,self.sequence_length_placeholder,dtype=tf.float32,)
        batch_size = tf.shape(self.output)[0]
        max_length = tf.shape(self.output)[1]
        out_size = int(self.output.get_shape()[2])
        index = tf.range(0, batch_size) * max_length + (self.sequence_length_placeholder - 1)
        flat = tf.reshape(self.output, [-1, out_size])
        self.Z = tf.reduce_mean(tf.gather(flat, index), axis = 0)
        
    
    def Decoder(self, decoder_out_dim, scope):
        return build_mlp(self.decoder_input_placeholder,decoder_out_dim,scope = scope,n_layers=1,size = 64,output_activation=None)
    
    
    def sample_paths_explore(self, env,mdp_num,Test = False, num_episodes = None):
        paths = []
        self.length = []
        episode_rewards = []
        self.sim.model.opt.gravity[-1] = -5 - mdp_num
        for i in range(self.num_traj):
            pad = False
            state = env.reset()
            new_states,states,new_actions, actions, rewards = [], [], [], [], []
            episode_reward = 0
            for step in range(self.max_ep_len):
                if (pad):
                    states.append([0]*self.observation_dim)
                    if(self.discrete):
                        actions.append(0)
                    else:
                        actions.append([0]*self.action_dim)
                    rewards.append(0)
                else:
                    states.append(state)
                    new_states.append(state)
                    #action = self.sess.run(self.explore_action, feed_dict={self.observation_placeholder_explore : states[-1][None]})[0]
                    action = self.policyfn.sample_action(state) #NEW
                    state, reward, done, info = env.step(action)
                    actions.append(action)
                    new_actions.append(action)
                    rewards.append(reward)
                    episode_reward += reward
                    if (done or step == self.max_ep_len-1):
                        episode_rewards.append(episode_reward)
                        self.length.append(step + 1)
                        pad = True 
                        
            episode_rewards.append(episode_reward)            
            #print("explore",np.array(actions))
            path = {"new_obs" : np.array(new_states),"observation" : np.array(states),
                                "reward" : np.array(rewards),"new_acs" : np.array(new_actions),
                                "action" : np.array(actions)}
            paths.append(path)
        return paths, episode_rewards
    
    def sample_paths_exploit(self, env,Z,mdp_num,Test = False, num_episodes = None):
        self.sim.model.opt.gravity[-1] = -5 - mdp_num
        
        paths = []
        num = 0
        episode_rewards = []
        for i in range(self.num_traj):
            state = env.reset()
            states, actions, rewards = [], [], []
            episode_reward = 0
            for step in range(self.max_ep_len):
                states.append(state)
                action = self.sess.run(self.exploit_action, feed_dict={self.observation_placeholder_exploit : state[None], self.decoder_input_placeholder: Z})[0]
                state, reward, done, info = env.step(action)
                actions.append(action)
                rewards.append(reward)
                episode_reward += reward
                if (done or step == self.max_ep_len-1):
                    episode_rewards.append(episode_reward)
                    break
            #print("exploit",np.array(actions))
            path = {"observation" : np.array(states),
                                "reward" : np.array(rewards),
                                "action" : np.array(actions)}
            paths.append(path)
 
        #print("exploit success: ", num)
        return paths, episode_rewards
    
    def get_returns(self,paths, explore = False):
        all_returns = []
        m = 0
        for path in paths:
            rewards = path["reward"]
            returns = []
            if(explore):
                length = self.length[m]
            else:
                length = len(rewards)
            for i in range(length):
                path_returns = 0
                k = 0
                for j in range(i,length):
                    path_returns = path_returns + rewards[j]*(self.gamma)**k
                    k = k+1
                returns.append(path_returns)
            all_returns.append(returns)
            m+=1
        returns = np.concatenate(all_returns)
        return returns
    
    def stack_trajectories(self,paths):
        trajectories = []
        for path in paths:
            rewards = path["reward"]
            states = path["observation"]
            action = path["action"]
            
            SAR = []
            for i in range(len(states)):
                SAR.append(list(states[i]) + list(action[i]) + [rewards[i]])
            trajectories.append(SAR)
        return np.array(trajectories)
    
    def addBaseline(self):
        self.baseline = build_mlp(self.observation_placeholder_explore,1,scope = "baseline",n_layers=self.num_layers, size = self.layers_size,output_activation=None)
        self.baseline_loss = tf.losses.mean_squared_error(self.baseline_target_placeholder,self.baseline,scope = "baseline")
        baseline_adam_optimizer =  tf.train.AdamOptimizer(learning_rate = self.lr)
        self.update_baseline_op = baseline_adam_optimizer.minimize(self.baseline_loss)

    def calculate_advantage(self,returns, observations):
        if (self.use_baseline):
            baseline = self.sess.run(self.baseline, {input_placeholder:observations})
            adv = returns - baseline
            adv = (adv - np.mean(adv))/np.std(adv)
        else:
            adv = returns
        return adv
    

        
    def ConstructGraph(self):
        tf.reset_default_graph()
        self.sess = tf.Session()
        
        self.vf = vfuncs.NnValueFunction(session=self.sess,ob_dim=self.observation_dim)
        self.policyfn = policies.GaussianPolicy(self.sess,self.observation_dim, self.action_dim)
        
        self.add_placeholders()
        
#         self.add_placeholders()
        
#         self.build_policy_explore()
#         self.explore_policy_loss = -tf.reduce_sum(self.explore_logprob * self.advantage_placeholder_explore)
#         self.loss_grads_explore = -self.explore_logprob * self.advantage_placeholder_explore
#         self.tvars_explore = tf.trainable_variables()
#         self.gradients_explore = tf.gradients(self.explore_policy_loss,self.tvars_explore)
        
#         #self.addBaseline()
        
#         self.baseline = build_mlp(self.observation_placeholder_explore,1,scope = "baseline",n_layers=1, size = 16,output_activation=None)
#         self.baseline_loss = tf.losses.mean_squared_error(self.baseline_target_placeholder,self.baseline,scope = "baseline")
#         baseline_adam_optimizer =  tf.train.AdamOptimizer(learning_rate = self.lr)
#         self.update_baseline_op = baseline_adam_optimizer.minimize(self.baseline_loss)
        
#         #Encoder LSTM
        self.LSTMEncoder()
        
        
        #decoder weights
        #self.d_W1 = self.Decoder(scope = "W1", decoder_out_dim = self.observation_dim*self.decoder_len)
        self.d_W2 = self.Decoder(scope = "W2", decoder_out_dim = self.observation_dim*self.decoder_len)
        #self.d_W3 = self.Decoder(scope = "W3", decoder_out_dim = self.decoder_len*action_dim)
        self.d_W3 = self.Decoder(scope = "W3", decoder_out_dim = self.decoder_len*self.action_dim)
        
        #self.d_W1 = ((self.d_W1 - (tf.reduce_max(self.d_W1) + tf.reduce_min(self.d_W1))/2)/(tf.reduce_max(self.d_W1) - tf.reduce_min(self.d_W1)))*2 
        #self.d_W2 = ((self.d_W2 - (tf.reduce_max(self.d_W2) + tf.reduce_min(self.d_W2))/2)/(tf.reduce_max(self.d_W2) - tf.reduce_min(self.d_W2)))*2 
        #self.d_W3 = ((self.d_W3 - (tf.reduce_max(self.d_W3) + tf.reduce_min(self.d_W3))/2)/(tf.reduce_max(self.d_W3) - tf.reduce_min(self.d_W3)))*2 
        
        #self.d_W1 = tf.reshape(self.d_W1, [self.observation_dim, self.decoder_len])
        self.d_W2 = tf.reshape(self.d_W2, [self.observation_dim, self.decoder_len])
        #self.d_W3 = tf.reshape(self.d_W3, [self.decoder_len, self.action_dim])
        self.d_W3 = tf.reshape(self.d_W3, [self.decoder_len, self.action_dim])
        
        # decoder output bias
        #self.d_B1 = tf.reshape(self.Decoder(decoder_out_dim = self.decoder_len, scope = "B1"), [self.decoder_len])
        self.d_B2 = tf.reshape(self.Decoder(decoder_out_dim = self.decoder_len, scope = "B2"), [self.decoder_len])
        self.d_B3 = tf.reshape(self.Decoder(decoder_out_dim = self.action_dim, scope = "B3"), [self.action_dim])
        #self.d_B1 = ((self.d_B1 - (tf.reduce_max(self.d_B1) + tf.reduce_min(self.d_B1))/2)/(tf.reduce_max(self.d_B1) - tf.reduce_min(self.d_B1)))*2 
        #self.d_B2 = ((self.d_B2 - (tf.reduce_max(self.d_B2) + tf.reduce_min(self.d_B2))/2)/(tf.reduce_max(self.d_B2) - tf.reduce_min(self.d_B2)))*2 
        
        
        # exploit policy
        self.build_policy_exploit()
        #self.d = [self.d_W1, self.d_B1, self.d_W2, self.d_B2, self.d_W3, self.d_B3]
        self.exploit_policy_loss = -tf.reduce_sum(self.exploit_logprob * self.advantage_placeholder_exploit)
        self.d = [self.d_W3, self.d_B3]
        self.gradients_exploit = tf.gradients(self.exploit_policy_loss,self.d)
        
        # train encoder and decoder
        adam_optimizer_exploit =  tf.train.AdamOptimizer(self.lr*0.3)
        self.output_train_op = adam_optimizer_exploit.minimize(self.exploit_policy_loss)
        # train original network
#         adam_optimizer_explore = tf.train.AdamOptimizer(self.lr)
#         self.input_train_op = adam_optimizer_explore.minimize(self.explore_policy_loss)
        init = tf.global_variables_initializer()
        self.sess.run(init)
    
    def initialize(self):
        self.ConstructGraph()
#         # create tf session
#         self.sess = tf.Session()
        
#         # initiliaze all variables
#         init = tf.global_variables_initializer()
#         self.sess.run(init)
    
    def train_step(self): 
        # sample num_traj*num_MDPs
        for i in range(self.num_mdps):
            explore_paths, explore_rewards = self.sample_paths_explore(self.env,i)
            observations_explore = np.concatenate([path["observation"] for path in explore_paths])
            new_observations_explore = np.concatenate([path["new_obs"] for path in explore_paths])
            new_actions_explore = np.concatenate([path["new_acs"] for path in explore_paths])
            actions_explore = np.concatenate([path["action"] for path in explore_paths])
            rewards_explore = np.concatenate([path["reward"] for path in explore_paths])
            
            vtargs, vpreds, advantages_explore = [], [], []
            for path in explore_paths:
                rew_t = path["reward"]
                return_t = utils.discount(rew_t, self.gamma)
                vpred_t = self.vf.predict(path["observation"])
                adv_t = return_t - vpred_t
                advantages_explore.append(adv_t)
                vtargs.append(return_t)
                vpreds.append(vpred_t)
                
                
            #returns_explore = self.get_returns(explore_paths, explore = True)
            advantages_explore = np.concatenate(advantages_explore)
            advantages_explore = (advantages_explore - advantages_explore.mean()) / (advantages_explore.std() + 1e-8)
            vtarg_n = np.concatenate(vtargs)
            vpred_n = np.concatenate(vpreds)
            #update baseline
            self.vf.fit(new_observations_explore, vtarg_n)
            
            surr_loss, oldmean_na, oldlogstd_a = self.policyfn.update_policy(
                    new_observations_explore, new_actions_explore, advantages_explore, self.lr)
            
            print("average reward explore:", np.mean(explore_rewards))
            
            #print(returns_explore)
#             print("average reward explore: MDP", i, np.sum(explore_rewards)/num_traj, len(explore_rewards))

#             baseline_explore = self.sess.run(self.baseline, {self.observation_placeholder_explore:new_observations_explore})
#             adv = returns_explore - np.squeeze(baseline_explore)
#             advantages_explore = (adv - np.mean(adv))/(np.std(adv) + 1e-12)


#             # update the baseline

#             self.sess.run(self.update_baseline_op, {self.observation_placeholder_explore:new_observations_explore, 
#                                            self.baseline_target_placeholder : returns_explore})

            # calculate explore gradients
    #         grads_explore = self.sess.run(self.gradients_explore, feed_dict={
    #                     self.observation_placeholder_explore : observations_explore,
    #                     self.action_placeholder_explore : actions_explore,
    #                     self.advantage_placeholder_explore : returns_explore})
            #print("explore",grads_explore )
            # form trajectory matrix

            M = np.array(self.stack_trajectories(explore_paths))


            #encoder LSTM
            Z = self.sess.run(self.Z, feed_dict = {self.encoder_input_placeholder: M,self.sequence_length_placeholder: self.length })
            Z = np.reshape(Z,[1,len(Z)])
#             #print("Z",Z)
#             #print(self.sess.run(self.d, feed_dict = {self.decoder_input_placeholder: Z}))
#             #print("d",self.d)
#             # sample paths
#             tvars = tf.trainable_variables()
#             tvars_vals = self.sess.run(tvars[-5:-1])
#             #print(tvars_vals)
            for j in range(10):
                exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z,i)
                # get observations, actions and rewards
                observations_exploit = np.concatenate([path["observation"] for path in exploit_paths])
                actions_exploit = np.concatenate([path["action"] for path in exploit_paths])
                rewards_exploit = np.concatenate([path["reward"] for path in exploit_paths])
                returns_exploit = self.get_returns(exploit_paths)
                print("average reward exploit: MDP", i, np.sum(exploit_rewards) / num_traj, len(exploit_rewards))


#             # exploit grads
#     #         grads_exploit = self.sess.run(self.gradients_exploit,feed_dict={
#     #                     self.observation_placeholder_exploit : observations_exploit,
#     #                     self.action_placeholder_exploit : actions_exploit,
#     #                     self.advantage_placeholder_exploit : returns_exploit,
#     #                     self.decoder_input_placeholder: Z})

            #train encoder and decoder network
                self.sess.run(self.output_train_op, feed_dict={
                                self.observation_placeholder_exploit : observations_exploit,
                                self.action_placeholder_exploit : actions_exploit,
                                self.advantage_placeholder_exploit : returns_exploit,
                                self.decoder_input_placeholder: Z})

            # find advantage for input network
    #         advantage_explore = 0
    #         for i in range(len(grads_exploit)):
    #             l1 = grads_exploit[i]
    #             l2 = grads_explore[i]
    #             advantage_explore = advantage_explore + np.matmul(l1.flatten(), l2.flatten())

            # train input policy
#             self.sess.run(self.input_train_op, feed_dict={
#                             self.observation_placeholder_explore : new_observations_explore,
#                             self.action_placeholder_explore : new_actions_explore,
#                             self.advantage_placeholder_explore : advantages_explore})
    
    def test(self):
        explore_paths, explore_rewards = self.sample_paths_explore(self.env, Test = True)
        M = self.stack_trajectories(explore_paths)
        Z = self.sess.run(self.Z, feed_dict = {self.encoder_input_placeholder: M,self.sequence_length_placeholder: self.length })
        Z = np.reshape(Z,[1,len(Z)])
        # sample paths
        exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z, Test = True)
        print("average reward exploit", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
        
    def train(self):
        self.initialize()
        num_epochs = 200
        for epoch in range(num_epochs):
            print("epoch number: ", epoch)
            self.train_step()

# %%
a = MetaLearner(env, max_ep_len, num_traj, latent_size)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
a.train()
# Out:
# epoch number:  0
# average reward explore: -5310.066074312663
# average reward exploit: MDP 0 -565.7242126885885 20
# average reward exploit: MDP 0 -596.2405979875969 20
# average reward exploit: MDP 0 -639.0962299746558 20
# average reward exploit: MDP 0 -496.9236126208666 20
# average reward exploit: MDP 0 -570.0544014836529 20
# average reward exploit: MDP 0 -590.2367972001124 20
# average reward exploit: MDP 0 -511.40432451515505 20
# average reward exploit: MDP 0 -572.8674025740679 20
# average reward exploit: MDP 0 -475.9333887833629 20
# average reward exploit: MDP 0 -561.9618459192357 20
# average reward explore: -4224.515114259144
# average reward exploit: MDP 1 -577.7034491840056 20
# average reward exploit: MDP 1 -537.3051393006888 20
# average reward exploit: MDP 1 -440.9168775826106 20
# average reward exploit: MDP 1 -439.8913469319731 20
# average reward exploit: MDP 1 -447.118194790489 20
# average reward exploit: MDP 1 -459.51644214006984 20
# average reward exploit: MDP 1 -456.9382182586727 20
# average reward exploit: MDP 1 -387.33171122451364 20
# average reward exploit: MDP 1 -505.7358213126613 20
# average reward exploit: MDP 1 -410.35617788776653 20
# average reward explore: -3521.3012636893086
# average reward exploit: MDP 2 -398.9862909625029 20
# average reward exploit: MDP 2 -325.91294977285673 20
# average reward exploit: MDP 2 -284.2415184709422 20
# average reward exploit: MDP 2 -378.5898524478373 20
# average reward exploit: MDP 2 -441.9715168151135 20
# average reward exploit: MDP 2 -498.4395497542806 20
# average reward exploit: MDP 2 -537.1451613301926 20
# average reward exploit: MDP 2 -503.6899867016312 20
# average reward exploit: MDP 2 -497.86315615058794 20
# average reward exploit: MDP 2 -517.2547316184216 20
# average reward explore: -3065.9342964020016
# average reward exploit: MDP 3 -586.6060665005913 20
# average reward exploit: MDP 3 -555.6276050280762 20
# average reward exploit: MDP 3 -543.2931806033805 20
# average reward exploit: MDP 3 -531.1464628292727 20
# average reward exploit: MDP 3 -517.160846362837 20
# average reward exploit: MDP 3 -466.38157849708875 20
# average reward exploit: MDP 3 -475.2795651841825 20
# average reward exploit: MDP 3 -396.7223925478968 20
# average reward exploit: MDP 3 -417.0923631374329 20
# average reward exploit: MDP 3 -401.04853927309205 20
# average reward explore: -2589.0017937397106
# average reward exploit: MDP 4 -264.3651445572874 20
# average reward exploit: MDP 4 -233.93260787231853 20
# average reward exploit: MDP 4 -218.50295397707 20
# average reward exploit: MDP 4 -165.2326200781776 20
# average reward exploit: MDP 4 -58.15056171988766 20
# average reward exploit: MDP 4 -67.34226829282258 20
# average reward exploit: MDP 4 -61.03075236394907 20
# average reward exploit: MDP 4 18.028056673597334 20
# average reward exploit: MDP 4 -80.38869896003118 20
# average reward exploit: MDP 4 -0.8635373194621081 20
# average reward explore: -2343.089316657792
# average reward exploit: MDP 5 -181.19324701258853 20
# average reward exploit: MDP 5 120.45000455173815 20
# average reward exploit: MDP 5 -169.7118287126954 20
# average reward exploit: MDP 5 -181.74221060126007 20
# average reward exploit: MDP 5 -308.6224095852468 20
# average reward exploit: MDP 5 -327.53479253677125 20
# average reward exploit: MDP 5 -263.44138803569854 20
# average reward exploit: MDP 5 -205.8509824671581 20
# average reward exploit: MDP 5 -241.64130144638793 20
# average reward exploit: MDP 5 -239.4274026640629 20
# average reward explore: -2096.49761573601
# average reward exploit: MDP 6 -323.4487801557373 20
# average reward exploit: MDP 6 -156.3299056995555 20
# average reward exploit: MDP 6 -167.9347272974116 20
# average reward exploit: MDP 6 -148.48762555111315 20
# average reward exploit: MDP 6 48.85335393805492 20
# average reward exploit: MDP 6 -86.51030729525796 20
# average reward exploit: MDP 6 -81.07910864017923 20
# average reward exploit: MDP 6 -64.1081836968508 20
# average reward exploit: MDP 6 -254.76318988936495 20
# average reward exploit: MDP 6 -283.2494743301655 20
# average reward explore: -1894.1856947805056
# average reward exploit: MDP 7 8.621939868959027 20
# average reward exploit: MDP 7 -13.356838386368532 20
# average reward exploit: MDP 7 -294.25728564905154 20
# average reward exploit: MDP 7 -325.6648966764691 20
# average reward exploit: MDP 7 -389.4188747780199 20
# average reward exploit: MDP 7 -459.31727738900656 20
# average reward exploit: MDP 7 -455.4865923849752 20
# average reward exploit: MDP 7 -451.2996130982021 20
# average reward exploit: MDP 7 -323.62689954937616 20
# average reward exploit: MDP 7 -271.51150494606316 20
# average reward explore: -1682.184447119214
# average reward exploit: MDP 8 -521.2849963819027 20
# average reward exploit: MDP 8 -477.95434644887536 20
# average reward exploit: MDP 8 -492.9515065518332 20
# average reward exploit: MDP 8 -460.0528887843567 20
# average reward exploit: MDP 8 -450.34345040391844 20
# average reward exploit: MDP 8 -374.0038044889269 20
# average reward exploit: MDP 8 -353.89643729103017 20
# average reward exploit: MDP 8 -393.6463768210029 20
# average reward exploit: MDP 8 -319.33333989871426 20
# average reward exploit: MDP 8 -373.81979923880743 20
# average reward explore: -1460.991000434642
# average reward exploit: MDP 9 -356.5749163210983 20
# average reward exploit: MDP 9 -366.61208079045673 20
# average reward exploit: MDP 9 -350.2736919891787 20
# average reward exploit: MDP 9 -294.6332856421403 20
# average reward exploit: MDP 9 -260.261687894138 20
# average reward exploit: MDP 9 -185.56066870534625 20
# average reward exploit: MDP 9 -226.0172670268884 20
# average reward exploit: MDP 9 -190.53342563134595 20
# average reward exploit: MDP 9 -229.1436637391127 20
# average reward exploit: MDP 9 -233.97349530123762 20
# epoch number:  1
# average reward explore: -1617.0151730868715
# average reward exploit: MDP 0 -271.11960709018564 20
# average reward exploit: MDP 0 -322.12920792949825 20
# average reward exploit: MDP 0 -378.9848701405507 20
# average reward exploit: MDP 0 -282.5048897142878 20
# average reward exploit: MDP 0 -199.76118605653073 20
# average reward exploit: MDP 0 -207.0986254307839 20
# average reward exploit: MDP 0 -191.0728486062316 20
# average reward exploit: MDP 0 -251.77196060583066 20
# average reward exploit: MDP 0 -214.3971626328304 20
# average reward exploit: MDP 0 -197.60694826956808 20
# average reward explore: -1431.086184665691
# average reward exploit: MDP 1 -340.39832554719214 20
# average reward exploit: MDP 1 -454.9121208485517 20
# average reward exploit: MDP 1 -321.54574892201254 20
# average reward exploit: MDP 1 -428.4211663825724 20
# average reward exploit: MDP 1 -429.7273905397389 20
# average reward exploit: MDP 1 -390.63688397985663 20
# average reward exploit: MDP 1 -433.8872729227319 20
# average reward exploit: MDP 1 -458.539351924834 20
# average reward exploit: MDP 1 -478.12431582239435 20
# average reward exploit: MDP 1 -373.75076249794336 20
# average reward explore: -1281.847957311454
# average reward exploit: MDP 2 -194.92879108678034 20
# average reward exploit: MDP 2 -38.85482681961601 20
# average reward exploit: MDP 2 -92.5366824829307 20
# average reward exploit: MDP 2 -126.67954708723957 20
# average reward exploit: MDP 2 -89.49940581240136 20
# average reward exploit: MDP 2 -181.88633846542285 20
# average reward exploit: MDP 2 -186.71119738838792 20
# average reward exploit: MDP 2 -17.18878144261145 20
# average reward exploit: MDP 2 -147.27976806782712 20
# average reward exploit: MDP 2 -148.0829556923929 20
# average reward explore: -1206.2115698702369
# average reward exploit: MDP 3 -274.77253674590287 20
# average reward exploit: MDP 3 -223.72339875224787 20
# average reward exploit: MDP 3 -259.20909763676696 20
# average reward exploit: MDP 3 -268.34353167556566 20
# average reward exploit: MDP 3 -322.2259852287858 20
# average reward exploit: MDP 3 -419.96499651156637 20
# average reward exploit: MDP 3 -372.17062221271624 20
# average reward exploit: MDP 3 -214.2060186948538 20
# average reward exploit: MDP 3 -249.61733137209967 20
# average reward exploit: MDP 3 -232.31349714048307 20
# average reward explore: -1134.1699187515783
# average reward exploit: MDP 4 -204.9405042170653 20
# average reward exploit: MDP 4 -286.9813925843404 20
# average reward exploit: MDP 4 -216.11176117477743 20
# average reward exploit: MDP 4 -271.16024169108084 20
# average reward exploit: MDP 4 -185.09705901700306 20
# average reward exploit: MDP 4 -242.8686390561496 20
# average reward exploit: MDP 4 -201.71609382615088 20
# average reward exploit: MDP 4 -218.9580284791955 20
# average reward exploit: MDP 4 -225.86485535338588 20
# average reward exploit: MDP 4 -242.9028797764312 20
# average reward explore: -1022.5150677493039
# average reward exploit: MDP 5 -519.840886429588 20
# average reward exploit: MDP 5 -520.6857440284555 20
# average reward exploit: MDP 5 -486.26501719215656 20
# average reward exploit: MDP 5 -487.4817548430389 20
# average reward exploit: MDP 5 -536.7860305461011 20
# average reward exploit: MDP 5 -645.6008131170476 20
# average reward exploit: MDP 5 -684.1156670527625 20
# average reward exploit: MDP 5 -657.8501333639175 20
# average reward exploit: MDP 5 -612.1220915703265 20
# average reward exploit: MDP 5 -584.402583610452 20
# average reward explore: -897.7388162918751
# average reward exploit: MDP 6 -450.2039997435535 20
# average reward exploit: MDP 6 -392.3805955255707 20
# average reward exploit: MDP 6 -399.805431023033 20
# average reward exploit: MDP 6 -345.57019656716386 20
# average reward exploit: MDP 6 -316.1431284472418 20
# average reward exploit: MDP 6 -340.41017797030577 20
# average reward exploit: MDP 6 -305.7335185896178 20
# average reward exploit: MDP 6 -328.39865553232795 20
# average reward exploit: MDP 6 -319.9105930309532 20
# average reward exploit: MDP 6 -324.97119709196437 20
# average reward explore: -842.9203358184601
# average reward exploit: MDP 7 -314.4712842615185 20
# average reward exploit: MDP 7 -257.72351571882166 20
# average reward exploit: MDP 7 -176.55897229435087 20
# average reward exploit: MDP 7 -166.5104787376323 20
# average reward exploit: MDP 7 -59.461825902675876 20
# average reward exploit: MDP 7 -127.72855465252329 20
# average reward exploit: MDP 7 -157.25336700285396 20
# average reward exploit: MDP 7 -122.00079486255098 20
# average reward exploit: MDP 7 -228.55945481908097 20
# average reward exploit: MDP 7 -241.30611259991124 20
# average reward explore: -774.8069841558815
# average reward exploit: MDP 8 -369.272525514842 20
# average reward exploit: MDP 8 -336.68027036768444 20
# average reward exploit: MDP 8 -315.2068975722808 20
# average reward exploit: MDP 8 -352.2925841661274 20
# average reward exploit: MDP 8 -333.57576432935434 20
# average reward exploit: MDP 8 -352.99327784940596 20
# average reward exploit: MDP 8 -334.35462463582485 20
# average reward exploit: MDP 8 -344.967289522344 20
# average reward exploit: MDP 8 -337.2754684510088 20
# average reward exploit: MDP 8 -351.9044619825519 20
# average reward explore: -729.1678867780175
# average reward exploit: MDP 9 -269.54319465521587 20
# average reward exploit: MDP 9 -221.35800213099824 20
# average reward exploit: MDP 9 -189.72780587623015 20
# average reward exploit: MDP 9 -174.9816875951936 20
# average reward exploit: MDP 9 -168.63228570160408 20
# average reward exploit: MDP 9 -127.52522500684839 20
# average reward exploit: MDP 9 -11.723680949791333 20
# average reward exploit: MDP 9 -148.88822445676504 20
# average reward exploit: MDP 9 -42.22938171762369 20
# average reward exploit: MDP 9 -38.66933209383915 20
# epoch number:  2
# average reward explore: -973.64492282144
# average reward exploit: MDP 0 -157.60044378386957 20
# average reward exploit: MDP 0 -202.83820985700552 20
# average reward exploit: MDP 0 -98.63190039245491 20
# average reward exploit: MDP 0 -189.73314402602495 20
# average reward exploit: MDP 0 -184.09993002112998 20
# average reward exploit: MDP 0 -146.1128944458399 20
# average reward exploit: MDP 0 -95.82165542032803 20
# average reward exploit: MDP 0 -186.62382332197805 20
# average reward exploit: MDP 0 -200.28100038793588 20
# average reward exploit: MDP 0 -179.3288496445784 20
# average reward explore: -936.146373716859
# average reward exploit: MDP 1 -386.8959649197781 20
# average reward exploit: MDP 1 -383.8845745998963 20
# average reward exploit: MDP 1 -247.14393198547018 20
# average reward exploit: MDP 1 -320.9220758208512 20
# average reward exploit: MDP 1 -273.2085578997386 20
# average reward exploit: MDP 1 -237.6254500449947 20
# average reward exploit: MDP 1 -160.60186448754686 20
# average reward exploit: MDP 1 -149.83809482677788 20
# average reward exploit: MDP 1 -128.6886033719921 20
# average reward exploit: MDP 1 -219.6102717211495 20
# average reward explore: -891.106125151493
# average reward exploit: MDP 2 -551.2359669886677 20
# average reward exploit: MDP 2 -495.1071606829536 20
# average reward exploit: MDP 2 -677.1565176768923 20
# average reward exploit: MDP 2 -644.0114343312123 20
# average reward exploit: MDP 2 -626.0567608883232 20
# average reward exploit: MDP 2 -609.0117656654614 20
# average reward exploit: MDP 2 -607.4915472329493 20
# average reward exploit: MDP 2 -656.639250160547 20
# average reward exploit: MDP 2 -741.2396374356598 20
# average reward exploit: MDP 2 -657.8698581076355 20
# average reward explore: -798.8930851750299
# average reward exploit: MDP 3 -339.11012679742043 20
# average reward exploit: MDP 3 -302.3186758171513 20
# average reward exploit: MDP 3 -313.38473706717315 20
# average reward exploit: MDP 3 -290.7685617821545 20
# average reward exploit: MDP 3 -266.73051911310824 20
# average reward exploit: MDP 3 -275.78129981991896 20
# average reward exploit: MDP 3 -229.21493949213408 20
# average reward exploit: MDP 3 -228.51453873093865 20
# average reward exploit: MDP 3 -212.09671525562104 20
# average reward exploit: MDP 3 -227.41747832682782 20
# average reward explore: -796.22081290755
# average reward exploit: MDP 4 -126.98603123547176 20
# average reward exploit: MDP 4 -136.48384689915065 20
# average reward exploit: MDP 4 -165.82617895528165 20
# average reward exploit: MDP 4 -154.87240177862108 20
# average reward exploit: MDP 4 -201.21369799963583 20
# average reward exploit: MDP 4 -150.82564502753695 20
# average reward exploit: MDP 4 -156.8656499362136 20
# average reward exploit: MDP 4 -85.84035418608076 20
# average reward exploit: MDP 4 -113.11434004329635 20
# average reward exploit: MDP 4 -83.96403291984579 20
# average reward explore: -711.68321153958
# average reward exploit: MDP 5 -154.14358960210075 20
# average reward exploit: MDP 5 -130.26830646270983 20
# average reward exploit: MDP 5 -121.2332297818114 20
# average reward exploit: MDP 5 -92.89947130841969 20
# average reward exploit: MDP 5 -78.11949108218818 20
# average reward exploit: MDP 5 -97.71142103823611 20
# average reward exploit: MDP 5 24.835069045940486 20
# average reward exploit: MDP 5 -80.21510396429696 20
# average reward exploit: MDP 5 -98.88402740160411 20
# average reward exploit: MDP 5 -28.445489689847598 20
# average reward explore: -666.4222295219479
# average reward exploit: MDP 6 19.408131667321385 20
# average reward exploit: MDP 6 17.891742513428365 20
# average reward exploit: MDP 6 21.04155219691604 20
# average reward exploit: MDP 6 21.192735778618776 20
# average reward exploit: MDP 6 -49.385808838283275 20
# average reward exploit: MDP 6 -40.04937310638707 20
# average reward exploit: MDP 6 -229.0996512894812 20
# average reward exploit: MDP 6 -244.3030410800903 20
# average reward exploit: MDP 6 -248.38168673292074 20
# average reward exploit: MDP 6 -348.1318495671483 20
# average reward explore: -622.435951940307
# average reward exploit: MDP 7 -294.2953896010471 20
# average reward exploit: MDP 7 -295.9160186177558 20
# average reward exploit: MDP 7 -266.54625823086417 20
# average reward exploit: MDP 7 -251.98058481223498 20
# average reward exploit: MDP 7 -238.23986409459212 20
# average reward exploit: MDP 7 -274.8043117802342 20
# average reward exploit: MDP 7 -230.9577889216082 20
# average reward exploit: MDP 7 -233.8493838559441 20
# average reward exploit: MDP 7 -252.12629896082103 20
# average reward exploit: MDP 7 -222.50080241318528 20
# average reward explore: -618.9271230622483
# average reward exploit: MDP 8 -198.833378128996 20
# average reward exploit: MDP 8 -170.61762422384388 20
# average reward exploit: MDP 8 -178.22762383154955 20
# average reward exploit: MDP 8 -165.37084965813835 20
# average reward exploit: MDP 8 -148.72121303629177 20
# average reward exploit: MDP 8 -138.6432770690343 20
# average reward exploit: MDP 8 -163.6497563899346 20
# average reward exploit: MDP 8 -135.43113494400453 20
# average reward exploit: MDP 8 -137.0955528795394 20
# average reward exploit: MDP 8 -188.72477918245465 20
# average reward explore: -554.9175471418664
# average reward exploit: MDP 9 -302.0863833509806 20
# average reward exploit: MDP 9 -323.8163123094188 20
# average reward exploit: MDP 9 -309.44753085481057 20
# average reward exploit: MDP 9 -282.5189885002032 20
# average reward exploit: MDP 9 -253.54968724442068 20
# average reward exploit: MDP 9 -265.70743044031116 20
# average reward exploit: MDP 9 -272.71650311895905 20
# average reward exploit: MDP 9 -249.68790836003026 20
# average reward exploit: MDP 9 -256.5943324757556 20
# average reward exploit: MDP 9 -267.6888449863956 20
# epoch number:  3
# average reward explore: -752.9147316572859
# average reward exploit: MDP 0 -130.09866203753134 20
# average reward exploit: MDP 0 -79.87851054902767 20
# average reward exploit: MDP 0 -49.47386328638167 20
# average reward exploit: MDP 0 -195.0161806751928 20
# average reward exploit: MDP 0 -164.6121461484387 20
# average reward exploit: MDP 0 -236.35859295301097 20
# average reward exploit: MDP 0 -173.5703220924309 20
# average reward exploit: MDP 0 2.083633545587977 20
# average reward exploit: MDP 0 -198.67911171677417 20
# average reward exploit: MDP 0 -156.99418439154428 20
# average reward explore: -752.1748318838925
# average reward exploit: MDP 1 -457.03079042318694 20
# average reward exploit: MDP 1 -356.65005276988006 20
# average reward exploit: MDP 1 -278.32990971990415 20
# average reward exploit: MDP 1 -247.34317580255288 20
# average reward exploit: MDP 1 -321.92839398875185 20
# average reward exploit: MDP 1 -242.70295583963792 20
# average reward exploit: MDP 1 -333.33208953929454 20
# average reward exploit: MDP 1 -340.72833515177433 20
# average reward exploit: MDP 1 -335.3089415316462 20
# average reward exploit: MDP 1 -378.8530122205873 20
# average reward explore: -686.4615290201612
# average reward exploit: MDP 2 -267.49873503459645 20
# average reward exploit: MDP 2 -276.83947108629405 20
# average reward exploit: MDP 2 -217.8359895010968 20
# average reward exploit: MDP 2 -151.98138166168036 20
# average reward exploit: MDP 2 -161.89539330317334 20
# average reward exploit: MDP 2 -65.56710797334556 20
# average reward exploit: MDP 2 -14.885710704628684 20
# average reward exploit: MDP 2 130.9054156373732 20
# average reward exploit: MDP 2 202.1562801611969 20
# average reward exploit: MDP 2 205.1121309275852 20
# average reward explore: -671.269048292407
# average reward exploit: MDP 3 55.40685852049504 20
# average reward exploit: MDP 3 -55.91100518621907 20
# average reward exploit: MDP 3 -144.6349436492587 20
# average reward exploit: MDP 3 -193.2236619768235 20
# average reward exploit: MDP 3 -118.1973032575853 20
# average reward exploit: MDP 3 -124.74302838056221 20
# average reward exploit: MDP 3 -50.924722278005184 20
# average reward exploit: MDP 3 -44.8291269613992 20
# average reward exploit: MDP 3 -106.86464109271876 20
# average reward exploit: MDP 3 -61.68864311641005 20
# average reward explore: -598.1016030423037
# average reward exploit: MDP 4 -249.36016659943897 20
# average reward exploit: MDP 4 -243.84741590332 20
# average reward exploit: MDP 4 -293.7755848857062 20
# average reward exploit: MDP 4 -239.8134601612645 20
# average reward exploit: MDP 4 -249.1787222638001 20
# average reward exploit: MDP 4 -242.00418878561246 20
# average reward exploit: MDP 4 -287.5842072263877 20
# average reward exploit: MDP 4 -269.9378227572869 20
# average reward exploit: MDP 4 -310.14306224289425 20
# average reward exploit: MDP 4 -327.3484193091994 20
# average reward explore: -524.190446431861
# average reward exploit: MDP 5 -454.42292975058234 20
# average reward exploit: MDP 5 -355.16798453158424 20
# average reward exploit: MDP 5 -290.4493477272557 20
# average reward exploit: MDP 5 -264.43686161042626 20
# average reward exploit: MDP 5 -218.8046090711394 20
# average reward exploit: MDP 5 -202.12331930669706 20
# average reward exploit: MDP 5 -261.7907124243002 20
# average reward exploit: MDP 5 -187.11459268653542 20
# average reward exploit: MDP 5 -243.72257365087088 20
# average reward exploit: MDP 5 -107.62477178043726 20
# average reward explore: -520.1743770740748
# average reward exploit: MDP 6 238.12521607359935 20
# average reward exploit: MDP 6 319.66794071273296 20
# average reward exploit: MDP 6 121.26605980591482 20
# average reward exploit: MDP 6 23.260578003239992 20
# average reward exploit: MDP 6 -70.41084816079072 20
# average reward exploit: MDP 6 -47.517013656681954 20
# average reward exploit: MDP 6 -111.74682622268615 20
# average reward exploit: MDP 6 -120.89427522869146 20
# average reward exploit: MDP 6 -155.2642119811176 20
# average reward exploit: MDP 6 -140.6810707659135 20
# average reward explore: -496.0480921043439
# average reward exploit: MDP 7 -263.4961720864728 20
# average reward exploit: MDP 7 -277.0259351883093 20
# average reward exploit: MDP 7 -282.59524434391915 20
# average reward exploit: MDP 7 -278.4673561807003 20
# average reward exploit: MDP 7 -240.52406336167465 20
# average reward exploit: MDP 7 -259.6218644731885 20
# average reward exploit: MDP 7 -227.54107826226186 20
# average reward exploit: MDP 7 -271.2158262952729 20
# average reward exploit: MDP 7 -257.9568967218942 20
# average reward exploit: MDP 7 -309.1365760075333 20
# average reward explore: -467.62584588752827
# average reward exploit: MDP 8 -260.02144272831816 20
# average reward exploit: MDP 8 -218.22349595787963 20
# average reward exploit: MDP 8 -282.34406494534164 20
# average reward exploit: MDP 8 -240.62159392007771 20
# average reward exploit: MDP 8 -224.2536073622403 20
# average reward exploit: MDP 8 -217.81545249128203 20
# average reward exploit: MDP 8 -259.6003141064633 20
# average reward exploit: MDP 8 -179.9345398329295 20
# average reward exploit: MDP 8 -150.5457354762755 20
# average reward exploit: MDP 8 -185.93517529942267 20
# average reward explore: -445.04824850883017
# average reward exploit: MDP 9 -206.3385434499844 20
# average reward exploit: MDP 9 -185.9039986828838 20
# average reward exploit: MDP 9 -180.91604957698033 20
# average reward exploit: MDP 9 -170.3558547880702 20
# average reward exploit: MDP 9 -164.57810186969905 20
# average reward exploit: MDP 9 -160.23661696363038 20
# average reward exploit: MDP 9 -160.2360020370774 20
# average reward exploit: MDP 9 -170.88665132199088 20
# average reward exploit: MDP 9 -159.17907636828068 20
# average reward exploit: MDP 9 -115.5586024597108 20
# epoch number:  4
# average reward explore: -686.7221336319517
# average reward exploit: MDP 0 -81.34031781756907 20
# average reward exploit: MDP 0 -4.797377538016332 20
# average reward exploit: MDP 0 21.85273685487325 20
# average reward exploit: MDP 0 104.03455662994182 20
# average reward exploit: MDP 0 -100.15805452365552 20
# average reward exploit: MDP 0 -54.454571424067716 20
# average reward exploit: MDP 0 7.050032235377364 20
# average reward exploit: MDP 0 -61.67306344447692 20
# average reward exploit: MDP 0 -114.70034098831029 20
# average reward exploit: MDP 0 78.9604554148124 20
# average reward explore: -640.9313113773853
# average reward exploit: MDP 1 -191.6214224385779 20
# average reward exploit: MDP 1 -200.0186971843053 20
# average reward exploit: MDP 1 -263.68287614692883 20
# average reward exploit: MDP 1 -200.95187842877777 20
# average reward exploit: MDP 1 -154.72669140660702 20
# average reward exploit: MDP 1 -146.95992255782204 20
# average reward exploit: MDP 1 -102.14666160046895 20
# average reward exploit: MDP 1 -30.2236527795134 20
# average reward exploit: MDP 1 -54.59493854071051 20
# average reward exploit: MDP 1 -21.410336466270927 20
# average reward explore: -604.3066492383475
# average reward exploit: MDP 2 242.38152223428852 20
# average reward exploit: MDP 2 171.28902008649266 20
# average reward exploit: MDP 2 288.92053659796414 20
# average reward exploit: MDP 2 148.52588392822122 20
# average reward exploit: MDP 2 338.5155861126244 20
# average reward exploit: MDP 2 98.26954237709671 20
# average reward exploit: MDP 2 97.87421921851008 20
# average reward exploit: MDP 2 186.50977275892356 20
# average reward exploit: MDP 2 -10.49468239283605 20
# average reward exploit: MDP 2 24.11843168056369 20
# average reward explore: -572.009139721569
# average reward exploit: MDP 3 -64.33049726164921 20
# average reward exploit: MDP 3 -50.85521839493883 20
# average reward exploit: MDP 3 10.921099312999583 20
# average reward exploit: MDP 3 -11.680235627462778 20
# average reward exploit: MDP 3 85.65250944707701 20
# average reward exploit: MDP 3 -92.12980421101615 20
# average reward exploit: MDP 3 -198.32526890566015 20
# average reward exploit: MDP 3 -150.60785022408982 20
# average reward exploit: MDP 3 -231.95965997991115 20
# average reward exploit: MDP 3 -210.31946173530278 20
# average reward explore: -619.0967437853076
# average reward exploit: MDP 4 -169.94509168888965 20
# average reward exploit: MDP 4 -133.0468290275124 20
# average reward exploit: MDP 4 -83.86852989482215 20
# average reward exploit: MDP 4 -12.185795456839358 20
# average reward exploit: MDP 4 52.94505043933985 20
# average reward exploit: MDP 4 101.14870110568857 20
# average reward exploit: MDP 4 198.7523195626554 20
# average reward exploit: MDP 4 170.2653736132917 20
# average reward exploit: MDP 4 88.72110378349993 20
# average reward exploit: MDP 4 106.79390574512222 20
# average reward explore: -523.2839326044259
# average reward exploit: MDP 5 -75.30319701602157 20
# average reward exploit: MDP 5 14.532167715722911 20
# average reward exploit: MDP 5 -23.769050443267435 20
# average reward exploit: MDP 5 -26.035582332008808 20
# average reward exploit: MDP 5 42.55742892068149 20
# average reward exploit: MDP 5 66.51489447870065 20
# average reward exploit: MDP 5 81.50662019461221 20
# average reward exploit: MDP 5 158.60080527267286 20
# average reward exploit: MDP 5 46.011672076861636 20
# average reward exploit: MDP 5 82.75421175376944 20
# average reward explore: -508.8969010334029
# average reward exploit: MDP 6 -164.47931202116703 20
# average reward exploit: MDP 6 -166.81089958133768 20
# average reward exploit: MDP 6 -137.75302176945223 20
# average reward exploit: MDP 6 -177.60105243777508 20
# average reward exploit: MDP 6 -166.28680311057843 20
# average reward exploit: MDP 6 -179.93659868972398 20
# average reward exploit: MDP 6 -165.46781365329687 20
# average reward exploit: MDP 6 -193.43533609919015 20
# average reward exploit: MDP 6 -179.2178981193749 20
# average reward exploit: MDP 6 -146.64594555652147 20
# average reward explore: -507.39575968954176
# average reward exploit: MDP 7 -54.20966521506813 20
# average reward exploit: MDP 7 -95.22679551478288 20
# average reward exploit: MDP 7 -104.29407050455725 20
# average reward exploit: MDP 7 -77.07996573812177 20
# average reward exploit: MDP 7 -35.17955534143073 20
# average reward exploit: MDP 7 -103.24491580800334 20
# average reward exploit: MDP 7 -48.805057677581615 20
# average reward exploit: MDP 7 -102.8356653251632 20
# average reward exploit: MDP 7 -71.1906705342611 20
# average reward exploit: MDP 7 -67.06014598011299 20
# average reward explore: -481.4437450965738
# average reward exploit: MDP 8 -159.89047061655816 20
# average reward exploit: MDP 8 -177.37233091517987 20
# average reward exploit: MDP 8 -182.67239094463986 20
# average reward exploit: MDP 8 -224.57229990621886 20
# average reward exploit: MDP 8 -201.74588878281318 20
# average reward exploit: MDP 8 -231.796081167583 20
# average reward exploit: MDP 8 -230.39655693075014 20
# average reward exploit: MDP 8 -243.98336183529577 20
# average reward exploit: MDP 8 -272.6259218924616 20
# average reward exploit: MDP 8 -305.0214211390743 20
# average reward explore: -438.50660662474246
# average reward exploit: MDP 9 255.4816241454957 20
# average reward exploit: MDP 9 342.70667838895724 20
# average reward exploit: MDP 9 482.05182519972396 20
# average reward exploit: MDP 9 89.78795754054741 20
# average reward exploit: MDP 9 -97.37555067077997 20
# average reward exploit: MDP 9 -162.74229981933223 20
# average reward exploit: MDP 9 -147.12054367111395 20
# average reward exploit: MDP 9 -202.182263024155 20
# average reward exploit: MDP 9 -317.8158731030739 20
# average reward exploit: MDP 9 -215.2019812801188 20
# epoch number:  5
# average reward explore: -605.9832163072572
# average reward exploit: MDP 0 -145.79755074194208 20
# average reward exploit: MDP 0 -173.0999443417632 20
# average reward exploit: MDP 0 -261.6555073444878 20
# average reward exploit: MDP 0 -157.81352290105724 20
# average reward exploit: MDP 0 -145.3538690379595 20
# average reward exploit: MDP 0 -197.67090103927882 20
# average reward exploit: MDP 0 -255.73952734724122 20
# average reward exploit: MDP 0 -204.35424451489104 20
# average reward exploit: MDP 0 -255.10466709110764 20
# average reward exploit: MDP 0 -292.9264884310968 20
# average reward explore: -608.2149017988197
# average reward exploit: MDP 1 -385.29745242438383 20
# average reward exploit: MDP 1 -316.6972105705373 20
# average reward exploit: MDP 1 -288.90079292337794 20
# average reward exploit: MDP 1 -369.31050152237174 20
# average reward exploit: MDP 1 -286.8128442943345 20
# average reward exploit: MDP 1 -318.9522488735562 20
# average reward exploit: MDP 1 -329.20629483485925 20
# average reward exploit: MDP 1 -346.9992704517333 20
# average reward exploit: MDP 1 -406.10570760545494 20
# average reward exploit: MDP 1 -367.835204330152 20
# average reward explore: -552.7519906051754
# average reward exploit: MDP 2 -290.16419623433364 20
# average reward exploit: MDP 2 -341.08020550590174 20
# average reward exploit: MDP 2 -383.6999652498773 20
# average reward exploit: MDP 2 -342.58002453361286 20
# average reward exploit: MDP 2 -355.72940094101693 20
# average reward exploit: MDP 2 -338.0201878124718 20
# average reward exploit: MDP 2 -276.0170443182493 20
# average reward exploit: MDP 2 -204.30212842320196 20
# average reward exploit: MDP 2 -147.74884996969206 20
# average reward exploit: MDP 2 -138.31398819206098 20
# average reward explore: -561.4744579760358
# average reward exploit: MDP 3 -560.6368200564004 20
# average reward exploit: MDP 3 -231.9303049655786 20
# average reward exploit: MDP 3 -130.83057397515114 20
# average reward exploit: MDP 3 -120.67049489236581 20
# average reward exploit: MDP 3 -112.61874916368575 20
# average reward exploit: MDP 3 -104.55272018070268 20
# average reward exploit: MDP 3 -87.65314213871085 20
# average reward exploit: MDP 3 -116.19472329599157 20
# average reward exploit: MDP 3 -90.06357553057951 20
# average reward exploit: MDP 3 -112.50759450106064 20
# average reward explore: -549.1320488044981
# average reward exploit: MDP 4 77.67381078405349 20
# average reward exploit: MDP 4 155.77526548391558 20
# average reward exploit: MDP 4 178.95017237007238 20
# average reward exploit: MDP 4 110.7655576944068 20
# average reward exploit: MDP 4 93.08282434099483 20
# average reward exploit: MDP 4 46.22232745314788 20
# average reward exploit: MDP 4 -35.68929643103736 20
# average reward exploit: MDP 4 -84.06489298158434 20
# average reward exploit: MDP 4 -117.90885898070576 20
# average reward exploit: MDP 4 -150.35826216919492 20
# average reward explore: -476.84526087763777
# average reward exploit: MDP 5 24.93809654025172 20
# average reward exploit: MDP 5 -24.404610984337275 20
# average reward exploit: MDP 5 71.19640502252994 20
# average reward exploit: MDP 5 75.140909558218 20
# average reward exploit: MDP 5 -12.118991013487593 20
# average reward exploit: MDP 5 -21.153422491149612 20
# average reward exploit: MDP 5 48.372750445204176 20
# average reward exploit: MDP 5 108.08392032416948 20
# average reward exploit: MDP 5 156.36798075335065 20
# average reward exploit: MDP 5 126.75254788059083 20
# average reward explore: -472.0600234332828
# average reward exploit: MDP 6 26.19879063117463 20
# average reward exploit: MDP 6 105.90794848058798 20
# average reward exploit: MDP 6 76.77115052880207 20
# average reward exploit: MDP 6 84.97740896009108 20
# average reward exploit: MDP 6 140.15873879568034 20
# average reward exploit: MDP 6 296.9242287472026 20
# average reward exploit: MDP 6 299.11751770632105 20
# average reward exploit: MDP 6 261.4901919505668 20
# average reward exploit: MDP 6 172.34443011250647 20
# average reward exploit: MDP 6 113.04492558370063 20
# average reward explore: -420.4731501872431
# average reward exploit: MDP 7 366.8432143977246 20
# average reward exploit: MDP 7 475.08705482028097 20
# average reward exploit: MDP 7 73.04393160891755 20
# average reward exploit: MDP 7 -111.34054634240712 20
# average reward exploit: MDP 7 -139.48544433447384 20
# average reward exploit: MDP 7 -139.912595361 20
# average reward exploit: MDP 7 -148.59424049576478 20
# average reward exploit: MDP 7 -155.82992928601874 20
# average reward exploit: MDP 7 -138.88915199095715 20
# average reward exploit: MDP 7 -125.29256723123312 20
# average reward explore: -398.0583558613416
# average reward exploit: MDP 8 -207.01998576959167 20
# average reward exploit: MDP 8 -217.28011179963988 20
# average reward exploit: MDP 8 -161.84510774687493 20
# average reward exploit: MDP 8 -147.21082305294382 20
# average reward exploit: MDP 8 -131.5542997092473 20
# average reward exploit: MDP 8 -121.94776472034297 20
# average reward exploit: MDP 8 -97.78408945375482 20
# average reward exploit: MDP 8 -78.75199799677434 20
# average reward exploit: MDP 8 -70.71649743756805 20
# average reward exploit: MDP 8 -50.13888296192127 20
# average reward explore: -371.5653889140272
# average reward exploit: MDP 9 -515.6641099874676 20
# average reward exploit: MDP 9 -341.51106031306875 20
# average reward exploit: MDP 9 -296.61041043817386 20
# average reward exploit: MDP 9 -278.99986372847354 20
# average reward exploit: MDP 9 -268.8073133026989 20
# average reward exploit: MDP 9 -259.4556982324367 20
# average reward exploit: MDP 9 -251.36367356899217 20
# average reward exploit: MDP 9 -271.7265831226967 20
# average reward exploit: MDP 9 -239.63800326196488 20
# average reward exploit: MDP 9 -255.2670545101301 20
# epoch number:  6
# average reward explore: -578.2998395957895
# average reward exploit: MDP 0 -267.28284783847903 20
# average reward exploit: MDP 0 -338.5770931178186 20
# average reward exploit: MDP 0 -237.84298904638194 20
# average reward exploit: MDP 0 -286.5382853750314 20
# average reward exploit: MDP 0 -309.0203482981476 20
# average reward exploit: MDP 0 -293.28463039253387 20
# average reward exploit: MDP 0 -382.1636646176407 20
# average reward exploit: MDP 0 -286.112069359262 20
# average reward exploit: MDP 0 -454.36104598782214 20
# average reward exploit: MDP 0 -791.4877403247472 20
# average reward explore: -540.7446386959125
# average reward exploit: MDP 1 -124.78368357447798 20
# average reward exploit: MDP 1 -88.75019155906863 20
# average reward exploit: MDP 1 -95.84100970446086 20
# average reward exploit: MDP 1 -162.7020750564285 20
# average reward exploit: MDP 1 -100.66521851881322 20
# average reward exploit: MDP 1 -69.80705595532471 20
# average reward exploit: MDP 1 -152.08438649059215 20
# average reward exploit: MDP 1 -175.6904741579259 20
# average reward exploit: MDP 1 -116.6167219178471 20
# average reward exploit: MDP 1 -142.18239376664854 20
# average reward explore: -528.0482717803077
# average reward exploit: MDP 2 -288.63724031212587 20
# average reward exploit: MDP 2 -224.63940352863256 20
# average reward exploit: MDP 2 -227.5498283557872 20
# average reward exploit: MDP 2 -222.55144420063638 20
# average reward exploit: MDP 2 -216.41461031626824 20
# average reward exploit: MDP 2 -205.72146112144037 20
# average reward exploit: MDP 2 -193.5367227578753 20
# average reward exploit: MDP 2 -185.9461330970517 20
# average reward exploit: MDP 2 -194.4094902524642 20
# average reward exploit: MDP 2 -191.24260404635623 20
# average reward explore: -512.0442878603241
# average reward exploit: MDP 3 -302.55259068454893 20
# average reward exploit: MDP 3 -293.262624468089 20
# average reward exploit: MDP 3 -479.8794715787594 20
# average reward exploit: MDP 3 -591.2356461106518 20
# average reward exploit: MDP 3 -806.6567086962159 20
# average reward exploit: MDP 3 -854.138040556885 20
# average reward exploit: MDP 3 -1194.6996562449872 20
# average reward exploit: MDP 3 -1049.444441496661 20
# average reward exploit: MDP 3 -1287.9132987929072 20
# average reward exploit: MDP 3 -1343.8374389767707 20
# average reward explore: -473.3693729665787
# average reward exploit: MDP 4 -57.88394087427666 20
# average reward exploit: MDP 4 -20.316928662185802 20
# average reward exploit: MDP 4 -42.94527096257391 20
# average reward exploit: MDP 4 -134.29304677086128 20
# average reward exploit: MDP 4 -46.89338656143557 20
# average reward exploit: MDP 4 52.34822565143958 20
# average reward exploit: MDP 4 148.1750747631789 20
# average reward exploit: MDP 4 -53.374991032756874 20
# average reward exploit: MDP 4 85.8433041758602 20
# average reward exploit: MDP 4 135.28712762059163 20
# average reward explore: -465.7409822006619
# average reward exploit: MDP 5 -353.4295774394657 20
# average reward exploit: MDP 5 -271.42825492455177 20
# average reward exploit: MDP 5 -248.30934453426204 20
# average reward exploit: MDP 5 -188.0512147578882 20
# average reward exploit: MDP 5 -166.60926891026756 20
# average reward exploit: MDP 5 -80.46037883125345 20
# average reward exploit: MDP 5 1.712326513924991 20
# average reward exploit: MDP 5 -7.84478862778482 20
# average reward exploit: MDP 5 139.13404541527316 20
# average reward exploit: MDP 5 150.4690051980279 20
# average reward explore: -452.37925080321463
# average reward exploit: MDP 6 -1053.0828882531162 20
# average reward exploit: MDP 6 -939.9508691043642 20
# average reward exploit: MDP 6 -823.5150763016767 20
# average reward exploit: MDP 6 -466.0913557079877 20
# average reward exploit: MDP 6 -416.8640539786966 20
# average reward exploit: MDP 6 -170.84403902630186 20
# average reward exploit: MDP 6 -29.907794604436095 20
# average reward exploit: MDP 6 154.81828523065752 20
# average reward exploit: MDP 6 94.69922613201842 20
# average reward exploit: MDP 6 32.23420031422509 20
# average reward explore: -414.63167420633107
# average reward exploit: MDP 7 -999.0844236020557 20
# average reward exploit: MDP 7 -715.3552679291208 20
# average reward exploit: MDP 7 -188.51953518130614 20
# average reward exploit: MDP 7 -15.669593698482947 20
# average reward exploit: MDP 7 -28.42866920393458 20
# average reward exploit: MDP 7 -126.03964900078685 20
# average reward exploit: MDP 7 -320.16852846400155 20
# average reward exploit: MDP 7 -507.33589920190917 20
# average reward exploit: MDP 7 -822.518881786585 20
# average reward exploit: MDP 7 -1129.669005241657 20
# average reward explore: -375.52630522480933
# average reward exploit: MDP 8 -133.2699277598125 20
# average reward exploit: MDP 8 -121.94431872500047 20
# average reward exploit: MDP 8 -93.07234894691138 20
# average reward exploit: MDP 8 -54.20470648410033 20
# average reward exploit: MDP 8 -30.290102480947525 20
# average reward exploit: MDP 8 -93.1372223464352 20
# average reward exploit: MDP 8 -160.49324351969798 20
# average reward exploit: MDP 8 -89.27667792492392 20
# average reward exploit: MDP 8 -22.226959019916354 20
# average reward exploit: MDP 8 -7.559103312112553 20
# average reward explore: -359.60203541587987
# average reward exploit: MDP 9 -769.7686337618733 20
# average reward exploit: MDP 9 -263.13488808414763 20
# average reward exploit: MDP 9 -61.864077955894274 20
# average reward exploit: MDP 9 -145.6295642667224 20
# average reward exploit: MDP 9 -207.7574215423048 20
# average reward exploit: MDP 9 -239.37516802569513 20
# average reward exploit: MDP 9 -222.77112361059827 20
# average reward exploit: MDP 9 -261.3938190266041 20
# average reward exploit: MDP 9 -233.12189807332894 20
# average reward exploit: MDP 9 -377.99922941045304 20
# epoch number:  7
# average reward explore: -519.7355472287303
# average reward exploit: MDP 0 -559.9300264994106 20
# average reward exploit: MDP 0 -451.88385276989374 20
# average reward exploit: MDP 0 -517.1235610435456 20
# average reward exploit: MDP 0 -564.8448616667331 20
# average reward exploit: MDP 0 -571.1727898648178 20
# average reward exploit: MDP 0 -798.995014853524 20
# average reward exploit: MDP 0 -550.6052034000647 20
# average reward exploit: MDP 0 -521.6042196226442 20
# average reward exploit: MDP 0 -485.74728675216886 20
# average reward exploit: MDP 0 -539.6579043445794 20
# average reward explore: -503.09553491268224
# average reward exploit: MDP 1 -1006.5853582331935 20
# average reward exploit: MDP 1 -885.160446054919 20
# average reward exploit: MDP 1 -875.221060026329 20
# average reward exploit: MDP 1 -1034.4492914221144 20
# average reward exploit: MDP 1 -1075.3782404604585 20
# average reward exploit: MDP 1 -1027.8819259793531 20
# average reward exploit: MDP 1 -927.1709564225861 20
# average reward exploit: MDP 1 -902.6214043105003 20
# average reward exploit: MDP 1 -924.5088931294398 20
# average reward exploit: MDP 1 -900.5932600230215 20
# average reward explore: -472.0002864034215
# average reward exploit: MDP 2 228.84580849912146 20
# average reward exploit: MDP 2 258.3771347988697 20
# average reward exploit: MDP 2 214.60370459901168 20
# average reward exploit: MDP 2 225.6495094513475 20
# average reward exploit: MDP 2 136.99805024890242 20
# average reward exploit: MDP 2 38.61885044211275 20
# average reward exploit: MDP 2 -138.43002523978004 20
# average reward exploit: MDP 2 -147.6057551518246 20
# average reward exploit: MDP 2 -149.74672304783687 20
# average reward exploit: MDP 2 -98.9658825315124 20
# average reward explore: -431.84363381494984
# average reward exploit: MDP 3 264.88996590521646 20
# average reward exploit: MDP 3 193.13519912693485 20
# average reward exploit: MDP 3 182.422696544133 20
# average reward exploit: MDP 3 138.75658878706383 20
# average reward exploit: MDP 3 78.56036205804075 20
# average reward exploit: MDP 3 20.855085341950122 20
# average reward exploit: MDP 3 -85.6255960413927 20
# average reward exploit: MDP 3 -77.69742707654474 20
# average reward exploit: MDP 3 -125.26916697667973 20
# average reward exploit: MDP 3 -132.1700980976598 20
# average reward explore: -446.0618360774641
# average reward exploit: MDP 4 -640.3827042350929 20
# average reward exploit: MDP 4 -695.876598283365 20
# average reward exploit: MDP 4 -595.7812291846305 20
# average reward exploit: MDP 4 -305.3952996884984 20
# average reward exploit: MDP 4 -363.6676469222561 20
# average reward exploit: MDP 4 -287.0557641542167 20
# average reward exploit: MDP 4 -230.4698969685537 20
# average reward exploit: MDP 4 -359.23578019036205 20
# average reward exploit: MDP 4 -317.48698212872887 20
# average reward exploit: MDP 4 -252.07365076827733 20
# average reward explore: -376.71607815273
# average reward exploit: MDP 5 -132.00330906435713 20
# average reward exploit: MDP 5 -120.86869863707504 20
# average reward exploit: MDP 5 -145.4504930472994 20
# average reward exploit: MDP 5 -144.5226782865071 20
# average reward exploit: MDP 5 -136.09463086736594 20
# average reward exploit: MDP 5 -110.72592724206966 20
# average reward exploit: MDP 5 -143.49414089903567 20
# average reward exploit: MDP 5 -108.74346474373729 20
# average reward exploit: MDP 5 -126.00087960106607 20
# average reward exploit: MDP 5 -136.1932546794041 20
# average reward explore: -335.22907134795616
# average reward exploit: MDP 6 18.19056509154023 20
# average reward exploit: MDP 6 23.47092383923158 20
# average reward exploit: MDP 6 52.175563455732096 20
# average reward exploit: MDP 6 89.795888232535 20
# average reward exploit: MDP 6 19.393856153791244 20
# average reward exploit: MDP 6 24.10231962934632 20
# average reward exploit: MDP 6 -3.9247080333209325 20
# average reward exploit: MDP 6 -40.61279778396874 20
# average reward exploit: MDP 6 -37.793738883584524 20
# average reward exploit: MDP 6 -35.25213556066258 20
# average reward explore: -362.38622690995027
# average reward exploit: MDP 7 80.72236454816002 20
# average reward exploit: MDP 7 195.25197979222284 20
# average reward exploit: MDP 7 -103.0190481283098 20
# average reward exploit: MDP 7 4.358871950640676 20
# average reward exploit: MDP 7 -55.87357578111837 20
# average reward exploit: MDP 7 -7.134975927386643 20
# average reward exploit: MDP 7 38.63870941965642 20
# average reward exploit: MDP 7 -153.43392717595955 20
# average reward exploit: MDP 7 -95.90672481330118 20
# average reward exploit: MDP 7 -217.6353487578157 20
# average reward explore: -329.2764723076365
# average reward exploit: MDP 8 208.18672658684596 20
# average reward exploit: MDP 8 234.43131551023157 20
# average reward exploit: MDP 8 185.63079030187419 20
# average reward exploit: MDP 8 213.5195514944688 20
# average reward exploit: MDP 8 86.79492869371622 20
# average reward exploit: MDP 8 80.64278647674755 20
# average reward exploit: MDP 8 0.6923098028106832 20
# average reward exploit: MDP 8 87.46308828367656 20
# average reward exploit: MDP 8 140.3862555901313 20
# average reward exploit: MDP 8 139.25163646979792 20
# average reward explore: -333.33284881770106
# average reward exploit: MDP 9 -454.4004566624417 20
# average reward exploit: MDP 9 -428.4340376679858 20
# average reward exploit: MDP 9 -410.8201900142475 20
# average reward exploit: MDP 9 -361.55406451263264 20
# average reward exploit: MDP 9 -295.079920812825 20
# average reward exploit: MDP 9 -347.69515151204337 20
# average reward exploit: MDP 9 -111.44422075881513 20
# average reward exploit: MDP 9 104.38713616050177 20
# average reward exploit: MDP 9 118.0937926504444 20
# average reward exploit: MDP 9 205.69547297452468 20
# epoch number:  8
# average reward explore: -461.99073219529754
# average reward exploit: MDP 0 -53.50446815055617 20
# average reward exploit: MDP 0 -236.775469208944 20
# average reward exploit: MDP 0 -328.0372453847532 20
# average reward exploit: MDP 0 -212.77804030002372 20
# average reward exploit: MDP 0 -274.2274804541315 20
# average reward exploit: MDP 0 -227.3363521305385 20
# average reward exploit: MDP 0 -500.00164683211295 20
# average reward exploit: MDP 0 -159.933615312209 20
# average reward exploit: MDP 0 -117.98360029177181 20
# average reward exploit: MDP 0 -28.935085561823392 20
# average reward explore: -470.11862555243044
# average reward exploit: MDP 1 -681.0220332555499 20
# average reward exploit: MDP 1 -967.2284593459859 20
# average reward exploit: MDP 1 -679.736428939164 20
# average reward exploit: MDP 1 -529.7949833581706 20
# average reward exploit: MDP 1 -468.85827826305524 20
# average reward exploit: MDP 1 -367.37172542533256 20
# average reward exploit: MDP 1 -418.8823931281553 20
# average reward exploit: MDP 1 -382.47048296590935 20
# average reward exploit: MDP 1 -367.5021932829955 20
# average reward exploit: MDP 1 -370.2758842640618 20
# average reward explore: -455.27157250749696
# average reward exploit: MDP 2 -411.13169347710925 20
# average reward exploit: MDP 2 -417.2770009681996 20
# average reward exploit: MDP 2 -558.9228816328998 20
# average reward exploit: MDP 2 -340.6573767586615 20
# average reward exploit: MDP 2 -387.45509390294484 20
# average reward exploit: MDP 2 -335.4060939299941 20
# average reward exploit: MDP 2 -321.8915550547082 20
# average reward exploit: MDP 2 -297.90219144041725 20
# average reward exploit: MDP 2 -345.6604569743208 20
# average reward exploit: MDP 2 -473.5073902907707 20
# average reward explore: -447.86836493328974
# average reward exploit: MDP 3 -371.1506613206404 20
# average reward exploit: MDP 3 -359.3895787321831 20
# average reward exploit: MDP 3 -416.2625459723645 20
# average reward exploit: MDP 3 -401.7580477286855 20
# average reward exploit: MDP 3 -443.77969448897665 20
# average reward exploit: MDP 3 -592.7709142617606 20
# average reward exploit: MDP 3 -478.5457453800421 20
# average reward exploit: MDP 3 -456.97773383650565 20
# average reward exploit: MDP 3 -436.308444133227 20
# average reward exploit: MDP 3 -449.86700525058995 20
# average reward explore: -373.9357430733789
# average reward exploit: MDP 4 -761.9420108910928 20
# average reward exploit: MDP 4 -615.8887804801037 20
# average reward exploit: MDP 4 -638.6526102879377 20
# average reward exploit: MDP 4 -632.0954621639704 20
# average reward exploit: MDP 4 -516.8274945666564 20
# ...
# average reward exploit: MDP 2 285.3584324051846 20
# average reward exploit: MDP 2 221.08575130146164 20
# average reward exploit: MDP 2 126.92071800090685 20
# average reward exploit: MDP 2 187.3124502220053 20
# average reward exploit: MDP 2 61.770461086283305 20
# average reward exploit: MDP 2 60.610139045223264 20
# average reward exploit: MDP 2 107.1252942423051 20
# average reward explore: -105.7595170876887
# average reward exploit: MDP 3 -134.78095080894423 20
# average reward exploit: MDP 3 -211.35431413522625 20
# average reward exploit: MDP 3 -47.91035076362526 20
# average reward exploit: MDP 3 -139.30808157323898 20
# average reward exploit: MDP 3 -27.57791580412779 20
# average reward exploit: MDP 3 -127.0189135358637 20
# average reward exploit: MDP 3 -57.80365382084257 20
# average reward exploit: MDP 3 -233.37418103991348 20
# average reward exploit: MDP 3 -146.95248649596743 20
# average reward exploit: MDP 3 -148.4105434236059 20
# average reward explore: -80.98144861531185
# average reward exploit: MDP 4 81.54834288648195 20
# average reward exploit: MDP 4 63.64618594050844 20
# average reward exploit: MDP 4 79.56846901982674 20
# average reward exploit: MDP 4 68.1660175449752 20
# average reward exploit: MDP 4 91.04166078282051 20
# average reward exploit: MDP 4 77.44459893646686 20
# average reward exploit: MDP 4 79.34425867396196 20
# average reward exploit: MDP 4 113.20773121999245 20
# average reward exploit: MDP 4 142.62721456208277 20
# average reward exploit: MDP 4 77.62085345533782 20
# average reward explore: -85.4379689215111
# average reward exploit: MDP 5 -57.905732254926534 20
# average reward exploit: MDP 5 -91.64481832081972 20
# average reward exploit: MDP 5 -122.60273576675846 20
# average reward exploit: MDP 5 -183.55642408242488 20
# average reward exploit: MDP 5 -192.810501867529 20
# average reward exploit: MDP 5 -164.14019960876547 20
# average reward exploit: MDP 5 -97.27122313400568 20
# average reward exploit: MDP 5 -60.5085549544464 20
# average reward exploit: MDP 5 -58.398831414940176 20
# average reward exploit: MDP 5 -249.59892304403456 20
# average reward explore: -37.06528119661589
# average reward exploit: MDP 6 -146.70886689276108 20
# average reward exploit: MDP 6 -139.5522611181594 20
# average reward exploit: MDP 6 -146.4554091865956 20
# average reward exploit: MDP 6 -99.81867549343765 20
# average reward exploit: MDP 6 -114.37817949014614 20
# average reward exploit: MDP 6 -112.58414715068227 20
# average reward exploit: MDP 6 -105.91824301541101 20
# average reward exploit: MDP 6 -114.140831497787 20
# average reward exploit: MDP 6 -111.43585891996808 20
# average reward exploit: MDP 6 -110.15253758967678 20
# average reward explore: 8.568487025165846
# average reward exploit: MDP 7 -215.9320972939876 20
# average reward exploit: MDP 7 -198.025797584674 20
# average reward exploit: MDP 7 -238.99748656898382 20
# average reward exploit: MDP 7 -191.62714570662848 20
# average reward exploit: MDP 7 -184.16139354304022 20
# average reward exploit: MDP 7 -202.76952093891373 20
# average reward exploit: MDP 7 -168.47935933821896 20
# average reward exploit: MDP 7 -142.33211169724296 20
# average reward exploit: MDP 7 -153.3455492211013 20
# average reward exploit: MDP 7 -129.86084145900938 20
# average reward explore: -7.942765173046553
# average reward exploit: MDP 8 -71.60227726693017 20
# average reward exploit: MDP 8 -91.29888280257036 20
# average reward exploit: MDP 8 -101.35424928696725 20
# average reward exploit: MDP 8 -100.42479850246595 20
# average reward exploit: MDP 8 -82.4616954228716 20
# average reward exploit: MDP 8 -77.86115646655207 20
# average reward exploit: MDP 8 -81.91586693338188 20
# average reward exploit: MDP 8 -67.44675408434398 20
# average reward exploit: MDP 8 -85.80840329646013 20
# average reward exploit: MDP 8 -53.7372105519947 20
# average reward explore: -2.116605093751857
# average reward exploit: MDP 9 213.77979264166106 20
# average reward exploit: MDP 9 195.44608790984088 20
# average reward exploit: MDP 9 221.2585734777778 20
# average reward exploit: MDP 9 233.0572886325424 20
# average reward exploit: MDP 9 246.97031603809145 20
# average reward exploit: MDP 9 296.34108622691605 20
# average reward exploit: MDP 9 313.13871815635787 20
# average reward exploit: MDP 9 447.2749046132126 20
# average reward exploit: MDP 9 491.01302652132244 20
# average reward exploit: MDP 9 253.92501203105599 20
# epoch number:  22
# average reward explore: -102.33219543266846
# average reward exploit: MDP 0 -70.06106943878922 20
# average reward exploit: MDP 0 -121.7259947253716 20
# average reward exploit: MDP 0 -101.19385224766158 20
# average reward exploit: MDP 0 5.779250222262922 20
# average reward exploit: MDP 0 -89.98328026252665 20
# average reward exploit: MDP 0 -103.62962275355008 20
# average reward exploit: MDP 0 -95.9849310965629 20
# average reward exploit: MDP 0 -82.92582459779146 20
# average reward exploit: MDP 0 -84.93874290472876 20
# average reward exploit: MDP 0 -111.08141807600175 20
# average reward explore: -95.98083268730194
# average reward exploit: MDP 1 -114.23342880297935 20
# average reward exploit: MDP 1 -100.22872764098402 20
# average reward exploit: MDP 1 -115.93359268410688 20
# average reward exploit: MDP 1 -69.44807794917764 20
# average reward exploit: MDP 1 -73.1559024076709 20
# average reward exploit: MDP 1 -93.59693888343446 20
# average reward exploit: MDP 1 -77.87772777101186 20
# average reward exploit: MDP 1 -89.13974668085602 20
# average reward exploit: MDP 1 -50.42069525633825 20
# average reward exploit: MDP 1 -16.347144027210387 20
# average reward explore: -59.46714787571035
# average reward exploit: MDP 2 -122.36080025209398 20
# average reward exploit: MDP 2 -129.33012407136715 20
# average reward exploit: MDP 2 -125.54087142453787 20
# average reward exploit: MDP 2 -146.1373674816184 20
# average reward exploit: MDP 2 -129.85311956571113 20
# average reward exploit: MDP 2 -101.6580143983986 20
# average reward exploit: MDP 2 -117.39840773441942 20
# average reward exploit: MDP 2 -117.92960746009969 20
# average reward exploit: MDP 2 -194.73617191113382 20
# average reward exploit: MDP 2 -128.7389640366931 20
# average reward explore: -45.67323898661398
# average reward exploit: MDP 3 254.69000766991203 20
# average reward exploit: MDP 3 181.95432108801242 20
# average reward exploit: MDP 3 295.41257990806145 20
# average reward exploit: MDP 3 331.4826335430872 20
# average reward exploit: MDP 3 371.8013131226556 20
# average reward exploit: MDP 3 437.51074555250415 20
# average reward exploit: MDP 3 592.1760666366636 20
# average reward exploit: MDP 3 425.98852907791877 20
# average reward exploit: MDP 3 558.601988406199 20
# average reward exploit: MDP 3 475.68356737233944 20
# average reward explore: -49.5755316583684
# average reward exploit: MDP 4 548.7909103966444 20
# average reward exploit: MDP 4 510.9866943548012 20
# average reward exploit: MDP 4 569.2788901242207 20
# average reward exploit: MDP 4 648.1951070003845 20
# average reward exploit: MDP 4 626.636524651741 20
# average reward exploit: MDP 4 538.0546488691164 20
# average reward exploit: MDP 4 246.33510673843625 20
# average reward exploit: MDP 4 282.84719612466154 20
# average reward exploit: MDP 4 210.4522654493257 20
# average reward exploit: MDP 4 74.8922155154016 20
# average reward explore: -6.834599492920385
# average reward exploit: MDP 5 230.58205572259695 20
# average reward exploit: MDP 5 346.4486992297181 20
# average reward exploit: MDP 5 231.90399148179077 20
# average reward exploit: MDP 5 109.94220132498349 20
# average reward exploit: MDP 5 80.35160107161913 20
# average reward exploit: MDP 5 42.25907678995391 20
# average reward exploit: MDP 5 61.505341530862815 20
# average reward exploit: MDP 5 22.465832270848423 20
# average reward exploit: MDP 5 -8.034506719886043 20
# average reward exploit: MDP 5 8.270674397281361 20
# average reward explore: 6.650594711181588
# average reward exploit: MDP 6 -140.7024815809363 20
# average reward exploit: MDP 6 -137.5453833530334 20
# average reward exploit: MDP 6 -110.36054868174608 20
# average reward exploit: MDP 6 -106.20714382811386 20
# average reward exploit: MDP 6 -89.67780572744618 20
# average reward exploit: MDP 6 -89.24757387575887 20
# average reward exploit: MDP 6 -71.9774255289244 20
# average reward exploit: MDP 6 -68.07007746608431 20
# average reward exploit: MDP 6 -70.72305745095125 20
# average reward exploit: MDP 6 -69.50666442081197 20
# average reward explore: -3.271229914441254
# average reward exploit: MDP 7 -87.56152107410489 20
# average reward exploit: MDP 7 -119.19441324848148 20
# average reward exploit: MDP 7 -169.06377594308012 20
# average reward exploit: MDP 7 -160.61755250977453 20
# average reward exploit: MDP 7 -69.03638140437457 20
# average reward exploit: MDP 7 -100.8490469282344 20
# average reward exploit: MDP 7 -130.82220166952686 20
# average reward exploit: MDP 7 -117.47350432726653 20
# average reward exploit: MDP 7 -103.14128056790601 20
# average reward exploit: MDP 7 -98.03073862089086 20
# average reward explore: 2.370324883474067
# average reward exploit: MDP 8 -22.803578123100927 20
# average reward exploit: MDP 8 -38.5815346416948 20
# average reward exploit: MDP 8 -38.0478115793086 20
# average reward exploit: MDP 8 -50.788301059026864 20
# average reward exploit: MDP 8 -56.2407166688173 20
# average reward exploit: MDP 8 -51.61516919103178 20
# average reward exploit: MDP 8 -54.84645448799414 20
# average reward exploit: MDP 8 -60.66791767114201 20
# average reward exploit: MDP 8 -47.329685645071784 20
# average reward exploit: MDP 8 -60.973762924523285 20
# average reward explore: -12.802929291108843
# average reward exploit: MDP 9 -66.23461715361405 20
# average reward exploit: MDP 9 -91.91629088487647 20
# average reward exploit: MDP 9 -54.97579632521972 20
# average reward exploit: MDP 9 -56.412044854901 20
# average reward exploit: MDP 9 -58.82291843198938 20
# average reward exploit: MDP 9 -77.91446288165122 20
# average reward exploit: MDP 9 -58.693798713528864 20
# average reward exploit: MDP 9 -96.26868426162751 20
# average reward exploit: MDP 9 -72.79700793094409 20
# average reward exploit: MDP 9 -60.5963004497342 20
# epoch number:  23
# average reward explore: -49.81317926446783
# average reward exploit: MDP 0 123.26514341001544 20
# average reward exploit: MDP 0 -8.739964556243256 20
# average reward exploit: MDP 0 100.60555363854023 20
# average reward exploit: MDP 0 116.72336512632675 20
# average reward exploit: MDP 0 347.03562304069237 20
# average reward exploit: MDP 0 400.59822544206713 20
# average reward exploit: MDP 0 165.66549946702614 20
# average reward exploit: MDP 0 351.4592937343833 20
# average reward exploit: MDP 0 468.46164324563387 20
# average reward exploit: MDP 0 487.49761585636196 20
# average reward explore: -31.481082011596538
# average reward exploit: MDP 1 92.6535801320528 20
# average reward exploit: MDP 1 22.094144978917857 20
# average reward exploit: MDP 1 71.06692353906851 20
# average reward exploit: MDP 1 85.12132007711571 20
# average reward exploit: MDP 1 53.111866379159174 20
# average reward exploit: MDP 1 127.44281785093256 20
# average reward exploit: MDP 1 49.10516569250647 20
# average reward exploit: MDP 1 63.10254114216347 20
# average reward exploit: MDP 1 43.53141205661731 20
# average reward exploit: MDP 1 73.2022348593488 20
# average reward explore: 3.2191349596311922
# average reward exploit: MDP 2 280.88939857493614 20
# average reward exploit: MDP 2 324.7515800902238 20
# average reward exploit: MDP 2 315.6161784478612 20
# average reward exploit: MDP 2 180.51620142238508 20
# average reward exploit: MDP 2 279.7869439592085 20
# average reward exploit: MDP 2 272.04050535224536 20
# average reward exploit: MDP 2 178.93960131764152 20
# average reward exploit: MDP 2 155.24706017380203 20
# average reward exploit: MDP 2 64.96729370870976 20
# average reward exploit: MDP 2 69.01711513788328 20
# average reward explore: 53.01655939053418
# average reward exploit: MDP 3 59.481251561596686 20
# average reward exploit: MDP 3 30.39457572301219 20
# average reward exploit: MDP 3 -16.959803614092735 20
# average reward exploit: MDP 3 -16.583677272701042 20
# average reward exploit: MDP 3 -40.83119542689339 20
# average reward exploit: MDP 3 17.92755329814268 20
# average reward exploit: MDP 3 27.483715568085653 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-bde7b6456197> in <module>()
# ----> 1 a.train()
#
# <ipython-input-29-b895b69641b5> in train(self)
#     441         for epoch in range(num_epochs):
#     442             print("epoch number: ", epoch)
# --> 443             self.train_step()
#     444
#
# <ipython-input-29-b895b69641b5> in train_step(self)
#     391 #             #print(tvars_vals)
#     392             for j in range(10):
# --> 393                 exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z,i)
#     394                 # get observations, actions and rewards
#     395                 observations_exploit = np.concatenate([path["observation"] for path in exploit_paths])
#
# <ipython-input-29-b895b69641b5> in sample_paths_exploit(self, env, Z, mdp_num, Test, num_episodes)
#     177             for step in range(self.max_ep_len):
#     178                 states.append(state)
# --> 179                 action = self.sess.run(self.exploit_action, feed_dict={self.observation_placeholder_exploit : state[None], self.decoder_input_placeholder: Z})[0]
#     180                 state, reward, done, info = env.step(action)
#     181                 actions.append(action)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     510   def __exit__(self, type_arg, value_arg, traceback_arg):
#     511     try:
# --> 512       if c_api.TF_GetCode(self.status.status) != 0:
#     513         raise _make_specific_exception(
#     514             None, None,
#
# KeyboardInterrupt:

# %%
a.lr = 3e-3
num_epochs = 200
for epoch in range(num_epochs):
    print("epoch number: ", epoch)
    a.train_step()
# Out:
# epoch number:  0
# average reward explore: 235.43240868895236
# average reward exploit: MDP 0 -56.196823765934234 20
# average reward exploit: MDP 0 -40.35286801557989 20
# average reward exploit: MDP 0 -24.02129771140376 20
# average reward exploit: MDP 0 5.6154089875947735 20
# average reward exploit: MDP 0 2.361316171514381 20
# average reward exploit: MDP 0 1.8780362510601762 20
# average reward exploit: MDP 0 6.468609164977151 20
# average reward exploit: MDP 0 15.634511581327839 20
# average reward exploit: MDP 0 19.544960570362772 20
# average reward exploit: MDP 0 16.576887624604538 20
# average reward explore: 228.65107311880274
# average reward exploit: MDP 1 -307.84492334345975 20
# average reward exploit: MDP 1 -383.96434798348656 20
# average reward exploit: MDP 1 -390.60449242570064 20
# average reward exploit: MDP 1 -279.28742585685853 20
# average reward exploit: MDP 1 -296.0112527865921 20
# average reward exploit: MDP 1 -427.442436974707 20
# average reward exploit: MDP 1 -266.4491958554944 20
# average reward exploit: MDP 1 -200.88190044478227 20
# average reward exploit: MDP 1 -179.10507038065992 20
# average reward exploit: MDP 1 -167.13463169760277 20
# average reward explore: 288.2018701892539
# average reward exploit: MDP 2 -936.2907452715702 20
# average reward exploit: MDP 2 -758.0675111285109 20
# average reward exploit: MDP 2 -172.58804335895147 20
# average reward exploit: MDP 2 -30.338999124188263 20
# average reward exploit: MDP 2 -27.347543891032707 20
# average reward exploit: MDP 2 -55.108726182003295 20
# average reward exploit: MDP 2 36.076986240669726 20
# average reward exploit: MDP 2 -7.824853287367846 20
# average reward exploit: MDP 2 30.14485117825631 20
# average reward exploit: MDP 2 6.400888545987715 20
# average reward explore: 287.6202616491025
# average reward exploit: MDP 3 101.25184614954811 20
# average reward exploit: MDP 3 94.44250842702193 20
# average reward exploit: MDP 3 138.36213019011367 20
# average reward exploit: MDP 3 163.23295842140777 20
# average reward exploit: MDP 3 166.99200103314337 20
# average reward exploit: MDP 3 231.83188504942018 20
# average reward exploit: MDP 3 263.5052450208347 20
# average reward exploit: MDP 3 250.35383866455726 20
# average reward exploit: MDP 3 270.27793250348583 20
# average reward exploit: MDP 3 304.20057522335696 20
# average reward explore: 299.3745974035676
# average reward exploit: MDP 4 -6.668716691007191 20
# average reward exploit: MDP 4 -10.754083593224593 20
# average reward exploit: MDP 4 18.79005465723722 20
# average reward exploit: MDP 4 37.483648824754965 20
# average reward exploit: MDP 4 61.620306807785084 20
# average reward exploit: MDP 4 67.70231525382465 20
# average reward exploit: MDP 4 36.63637104386318 20
# average reward exploit: MDP 4 67.25654467584397 20
# average reward exploit: MDP 4 39.23956964136488 20
# average reward exploit: MDP 4 51.7941555666509 20
# average reward explore: 267.1899879895544
# average reward exploit: MDP 5 20.231763709473178 20
# average reward exploit: MDP 5 7.121082854864943 20
# average reward exploit: MDP 5 -2.310534788444488 20
# average reward exploit: MDP 5 1.328486442289794 20
# average reward exploit: MDP 5 -1.5543335295039278 20
# average reward exploit: MDP 5 -12.665881282232936 20
# average reward exploit: MDP 5 -26.279584790022813 20
# average reward exploit: MDP 5 -18.85854872449201 20
# average reward exploit: MDP 5 -23.643771125512487 20
# average reward exploit: MDP 5 -26.232342680811758 20
# average reward explore: 263.0862549764782
# average reward exploit: MDP 6 40.64777930894445 20
# average reward exploit: MDP 6 45.58549066853477 20
# average reward exploit: MDP 6 35.82771125787282 20
# average reward exploit: MDP 6 23.20918439238171 20
# average reward exploit: MDP 6 -11.590637235306628 20
# average reward exploit: MDP 6 13.518945856493056 20
# average reward exploit: MDP 6 -2.2120579630004182 20
# average reward exploit: MDP 6 -21.292648129666297 20
# average reward exploit: MDP 6 -21.907618006538346 20
# average reward exploit: MDP 6 -36.65880697057589 20
# average reward explore: 277.40531259157575
# average reward exploit: MDP 7 -31.317248424511956 20
# average reward exploit: MDP 7 -36.25782252073616 20
# average reward exploit: MDP 7 -74.75308012634584 20
# average reward exploit: MDP 7 -54.91689703827319 20
# average reward exploit: MDP 7 -36.08238003108841 20
# average reward exploit: MDP 7 -45.289446153004576 20
# average reward exploit: MDP 7 -33.316368285243705 20
# average reward exploit: MDP 7 -52.21570332616441 20
# average reward exploit: MDP 7 -45.121834121619514 20
# average reward exploit: MDP 7 -43.646441551502505 20
# average reward explore: 257.6661264620049
# average reward exploit: MDP 8 -69.25701136726603 20
# average reward exploit: MDP 8 -72.1273011982628 20
# average reward exploit: MDP 8 -65.82480314978638 20
# average reward exploit: MDP 8 -68.86083525620577 20
# average reward exploit: MDP 8 -63.61133840628226 20
# average reward exploit: MDP 8 -67.05884031884862 20
# average reward exploit: MDP 8 -73.50304267726533 20
# average reward exploit: MDP 8 -72.3706783557119 20
# average reward exploit: MDP 8 -64.49293603493662 20
# average reward exploit: MDP 8 -61.34696271283874 20
# average reward explore: 102.47345032369348
# average reward exploit: MDP 9 -10.66179498050807 20
# average reward exploit: MDP 9 -13.032381172863188 20
# average reward exploit: MDP 9 -21.110058935056806 20
# average reward exploit: MDP 9 -14.485622708184128 20
# average reward exploit: MDP 9 -9.956749122753923 20
# average reward exploit: MDP 9 2.212819854489137 20
# average reward exploit: MDP 9 -7.840264199195515 20
# average reward exploit: MDP 9 -20.822196958234287 20
# average reward exploit: MDP 9 -11.935238421911855 20
# average reward exploit: MDP 9 -15.922114637606771 20
# epoch number:  1
# average reward explore: 99.68559702473797
# average reward exploit: MDP 0 -1576.3642513923155 20
# average reward exploit: MDP 0 -335.9433057709338 20
# average reward exploit: MDP 0 -188.03123914976848 20
# average reward exploit: MDP 0 -176.70920407011113 20
# average reward exploit: MDP 0 -175.09884308496163 20

# %%
for i in range(20):
    explore_paths, explore_rewards = a.sample_paths_explore(a.env,i)
    print("gravity:", a.sim.model.opt.gravity)
    print("average reward explore:", np.mean(explore_rewards))
    M = a.stack_trajectories(explore_paths)
    Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })
    Z = np.reshape(Z,[1,len(Z)])
    exploit_paths, exploit_rewards = a.sample_paths_exploit(a.env,Z,1)
    print("average reward exploit", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-fe3a5af3f871> in <module>()
#       1 for i in range(20):
# ----> 2     explore_paths, explore_rewards = a.sample_paths_explore(a.env,i)
#       3     print("gravity:", a.sim.model.opt.gravity)
#       4     print("average reward explore:", np.mean(explore_rewards))
#       5     M = a.stack_trajectories(explore_paths)
#
# <ipython-input-29-b895b69641b5> in sample_paths_explore(self, env, mdp_num, Test, num_episodes)
#     147                     #action = self.sess.run(self.explore_action, feed_dict={self.observation_placeholder_explore : states[-1][None]})[0]
#     148                     action = self.policyfn.sample_action(state) #NEW
# --> 149                     state, reward, done, info = env.step(action)
#     150                     actions.append(action)
#     151                     new_actions.append(action)
#
# /anaconda3/lib/python3.6/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      29     def step(self, action):
#      30         assert self._episode_started_at is not None, "Cannot call env.step() before calling reset()"
# ---> 31         observation, reward, done, info = self.env.step(action)
#      32         self._elapsed_steps += 1
#      33
#
# /anaconda3/lib/python3.6/site-packages/gym/envs/mujoco/half_cheetah.py in step(self, action)
#      12         self.do_simulation(action, self.frame_skip)
#      13         xposafter = self.sim.data.qpos[0]
# ---> 14         ob = self._get_obs()
#      15         reward_ctrl = - 0.1 * np.square(action).sum()
#      16         reward_run = (xposafter - xposbefore)/self.dt
#
# /anaconda3/lib/python3.6/site-packages/gym/envs/mujoco/half_cheetah.py in _get_obs(self)
#      22         return np.concatenate([
#      23             self.sim.data.qpos.flat[1:],
# ---> 24             self.sim.data.qvel.flat,
#      25         ])
#      26
#
# KeyboardInterrupt:

# %%
explore_paths, explore_rewards = a.sample_paths_explore(a.env,1)
print("average reward explore", np.sum(explore_rewards) / len(explore_rewards))
# Out:
# average reward explore 10096.764246907856

# %%
M = a.stack_trajectories(explore_paths)
Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })

# %%
Z = np.reshape(Z,[1,len(Z)])

# %%
exploit_paths, exploit_rewards = a.sample_paths_exploit(a.env,Z,1)

# %%
print("average reward exploit", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
# Out:
# average reward exploit 1275.3226317979522 400

# %%
a.sim.model.opt.gravity[-1] = -18

# %%
a.num_traj = 800

# %%
a.sim.model.opt.gravity[-1] = -15

# %%
observations_explore = np.concatenate([path["observation"] for path in explore_paths])
new_observations_explore = np.concatenate([path["new_obs"] for path in explore_paths])
new_actions_explore = np.concatenate([path["new_acs"] for path in explore_paths])
actions_explore = np.concatenate([path["action"] for path in explore_paths])
rewards_explore = np.concatenate([path["reward"] for path in explore_paths])
returns_explore = a.get_returns(explore_paths, explore = True)

# %%
M = np.array(a.stack_trajectories(explore_paths))
Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })
Z = np.reshape(Z,[1,len(Z)])

# %%
 print("average reward explore: MDP", np.sum(explore_rewards)/num_traj, len(explore_rewards))

# %%
exploit_paths, exploit_rewards = a.sample_paths_exploit(a.env,Z,1000)

# %%
print("average reward exploit: MDP", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))

# %%
def randomize_pendulum(env):
    m = config['pendulum_mass_min'] + np.random.rand()*(config['pendulum_mass_max'] - config['pendulum_mass_min'])
    l = config['pendulum_len_min'] + np.random.rand()*(config['pendulum_len_max'] - config['pendulum_len_min'])
    env.m = m
    env.l = l

# %%
def randomize_hopper(env):
    ts = config['torso_min'] + np.random.rand()*(config['torso_max'] - config['torso_min'])
    f = config['friction_min'] + np.random.rand()*(config['friction_max'] - config['friction_min'])
    
    env.friction = f
    env.torso_size = ts
    env.apply_env_modifications()

# %%
import yaml
cfg_filename = 'hopper-config.yml'
with open(cfg_filename,'r') as ymlfile:
    config = yaml.load(ymlfile)

# %%
env = Randomizer(gym.make('Hopper-v2'), randomize_hopper)
env.unwrapped.__dict__.keys()
env.reset()

# %%
m = config['pendulum_mass_min'] + np.random.rand()*(config['pendulum_mass_max'] - config['pendulum_mass_min'])

# %%
config

# %%
env_id = 'Hopper-v2'
e = gym.make(env_id)

# %%
e.unwrapped.__dict__.keys()

# %%
e.unwrapped.apply_env_modifications()
