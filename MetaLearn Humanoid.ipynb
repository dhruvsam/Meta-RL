# %%
# Include Libraries
import numpy as np
import tensorflow as tf
import gym
import tensorflow.contrib.layers as layers
from mujoco_py import load_model_from_xml, MjSim, MjViewer
import policies
import value_functions as vfuncs
import utils_pg as utils

# Environment setup
#env = "CartPole-v0"
#env="InvertedPendulum-v2"
env = "Humanoid-v2"

# discrete = isinstance(env.action_space, gym.spaces.Discrete)
# observation_dim = env.observation_space.shape[0]
# action_dim = env.action_space.n if discrete else env.action_space.shape[0]
max_ep_len = 1000
num_traj = 30
#traj_length = max_ep_len*(observation_dim + 2)
latent_size = 150
use_baseline = True
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %%
# Feed forward network (multi-layer-perceptron, or mlp)

def build_mlp(mlp_input,output_size,scope,n_layers,size,output_activation=None):
    '''
    Build a feed forward network
    '''
    Input = mlp_input
    with tf.variable_scope(scope):
        # Dense Layers
        for i in range(n_layers-1):
            dense = tf.layers.dense(inputs = Input, units = size, activation = tf.nn.relu, bias_initializer=tf.constant_initializer(1.0))
            Input = dense
        # Fully Connected Layer
        out = layers.fully_connected(inputs = Input, num_outputs = output_size, activation_fn=output_activation)
    return out

# %%
class MetaLearner():
    def __init__(self, env, max_ep_len, num_traj,latent_size ):
        self.env = gym.make(env)
        self.discrete = isinstance(self.env.action_space, gym.spaces.Discrete)
        self.observation_dim = self.env.observation_space.shape[0]
        self.action_dim = self.env.action_space.n if self.discrete else self.env.action_space.shape[0]
        self.max_ep_len = max_ep_len
        self.num_traj = num_traj
        self.traj_length = self.max_ep_len*(self.observation_dim + 2) # TO Change
        self.use_baseline = True
        self.latent_size = latent_size
        self.feature_size = self.observation_dim + 1 + self.env.action_space.shape[0] # HC
        self.lr = 3e-3
        self.num_layers = 2
        self.layers_size = 32
        self.num_mdps = 10
        self.model = self.env.env.model
        self.sim = MjSim(self.model)
        self.gamma = 0.97
        self.decoder_len = 32

        # build model
        self.ConstructGraph()
    
    def add_placeholders(self):
        self.observation_placeholder_explore = tf.placeholder(tf.float32, shape=(None,self.observation_dim))
        if(self.discrete):
            self.action_placeholder_explore = tf.placeholder(tf.int32, shape=(None))
            self.action_placeholder_exploit = tf.placeholder(tf.int32, shape=(None))
        else:
            self.action_placeholder_explore = tf.placeholder(tf.float32, shape=(None,self.action_dim))
            self.action_placeholder_exploit= tf.placeholder(tf.float32, shape=(None,self.action_dim))

        self.baseline_target_placeholder = tf.placeholder(tf.float32, shape= None)
        self.advantage_placeholder_explore = tf.placeholder(tf.float32, shape=(None))
        
        #self.encoder_input_placeholder = tf.placeholder(tf.float32, shape= (self.num_traj,self.traj_length))
        self.encoder_input_placeholder = tf.placeholder(tf.float32, [None, None, self.feature_size])
        self.decoder_input_placeholder = tf.placeholder(tf.float32, shape= (1,self.latent_size))
        self.sequence_length_placeholder = tf.placeholder(tf.int32, [None, ])
        
        self.observation_placeholder_exploit = tf.placeholder(tf.float32, shape=(None,self.observation_dim))
        #TODO
        self.advantage_placeholder_exploit = tf.placeholder(tf.float32, shape=(None))
        
        
    def build_policy_explore(self, scope = "policy_explore"):
        if (self.discrete):
            self.action_logits = build_mlp(self.observation_placeholder_explore,self.action_dim,scope = scope,n_layers=self.num_layers,size = self.layers_size,output_activation=None)
            self.explore_action = tf.multinomial(self.action_logits,1)
            self.explore_action = tf.squeeze(self.explore_action, axis=1)
            self.explore_logprob = -tf.nn.sparse_softmax_cross_entropy_with_logits(logits = self.action_logits, labels = self.action_placeholder_explore)

        else:   
            action_means = build_mlp(self.observation_placeholder_explore,self.action_dim,scope,n_layers=self.num_layers, size = self.layers_size,output_activation=None)
            init = tf.constant(np.random.rand(1, 2))
            #log_std = tf.get_variable("log_std", [self.action_dim])
            log_std = tf.get_variable(
                'log_std',
                shape=[1, self.action_dim],
                dtype=tf.float32,
                initializer=tf.zeros_initializer(),
                trainable=True
            )
            log_std = tf.log(tf.exp(log_std) + 1.)
            log_std = tf.tile(log_std,
                                   [tf.shape(action_means)[0], 1])
            self.explore_action = tf.random_normal((1,),
                                                   action_means,
                                                   log_std)
            dist = tf.contrib.distributions.MultivariateNormalDiag(action_means, log_std)
            self.explore_logprob = dist.prob(self.action_placeholder_explore, name = 'log_prob')
            #self.explore_action =   action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
            #mvn = tf.contrib.distributions.MultivariateNormalDiag(action_means, tf.exp(log_std))
            #self.explore_logprob =  mvn.log_prob(value = self.action_placeholder_explore, name='log_prob')

    
    
    def build_policy_exploit(self, scope = "policy_exploit"):
        if(self.discrete):
            #self.exploit_action_logits = (tf.matmul(tf.nn.relu(tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W1) + self.d_B1), self.d_W2) + self.d_B2),self.d_W3) + self.d_B3)
            #self.exploit_action_logits = tf.matmul(self.observation_placeholder_exploit,self.d_W3) + self.d_B3
            self.exploit_action_logits = tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W2) + self.d_B2), self.d_W3) + self.d_B3
            self.exploit_action = tf.multinomial(self.exploit_action_logits,1)
            self.exploit_action = tf.squeeze(self.exploit_action, axis=1)
            self.exploit_logprob = -tf.nn.sparse_softmax_cross_entropy_with_logits(logits = self.exploit_action_logits, labels = self.action_placeholder_exploit)
        else:
            action_means = tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W2) + self.d_B2), self.d_W3) + self.d_B3
            init = tf.constant(np.random.rand(1, 2))
            log_std = tf.get_variable("exploit_log_prob", [self.action_dim])
            self.exploit_action = action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
            self.exploit_logprob = utils.gauss_log_prob(mu=action_means, logstd=log_std, x=self.action_placeholder_exploit)
            
#             init = tf.constant(np.random.rand(1, 2))
#             log_std = tf.get_variable("exploit_log_prob", [self.action_dim])
#             self.exploit_action =   action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
#             mvn = tf.contrib.distributions.MultivariateNormalDiag(action_means, tf.exp(log_std))
#             self.exploit_logprob =  mvn.log_prob(value = self.action_placeholder_exploit, name='exploit_log_prob')

        #self.loss_grads_exploit = self.exploit_logprob * self.advantage_placeholder_exploit
        
    def NNEncoder(self, scope = "NNEncoder"):
        self.Z = build_mlp(self.encoder_input_placeholder,self.latent_size,scope = scope,n_layers=3,size = 60,output_activation=None)
    
 

    # input [num_traj, length, features (obs + action + reward) ]
    def LSTMEncoder(self, scope = "LSTMEncoder"):
        self.hidden_size = 64
        initializer = tf.random_uniform_initializer(-1, 1)
        cell = tf.nn.rnn_cell.LSTMCell(self.hidden_size, self.feature_size, initializer=initializer)
        cell_out = tf.contrib.rnn.OutputProjectionWrapper(cell, self.latent_size)
        self.output, _ = tf.nn.dynamic_rnn(cell_out,self.encoder_input_placeholder,self.sequence_length_placeholder,dtype=tf.float32,)
        batch_size = tf.shape(self.output)[0]
        max_length = tf.shape(self.output)[1]
        out_size = int(self.output.get_shape()[2])
        index = tf.range(0, batch_size) * max_length + (self.sequence_length_placeholder - 1)
        flat = tf.reshape(self.output, [-1, out_size])
        self.Z = tf.reduce_mean(tf.gather(flat, index), axis = 0)
        
    
    def Decoder(self, decoder_out_dim, scope):
        return build_mlp(self.decoder_input_placeholder,decoder_out_dim,scope = scope,n_layers=1,size = 64,output_activation=None)
    
    
    def sample_paths_explore(self, env,mdp_num,Test = False, num_episodes = None):
        paths = []
        self.length = []
        episode_rewards = []
        self.sim.model.opt.gravity[-1] = -5 - mdp_num
        for i in range(self.num_traj):
            pad = False
            state = env.reset()
            new_states,states,new_actions, actions, rewards,new_rewards = [], [], [], [], [],[]
            episode_reward = 0
            for step in range(self.max_ep_len):
                if (pad):
                    states.append([0]*self.observation_dim)
                    if(self.discrete):
                        actions.append(0)
                    else:
                        actions.append([0]*self.action_dim)
                    rewards.append(0)
                else:
                    states.append(state)
                    new_states.append(state)
                    #action = self.sess.run(self.explore_action, feed_dict={self.observation_placeholder_explore : states[-1][None]})[0]
                    action = self.policyfn.sample_action(state) #NEW
                    state, reward, done, info = env.step(action)
                    actions.append(action)
                    new_actions.append(action)
                    rewards.append(reward)
                    new_rewards.append(reward)
                    episode_reward += reward
                    if (done or step == self.max_ep_len-1):
                        episode_rewards.append(episode_reward)
                        self.length.append(step + 1)
                        pad = True 
                        
            episode_rewards.append(episode_reward)            
            #print("explore",np.array(actions))
            path = {"new_obs" : np.array(new_states),"observation" : np.array(states),
                                "reward" : np.array(rewards),"new_acs" : np.array(new_actions),
                                "action" : np.array(actions),"new_rewards":np.array(new_rewards)}
            paths.append(path)
        return paths, episode_rewards
    
    def sample_paths_exploit(self, env,Z,mdp_num,Test = False, num_episodes = None):
        self.sim.model.opt.gravity[-1] = -5 - mdp_num
        
        paths = []
        num = 0
        episode_rewards = []
        for i in range(self.num_traj):
            state = env.reset()
            states, actions, rewards = [], [], []
            episode_reward = 0
            for step in range(self.max_ep_len):
                states.append(state)
                action = self.sess.run(self.exploit_action, feed_dict={self.observation_placeholder_exploit : state[None], self.decoder_input_placeholder: Z})[0]
                state, reward, done, info = env.step(action)
                actions.append(action)
                rewards.append(reward)
                episode_reward += reward
                if (done or step == self.max_ep_len-1):
                    episode_rewards.append(episode_reward)
                    break
            #print("exploit",np.array(actions))
            path = {"observation" : np.array(states),
                                "reward" : np.array(rewards),
                                "action" : np.array(actions)}
            paths.append(path)
 
        #print("exploit success: ", num)
        return paths, episode_rewards
    
    def get_returns(self,paths, explore = False):
        all_returns = []
        m = 0
        for path in paths:
            rewards = path["reward"]
            returns = []
            if(explore):
                length = self.length[m]
            else:
                length = len(rewards)
            for i in range(length):
                path_returns = 0
                k = 0
                for j in range(i,length):
                    path_returns = path_returns + rewards[j]*(self.gamma)**k
                    k = k+1
                returns.append(path_returns)
            all_returns.append(returns)
            m+=1
        returns = np.concatenate(all_returns)
        return returns
    
    def stack_trajectories(self,paths):
        trajectories = []
        for path in paths:
            rewards = path["reward"]
            states = path["observation"]
            action = path["action"]
            
            SAR = []
            for i in range(len(states)):
                SAR.append(list(states[i]) + list(action[i]) + [rewards[i]])
            trajectories.append(SAR)
        return np.array(trajectories)
    
    def addBaseline(self):
        self.baseline = build_mlp(self.observation_placeholder_explore,1,scope = "baseline",n_layers=self.num_layers, size = self.layers_size,output_activation=None)
        self.baseline_loss = tf.losses.mean_squared_error(self.baseline_target_placeholder,self.baseline,scope = "baseline")
        baseline_adam_optimizer =  tf.train.AdamOptimizer(learning_rate = self.lr)
        self.update_baseline_op = baseline_adam_optimizer.minimize(self.baseline_loss)

    def calculate_advantage(self,returns, observations):
        if (self.use_baseline):
            baseline = self.sess.run(self.baseline, {input_placeholder:observations})
            adv = returns - baseline
            adv = (adv - np.mean(adv))/np.std(adv)
        else:
            adv = returns
        return adv
    

        
    def ConstructGraph(self):
        tf.reset_default_graph()
        self.sess = tf.Session()
        
        self.vf = vfuncs.NnValueFunction(session=self.sess,ob_dim=self.observation_dim)
        self.policyfn = policies.GaussianPolicy(self.sess,self.observation_dim, self.action_dim)
        
        self.add_placeholders()
        
#         self.add_placeholders()
        
#         self.build_policy_explore()
#         self.explore_policy_loss = -tf.reduce_sum(self.explore_logprob * self.advantage_placeholder_explore)
#         self.loss_grads_explore = -self.explore_logprob * self.advantage_placeholder_explore
#         self.tvars_explore = tf.trainable_variables()
#         self.gradients_explore = tf.gradients(self.explore_policy_loss,self.tvars_explore)
        
#         #self.addBaseline()
        
#         self.baseline = build_mlp(self.observation_placeholder_explore,1,scope = "baseline",n_layers=1, size = 16,output_activation=None)
#         self.baseline_loss = tf.losses.mean_squared_error(self.baseline_target_placeholder,self.baseline,scope = "baseline")
#         baseline_adam_optimizer =  tf.train.AdamOptimizer(learning_rate = self.lr)
#         self.update_baseline_op = baseline_adam_optimizer.minimize(self.baseline_loss)
        
#         #Encoder LSTM
        self.LSTMEncoder()
        
        
        #decoder weights
        #self.d_W1 = self.Decoder(scope = "W1", decoder_out_dim = self.observation_dim*self.decoder_len)
        self.d_W2 = self.Decoder(scope = "W2", decoder_out_dim = self.observation_dim*self.decoder_len)
        #self.d_W3 = self.Decoder(scope = "W3", decoder_out_dim = self.decoder_len*action_dim)
        self.d_W3 = self.Decoder(scope = "W3", decoder_out_dim = self.decoder_len*self.action_dim)
        
        #self.d_W1 = ((self.d_W1 - (tf.reduce_max(self.d_W1) + tf.reduce_min(self.d_W1))/2)/(tf.reduce_max(self.d_W1) - tf.reduce_min(self.d_W1)))*2 
        #self.d_W2 = ((self.d_W2 - (tf.reduce_max(self.d_W2) + tf.reduce_min(self.d_W2))/2)/(tf.reduce_max(self.d_W2) - tf.reduce_min(self.d_W2)))*2 
        #self.d_W3 = ((self.d_W3 - (tf.reduce_max(self.d_W3) + tf.reduce_min(self.d_W3))/2)/(tf.reduce_max(self.d_W3) - tf.reduce_min(self.d_W3)))*2 
        
        #self.d_W1 = tf.reshape(self.d_W1, [self.observation_dim, self.decoder_len])
        self.d_W2 = tf.reshape(self.d_W2, [self.observation_dim, self.decoder_len])
        #self.d_W3 = tf.reshape(self.d_W3, [self.decoder_len, self.action_dim])
        self.d_W3 = tf.reshape(self.d_W3, [self.decoder_len, self.action_dim])
        
        # decoder output bias
        #self.d_B1 = tf.reshape(self.Decoder(decoder_out_dim = self.decoder_len, scope = "B1"), [self.decoder_len])
        self.d_B2 = tf.reshape(self.Decoder(decoder_out_dim = self.decoder_len, scope = "B2"), [self.decoder_len])
        self.d_B3 = tf.reshape(self.Decoder(decoder_out_dim = self.action_dim, scope = "B3"), [self.action_dim])
        #self.d_B1 = ((self.d_B1 - (tf.reduce_max(self.d_B1) + tf.reduce_min(self.d_B1))/2)/(tf.reduce_max(self.d_B1) - tf.reduce_min(self.d_B1)))*2 
        #self.d_B2 = ((self.d_B2 - (tf.reduce_max(self.d_B2) + tf.reduce_min(self.d_B2))/2)/(tf.reduce_max(self.d_B2) - tf.reduce_min(self.d_B2)))*2 
        
        
        # exploit policy
        self.build_policy_exploit()
        #self.d = [self.d_W1, self.d_B1, self.d_W2, self.d_B2, self.d_W3, self.d_B3]
        self.exploit_policy_loss = -tf.reduce_sum(self.exploit_logprob * self.advantage_placeholder_exploit)
        self.d = [self.d_W3, self.d_B3]
        self.gradients_exploit = tf.gradients(self.exploit_policy_loss,self.d)
        
        # train encoder and decoder
        adam_optimizer_exploit =  tf.train.AdamOptimizer(self.lr*0.1)
        self.output_train_op = adam_optimizer_exploit.minimize(self.exploit_policy_loss)
        # train original network
#         adam_optimizer_explore = tf.train.AdamOptimizer(self.lr)
#         self.input_train_op = adam_optimizer_explore.minimize(self.explore_policy_loss)
        init = tf.global_variables_initializer()
        self.sess.run(init)
    
    def initialize(self):
        self.ConstructGraph()
#         # create tf session
#         self.sess = tf.Session()
        
#         # initiliaze all variables
#         init = tf.global_variables_initializer()
#         self.sess.run(init)
    
    def train_step(self): 
        # sample num_traj*num_MDPs
        for i in range(self.num_mdps):
            explore_paths, explore_rewards = self.sample_paths_explore(self.env,i)
            observations_explore = np.concatenate([path["observation"] for path in explore_paths])
            new_observations_explore = np.concatenate([path["new_obs"] for path in explore_paths])
            new_actions_explore = np.concatenate([path["new_acs"] for path in explore_paths])
            actions_explore = np.concatenate([path["action"] for path in explore_paths])
            rewards_explore = np.concatenate([path["reward"] for path in explore_paths])
            
            vtargs, vpreds, advantages_explore = [], [], []
            for path in explore_paths:
                rew_t = path["new_rewards"]
                return_t = utils.discount(rew_t, self.gamma)
                vpred_t = self.vf.predict(path["new_obs"])
                adv_t = return_t - vpred_t
                advantages_explore.append(adv_t)
                vtargs.append(return_t)
                vpreds.append(vpred_t)
                
                
            #returns_explore = self.get_returns(explore_paths, explore = True)
            advantages_explore = np.concatenate(advantages_explore)
            advantages_explore = (advantages_explore - advantages_explore.mean()) / (advantages_explore.std() + 1e-8)
            vtarg_n = np.concatenate(vtargs)
            vpred_n = np.concatenate(vpreds)
            #update baseline
            #print(advantages_explore.shape,new_observations_explore.shape)
            self.vf.fit(new_observations_explore, vtarg_n)
            
            surr_loss, oldmean_na, oldlogstd_a = self.policyfn.update_policy(
                    new_observations_explore, new_actions_explore, advantages_explore, self.lr)
            
            print("average reward explore:", np.mean(explore_rewards))
            
            #print(returns_explore)
#             print("average reward explore: MDP", i, np.sum(explore_rewards)/num_traj, len(explore_rewards))

#             baseline_explore = self.sess.run(self.baseline, {self.observation_placeholder_explore:new_observations_explore})
#             adv = returns_explore - np.squeeze(baseline_explore)
#             advantages_explore = (adv - np.mean(adv))/(np.std(adv) + 1e-12)


#             # update the baseline

#             self.sess.run(self.update_baseline_op, {self.observation_placeholder_explore:new_observations_explore, 
#                                            self.baseline_target_placeholder : returns_explore})

            # calculate explore gradients
    #         grads_explore = self.sess.run(self.gradients_explore, feed_dict={
    #                     self.observation_placeholder_explore : observations_explore,
    #                     self.action_placeholder_explore : actions_explore,
    #                     self.advantage_placeholder_explore : returns_explore})
            #print("explore",grads_explore )
            # form trajectory matrix

            M = np.array(self.stack_trajectories(explore_paths))


            #encoder LSTM
            Z = self.sess.run(self.Z, feed_dict = {self.encoder_input_placeholder: M,self.sequence_length_placeholder: self.length })
            Z = np.reshape(Z,[1,len(Z)])
#             #print("Z",Z)
#             #print(self.sess.run(self.d, feed_dict = {self.decoder_input_placeholder: Z}))
#             #print("d",self.d)
#             # sample paths
#             tvars = tf.trainable_variables()
#             tvars_vals = self.sess.run(tvars[-5:-1])
#             #print(tvars_vals)
            for j in range(10):
                exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z,i)
                # get observations, actions and rewards
                observations_exploit = np.concatenate([path["observation"] for path in exploit_paths])
                actions_exploit = np.concatenate([path["action"] for path in exploit_paths])
                rewards_exploit = np.concatenate([path["reward"] for path in exploit_paths])
                returns_exploit = self.get_returns(exploit_paths)
                print("average reward exploit: MDP", i, np.sum(exploit_rewards) / num_traj, len(exploit_rewards))


#             # exploit grads
#     #         grads_exploit = self.sess.run(self.gradients_exploit,feed_dict={
#     #                     self.observation_placeholder_exploit : observations_exploit,
#     #                     self.action_placeholder_exploit : actions_exploit,
#     #                     self.advantage_placeholder_exploit : returns_exploit,
#     #                     self.decoder_input_placeholder: Z})

            #train encoder and decoder network
                self.sess.run(self.output_train_op, feed_dict={
                                self.observation_placeholder_exploit : observations_exploit,
                                self.action_placeholder_exploit : actions_exploit,
                                self.advantage_placeholder_exploit : returns_exploit,
                                self.decoder_input_placeholder: Z})

            # find advantage for input network
    #         advantage_explore = 0
    #         for i in range(len(grads_exploit)):
    #             l1 = grads_exploit[i]
    #             l2 = grads_explore[i]
    #             advantage_explore = advantage_explore + np.matmul(l1.flatten(), l2.flatten())

            # train input policy
#             self.sess.run(self.input_train_op, feed_dict={
#                             self.observation_placeholder_explore : new_observations_explore,
#                             self.action_placeholder_explore : new_actions_explore,
#                             self.advantage_placeholder_explore : advantages_explore})
    
    def test(self):
        explore_paths, explore_rewards = self.sample_paths_explore(self.env,20*np.random.rand())
        print("gravity: ",self.sim.model.opt.gravity )
        M = self.stack_trajectories(explore_paths)
        Z = self.sess.run(self.Z, feed_dict = {self.encoder_input_placeholder: M,self.sequence_length_placeholder: self.length })
        Z = np.reshape(Z,[1,len(Z)])
        # sample paths
        exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z,20*np.random.rand())
        print("average reward exploit", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
        
    def train(self):
        self.initialize()
        num_epochs = 200
        for epoch in range(num_epochs):
            self.num_traj = 20
            print("epoch number: ", epoch)
            self.train_step()
            print("evaluating on new MDPs")
            self.num_traj = 400
            self.test()

# %%
a = MetaLearner(env, max_ep_len, num_traj, latent_size)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
a.train()
# Out:
# epoch number:  0
# average reward explore: 87.89810504610844
# average reward exploit: MDP 0 70.67102469406363 20
# average reward exploit: MDP 0 56.9229227137672 20
# average reward exploit: MDP 0 58.806632485294294 20
# average reward exploit: MDP 0 59.07209559249964 20
# average reward exploit: MDP 0 57.0035024271645 20
# average reward exploit: MDP 0 59.071488782162845 20
# average reward exploit: MDP 0 55.15726973189076 20
# average reward exploit: MDP 0 58.31024338805231 20
# average reward exploit: MDP 0 57.0984469601896 20
# average reward exploit: MDP 0 57.79130592306911 20
# average reward explore: 84.0697328782916
# average reward exploit: MDP 1 49.68789335136884 20
# average reward exploit: MDP 1 51.28713936863396 20
# average reward exploit: MDP 1 54.95621693150508 20
# average reward exploit: MDP 1 63.23139727293232 20
# average reward exploit: MDP 1 76.55806374232762 20
# average reward exploit: MDP 1 95.5536503244824 20
# average reward exploit: MDP 1 106.09777742265584 20
# average reward exploit: MDP 1 102.65199215220845 20
# average reward exploit: MDP 1 115.25824452664266 20
# average reward exploit: MDP 1 112.20006851759862 20
# average reward explore: 79.82239293462659
# average reward exploit: MDP 2 110.44413574183142 20
# average reward exploit: MDP 2 111.60575726914544 20
# average reward exploit: MDP 2 113.9089075346849 20
# average reward exploit: MDP 2 100.79485643149982 20
# average reward exploit: MDP 2 95.44118657214904 20
# average reward exploit: MDP 2 90.57430917995576 20
# average reward exploit: MDP 2 88.6197186785877 20
# average reward exploit: MDP 2 82.52397978075503 20
# average reward exploit: MDP 2 81.18873454891067 20
# average reward exploit: MDP 2 80.48315957481152 20
# average reward explore: 75.62461744929797
# average reward exploit: MDP 3 47.652914107730304 20
# average reward exploit: MDP 3 47.69134567663703 20
# average reward exploit: MDP 3 48.200157617410994 20
# average reward exploit: MDP 3 47.800411669918205 20
# average reward exploit: MDP 5 48.702136445419164 20
# average reward exploit: MDP 5 51.688346085902616 20
# average reward exploit: MDP 5 55.024022292768194 20
# average reward exploit: MDP 5 54.61702685994758 20
# average reward exploit: MDP 5 56.59535561061875 20
# average reward exploit: MDP 5 54.86336677396745 20
# average reward exploit: MDP 5 57.2467184156978 20
# average reward explore: 67.12222934957988
# average reward exploit: MDP 6 54.150360664473574 20
# average reward exploit: MDP 6 56.2440483361329 20
# average reward exploit: MDP 6 54.61537522571607 20
# average reward exploit: MDP 6 56.154141274734414 20
# average reward exploit: MDP 6 56.40529846055051 20
# average reward exploit: MDP 6 56.84150098198722 20
# average reward exploit: MDP 6 55.239014195815734 20
# average reward exploit: MDP 6 56.87616465212018 20
# average reward exploit: MDP 6 57.01981304558098 20
# average reward exploit: MDP 6 57.18422828863563 20
# average reward explore: 65.08546462441632
# average reward exploit: MDP 7 53.08262028548019 20
# average reward exploit: MDP 7 51.60866175430231 20
# average reward exploit: MDP 7 51.424814416287795 20
# average reward exploit: MDP 7 52.47799608554565 20
# average reward exploit: MDP 7 52.78272692139876 20
# average reward exploit: MDP 7 52.556433437576764 20
# average reward exploit: MDP 7 52.023948896992955 20
# average reward exploit: MDP 7 52.71372278896289 20
# average reward exploit: MDP 7 52.870087966814516 20
# average reward exploit: MDP 7 52.605737093595764 20
# average reward explore: 62.946160775504175
# average reward exploit: MDP 8 50.18401593620083 20
# average reward exploit: MDP 8 50.12822091727649 20
# average reward exploit: MDP 8 50.85210680779681 20
# average reward exploit: MDP 8 51.70148032010251 20
# average reward exploit: MDP 8 50.54531837229431 20
# average reward exploit: MDP 8 49.61515738628048 20
# average reward exploit: MDP 8 49.55534666100841 20
# average reward exploit: MDP 8 50.43482464949859 20
# average reward exploit: MDP 8 48.76445880237172 20
# average reward exploit: MDP 8 48.90762824949615 20
# average reward explore: 60.5716002946622
# average reward exploit: MDP 9 36.38076085434768 20
# average reward exploit: MDP 9 36.48419699859701 20
# average reward exploit: MDP 9 36.817121651488975 20
# average reward exploit: MDP 9 36.8299962426246 20
# average reward exploit: MDP 9 37.33416068400248 20
# average reward exploit: MDP 9 37.04361563122614 20
# average reward exploit: MDP 9 37.56643966793822 20
# average reward exploit: MDP 9 39.23933319063807 20
# average reward exploit: MDP 9 39.24283183832636 20
# average reward exploit: MDP 9 39.676683040269104 20
# evaluating on new MDPs
# gravity:  [  0.           0.         -16.98507426]
# average reward exploit 748.4677328448948 400
# epoch number:  2
# average reward explore: 91.30199984443126
# average reward exploit: MDP 0 81.75776504394611 20
# average reward exploit: MDP 0 80.69664873558327 20
# average reward exploit: MDP 0 103.7296231644623 20
# average reward exploit: MDP 0 106.71787439357351 20
# average reward exploit: MDP 0 109.28039010352101 20
# average reward exploit: MDP 0 122.24805090323126 20
# average reward exploit: MDP 0 118.69461683582846 20
# average reward exploit: MDP 0 105.354347007514 20
# average reward exploit: MDP 0 91.26779259396089 20
# average reward exploit: MDP 0 83.7101459272258 20
# average reward explore: 86.83397255640952
# average reward exploit: MDP 1 80.22280873322954 20
# average reward exploit: MDP 9 32.76422882109163 20
# average reward exploit: MDP 9 32.78652141062839 20
# average reward exploit: MDP 9 32.769567727923565 20
# average reward exploit: MDP 9 32.76135369939464 20
# average reward exploit: MDP 9 32.63921986628553 20
# average reward exploit: MDP 9 32.6926478375257 20
# average reward exploit: MDP 9 32.70561395509393 20
# average reward exploit: MDP 9 32.69923500500386 20
# average reward exploit: MDP 9 32.649152027739696 20
# average reward exploit: MDP 9 32.718407041722855 20
# evaluating on new MDPs
# gravity:  [  0.           0.         -10.75741906]
# average reward exploit 700.9530967453072 400
# epoch number:  4
# average reward explore: 84.44826418106905
# average reward exploit: MDP 0 47.29968478147402 20
# average reward exploit: MDP 0 46.99108084427996 20
# average reward exploit: MDP 0 46.9325928646665 20
# average reward exploit: MDP 0 46.60085681674203 20
# average reward exploit: MDP 0 47.5172127159976 20
# average reward exploit: MDP 0 47.42496938733848 20
# average reward exploit: MDP 0 47.884653942605674 20
# average reward exploit: MDP 0 52.49563289903481 20
# average reward exploit: MDP 0 52.66595277159631 20
# average reward exploit: MDP 0 52.18370373078872 20
# average reward explore: 78.80962821496087
# average reward exploit: MDP 1 47.69609049401035 20
# average reward exploit: MDP 1 48.825316912985706 20
# average reward exploit: MDP 1 50.019825285940506 20
# average reward exploit: MDP 1 55.31661340861282 20
# average reward exploit: MDP 1 59.71868103347204 20
# average reward exploit: MDP 1 62.36260447839477 20
# average reward exploit: MDP 1 64.87723413391727 20
# average reward exploit: MDP 1 63.323326539372346 20
# average reward exploit: MDP 1 73.42186567121743 20
# average reward exploit: MDP 1 81.49001216487827 20
# average reward explore: 76.01294829305606
# average reward exploit: MDP 2 70.57634037440829 20
# average reward exploit: MDP 2 71.00378887415195 20
# average reward exploit: MDP 2 70.9231926830573 20
# average reward exploit: MDP 2 71.14348372074534 20
# average reward exploit: MDP 2 72.40736673468972 20
# average reward exploit: MDP 2 76.31494715909822 20
# average reward exploit: MDP 2 79.0678591898828 20
# average reward exploit: MDP 2 80.46396616013057 20
# average reward exploit: MDP 2 78.33086026179453 20
# average reward exploit: MDP 2 80.89053622426529 20
# average reward explore: 68.95629741541563
# average reward exploit: MDP 3 40.370241160480575 20
# average reward exploit: MDP 3 40.133187680462335 20
# average reward exploit: MDP 3 39.821505522743315 20
# average reward exploit: MDP 3 40.646800338841516 20
# average reward exploit: MDP 3 40.72924947957492 20
# average reward exploit: MDP 3 40.48710428269362 20
# average reward exploit: MDP 3 40.0865645800085 20
# average reward exploit: MDP 3 40.23775879211912 20
# average reward exploit: MDP 3 40.78991762818598 20
# average reward exploit: MDP 3 41.100968090075575 20
# average reward explore: 64.8034223785269
# average reward exploit: MDP 4 37.731216300497145 20
# average reward exploit: MDP 4 38.062828355351584 20
# average reward exploit: MDP 4 37.93412419596034 20
# average reward exploit: MDP 4 37.45595065653505 20
# average reward exploit: MDP 4 36.99808828802312 20
# average reward exploit: MDP 4 38.06206914663649 20
# average reward exploit: MDP 4 37.11367833966119 20
# average reward exploit: MDP 4 38.12537742934856 20
# average reward exploit: MDP 4 37.69928772000527 20
# average reward exploit: MDP 4 37.67222607082049 20
# average reward explore: 60.34076216368021
# average reward exploit: MDP 5 35.923525072083756 20
# average reward exploit: MDP 5 35.93127560469137 20
# average reward exploit: MDP 5 35.93729977008493 20
# average reward exploit: MDP 5 35.92877105852819 20
# average reward exploit: MDP 5 35.9373645564951 20
# average reward exploit: MDP 5 35.930406555493065 20
# average reward exploit: MDP 5 35.89866494657642 20
# average reward exploit: MDP 5 35.94688967310261 20
# average reward exploit: MDP 5 35.92473703298367 20
# average reward exploit: MDP 5 35.92332351938785 20
# average reward explore: 55.62562251152194
# average reward exploit: MDP 6 35.76693823654206 20
# average reward exploit: MDP 6 35.42547889955382 20
# average reward exploit: MDP 6 35.940480121068504 20
# average reward exploit: MDP 6 35.428651384011715 20
# average reward exploit: MDP 6 35.622277842877295 20
# average reward exploit: MDP 6 35.607082684237845 20
# average reward exploit: MDP 6 35.76596497157055 20
# average reward exploit: MDP 6 35.932559941495164 20
# average reward exploit: MDP 6 35.745048361508864 20
# average reward exploit: MDP 6 35.92494421773409 20
# average reward explore: 55.20476215650401
# average reward exploit: MDP 7 50.844064664484456 20
# average reward exploit: MDP 7 52.575853670260855 20
# average reward exploit: MDP 7 54.58759209980124 20
# average reward exploit: MDP 7 52.415418482308546 20
# average reward exploit: MDP 7 52.303801889360464 20
# average reward exploit: MDP 7 50.73529945615207 20
# average reward exploit: MDP 7 51.97634192543731 20
# average reward exploit: MDP 7 52.27197082137127 20
# average reward exploit: MDP 7 51.260062512992725 20
# average reward exploit: MDP 7 49.98802581782549 20
# average reward explore: 53.02184745814257
# average reward exploit: MDP 8 32.7714945805535 20
# average reward exploit: MDP 8 32.74177571938544 20
# average reward exploit: MDP 8 32.79717636424464 20
# average reward exploit: MDP 8 32.778759983881635 20
# average reward exploit: MDP 8 32.78388965194495 20
# average reward exploit: MDP 8 32.78563017197623 20
# average reward exploit: MDP 8 32.754987570216166 20
# average reward exploit: MDP 8 32.7820896163856 20
# average reward exploit: MDP 8 32.77580540657683 20
# average reward exploit: MDP 8 32.791365370158296 20
# average reward explore: 52.32779112632181
# average reward exploit: MDP 9 32.77295487705734 20
# average reward exploit: MDP 9 32.77487330424404 20
# average reward exploit: MDP 9 32.78556154675212 20
# average reward exploit: MDP 9 32.780705926297784 20
# average reward exploit: MDP 9 32.77820303989018 20
# average reward exploit: MDP 9 32.746727780588316 20
# average reward exploit: MDP 9 32.79122996330489 20
# average reward exploit: MDP 9 32.78486799230608 20
# average reward exploit: MDP 9 32.77472889537489 20
# average reward exploit: MDP 9 32.75987731752319 20
# evaluating on new MDPs
# gravity:  [  0.           0.         -20.28762066]
# average reward exploit 749.816832843908 400
# epoch number:  5
# average reward explore: 84.44541459989497
# average reward exploit: MDP 0 46.685466469749535 20
# average reward exploit: MDP 0 46.54243848850265 20
# average reward exploit: MDP 0 46.3925843584567 20
# average reward exploit: MDP 0 47.18890122917597 20
# average reward exploit: MDP 0 46.6004177968252 20
# average reward exploit: MDP 0 47.43202781497202 20
# average reward exploit: MDP 0 48.232436798569005 20
# average reward exploit: MDP 0 47.22488387920585 20
# average reward exploit: MDP 0 47.258942896055224 20
# average reward exploit: MDP 0 47.736987628013416 20
# average reward explore: 77.622119236907
# average reward exploit: MDP 1 44.8962631590186 20
# average reward exploit: MDP 1 45.07077159347567 20
# average reward exploit: MDP 1 44.73681460985655 20
# average reward exploit: MDP 1 45.06013852534181 20
# average reward exploit: MDP 1 44.42500638108996 20
# average reward exploit: MDP 1 45.035594838693974 20
# average reward exploit: MDP 1 45.75463944236306 20
# average reward exploit: MDP 1 46.16496430947273 20
# average reward exploit: MDP 1 46.34300841017321 20
# average reward exploit: MDP 1 46.17434325564747 20
# average reward explore: 72.00362211870568
# average reward exploit: MDP 2 43.287449589153965 20
# average reward exploit: MDP 2 43.73826170822256 20
# average reward exploit: MDP 2 43.51663005429569 20
# average reward exploit: MDP 2 43.632403611350234 20
# average reward exploit: MDP 2 43.63944815104527 20
# average reward exploit: MDP 2 43.58029290928809 20
# average reward exploit: MDP 2 43.94917949462784 20
# average reward exploit: MDP 2 44.09345673212689 20
# average reward exploit: MDP 2 43.279292542702734 20
# average reward exploit: MDP 2 43.49344413025547 20
# average reward explore: 68.19394455707625
# average reward exploit: MDP 3 41.570694880545865 20
# average reward exploit: MDP 3 41.77266089436348 20
# average reward exploit: MDP 3 39.219465893499674 20
# average reward exploit: MDP 3 39.1085846482422 20
# average reward exploit: MDP 3 39.353675048602604 20
# average reward exploit: MDP 3 39.09417841489462 20
# average reward exploit: MDP 3 38.82610597561157 20
# average reward exploit: MDP 3 39.02257634632952 20
# average reward exploit: MDP 3 38.97249189821077 20
# average reward exploit: MDP 3 38.9832956236088 20
# average reward explore: 65.10140008060061
# average reward exploit: MDP 4 37.85806377423925 20
# average reward exploit: MDP 4 37.1095394734045 20
# average reward exploit: MDP 4 37.61413221806366 20
# average reward exploit: MDP 4 37.75318653310292 20
# average reward exploit: MDP 4 37.30397813358761 20
# average reward exploit: MDP 4 37.48641355945663 20
# average reward exploit: MDP 4 36.975124885157015 20
# average reward exploit: MDP 4 38.07458209710406 20
# average reward exploit: MDP 4 37.60490512466662 20
# average reward exploit: MDP 4 37.15993140074272 20
# average reward explore: 61.78560200181007
# average reward exploit: MDP 5 38.96784528488458 20
# average reward exploit: MDP 5 38.75138705261013 20
# average reward exploit: MDP 5 38.40329599518835 20
# average reward exploit: MDP 5 38.406859907178834 20
# average reward exploit: MDP 5 38.528151085311386 20
# average reward exploit: MDP 5 38.4489409397017 20
# average reward exploit: MDP 5 38.320867303581025 20
# average reward exploit: MDP 5 38.18492170701554 20
# average reward exploit: MDP 5 38.93709002901652 20
# average reward exploit: MDP 5 49.01759172422972 20
# average reward explore: 61.05792593765267
# average reward exploit: MDP 6 51.31548908238836 20
# average reward exploit: MDP 6 54.34625235941132 20
# average reward exploit: MDP 6 54.96220234664157 20
# average reward exploit: MDP 6 57.34125186048559 20
# average reward exploit: MDP 6 57.59017822698226 20
# average reward exploit: MDP 6 57.43652841428764 20
# average reward exploit: MDP 6 57.53380838380443 20
# average reward exploit: MDP 6 57.45923451904468 20
# average reward exploit: MDP 8 32.76934264533855 20
# average reward exploit: MDP 8 32.76999016387395 20
# average reward exploit: MDP 8 32.736793134410874 20
# average reward exploit: MDP 8 32.80050094050809 20
# average reward explore: 53.49678925411306
# average reward exploit: MDP 9 32.7643080559357 20
# average reward exploit: MDP 9 32.7686470368468 20
# average reward exploit: MDP 9 32.76216813211782 20
# average reward exploit: MDP 9 32.76556344028516 20
# average reward exploit: MDP 9 32.77011138416971 20
# average reward exploit: MDP 9 32.737559250909406 20
# average reward exploit: MDP 9 32.76628424899942 20
# average reward exploit: MDP 9 32.77758668586153 20
# average reward exploit: MDP 9 32.75742820429681 20
# average reward exploit: MDP 9 32.78495421919873 20
# evaluating on new MDPs
# gravity:  [  0.          0.        -20.9160342]
# average reward exploit 592.4758652702167 400
# epoch number:  7
# average reward explore: 84.80189465295066
# average reward exploit: MDP 0 54.87177913340442 20
# average reward exploit: MDP 0 56.41996102519956 20
# average reward exploit: MDP 0 60.82189322045317 20
# average reward exploit: MDP 0 62.72556963396963 20
# average reward exploit: MDP 0 63.063363837278935 20
# average reward exploit: MDP 0 61.31076517050212 20
# average reward exploit: MDP 0 60.86658597683256 20
# average reward exploit: MDP 0 60.6481129736018 20
# average reward exploit: MDP 0 71.18989999338565 20
# average reward exploit: MDP 0 78.54618638153597 20
# average reward explore: 78.27286061302615
# average reward exploit: MDP 1 61.682852524242286 20
# average reward exploit: MDP 1 66.40909091302429 20
# average reward exploit: MDP 1 58.02187899542988 20
# average reward exploit: MDP 1 59.902988657052695 20
# average reward exploit: MDP 1 61.330997100362275 20
# average reward exploit: MDP 1 60.92025693397895 20
# average reward exploit: MDP 1 60.63896720623271 20
# average reward exploit: MDP 1 60.21442855552937 20
# average reward exploit: MDP 1 58.63772883400369 20
# average reward exploit: MDP 1 56.26775795039565 20
# average reward explore: 71.51421254023545
# average reward exploit: MDP 2 42.618567811028335 20
# average reward exploit: MDP 2 42.179810511439 20
# average reward exploit: MDP 2 42.31852227296578 20
# average reward exploit: MDP 2 42.31329931851322 20
# average reward exploit: MDP 2 42.333962791262586 20
# average reward exploit: MDP 2 42.352370361055904 20
# average reward exploit: MDP 2 42.308384925779144 20
# average reward exploit: MDP 2 42.13337466369767 20
# average reward exploit: MDP 2 42.334588334657774 20
# average reward exploit: MDP 2 42.325714031977896 20
# average reward explore: 70.80389091375756
# average reward exploit: MDP 3 64.12567246635498 20
# average reward exploit: MDP 3 54.834265279581935 20
# average reward exploit: MDP 3 60.884528605089784 20
# average reward exploit: MDP 3 60.19949288409129 20
# average reward exploit: MDP 3 70.25390652117467 20
# average reward exploit: MDP 3 53.89997826750631 20
# average reward exploit: MDP 3 45.35588408997282 20
# average reward exploit: MDP 3 51.86928448000386 20
# average reward exploit: MDP 3 68.09607725130515 20
# average reward exploit: MDP 3 70.17380901805535 20
# average reward explore: 67.05097627762137
# average reward exploit: MDP 4 58.55590499394202 20
# average reward exploit: MDP 4 58.317084754573834 20
# average reward exploit: MDP 4 56.87063890799254 20
# average reward exploit: MDP 4 57.25932844616089 20
# average reward exploit: MDP 0 49.07197647884128 20
# average reward exploit: MDP 0 48.64939721163286 20
# average reward exploit: MDP 0 46.00934137188968 20
# average reward exploit: MDP 0 56.607343354549336 20
# average reward exploit: MDP 0 52.38998864497036 20
# average reward exploit: MDP 0 51.241398716602426 20
# average reward exploit: MDP 0 57.846432820014186 20
# average reward exploit: MDP 0 51.807842288107445 20
# average reward explore: 77.75849585252709
# average reward exploit: MDP 1 45.96111561310359 20
# average reward exploit: MDP 1 45.02239389163957 20
# average reward exploit: MDP 1 44.36598522681327 20
# average reward exploit: MDP 1 45.03420557199753 20
# average reward exploit: MDP 1 45.33834893237916 20
# average reward exploit: MDP 1 46.239119930321635 20
# average reward exploit: MDP 1 46.68254149045049 20
# average reward exploit: MDP 1 47.35715017318652 20
# average reward exploit: MDP 1 48.49375540682006 20
# average reward exploit: MDP 1 48.524912878156584 20
# average reward explore: 71.77741211784186
# average reward exploit: MDP 2 42.08498975898123 20
# average reward exploit: MDP 2 42.22882289428087 20
# average reward exploit: MDP 2 42.26263975687096 20
# average reward exploit: MDP 2 42.674222975196365 20
# average reward exploit: MDP 2 42.15012966268731 20
# average reward exploit: MDP 2 73.46733885661163 20
# average reward exploit: MDP 2 72.94639346629748 20
# average reward exploit: MDP 2 58.499019453751444 20
# average reward exploit: MDP 2 61.865718243060705 20
# average reward exploit: MDP 2 60.56386825308077 20
# average reward explore: 70.03111864259786
# average reward exploit: MDP 3 44.301026466680156 20
# average reward exploit: MDP 3 41.25689680662508 20
# average reward exploit: MDP 3 41.36688333648369 20
# average reward exploit: MDP 3 41.24008793928899 20
# average reward exploit: MDP 3 54.04077633199031 20
# average reward exploit: MDP 3 41.730125823889644 20
# average reward exploit: MDP 3 41.94297026410516 20
# average reward exploit: MDP 3 42.24338070489798 20
# average reward exploit: MDP 3 43.286700068823535 20
# average reward exploit: MDP 3 42.33129231201054 20
# average reward explore: 64.36534428056561
# average reward exploit: MDP 4 40.31607913362741 20
# average reward exploit: MDP 4 39.83420501780632 20
# average reward exploit: MDP 4 39.54847693518206 20
# average reward exploit: MDP 4 39.293916427831846 20
# average reward exploit: MDP 4 39.07575240955712 20
# average reward exploit: MDP 4 39.032229435739126 20
# average reward exploit: MDP 4 38.4704001872663 20
# average reward exploit: MDP 4 38.705289613518566 20
# average reward exploit: MDP 4 42.22261659241911 20
# average reward exploit: MDP 4 42.206945857109154 20
# average reward explore: 63.057259979271464
# average reward exploit: MDP 5 36.242059986312334 20
# average reward exploit: MDP 5 35.913236765667165 20
# average reward exploit: MDP 5 35.90098952560227 20
# average reward exploit: MDP 5 35.91125911577672 20
# average reward exploit: MDP 5 37.8245210340025 20
# average reward exploit: MDP 5 37.52688899740128 20
# average reward exploit: MDP 5 37.5137879622764 20
# average reward exploit: MDP 5 37.822926331886876 20
# average reward exploit: MDP 5 37.679354230316726 20
# average reward exploit: MDP 5 37.510175407795835 20
# average reward explore: 57.26654271348555
# average reward exploit: MDP 6 39.02140575392916 20
# average reward exploit: MDP 6 39.06209330685746 20
# average reward exploit: MDP 6 38.98662419037548 20
# average reward exploit: MDP 2 74.90562668453258 20
# average reward exploit: MDP 2 74.74859886237248 20
# average reward exploit: MDP 2 75.11578778055537 20
# average reward exploit: MDP 2 74.2724646235281 20
# average reward exploit: MDP 2 57.16000577956132 20
# average reward exploit: MDP 2 44.953285730900014 20
# average reward exploit: MDP 2 42.210645460959114 20
# average reward exploit: MDP 2 41.275262731964 20
# average reward exploit: MDP 2 41.338918777588724 20
# average reward explore: 70.05564696456918
# average reward exploit: MDP 3 38.935704678627296 20
# average reward exploit: MDP 3 38.89193993881219 20
# average reward exploit: MDP 3 38.925463090360374 20
# average reward exploit: MDP 3 38.969195457944835 20
# average reward exploit: MDP 3 38.948452507442425 20
# average reward exploit: MDP 3 38.95108779744657 20
# average reward exploit: MDP 3 38.95060338933562 20
# average reward exploit: MDP 3 38.96112494823732 20
# average reward exploit: MDP 3 38.966758315305384 20
# average reward exploit: MDP 3 38.96792345037252 20
# average reward explore: 65.21641320103376
# average reward exploit: MDP 4 37.275666478605636 20
# average reward exploit: MDP 4 37.48992088718892 20
# average reward exploit: MDP 4 37.42886714230164 20
# average reward exploit: MDP 4 37.138753908869674 20
# average reward exploit: MDP 4 37.43009341369179 20
# average reward exploit: MDP 4 37.27300730919355 20
# average reward exploit: MDP 4 37.30543344072245 20
# average reward exploit: MDP 4 37.724815793831496 20
# average reward exploit: MDP 4 37.44734310456582 20
# average reward exploit: MDP 4 36.92698480585 20
# average reward explore: 64.16090354754772
# average reward exploit: MDP 5 35.95559970197477 20
# average reward exploit: MDP 5 35.92782660270867 20
# average reward exploit: MDP 5 36.08603583294144 20
# average reward exploit: MDP 5 37.00409729800985 20
# average reward exploit: MDP 5 37.788282722257264 20
# average reward exploit: MDP 5 37.61911357295609 20
# average reward exploit: MDP 5 39.07199584829986 20
# average reward exploit: MDP 5 39.380152549652976 20
# average reward exploit: MDP 5 39.22904328046376 20
# average reward exploit: MDP 5 39.13123861303447 20
# average reward explore: 60.78905261633499
# average reward exploit: MDP 6 38.93148665582299 20
# average reward exploit: MDP 6 38.74466130893005 20
# average reward exploit: MDP 6 38.93238624705369 20
# average reward exploit: MDP 6 38.762545298923456 20
# average reward exploit: MDP 6 39.063835177431834 20
# average reward exploit: MDP 6 38.92289928841317 20
# average reward exploit: MDP 6 38.7892394264102 20
# average reward exploit: MDP 6 39.0550195358487 20
# average reward exploit: MDP 6 39.0736896064365 20
# average reward exploit: MDP 6 39.073386007537955 20
# average reward explore: 58.17120463347036
# average reward exploit: MDP 7 37.501997277907485 20
# average reward exploit: MDP 7 36.91869342829347 20
# average reward exploit: MDP 7 37.836034654615766 20
# average reward exploit: MDP 7 38.915049764023486 20
# average reward exploit: MDP 7 39.22721735270969 20
# average reward exploit: MDP 7 39.08403100796503 20
# average reward exploit: MDP 7 39.378089980595604 20
# average reward exploit: MDP 7 39.23970038059848 20
# average reward exploit: MDP 7 39.08975457261169 20
# average reward exploit: MDP 7 39.38545798796768 20
# average reward explore: 57.58737447440874
# average reward exploit: MDP 8 32.7708138994609 20
# average reward exploit: MDP 8 32.76165626398258 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-bde7b6456197> in <module>()
# ----> 1 a.train()
#
# <ipython-input-5-e0054b5a79cc> in train(self)
#     445             self.num_traj = 20
#     446             print("epoch number: ", epoch)
# --> 447             self.train_step()
#     448             print("evaluating on new MDPs")
#     449             self.num_traj = 400
#
# <ipython-input-5-e0054b5a79cc> in train_step(self)
#     393 #             #print(tvars_vals)
#     394             for j in range(10):
# --> 395                 exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z,i)
#     396                 # get observations, actions and rewards
#     397                 observations_exploit = np.concatenate([path["observation"] for path in exploit_paths])
#
# <ipython-input-5-e0054b5a79cc> in sample_paths_exploit(self, env, Z, mdp_num, Test, num_episodes)
#     179                 states.append(state)
#     180                 action = self.sess.run(self.exploit_action, feed_dict={self.observation_placeholder_exploit : state[None], self.decoder_input_placeholder: Z})[0]
# --> 181                 state, reward, done, info = env.step(action)
#     182                 actions.append(action)
#     183                 rewards.append(reward)
#
# /anaconda3/lib/python3.6/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      29     def step(self, action):
#      30         assert self._episode_started_at is not None, "Cannot call env.step() before calling reset()"
# ---> 31         observation, reward, done, info = self.env.step(action)
#      32         self._elapsed_steps += 1
#      33
#
# /anaconda3/lib/python3.6/site-packages/gym/envs/mujoco/humanoid.py in step(self, a)
#      24     def step(self, a):
#      25         pos_before = mass_center(self.model, self.sim)
# ---> 26         self.do_simulation(a, self.frame_skip)
#      27         pos_after = mass_center(self.model, self.sim)
#      28         alive_bonus = 5.0
#
# /anaconda3/lib/python3.6/site-packages/gym/envs/mujoco/mujoco_env.py in do_simulation(self, ctrl, n_frames)
#      98         self.sim.data.ctrl[:] = ctrl
#      99         for _ in range(n_frames):
# --> 100             self.sim.step()
#     101
#     102     def render(self, mode='human'):
#
# KeyboardInterrupt:

# %%
for epoch in range(200):
        print("epoch number: ", epoch)
        a.train_step()
# Out:
# epoch number:  0
# average reward explore: 82.96251755642649
# average reward exploit: MDP 0 73.82496456351859 30
# average reward exploit: MDP 0 72.63798571588255 30
# average reward exploit: MDP 0 72.9195911751872 30
# average reward exploit: MDP 0 73.57823085200245 30
# average reward exploit: MDP 0 73.94708967913637 30
# average reward exploit: MDP 0 74.49656268863008 30
# average reward exploit: MDP 0 73.65975738682121 30
# average reward exploit: MDP 0 75.16580731982253 30
# average reward exploit: MDP 0 74.54466412274041 30
# average reward exploit: MDP 0 73.5883272924395 30
# average reward explore: 78.37416715003496
# average reward exploit: MDP 1 67.51819471570535 30
# average reward exploit: MDP 1 67.97158607986732 30
# average reward exploit: MDP 1 66.72792142490734 30
# average reward exploit: MDP 1 74.5388548880442 30
# average reward exploit: MDP 1 84.03547942829246 30
# average reward exploit: MDP 1 84.68315754125462 30
# average reward exploit: MDP 1 84.1231174736365 30
# average reward exploit: MDP 1 80.07914452874239 30
# average reward exploit: MDP 1 74.76491574686919 30
# average reward exploit: MDP 1 80.47616164108699 30
# average reward explore: 73.15578584412624
# average reward exploit: MDP 2 63.18634205314384 30
# average reward exploit: MDP 2 63.09352600130168 30
# average reward exploit: MDP 2 62.968167172813274 30
# average reward exploit: MDP 2 63.247124915938706 30
# average reward exploit: MDP 2 63.2906177709074 30
# average reward exploit: MDP 2 63.23105251306287 30
# average reward exploit: MDP 2 63.48008899378877 30
# average reward exploit: MDP 2 63.491773104224315 30
# average reward exploit: MDP 2 63.163674322835035 30
# average reward exploit: MDP 2 65.4431612653127 30
# average reward explore: 70.38394505012447
# average reward exploit: MDP 3 58.43060740018359 30
# average reward exploit: MDP 3 58.39914142366484 30
# average reward exploit: MDP 3 58.36910845804691 30
# average reward exploit: MDP 3 59.26892159350018 30
# average reward exploit: MDP 3 59.48829162750362 30
# average reward exploit: MDP 3 59.599421783477865 30
# average reward exploit: MDP 3 60.0669196278721 30
# average reward exploit: MDP 3 61.3921054693951 30
# average reward exploit: MDP 3 61.272135167659606 30
# average reward exploit: MDP 3 61.669714521778694 30
# average reward explore: 66.40893774505965
# average reward exploit: MDP 4 64.42787176400311 30
# average reward exploit: MDP 4 66.18491753917203 30
# average reward exploit: MDP 4 63.334295747044635 30
# average reward exploit: MDP 4 68.60142292908671 30
# average reward exploit: MDP 4 72.37370023385333 30
# average reward exploit: MDP 4 70.58538065044993 30
# average reward exploit: MDP 4 70.27837431134652 30
# average reward exploit: MDP 4 70.42551631266556 30
# average reward exploit: MDP 4 71.22436753986361 30
# average reward exploit: MDP 4 70.90654671309908 30
# average reward explore: 65.17849646161022
# average reward exploit: MDP 5 53.49798361783169 30
# average reward exploit: MDP 5 54.616960897239004 30
# average reward exploit: MDP 5 54.44970414284629 30
# average reward exploit: MDP 5 53.74894921912202 30
# average reward exploit: MDP 5 53.82686040740029 30
# average reward exploit: MDP 5 53.76739282807513 30
# average reward exploit: MDP 5 54.71385747403289 30
# average reward exploit: MDP 5 58.57610719123232 30
# average reward exploit: MDP 5 58.77203223959591 30
# average reward exploit: MDP 5 59.084256811483485 30
# average reward explore: 62.04686912601746
# average reward exploit: MDP 6 74.4054624599365 30
# average reward exploit: MDP 6 89.10474070312324 30
# average reward exploit: MDP 6 86.02109665750717 30
# average reward exploit: MDP 6 86.00539877568737 30
# average reward exploit: MDP 6 86.12973320248865 30
# average reward exploit: MDP 6 89.9477032881436 30
# average reward exploit: MDP 6 89.66718522965958 30
# average reward exploit: MDP 6 89.80301651969015 30
# average reward exploit: MDP 6 91.8247470952797 30
# average reward exploit: MDP 6 93.52793020283927 30
# average reward explore: 57.9207974296185
# average reward exploit: MDP 7 100.29639848642127 30
# average reward exploit: MDP 7 103.2908789671359 30
# average reward exploit: MDP 7 100.59348449437948 30
# average reward exploit: MDP 7 105.67219223708493 30
# average reward exploit: MDP 7 112.550709778114 30
# average reward exploit: MDP 7 103.30180819878123 30
# average reward exploit: MDP 7 105.1447022143626 30
# average reward exploit: MDP 7 97.66015253094471 30
# average reward exploit: MDP 7 108.57080676347755 30
# average reward exploit: MDP 7 100.82119405754487 30
# average reward explore: 56.652333352909594
# average reward exploit: MDP 8 97.14601095752727 30
# average reward exploit: MDP 8 98.3582950917749 30
# average reward exploit: MDP 8 98.32561249041709 30
# average reward exploit: MDP 8 94.60033138197014 30
# average reward exploit: MDP 8 97.64014501342136 30
# average reward exploit: MDP 8 122.35420085089132 30
# average reward exploit: MDP 8 117.34772295496745 30
# average reward exploit: MDP 8 116.81120807521263 30
# average reward exploit: MDP 8 115.14684030158679 30
# average reward exploit: MDP 8 115.54511548247213 30
# average reward explore: 55.237944384673
# average reward exploit: MDP 9 77.60951663707004 30
# average reward exploit: MDP 9 76.07718849134491 30
# average reward exploit: MDP 9 75.91851964488804 30
# average reward exploit: MDP 9 78.23390503150715 30
# average reward exploit: MDP 9 81.00096089140041 30
# average reward exploit: MDP 9 84.25609664158073 30
# average reward exploit: MDP 9 77.23757458025482 30
# average reward exploit: MDP 9 78.31720985894847 30
# average reward exploit: MDP 9 77.00169383202409 30
# average reward exploit: MDP 9 79.69813783402411 30
# epoch number:  1
# average reward explore: 80.49435700172516
# average reward exploit: MDP 0 115.61763253258691 30
# average reward exploit: MDP 0 115.05958198715142 30
# average reward exploit: MDP 0 114.94026877886607 30
# average reward exploit: MDP 0 115.15912014979902 30
# average reward exploit: MDP 0 114.72765808388036 30
# average reward exploit: MDP 0 115.13252722672554 30
# average reward exploit: MDP 0 115.79095990925472 30
# average reward exploit: MDP 0 115.1292299708044 30
# average reward exploit: MDP 0 115.90894831569773 30
# average reward exploit: MDP 0 115.42302107781298 30
# average reward explore: 74.1295481006241
# average reward exploit: MDP 1 198.7367279836001 30
# average reward exploit: MDP 1 198.1174801749772 30
# average reward exploit: MDP 1 209.47965117446975 30
# average reward exploit: MDP 1 195.35919841589856 30
# average reward exploit: MDP 1 204.00690959586487 30
# average reward exploit: MDP 1 316.66752787575865 30
# average reward exploit: MDP 1 286.8693297761736 30
# average reward exploit: MDP 1 370.59943733224594 30
# average reward exploit: MDP 1 359.4854094176637 30
# average reward exploit: MDP 1 168.81576545184154 30
# average reward explore: 63.11824681919026
# average reward exploit: MDP 2 253.35937299208302 30
# average reward exploit: MDP 2 149.9589645546791 30
# average reward exploit: MDP 2 127.17272980308243 30
# average reward exploit: MDP 2 124.97447487839464 30
# average reward exploit: MDP 2 121.84805688541698 30
# average reward exploit: MDP 2 121.89402762573577 30
# average reward exploit: MDP 2 121.92011117252173 30
# average reward exploit: MDP 2 122.52403084580692 30
# average reward exploit: MDP 2 122.3239829268364 30
# average reward exploit: MDP 2 118.5718039524204 30
# average reward explore: 60.94969362481775
# average reward exploit: MDP 3 100.87601108944797 30
# average reward exploit: MDP 3 98.08851677259108 30
# average reward exploit: MDP 3 107.23357876860842 30
# average reward exploit: MDP 3 111.77380138050106 30
# average reward exploit: MDP 3 112.37231772764092 30
# average reward exploit: MDP 3 115.82099431125746 30
# average reward exploit: MDP 3 113.62683302720482 30
# average reward exploit: MDP 3 115.97472835062986 30
# average reward exploit: MDP 3 113.55202124043768 30
# average reward exploit: MDP 3 112.56467839887831 30
# average reward explore: 57.384598520070554
# average reward exploit: MDP 4 108.33783401972255 30
# average reward exploit: MDP 4 107.20958312600264 30
# average reward exploit: MDP 4 96.606698558552 30
# average reward exploit: MDP 4 94.76340076921981 30
# average reward exploit: MDP 4 95.03750175697861 30
# average reward exploit: MDP 4 97.62620562457491 30
# average reward exploit: MDP 4 97.55874777264495 30
# average reward exploit: MDP 4 103.82656167706229 30
# average reward exploit: MDP 4 106.74874124081475 30
# average reward exploit: MDP 4 107.61798199112913 30
# average reward explore: 55.44522103852402
# average reward exploit: MDP 5 97.57707892030976 30
# average reward exploit: MDP 5 97.35794309574439 30
# average reward exploit: MDP 5 97.14304035226478 30
# average reward exploit: MDP 5 96.75155723414983 30
# average reward exploit: MDP 5 97.95902305871641 30
# average reward exploit: MDP 5 98.16005921381894 30
# average reward exploit: MDP 5 98.43185242857135 30
# average reward exploit: MDP 5 97.15975616034534 30
# average reward exploit: MDP 5 96.42401201018356 30
# average reward exploit: MDP 5 98.07924893318658 30
# average reward explore: 52.21646807267904
# average reward exploit: MDP 6 98.82165005722794 30
# average reward exploit: MDP 6 95.56435337720399 30
# average reward exploit: MDP 6 95.24608281692635 30
# average reward exploit: MDP 6 95.8071353368924 30
# average reward exploit: MDP 6 95.54619788171735 30
# average reward exploit: MDP 6 95.44407900301914 30
# average reward exploit: MDP 6 95.6229492859077 30
# average reward exploit: MDP 6 95.79802683544504 30
# average reward exploit: MDP 6 95.43343485758274 30
# average reward exploit: MDP 6 95.57166426474525 30
# average reward explore: 51.28892453046739
# average reward exploit: MDP 7 94.21489287484887 30
# average reward exploit: MDP 7 96.11820816607673 30
# average reward exploit: MDP 7 97.88468446460715 30
# average reward exploit: MDP 7 96.00892673655298 30
# average reward exploit: MDP 7 96.12716678410534 30
# average reward exploit: MDP 7 96.48241450506478 30
# average reward exploit: MDP 7 96.24813420868895 30
# average reward exploit: MDP 7 96.01652621414208 30
# average reward exploit: MDP 7 95.96405186948728 30
# average reward exploit: MDP 7 95.17737462761467 30
# average reward explore: 47.25373436571855
# average reward exploit: MDP 8 90.05033383870487 30
# average reward exploit: MDP 8 89.57853329827023 30
# average reward exploit: MDP 8 89.4279724878001 30
# average reward exploit: MDP 8 89.59907276538287 30
# average reward exploit: MDP 8 89.44587505349607 30
# average reward exploit: MDP 8 90.1147829374416 30
# average reward exploit: MDP 8 89.74559003679441 30
# average reward exploit: MDP 8 89.09328108838302 30
# average reward exploit: MDP 8 89.73892630966608 30
# average reward exploit: MDP 8 89.5151367013691 30
# average reward explore: 44.243205152716186
# average reward exploit: MDP 9 82.07085848062562 30
# average reward exploit: MDP 9 81.01675669625315 30
# average reward exploit: MDP 9 83.54656440899343 30
# average reward exploit: MDP 9 83.82938596193863 30
# average reward exploit: MDP 9 81.31806137250523 30
# average reward exploit: MDP 9 82.21384733233934 30
# average reward exploit: MDP 9 81.62391777434465 30
# average reward exploit: MDP 9 81.67842504442687 30
# average reward exploit: MDP 9 81.48293255346807 30
# average reward exploit: MDP 9 82.33358313342347 30
# epoch number:  2
# average reward explore: 69.895467419692
# average reward exploit: MDP 0 135.9683992982834 30
# average reward exploit: MDP 0 135.60808246124455 30
# average reward exploit: MDP 0 135.36028652354761 30
# average reward exploit: MDP 0 137.22559346600733 30
# average reward exploit: MDP 0 136.35390349362368 30
# average reward exploit: MDP 0 136.73460809775685 30
# average reward exploit: MDP 0 135.19591444737932 30
# average reward exploit: MDP 0 135.60002114285518 30
# average reward exploit: MDP 0 115.16490614625383 30
# average reward exploit: MDP 0 117.87822475605736 30
# average reward explore: 66.74908315215795
# average reward exploit: MDP 1 108.09433928480422 30
# average reward exploit: MDP 1 96.86332782736835 30
# average reward exploit: MDP 1 99.64088114261186 30
# average reward exploit: MDP 1 97.39048888501056 30
# average reward exploit: MDP 1 90.93916656737932 30
# average reward exploit: MDP 1 75.71660087827298 30
# average reward exploit: MDP 1 76.74238513265723 30
# average reward exploit: MDP 1 67.31944522642502 30
# average reward exploit: MDP 1 68.38144919927325 30
# average reward exploit: MDP 1 68.46436153976506 30
# average reward explore: 66.77580018700144
# average reward exploit: MDP 2 67.39019031287458 30
# average reward exploit: MDP 2 66.79363909968737 30
# average reward exploit: MDP 2 69.47920193511324 30
# average reward exploit: MDP 2 70.25166243571411 30
# average reward exploit: MDP 2 69.54909101081954 30
# average reward exploit: MDP 2 68.57488174948564 30
# average reward exploit: MDP 2 68.48733666009865 30
# average reward exploit: MDP 2 62.7635240880908 30
# average reward exploit: MDP 2 63.32829363426897 30
# average reward exploit: MDP 2 68.67179572715175 30
# average reward explore: 66.18826506438238
# average reward exploit: MDP 3 61.077621186786274 30
# average reward exploit: MDP 3 57.27555582061768 30
# average reward exploit: MDP 3 58.38018222485955 30
# average reward exploit: MDP 3 58.38439970393665 30
# average reward exploit: MDP 3 58.39379022085688 30
# average reward exploit: MDP 3 61.02013181193111 30
# average reward exploit: MDP 3 59.54029024875953 30
# average reward exploit: MDP 3 58.887444229330434 30
# average reward exploit: MDP 3 59.35712989974505 30
# average reward exploit: MDP 3 58.586442648864356 30
# average reward explore: 63.153362441491524
# average reward exploit: MDP 4 58.44630942720642 30
# average reward exploit: MDP 4 58.40638391014446 30
# average reward exploit: MDP 4 58.434450850472196 30
# average reward exploit: MDP 4 58.480476183308646 30
# average reward exploit: MDP 4 58.40531706207045 30
# average reward exploit: MDP 4 58.069210660776974 30
# average reward exploit: MDP 4 57.72826087583459 30
# average reward exploit: MDP 4 58.07884986581317 30
# average reward exploit: MDP 4 57.81377137492566 30
# average reward exploit: MDP 4 56.63216375790273 30
# average reward explore: 59.94463177117862
# average reward exploit: MDP 5 54.91796915531437 30
# average reward exploit: MDP 5 54.31368368851421 30
# average reward exploit: MDP 5 53.829736114149654 30
# average reward exploit: MDP 5 53.782077451389654 30
# average reward exploit: MDP 5 53.760168238934156 30
# average reward exploit: MDP 5 53.821895109146894 30
# average reward exploit: MDP 5 53.80778288054234 30
# average reward exploit: MDP 5 53.8103215166913 30
# average reward exploit: MDP 5 53.818226358456805 30
# average reward exploit: MDP 5 53.80376691998945 30
# average reward explore: 57.85419957889103
# average reward exploit: MDP 6 53.05043488227522 30
# average reward exploit: MDP 6 52.41668623804635 30
# average reward exploit: MDP 6 52.887684664973364 30
# average reward exploit: MDP 6 52.01281947902108 30
# average reward exploit: MDP 6 48.39707862434962 30
# average reward exploit: MDP 6 48.389910977269864 30
# average reward exploit: MDP 6 48.40868323499755 30
# average reward exploit: MDP 6 48.43057285791378 30
# average reward exploit: MDP 6 48.40780249242255 30
# average reward exploit: MDP 6 48.460048643676615 30
# average reward explore: 56.38677363699776
# average reward exploit: MDP 7 47.9723495373538 30
# average reward exploit: MDP 7 48.750587267895455 30
# average reward exploit: MDP 7 48.64128117561089 30
# average reward exploit: MDP 7 48.894319707969466 30
# average reward exploit: MDP 7 49.56007480652748 30
# average reward exploit: MDP 7 49.273619215798256 30
# average reward exploit: MDP 7 49.11260343738616 30
# average reward exploit: MDP 7 49.74352757732549 30
# average reward exploit: MDP 7 50.07691834041681 30
# average reward exploit: MDP 7 49.91723107874019 30
# average reward explore: 54.95732690363162
# average reward exploit: MDP 8 49.0284619589495 30
# average reward exploit: MDP 8 49.04497253509475 30
# average reward exploit: MDP 8 49.02587873945544 30
# average reward exploit: MDP 8 49.07161217721684 30
# average reward exploit: MDP 8 49.05479929612063 30
# average reward exploit: MDP 8 49.05452993504193 30
# average reward exploit: MDP 8 49.06855779301691 30
# average reward exploit: MDP 8 49.04165918257356 30
# average reward exploit: MDP 8 49.03766758478753 30
# average reward exploit: MDP 8 49.0386046960156 30
# average reward explore: 53.328812937385955
# average reward exploit: MDP 9 49.01520003413212 30
# average reward exploit: MDP 9 48.981718909264 30
# average reward exploit: MDP 9 48.99994767560544 30
# average reward exploit: MDP 9 49.015411823304795 30
# average reward exploit: MDP 9 48.98768320720013 30
# average reward exploit: MDP 9 48.998675166760876 30
# average reward exploit: MDP 9 48.97631813856061 30
# average reward exploit: MDP 9 48.98356888138383 30
# average reward exploit: MDP 9 49.04473449566569 30
# average reward exploit: MDP 9 48.98695784681199 30
# epoch number:  3
# average reward explore: 81.89384749909992
# average reward exploit: MDP 0 71.2346432749161 30
# average reward exploit: MDP 0 70.28655539223102 30
# average reward exploit: MDP 0 70.77535255736056 30
# average reward exploit: MDP 0 70.5225059208699 30
# average reward exploit: MDP 0 70.23771475628105 30
# average reward exploit: MDP 0 68.8419965769967 30
# average reward exploit: MDP 0 70.20093058808654 30
# average reward exploit: MDP 0 71.57894717266548 30
# average reward exploit: MDP 0 70.3250963406393 30
# average reward exploit: MDP 0 71.42248928948986 30
# average reward explore: 76.49678503106965
# average reward exploit: MDP 1 64.30695015566421 30
# average reward exploit: MDP 1 65.19956960400094 30
# average reward exploit: MDP 1 65.66769183548828 30
# average reward exploit: MDP 1 65.25067991138073 30
# average reward exploit: MDP 1 65.70122196534608 30
# average reward exploit: MDP 1 66.46278522136515 30
# average reward exploit: MDP 1 65.36212339360448 30
# average reward exploit: MDP 1 65.41388453472156 30
# average reward exploit: MDP 1 65.26679014020532 30
# average reward exploit: MDP 1 65.88582610226936 30
# average reward explore: 72.55635583432122
# average reward exploit: MDP 2 61.965552169318244 30
# average reward exploit: MDP 2 61.63536548700211 30
# average reward exploit: MDP 2 61.98168351204791 30
# average reward exploit: MDP 2 63.815925199403345 30
# average reward exploit: MDP 2 64.28067466988401 30
# average reward exploit: MDP 2 64.85607149284351 30
# average reward exploit: MDP 2 65.13104788326226 30
# average reward exploit: MDP 2 64.42764253212496 30
# average reward exploit: MDP 2 67.68886038539924 30
# average reward exploit: MDP 2 69.26438465118167 30
# average reward explore: 68.22895331631665
# average reward exploit: MDP 3 62.25704661490535 30
# average reward exploit: MDP 3 61.46060577606858 30
# average reward exploit: MDP 3 62.36438384648481 30
# average reward exploit: MDP 3 61.74635549667611 30
# average reward exploit: MDP 3 61.63982630282869 30
# average reward exploit: MDP 3 62.395293312557556 30
# average reward exploit: MDP 3 61.955088446054795 30
# average reward exploit: MDP 3 58.45833494753982 30
# average reward exploit: MDP 3 58.48616513738295 30
# average reward exploit: MDP 3 58.538388038559134 30
# average reward explore: 65.24607377728195
# average reward exploit: MDP 4 54.57186590445569 30
# average reward exploit: MDP 4 54.25570703450658 30
# average reward exploit: MDP 4 54.57972843084884 30
# average reward exploit: MDP 4 54.560491426641356 30
# average reward exploit: MDP 4 54.713664715248406 30
# average reward exploit: MDP 4 54.41440851444167 30
# average reward exploit: MDP 4 54.74524513709344 30
# average reward exploit: MDP 4 54.426631446115486 30
# average reward exploit: MDP 4 55.20990080514423 30
# average reward exploit: MDP 4 54.882848148371444 30
# average reward explore: 64.16268254347766
# average reward exploit: MDP 5 53.92627703032609 30
# average reward exploit: MDP 5 54.690707385718426 30
# average reward exploit: MDP 5 54.18843694646333 30
# average reward exploit: MDP 5 53.88295990237295 30
# average reward exploit: MDP 5 53.96054513388007 30
# average reward exploit: MDP 5 54.086523733609916 30
# average reward exploit: MDP 5 53.62127522480907 30
# average reward exploit: MDP 5 53.59496267283108 30
# average reward exploit: MDP 5 53.6458951645729 30
# average reward exploit: MDP 5 53.631455259204465 30
# average reward explore: 59.88006701940556
# average reward exploit: MDP 6 53.659700764386585 30
# average reward exploit: MDP 6 53.61462894856108 30
# average reward exploit: MDP 6 53.65117041947708 30
# average reward exploit: MDP 6 53.62233213818529 30
# average reward exploit: MDP 6 53.656040936168026 30
# average reward exploit: MDP 6 53.64719550040868 30
# average reward exploit: MDP 6 51.41018350757799 30
# average reward exploit: MDP 6 51.11598146698416 30
# average reward exploit: MDP 6 51.274656390407664 30
# average reward exploit: MDP 6 52.20538270296052 30
# average reward explore: 57.62445441311422
# average reward exploit: MDP 7 53.552714406854115 30
# average reward exploit: MDP 7 53.30172621460785 30
# average reward exploit: MDP 7 52.981718665060264 30
# average reward exploit: MDP 7 53.55227848293461 30
# average reward exploit: MDP 7 53.549992369700796 30
# average reward exploit: MDP 7 52.605849305693276 30
# average reward exploit: MDP 7 51.07239822409109 30
# average reward exploit: MDP 7 52.26165900483144 30
# average reward exploit: MDP 7 52.583418220819 30
# average reward exploit: MDP 7 52.566042144399276 30
# average reward explore: 56.40542904381996
# average reward exploit: MDP 8 49.153568551021635 30
# average reward exploit: MDP 8 49.15819818333032 30
# average reward exploit: MDP 8 49.13011940264477 30
# average reward exploit: MDP 8 49.15681876658236 30
# average reward exploit: MDP 8 49.17273380643537 30
# average reward exploit: MDP 8 49.13712779538541 30
# average reward exploit: MDP 8 49.15311714385601 30
# average reward exploit: MDP 8 49.16506278207114 30
# average reward exploit: MDP 8 49.170833757411174 30
# average reward exploit: MDP 8 49.16858880406839 30
# average reward explore: 55.0614760538125
# average reward exploit: MDP 9 48.82825709444091 30
# average reward exploit: MDP 9 48.845675494236964 30
# average reward exploit: MDP 9 48.86909769036536 30
# average reward exploit: MDP 9 48.832821775790265 30
# average reward exploit: MDP 9 48.84947922228062 30
# average reward exploit: MDP 9 48.84211542827641 30
# average reward exploit: MDP 9 48.80347466376144 30
# average reward exploit: MDP 9 48.89068570568441 30
# average reward exploit: MDP 9 48.90481623103083 30
# average reward exploit: MDP 9 48.91110917043975 30
# epoch number:  4
# average reward explore: 82.63959313775159
# average reward exploit: MDP 0 71.03366814642146 30
# average reward exploit: MDP 0 70.28551838060156 30
# average reward exploit: MDP 0 70.96674448924568 30
# average reward exploit: MDP 0 68.69307834264227 30
# average reward exploit: MDP 0 68.9933181793735 30
# average reward exploit: MDP 0 69.31796700596718 30
# average reward exploit: MDP 0 69.65619841015213 30
# average reward exploit: MDP 0 68.83016154621693 30
# average reward exploit: MDP 0 68.50728249632819 30
# average reward exploit: MDP 0 67.45306913016617 30
# average reward explore: 77.8329197473116
# average reward exploit: MDP 1 59.79817073088632 30
# average reward exploit: MDP 1 60.979474225387115 30
# average reward exploit: MDP 1 59.738502282314585 30
# average reward exploit: MDP 1 61.16273233042004 30
# average reward exploit: MDP 1 59.847843825043654 30
# average reward exploit: MDP 1 61.13206642713168 30
# average reward exploit: MDP 1 60.55722475022942 30
# average reward exploit: MDP 1 59.08260031501418 30
# average reward exploit: MDP 1 59.59282643620523 30
# average reward exploit: MDP 1 60.70062416556451 30
# average reward explore: 73.24879771804905
# average reward exploit: MDP 2 62.40885449499271 30
# average reward exploit: MDP 2 61.910578928437026 30
# average reward exploit: MDP 2 62.232979202105774 30
# average reward exploit: MDP 2 61.76937475693357 30
# average reward exploit: MDP 2 61.56639203130761 30
# average reward exploit: MDP 2 61.762036940691885 30
# average reward exploit: MDP 2 61.56738936894697 30
# average reward exploit: MDP 2 62.34046993742022 30
# average reward exploit: MDP 2 61.761641004594146 30
# average reward exploit: MDP 2 60.658927941497595 30
# average reward explore: 69.0898465032566
# average reward exploit: MDP 3 54.48995345971036 30
# average reward exploit: MDP 3 55.20833301060072 30
# average reward exploit: MDP 3 54.70184797387171 30
# average reward exploit: MDP 3 54.408097039777246 30
# average reward exploit: MDP 3 55.32371868482796 30
# average reward exploit: MDP 3 55.48336869525019 30
# average reward exploit: MDP 3 57.848729350212835 30
# average reward exploit: MDP 3 58.20614925829715 30
# average reward exploit: MDP 3 55.45585517115161 30
# average reward exploit: MDP 3 54.592591828267324 30
# average reward explore: 65.66413584280895
# average reward exploit: MDP 4 53.224994412488385 30
# average reward exploit: MDP 4 52.570537820315934 30
# average reward exploit: MDP 4 52.91795535017529 30
# average reward exploit: MDP 4 52.94277566161709 30
# average reward exploit: MDP 4 52.89045764120508 30
# average reward exploit: MDP 4 52.83260943217138 30
# average reward exploit: MDP 4 52.451106552446625 30
# average reward exploit: MDP 4 52.42036412047077 30
# average reward exploit: MDP 4 51.875005268701734 30
# average reward exploit: MDP 4 52.82398235024883 30
# average reward explore: 63.933107610325784
# average reward exploit: MDP 5 51.11134724537389 30
# average reward exploit: MDP 5 51.378204326913504 30
# average reward exploit: MDP 5 50.894521301115915 30
# average reward exploit: MDP 5 51.55437040849117 30
# average reward exploit: MDP 5 50.65754005266491 30
# average reward exploit: MDP 5 50.19004309521834 30
# average reward exploit: MDP 5 51.2355832265118 30
# average reward exploit: MDP 5 51.22204190752637 30
# average reward exploit: MDP 5 51.7334290097888 30
# average reward exploit: MDP 5 50.29785398781415 30
# average reward explore: 62.1257571773232
# average reward exploit: MDP 6 48.06396829335037 30
# average reward exploit: MDP 6 47.92708441193481 30
# average reward exploit: MDP 6 47.92102995895219 30
# average reward exploit: MDP 6 47.68794748679007 30
# average reward exploit: MDP 6 47.556627178292985 30
# average reward exploit: MDP 6 47.69049678161364 30
# average reward exploit: MDP 6 47.274543470889164 30
# average reward exploit: MDP 6 48.12017134749102 30
# average reward exploit: MDP 6 47.5015998070435 30
# average reward exploit: MDP 6 47.31047118779914 30
# average reward explore: 57.495945615330825
# average reward exploit: MDP 7 48.05007516528159 30
# average reward exploit: MDP 7 47.57307386849486 30
# average reward exploit: MDP 7 47.921060714551615 30
# average reward exploit: MDP 7 47.73317215850701 30
# average reward exploit: MDP 7 47.73261395898889 30
# average reward exploit: MDP 7 47.887513905871465 30
# average reward exploit: MDP 7 47.709655073510724 30
# average reward exploit: MDP 7 47.36276634700949 30
# average reward exploit: MDP 7 47.9105393527592 30
# average reward exploit: MDP 7 47.5309200980958 30
# average reward explore: 56.929953898537164
# average reward exploit: MDP 8 46.42775329227944 30
# average reward exploit: MDP 8 46.73786502983512 30
# average reward exploit: MDP 8 45.86551646217069 30
# average reward exploit: MDP 8 46.1916642830795 30
# average reward exploit: MDP 8 46.176840916304506 30
# average reward exploit: MDP 8 45.99166603247959 30
# average reward exploit: MDP 8 46.28883438334374 30
# average reward exploit: MDP 8 46.20988837501027 30
# average reward exploit: MDP 8 46.399502360569315 30
# average reward exploit: MDP 8 45.9932009235259 30
# average reward explore: 55.675447391142754
# average reward exploit: MDP 9 44.298409133235964 30
# average reward exploit: MDP 9 44.28442135993578 30
# average reward exploit: MDP 9 44.33102462606853 30
# average reward exploit: MDP 9 44.452368141019335 30
# average reward exploit: MDP 9 44.54335734372997 30
# average reward exploit: MDP 9 44.44991729203877 30
# average reward exploit: MDP 9 44.32472371524396 30
# average reward exploit: MDP 9 44.30002970720721 30
# average reward exploit: MDP 9 44.27569479838412 30
# average reward exploit: MDP 9 44.39493991231418 30
# epoch number:  5
# average reward explore: 83.60656535233235
# average reward exploit: MDP 0 66.5479570454992 30
# average reward exploit: MDP 0 66.63836839522588 30
# average reward exploit: MDP 0 66.53690081858764 30
# average reward exploit: MDP 0 66.83572028334244 30
# average reward exploit: MDP 0 67.30197371324792 30
# average reward exploit: MDP 0 66.5701494521497 30
# average reward exploit: MDP 0 66.09364838442788 30
# average reward exploit: MDP 0 66.85433876614817 30
# average reward exploit: MDP 0 66.80856263405816 30
# average reward exploit: MDP 0 66.47928486218994 30
# average reward explore: 77.9960521130988
# average reward exploit: MDP 1 60.74016192300194 30
# average reward exploit: MDP 1 60.61961103487421 30
# average reward exploit: MDP 1 61.80645310309023 30
# average reward exploit: MDP 1 63.33480323969949 30
# average reward exploit: MDP 1 63.508746346807314 30
# average reward exploit: MDP 1 63.16524126960156 30
# average reward exploit: MDP 1 63.42178461252018 30
# average reward exploit: MDP 1 63.86006574972704 30
# average reward exploit: MDP 1 63.986345784473585 30
# average reward exploit: MDP 1 64.04037448836308 30
# average reward explore: 73.09868751294711
# average reward exploit: MDP 2 58.571297690125625 30
# average reward exploit: MDP 2 59.750775534648355 30
# average reward exploit: MDP 2 58.714143505038464 30
# average reward exploit: MDP 2 59.1119493528375 30
# average reward exploit: MDP 2 60.07665485897776 30
# average reward exploit: MDP 2 59.54988334346059 30
# average reward exploit: MDP 2 58.5439813995169 30
# average reward exploit: MDP 2 58.70781011176032 30
# average reward exploit: MDP 2 59.429998894058684 30
# average reward exploit: MDP 2 60.3805989276167 30
# average reward explore: 69.86341292748853
# average reward exploit: MDP 3 56.24729238847646 30
# average reward exploit: MDP 3 55.68476065912238 30
# average reward exploit: MDP 3 54.77933386023838 30
# average reward exploit: MDP 3 54.83142586550074 30
# average reward exploit: MDP 3 55.75768262206004 30
# average reward exploit: MDP 3 55.61890648067258 30
# average reward exploit: MDP 3 56.08814972331627 30
# average reward exploit: MDP 3 56.26127508013844 30
# average reward exploit: MDP 3 56.021775730772916 30
# average reward exploit: MDP 3 56.10279525691474 30
# average reward explore: 69.2655602744685
# average reward exploit: MDP 4 52.90066669593437 30
# average reward exploit: MDP 4 52.8128240295977 30
# average reward exploit: MDP 4 51.237508362717115 30
# average reward exploit: MDP 4 52.639081591799886 30
# average reward exploit: MDP 4 52.25111560193402 30
# average reward exploit: MDP 4 52.46264888655006 30
# average reward exploit: MDP 4 52.236042955395156 30
# average reward exploit: MDP 4 52.99577099995478 30
# average reward exploit: MDP 4 52.69028914788694 30
# average reward exploit: MDP 4 52.81004587534826 30
# average reward explore: 64.67088754396129
# average reward exploit: MDP 5 50.522185320792815 30
# average reward exploit: MDP 5 51.28832586925207 30
# average reward exploit: MDP 5 50.03527408690094 30
# average reward exploit: MDP 5 51.39557652918104 30
# average reward exploit: MDP 5 51.008795337027564 30
# average reward exploit: MDP 5 50.91386176981941 30
# average reward exploit: MDP 5 50.52359154218541 30
# average reward exploit: MDP 5 50.5099158145974 30
# average reward exploit: MDP 5 50.07750002060266 30
# average reward exploit: MDP 5 50.976338456116345 30
# average reward explore: 62.840540616446894
# average reward exploit: MDP 6 47.957689784431196 30
# average reward exploit: MDP 6 47.876832330916635 30
# average reward exploit: MDP 6 47.68672116406773 30
# average reward exploit: MDP 6 46.30356289283404 30
# average reward exploit: MDP 6 48.28963682691032 30
# average reward exploit: MDP 6 48.26570899356037 30
# average reward exploit: MDP 6 48.691005136365646 30
# average reward exploit: MDP 6 48.32991250526301 30
# average reward exploit: MDP 6 48.32302245022288 30
# average reward exploit: MDP 6 48.89779782949291 30
# average reward explore: 58.73422132212215
# average reward exploit: MDP 7 47.62900672604057 30
# average reward exploit: MDP 7 47.54212189174179 30
# average reward exploit: MDP 7 47.570336728229584 30
# average reward exploit: MDP 7 47.6409367103748 30
# average reward exploit: MDP 7 47.56902452632004 30
# average reward exploit: MDP 7 47.57294304627969 30
# average reward exploit: MDP 7 47.46109043764498 30
# average reward exploit: MDP 7 47.547946425859 30
# average reward exploit: MDP 7 47.55644015158437 30
# average reward exploit: MDP 7 47.52557478225012 30
# average reward explore: 56.48957704902676
# average reward exploit: MDP 8 47.566631472833116 30
# average reward exploit: MDP 8 47.429588834737686 30
# average reward exploit: MDP 8 47.61244676965168 30
# average reward exploit: MDP 8 47.66496236509622 30
# average reward exploit: MDP 8 47.6479297896435 30
# average reward exploit: MDP 8 47.68058152714328 30
# average reward exploit: MDP 8 47.544555470686724 30
# average reward exploit: MDP 8 47.49790817868996 30
# average reward exploit: MDP 8 47.0736296614695 30
# average reward exploit: MDP 8 46.99984108882355 30
# average reward explore: 55.2217538131603
# average reward exploit: MDP 9 44.15875819528311 30
# average reward exploit: MDP 9 44.32430036725562 30
# average reward exploit: MDP 9 45.261324468493164 30
# average reward exploit: MDP 9 43.87523388186061 30
# average reward exploit: MDP 9 44.85740674424618 30
# average reward exploit: MDP 9 45.05557786045133 30
# average reward exploit: MDP 9 44.67317379482956 30
# average reward exploit: MDP 9 45.64198274423094 30
# average reward exploit: MDP 9 44.64079683065837 30
# average reward exploit: MDP 9 44.89994515779729 30
# epoch number:  6
# average reward explore: 83.07040747490943
# average reward exploit: MDP 0 92.88432619783582 30
# average reward exploit: MDP 0 93.38040797132786 30
# average reward exploit: MDP 0 93.41461219111642 30
# average reward exploit: MDP 0 93.99440564312984 30
# average reward exploit: MDP 0 93.95803026987466 30
# average reward exploit: MDP 0 87.76285248932255 30
# average reward exploit: MDP 0 83.05423236633432 30
# average reward exploit: MDP 0 83.81528665441506 30
# average reward exploit: MDP 0 83.83455980408257 30
# average reward exploit: MDP 0 80.75019263658743 30
# average reward explore: 77.05331887011576
# average reward exploit: MDP 1 82.28441363122654 30
# average reward exploit: MDP 1 81.94685584440448 30
# average reward exploit: MDP 1 81.77758445688173 30
# average reward exploit: MDP 1 82.0749375855068 30
# average reward exploit: MDP 1 82.41621347813104 30
# average reward exploit: MDP 1 81.66915226250066 30
# average reward exploit: MDP 1 81.620460489529 30
# average reward exploit: MDP 1 81.80290403807902 30
# average reward exploit: MDP 1 81.16907176678232 30
# average reward exploit: MDP 1 76.258660493649 30
# average reward explore: 72.94704530636743
# average reward exploit: MDP 2 58.823037313254034 30
# average reward exploit: MDP 2 60.12785437877417 30
# average reward exploit: MDP 2 60.582192205110985 30
# average reward exploit: MDP 2 59.73319117817978 30
# average reward exploit: MDP 2 59.61982059637147 30
# average reward exploit: MDP 2 59.99026691612734 30
# average reward exploit: MDP 2 59.319641993445835 30
# average reward exploit: MDP 2 58.86952596042452 30
# average reward exploit: MDP 2 58.198756681650394 30
# average reward exploit: MDP 2 58.813938226285764 30
# average reward explore: 68.75400098157341
# average reward exploit: MDP 3 55.819059703709854 30
# average reward exploit: MDP 3 56.08667274773597 30
# average reward exploit: MDP 3 56.38350836166619 30
# average reward exploit: MDP 3 54.76797077726834 30
# average reward exploit: MDP 3 55.91936718068452 30
# average reward exploit: MDP 3 55.275607223538486 30
# average reward exploit: MDP 3 56.45312985823023 30
# average reward exploit: MDP 3 55.38617593842168 30
# average reward exploit: MDP 3 56.15444800983112 30
# average reward exploit: MDP 3 55.39337213448118 30
# average reward explore: 67.97074645058447
# average reward exploit: MDP 4 57.58726604846327 30
# average reward exploit: MDP 4 58.23615507552164 30
# average reward exploit: MDP 4 57.71759954028466 30
# average reward exploit: MDP 4 57.51051814595137 30
# average reward exploit: MDP 4 56.58461990090009 30
# average reward exploit: MDP 4 56.314692464114884 30
# average reward exploit: MDP 4 53.778041396181266 30
# average reward exploit: MDP 4 53.79564213336282 30
# average reward exploit: MDP 4 53.81089311815274 30
# average reward exploit: MDP 4 53.79643494845274 30
# average reward explore: 63.90517888504323
# average reward exploit: MDP 5 53.622578377001425 30
# average reward exploit: MDP 5 53.68391931007268 30
# average reward exploit: MDP 5 53.668419874617946 30
# average reward exploit: MDP 5 53.627396426147236 30
# average reward exploit: MDP 5 53.65351099471365 30
# average reward exploit: MDP 5 53.62042517906803 30
# average reward exploit: MDP 5 53.64908432560494 30
# average reward exploit: MDP 5 53.66368776633423 30
# average reward exploit: MDP 5 53.678170230771634 30
# average reward exploit: MDP 5 53.64578959429146 30
# average reward explore: 61.72028107723892
# average reward exploit: MDP 6 47.53535003926554 30
# average reward exploit: MDP 6 47.83469900636876 30
# average reward exploit: MDP 6 47.486645370202424 30
# average reward exploit: MDP 6 47.17209997669458 30
# average reward exploit: MDP 6 47.15586479863414 30
# average reward exploit: MDP 6 47.573078769281956 30
# average reward exploit: MDP 6 48.12200658889482 30
# average reward exploit: MDP 6 47.77916257282646 30
# average reward exploit: MDP 6 46.966492699252896 30
# average reward exploit: MDP 6 47.82722195084619 30
# average reward explore: 56.43190554600151
# average reward exploit: MDP 7 50.5511102521647 30
# average reward exploit: MDP 7 50.36633924491749 30
# average reward exploit: MDP 7 49.786284781061745 30
# average reward exploit: MDP 7 49.62582542081916 30
# average reward exploit: MDP 7 50.43032898972463 30
# average reward exploit: MDP 7 49.50250906204497 30
# average reward exploit: MDP 7 50.412647680400816 30
# average reward exploit: MDP 7 49.95247103899882 30
# average reward exploit: MDP 7 49.78241541136016 30
# average reward exploit: MDP 7 50.2602926915599 30
# average reward explore: 54.73072279094664
# average reward exploit: MDP 8 49.157614379145436 30
# average reward exploit: MDP 8 49.150258237549004 30
# average reward exploit: MDP 8 49.17168354478372 30
# average reward exploit: MDP 8 49.17030475407817 30
# average reward exploit: MDP 8 49.201293649384816 30
# average reward exploit: MDP 8 49.16544696760113 30
# average reward exploit: MDP 8 49.16925530158993 30
# average reward exploit: MDP 8 49.210195097108716 30
# average reward exploit: MDP 8 49.19041594980265 30
# average reward exploit: MDP 8 49.184281064628884 30
# average reward explore: 53.843748172187276
# average reward exploit: MDP 9 49.157188291751986 30
# average reward exploit: MDP 9 49.155554199583925 30
# average reward exploit: MDP 9 49.13830019701361 30
# average reward exploit: MDP 9 49.15120095612959 30
# average reward exploit: MDP 9 49.127908253756225 30
# average reward exploit: MDP 9 49.171017617590856 30
# average reward exploit: MDP 9 49.15624629302694 30
# average reward exploit: MDP 9 49.15767213318488 30
# average reward exploit: MDP 9 49.20582815583602 30
# average reward exploit: MDP 9 49.159866839732416 30
# epoch number:  7
# average reward explore: 79.84077182379563
# average reward exploit: MDP 0 71.85827918501631 30
# average reward exploit: MDP 0 71.70255853441999 30
# average reward exploit: MDP 0 70.79116475229502 30
# average reward exploit: MDP 0 71.94398461211742 30
# average reward exploit: MDP 0 71.82440122191356 30
# average reward exploit: MDP 0 70.39669271893169 30
# average reward exploit: MDP 0 70.7341832447546 30
# average reward exploit: MDP 0 69.74543244158691 30
# average reward exploit: MDP 0 71.31365030616458 30
# average reward exploit: MDP 0 68.26757941493075 30
# average reward explore: 74.67190831648168
# average reward exploit: MDP 1 65.51955640690474 30
# average reward exploit: MDP 1 65.40451917938934 30
# average reward exploit: MDP 1 65.11047257524825 30
# average reward exploit: MDP 1 66.78251500454074 30
# average reward exploit: MDP 1 65.87253242657587 30
# average reward exploit: MDP 1 65.99068093327611 30
# average reward exploit: MDP 1 65.99695680582238 30
# average reward exploit: MDP 1 65.1969827079967 30
# average reward exploit: MDP 1 65.3532284362422 30
# average reward exploit: MDP 1 65.37493256027933 30
# average reward explore: 73.69936384703048
# average reward exploit: MDP 2 62.05373742705367 30
# average reward exploit: MDP 2 62.17448713341759 30
# average reward exploit: MDP 2 61.90530092797567 30
# average reward exploit: MDP 2 61.91074611530616 30
# average reward exploit: MDP 2 61.93708118618408 30
# average reward exploit: MDP 2 62.41199513652496 30
# average reward exploit: MDP 2 62.08465324420172 30
# average reward exploit: MDP 2 61.892386846704994 30
# average reward exploit: MDP 2 61.08907480832105 30
# average reward exploit: MDP 2 62.209996067209886 30
# average reward explore: 70.22532595924511
# average reward exploit: MDP 3 58.36966409837017 30
# average reward exploit: MDP 3 58.42455285922905 30
# average reward exploit: MDP 3 58.474908751280886 30
# average reward exploit: MDP 3 58.54859701556936 30
# average reward exploit: MDP 3 58.65798822088808 30
# average reward exploit: MDP 3 59.863748986677685 30
# average reward exploit: MDP 3 61.7522082688274 30
# average reward exploit: MDP 3 61.1294177114382 30
# average reward exploit: MDP 3 62.24771396195696 30
# average reward exploit: MDP 3 62.12354296009548 30
# average reward explore: 68.76127394420395
# average reward exploit: MDP 4 58.18784440215668 30
# average reward exploit: MDP 4 58.002565720865036 30
# average reward exploit: MDP 4 53.715575727645486 30
# average reward exploit: MDP 4 56.09300642818838 30
# average reward exploit: MDP 4 54.866451681682555 30
# average reward exploit: MDP 4 58.016452690740465 30
# average reward exploit: MDP 4 57.91725460699533 30
# average reward exploit: MDP 4 57.87350790515076 30
# average reward exploit: MDP 4 58.13792982011311 30
# average reward exploit: MDP 4 58.58337608492526 30
# average reward explore: 65.6527473892298
# average reward exploit: MDP 5 53.88986251226899 30
# average reward exploit: MDP 5 53.901609550300286 30
# average reward exploit: MDP 5 53.87624203807219 30
# average reward exploit: MDP 5 53.897635446921846 30
# average reward exploit: MDP 5 53.86422104763445 30
# average reward exploit: MDP 5 53.87269160136109 30
# average reward exploit: MDP 5 53.906427515951655 30
# average reward exploit: MDP 5 53.87413375619406 30
# average reward exploit: MDP 5 53.88747513484306 30
# average reward exploit: MDP 5 53.87756944435451 30
# average reward explore: 63.075738786275515
# average reward exploit: MDP 6 53.342609179732946 30
# average reward exploit: MDP 6 53.81771469274937 30
# average reward exploit: MDP 6 54.611349462142115 30
# average reward exploit: MDP 6 54.637619883568924 30
# average reward exploit: MDP 6 53.86478795382114 30
# average reward exploit: MDP 6 54.529636575466014 30
# average reward exploit: MDP 6 54.08079963673208 30
# average reward exploit: MDP 6 53.88902517970143 30
# average reward exploit: MDP 6 54.23142782545781 30
# average reward exploit: MDP 6 54.23108762209517 30
# average reward explore: 61.318864345849065
# average reward exploit: MDP 7 50.10995774665898 30
# average reward exploit: MDP 7 51.827893559996305 30
# average reward exploit: MDP 7 52.74858041676723 30
# average reward exploit: MDP 7 52.67918295825544 30
# average reward exploit: MDP 7 52.62473513331576 30
# average reward exploit: MDP 7 52.47215138717582 30
# average reward exploit: MDP 7 52.38796509126009 30
# average reward exploit: MDP 7 53.91408090895413 30
# average reward exploit: MDP 7 53.8222949062664 30
# average reward exploit: MDP 7 53.92964690280728 30
# average reward explore: 57.88441025740473
# average reward exploit: MDP 8 53.586183069821594 30
# average reward exploit: MDP 8 52.62475821445344 30
# average reward exploit: MDP 8 53.24405247991155 30
# average reward exploit: MDP 8 52.63435029768331 30
# average reward exploit: MDP 8 52.61606261713935 30
# average reward exploit: MDP 8 52.779781396786134 30
# average reward exploit: MDP 8 52.9305689451477 30
# average reward exploit: MDP 8 53.04604924875961 30
# average reward exploit: MDP 8 52.93909031539083 30
# average reward exploit: MDP 8 52.31365585867828 30
# average reward explore: 57.394319898021806
# average reward exploit: MDP 9 49.59926358932799 30
# average reward exploit: MDP 9 50.082788589724274 30
# average reward exploit: MDP 9 49.29222397752214 30
# average reward exploit: MDP 9 49.340811965042384 30
# average reward exploit: MDP 9 49.472472664427166 30
# average reward exploit: MDP 9 49.471733748285935 30
# average reward exploit: MDP 9 49.33065679186534 30
# average reward exploit: MDP 9 49.33353083336123 30
# average reward exploit: MDP 9 49.45416709290557 30
# average reward exploit: MDP 9 49.34038953865575 30
# epoch number:  8
# average reward explore: 83.25060039822641
# average reward exploit: MDP 0 93.95697150814941 30
# average reward exploit: MDP 0 94.41453822673948 30
# average reward exploit: MDP 0 93.26369378226383 30
# average reward exploit: MDP 0 94.0203265235562 30
# average reward exploit: MDP 0 94.61296789149351 30
# average reward exploit: MDP 0 93.66583750180965 30
# average reward exploit: MDP 0 93.12996407043339 30
# average reward exploit: MDP 0 93.58906577695889 30
# average reward exploit: MDP 0 94.25311491711894 30
# average reward exploit: MDP 0 93.47523800368201 30
# average reward explore: 77.49596349969325
# average reward exploit: MDP 1 82.06677388506245 30
# average reward exploit: MDP 1 85.53602266623305 30
# average reward exploit: MDP 1 84.7597734643102 30
# average reward exploit: MDP 1 85.33406409933265 30
# average reward exploit: MDP 1 87.20651163177637 30
# average reward exploit: MDP 1 83.88624595617739 30
# average reward exploit: MDP 1 83.99036855592031 30
# average reward exploit: MDP 1 83.66358467160343 30
# average reward exploit: MDP 1 86.69584431716173 30
# average reward exploit: MDP 1 85.11863888808087 30
# average reward explore: 73.1613286452684
# average reward exploit: MDP 2 73.09213437340888 30
# average reward exploit: MDP 2 73.58534981500087 30
# average reward exploit: MDP 2 73.90160120032562 30
# average reward exploit: MDP 2 74.67817170640028 30
# average reward exploit: MDP 2 73.7842287309257 30
# average reward exploit: MDP 2 73.50905111932337 30
# average reward exploit: MDP 2 73.73764403857966 30
# average reward exploit: MDP 2 73.61945206600961 30
# average reward exploit: MDP 2 73.92486455465594 30
# average reward exploit: MDP 2 73.8973269448382 30
# average reward explore: 70.99383528185446
# average reward exploit: MDP 3 67.29568565392127 30
# average reward exploit: MDP 3 70.78615583344315 30
# average reward exploit: MDP 3 73.3855418562923 30
# average reward exploit: MDP 3 74.5935058413006 30
# average reward exploit: MDP 3 75.46714950694818 30
# average reward exploit: MDP 3 74.20248335124869 30
# average reward exploit: MDP 3 77.06246603131656 30
# average reward exploit: MDP 3 77.39229882174386 30
# average reward exploit: MDP 3 77.5388519122745 30
# average reward exploit: MDP 3 77.2154341010602 30
# average reward explore: 67.11861313231519
# average reward exploit: MDP 4 68.41802372793993 30
# average reward exploit: MDP 4 67.93486569663266 30
# average reward exploit: MDP 4 68.09257689792875 30
# average reward exploit: MDP 4 70.26992542177835 30
# average reward exploit: MDP 4 70.84120238381044 30
# average reward exploit: MDP 4 69.49184075200505 30
# average reward exploit: MDP 4 68.70979537104827 30
# average reward exploit: MDP 4 68.43144990218074 30
# average reward exploit: MDP 4 68.8088332470377 30
# average reward exploit: MDP 4 70.91859164313928 30
# average reward explore: 64.42014452657511
# average reward exploit: MDP 5 60.92300514116712 30
# average reward exploit: MDP 5 59.32618502949514 30
# average reward exploit: MDP 5 59.328434285611465 30
# average reward exploit: MDP 5 61.98867271303188 30
# average reward exploit: MDP 5 64.67879550301346 30
# average reward exploit: MDP 5 70.80282249570637 30
# average reward exploit: MDP 5 77.95436991561907 30
# average reward exploit: MDP 5 75.48044024120283 30
# average reward exploit: MDP 5 78.43219754925617 30
# average reward exploit: MDP 5 78.45776578717657 30
# average reward explore: 62.44596514231209
# average reward exploit: MDP 6 95.04215142459044 30
# average reward exploit: MDP 6 92.85903071610578 30
# average reward exploit: MDP 6 92.93040756335199 30
# ...
# average reward exploit: MDP 1 62.045126836615516 30
# average reward exploit: MDP 1 62.08822749382394 30
# average reward exploit: MDP 1 61.69931537989984 30
# average reward exploit: MDP 1 61.546893417371265 30
# average reward exploit: MDP 1 62.086678151258845 30
# average reward exploit: MDP 1 62.25514497267263 30
# average reward exploit: MDP 1 62.0947017642641 30
# average reward exploit: MDP 1 61.83890383846531 30
# average reward explore: 75.80146206346042
# average reward exploit: MDP 2 57.53150115320519 30
# average reward exploit: MDP 2 58.242139256514164 30
# average reward exploit: MDP 2 57.89054489460117 30
# average reward exploit: MDP 2 57.81789305646583 30
# average reward exploit: MDP 2 56.70647435269806 30
# average reward exploit: MDP 2 58.63208085385964 30
# average reward exploit: MDP 2 58.255124187932736 30
# average reward exploit: MDP 2 58.126525900699406 30
# average reward exploit: MDP 2 58.85660745544672 30
# average reward exploit: MDP 2 57.926041500109044 30
# average reward explore: 69.93716903982843
# average reward exploit: MDP 3 56.03553063115125 30
# average reward exploit: MDP 3 56.29868558262606 30
# average reward exploit: MDP 3 55.152413008854666 30
# average reward exploit: MDP 3 55.398906248919836 30
# average reward exploit: MDP 3 55.157219607664224 30
# average reward exploit: MDP 3 56.090690806361415 30
# average reward exploit: MDP 3 56.00486816903451 30
# average reward exploit: MDP 3 56.08379569380058 30
# average reward exploit: MDP 3 55.43290115856819 30
# average reward exploit: MDP 3 55.00828777390844 30
# average reward explore: 66.75051237217927
# average reward exploit: MDP 4 51.861676198657044 30
# average reward exploit: MDP 4 52.39147301942716 30
# average reward exploit: MDP 4 52.955786045136264 30
# average reward exploit: MDP 4 52.658706627720086 30
# average reward exploit: MDP 4 52.606759939313264 30
# average reward exploit: MDP 4 51.80703579675929 30
# average reward exploit: MDP 4 52.643540073730534 30
# average reward exploit: MDP 4 52.5982090216646 30
# average reward exploit: MDP 4 52.65937778137781 30
# average reward exploit: MDP 4 52.88078598235814 30
# average reward explore: 62.959943700288704
# average reward exploit: MDP 5 50.60035336647325 30
# average reward exploit: MDP 5 51.24954607044638 30
# average reward exploit: MDP 5 49.688178547891034 30
# average reward exploit: MDP 5 50.92818134357103 30
# average reward exploit: MDP 5 50.6469744229713 30
# average reward exploit: MDP 5 49.87806503611281 30
# average reward exploit: MDP 5 50.52595595401101 30
# average reward exploit: MDP 5 51.0554579717407 30
# average reward exploit: MDP 5 50.91009214934672 30
# average reward exploit: MDP 5 50.4853375361666 30
# average reward explore: 60.011226660822544
# average reward exploit: MDP 6 47.63009944886678 30
# average reward exploit: MDP 6 48.080957326839055 30
# average reward exploit: MDP 6 47.76831368561899 30
# average reward exploit: MDP 6 47.96990254139191 30
# average reward exploit: MDP 6 47.536271419838926 30
# average reward exploit: MDP 6 47.87671726362021 30
# average reward exploit: MDP 6 47.33785002145378 30
# average reward exploit: MDP 6 47.53947194706426 30
# average reward exploit: MDP 6 48.32014310358321 30
# average reward exploit: MDP 6 47.834543452037586 30
# average reward explore: 58.36919073721108
# average reward exploit: MDP 7 47.967537072007445 30
# average reward exploit: MDP 7 47.978370570194066 30
# average reward exploit: MDP 7 48.372908312555765 30
# average reward exploit: MDP 7 47.718998191259104 30
# average reward exploit: MDP 7 47.26612476425435 30
# average reward exploit: MDP 7 47.709450503401236 30
# average reward exploit: MDP 7 47.96705929889626 30
# average reward exploit: MDP 7 47.546850840244154 30
# average reward exploit: MDP 7 47.91631495709695 30
# average reward exploit: MDP 7 47.88231291333124 30
# average reward explore: 56.507788718596366
# average reward exploit: MDP 8 46.5808570243846 30
# average reward exploit: MDP 8 45.687710932675785 30
# average reward exploit: MDP 8 46.499430751334245 30
# average reward exploit: MDP 8 46.09539903052356 30
# average reward exploit: MDP 8 46.142191649588845 30
# average reward exploit: MDP 8 46.56846721962919 30
# average reward exploit: MDP 8 46.606144436234096 30
# average reward exploit: MDP 8 45.542630192764896 30
# average reward exploit: MDP 8 46.78157768746666 30
# average reward exploit: MDP 8 46.63854163957592 30
# average reward explore: 55.05522730407078
# average reward exploit: MDP 9 44.42673591179026 30
# average reward exploit: MDP 9 44.27529586320354 30
# average reward exploit: MDP 9 44.326028392259474 30
# average reward exploit: MDP 9 44.32288933948577 30
# average reward exploit: MDP 9 44.3049602355762 30
# average reward exploit: MDP 9 44.295216273786615 30
# average reward exploit: MDP 9 44.42610749195403 30
# average reward exploit: MDP 9 44.46245848887481 30
# average reward exploit: MDP 9 44.308190355637585 30
# average reward exploit: MDP 9 44.458366550964016 30
# epoch number:  198
# average reward explore: 89.19727589631351
# average reward exploit: MDP 0 67.2153233977126 30
# average reward exploit: MDP 0 66.67633073856713 30
# average reward exploit: MDP 0 66.59928942796809 30
# average reward exploit: MDP 0 66.42931660105245 30
# average reward exploit: MDP 0 66.5372111966252 30
# average reward exploit: MDP 0 66.75751086162194 30
# average reward exploit: MDP 0 66.30306815135629 30
# average reward exploit: MDP 0 67.10693229596878 30
# average reward exploit: MDP 0 66.84329041661574 30
# average reward exploit: MDP 0 66.56436417307852 30
# average reward explore: 83.31057051597443
# average reward exploit: MDP 1 61.53311926304797 30
# average reward exploit: MDP 1 61.7342176525776 30
# average reward exploit: MDP 1 61.72568646982826 30
# average reward exploit: MDP 1 61.906879889263294 30
# average reward exploit: MDP 1 61.27724496087045 30
# average reward exploit: MDP 1 61.336056676784956 30
# average reward exploit: MDP 1 61.852921803617875 30
# average reward exploit: MDP 1 62.62943526307514 30
# average reward exploit: MDP 1 61.58503374082059 30
# average reward exploit: MDP 1 62.68821345366691 30
# average reward explore: 76.36374391574476
# average reward exploit: MDP 2 58.38414406810781 30
# average reward exploit: MDP 2 58.6863132705267 30
# average reward exploit: MDP 2 57.935036434011096 30
# average reward exploit: MDP 2 58.344031362358926 30
# average reward exploit: MDP 2 58.10073635590925 30
# average reward exploit: MDP 2 58.35883251341773 30
# average reward exploit: MDP 2 58.55122478943885 30
# average reward exploit: MDP 2 58.279555396056494 30
# average reward exploit: MDP 2 58.91468284893606 30
# average reward exploit: MDP 2 57.7662881146136 30
# average reward explore: 72.74671283816407
# average reward exploit: MDP 3 55.29519431738791 30
# average reward exploit: MDP 3 56.25815903604395 30
# average reward exploit: MDP 3 55.575140906932575 30
# average reward exploit: MDP 3 56.2864204091456 30
# average reward exploit: MDP 3 55.94624475523525 30
# average reward exploit: MDP 3 56.2308275208326 30
# average reward exploit: MDP 3 55.96271790834654 30
# average reward exploit: MDP 3 56.01145921966164 30
# average reward exploit: MDP 3 55.10015711858056 30
# average reward exploit: MDP 3 54.99979145246751 30
# average reward explore: 68.65918038299584
# average reward exploit: MDP 4 52.514902703392515 30
# average reward exploit: MDP 4 52.24427894433641 30
# average reward exploit: MDP 4 52.63862124405323 30
# average reward exploit: MDP 4 52.47707264772198 30
# average reward exploit: MDP 4 52.397783005683955 30
# average reward exploit: MDP 4 52.55039181024501 30
# average reward exploit: MDP 4 52.62507496968067 30
# average reward exploit: MDP 4 52.445763557110006 30
# average reward exploit: MDP 4 51.82026454698413 30
# average reward exploit: MDP 4 52.86029330543465 30
# average reward explore: 63.61191405481104
# average reward exploit: MDP 5 50.57744341444186 30
# average reward exploit: MDP 5 50.732989994459 30
# average reward exploit: MDP 5 50.58441343699981 30
# average reward exploit: MDP 5 50.497759055579266 30
# average reward exploit: MDP 5 50.58028939213231 30
# average reward exploit: MDP 5 50.58030387416602 30
# average reward exploit: MDP 5 50.592510375117854 30
# average reward exploit: MDP 5 51.057809805743396 30
# average reward exploit: MDP 5 49.336692996947164 30
# average reward exploit: MDP 5 50.70666861897099 30
# average reward explore: 60.05080465154769
# average reward exploit: MDP 6 48.13518930063719 30
# average reward exploit: MDP 6 47.690406836241415 30
# average reward exploit: MDP 6 48.46689089127616 30
# average reward exploit: MDP 6 47.677907097733886 30
# average reward exploit: MDP 6 48.37631154451552 30
# average reward exploit: MDP 6 47.69354312247585 30
# average reward exploit: MDP 6 48.25254509420582 30
# average reward exploit: MDP 6 48.12618913472179 30
# average reward exploit: MDP 6 48.30017584232954 30
# average reward exploit: MDP 6 47.92624942991302 30
# average reward explore: 59.265394408156574
# average reward exploit: MDP 7 47.85192066516973 30
# average reward exploit: MDP 7 47.761188680081 30
# average reward exploit: MDP 7 48.146263094430374 30
# average reward exploit: MDP 7 48.319689149932955 30
# average reward exploit: MDP 7 47.95209568053993 30
# average reward exploit: MDP 7 47.3430904126185 30
# average reward exploit: MDP 7 47.48270977514381 30
# average reward exploit: MDP 7 48.15459349736462 30
# average reward exploit: MDP 7 46.96355354818383 30
# average reward exploit: MDP 7 47.71537704240779 30
# average reward explore: 57.60953710731681
# average reward exploit: MDP 8 45.93266472074186 30
# average reward exploit: MDP 8 46.98063298829956 30
# average reward exploit: MDP 8 46.803109534571 30
# average reward exploit: MDP 8 45.646070015358326 30
# average reward exploit: MDP 8 47.67117320990537 30
# average reward exploit: MDP 8 46.18264838338466 30
# average reward exploit: MDP 8 46.3936028082858 30
# average reward exploit: MDP 8 46.252451097732674 30
# average reward exploit: MDP 8 46.699942705629354 30
# average reward exploit: MDP 8 46.10728031951031 30
# average reward explore: 54.624364680168355
# average reward exploit: MDP 9 44.31362389429521 30
# average reward exploit: MDP 9 44.45792311008223 30
# average reward exploit: MDP 9 44.29945287373543 30
# average reward exploit: MDP 9 44.428376593949444 30
# average reward exploit: MDP 9 44.26800849540071 30
# average reward exploit: MDP 9 44.29250215466356 30
# average reward exploit: MDP 9 44.22130395566262 30
# average reward exploit: MDP 9 44.424280938987046 30
# average reward exploit: MDP 9 44.57500612199486 30
# average reward exploit: MDP 9 44.45509372993526 30
# epoch number:  199
# average reward explore: 90.59644841396197
# average reward exploit: MDP 0 65.67829522830591 30
# average reward exploit: MDP 0 66.26158440675668 30
# average reward exploit: MDP 0 67.04788483884788 30
# average reward exploit: MDP 0 66.79963591680178 30
# average reward exploit: MDP 0 66.42515012150895 30
# average reward exploit: MDP 0 66.62066509776533 30
# average reward exploit: MDP 0 66.14396115532767 30
# average reward exploit: MDP 0 66.45268517339561 30
# average reward exploit: MDP 0 66.41375811732502 30
# average reward exploit: MDP 0 66.63775467351984 30
# average reward explore: 85.53584731528352
# average reward exploit: MDP 1 62.25282536849056 30
# average reward exploit: MDP 1 61.28813127491678 30
# average reward exploit: MDP 1 62.048618668943064 30
# average reward exploit: MDP 1 61.65410875355919 30
# average reward exploit: MDP 1 62.142463820372086 30
# average reward exploit: MDP 1 62.24078817081199 30
# average reward exploit: MDP 1 61.8574998112618 30
# average reward exploit: MDP 1 62.094992856088304 30
# average reward exploit: MDP 1 61.904352360832526 30
# average reward exploit: MDP 1 61.89352609358567 30
# average reward explore: 79.57305033071171
# average reward exploit: MDP 2 57.7991803392803 30
# average reward exploit: MDP 2 57.528543813405314 30
# average reward exploit: MDP 2 58.267867183982 30
# average reward exploit: MDP 2 58.478494188917956 30
# average reward exploit: MDP 2 58.28426746385245 30
# average reward exploit: MDP 2 58.29526703777792 30
# average reward exploit: MDP 2 57.48703578559441 30
# average reward exploit: MDP 2 58.23887679532861 30
# average reward exploit: MDP 2 58.45487202050367 30
# average reward exploit: MDP 2 59.288353226189685 30
# average reward explore: 74.23586995057175
# average reward exploit: MDP 3 55.741150579137276 30
# average reward exploit: MDP 3 55.75995051653729 30
# average reward exploit: MDP 3 56.4753440242528 30
# average reward exploit: MDP 3 56.05970472860302 30
# average reward exploit: MDP 3 54.814033916950876 30
# average reward exploit: MDP 3 55.62013093702193 30
# average reward exploit: MDP 3 55.8879385802964 30
# average reward exploit: MDP 3 55.96493781448883 30
# average reward exploit: MDP 3 56.05692074044168 30
# average reward exploit: MDP 3 56.00305720125411 30
# average reward explore: 68.48022697946924
# average reward exploit: MDP 4 52.015421924022476 30
# average reward exploit: MDP 4 52.21882849375174 30
# average reward exploit: MDP 4 52.661739526764514 30
# average reward exploit: MDP 4 52.258324564019084 30
# average reward exploit: MDP 4 52.43296473015683 30
# average reward exploit: MDP 4 52.632759882584246 30
# average reward exploit: MDP 4 52.41310291500558 30
# average reward exploit: MDP 4 52.676171763029195 30
# average reward exploit: MDP 4 52.6602034620615 30
# average reward exploit: MDP 4 52.69865381346384 30
# average reward explore: 65.38787441788502
# average reward exploit: MDP 5 51.60421901919605 30
# average reward exploit: MDP 5 50.68256961967339 30
# average reward exploit: MDP 5 50.05123945123666 30
# average reward exploit: MDP 5 51.317928573161645 30
# average reward exploit: MDP 5 50.49253175807971 30
# average reward exploit: MDP 5 50.744093448067524 30
# average reward exploit: MDP 5 51.500473519279566 30
# average reward exploit: MDP 5 50.69635967983485 30
# average reward exploit: MDP 5 50.748750375954494 30
# average reward exploit: MDP 5 49.812703978423734 30
# average reward explore: 62.3488792422796
# average reward exploit: MDP 6 46.58870537133654 30
# average reward exploit: MDP 6 47.13942827126255 30
# average reward exploit: MDP 6 47.50691363035983 30
# average reward exploit: MDP 6 47.3198089357247 30
# average reward exploit: MDP 6 47.30299221627244 30
# average reward exploit: MDP 6 47.50711753411494 30
# average reward exploit: MDP 6 48.14546285732521 30
# average reward exploit: MDP 6 47.40052686963064 30
# average reward exploit: MDP 6 47.51361734495236 30
# average reward exploit: MDP 6 47.755639739308954 30
# average reward explore: 61.48038951850906
# average reward exploit: MDP 7 47.72820867581065 30
# average reward exploit: MDP 7 47.144622920149416 30
# average reward exploit: MDP 7 47.321356901830356 30
# average reward exploit: MDP 7 48.12192375480393 30
# average reward exploit: MDP 7 47.73916254470809 30
# average reward exploit: MDP 7 48.09216811439426 30
# average reward exploit: MDP 7 47.77662340054132 30
# average reward exploit: MDP 7 47.95521880585566 30
# average reward exploit: MDP 7 47.690819225597146 30
# average reward exploit: MDP 7 47.9010055369964 30
# average reward explore: 58.706389927482164
# average reward exploit: MDP 8 46.26242564336824 30
# average reward exploit: MDP 8 45.49098012674761 30
# average reward exploit: MDP 8 45.85799870462668 30
# average reward exploit: MDP 8 46.22621402819937 30
# average reward exploit: MDP 8 47.143888409711685 30
# average reward exploit: MDP 8 46.47126641391222 30
# average reward exploit: MDP 8 46.36733918923596 30
# average reward exploit: MDP 8 46.39497634356738 30
# average reward exploit: MDP 8 46.29472755122199 30
# average reward exploit: MDP 8 46.94568271571583 30
# average reward explore: 54.98333751057762
# average reward exploit: MDP 9 44.297977278087174 30
# average reward exploit: MDP 9 44.30433062282271 30
# average reward exploit: MDP 9 44.58259257545304 30
# average reward exploit: MDP 9 44.56933649079074 30
# average reward exploit: MDP 9 44.424726702475496 30
# average reward exploit: MDP 9 44.43338021190982 30
# average reward exploit: MDP 9 44.29686881571538 30
# average reward exploit: MDP 9 44.3149951968434 30
# average reward exploit: MDP 9 44.50047586504839 30
# average reward exploit: MDP 9 44.3243844708467 30

# %%
explore_paths, explore_rewards = a.sample_paths_explore(a.env,1)

# %%
print("average reward explore:", np.mean(explore_rewards))
M = a.stack_trajectories(explore_paths)
# Out:
# average reward explore: 78.12981287064275

# %%
Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })

# %%
Z = np.reshape(Z,[1,len(Z)])

# %%
exploit_paths, exploit_rewards = a.sample_paths_exploit(a.env,Z,1)

# %%
print("average reward exploit", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
# Out:
# average reward exploit 4466.792213821265 2000

# %%
a.num_traj = 2000

# %%
for i in range(20):
    explore_paths, explore_rewards = a.sample_paths_explore(a.env,30*np.random.rand())
    print("gravity:", a.sim.model.opt.gravity)
    print("average reward explore:", np.mean(explore_rewards))
    M = a.stack_trajectories(explore_paths)
    Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })
    Z = np.reshape(Z,[1,len(Z)])
    exploit_paths, exploit_rewards = a.sample_paths_exploit(a.env,Z,1)
    print("average reward exploit", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
# Out:
# gravity: [  0.           0.         -14.23799705]
# average reward explore: 55.876055596810076
# average reward exploit 4131.248029732218 2000
# gravity: [  0.           0.         -28.92469711]
# average reward explore: 26.375929544684027
# average reward exploit 4128.3822263169 2000
# gravity: [  0.           0.         -13.78489803]
# average reward explore: 56.98693803520648
# average reward exploit 4131.243695054299 2000
# gravity: [  0.           0.         -13.99769514]
# average reward explore: 56.371840402102315
# average reward exploit 4127.052310839154 2000
# gravity: [  0.           0.         -24.81371372]
# average reward explore: 35.30427806908966
# average reward exploit 4130.655895877959 2000
# gravity: [  0.          0.        -20.5110446]
# average reward explore: 39.77185976141281
# average reward exploit 4126.369389991184 2000
# gravity: [  0.           0.         -24.32955676]
# average reward explore: 36.2316832686866
# average reward exploit 4124.35278186741 2000
# gravity: [  0.           0.         -19.24202723]
# average reward explore: 42.29627702963969
# average reward exploit 4129.255822429783 2000
# gravity: [  0.          0.        -13.7164081]
# average reward explore: 57.20762451603396

# %%
observations_explore = np.concatenate([path["observation"] for path in explore_paths])
new_observations_explore = np.concatenate([path["new_obs"] for path in explore_paths])
new_actions_explore = np.concatenate([path["new_acs"] for path in explore_paths])
actions_explore = np.concatenate([path["action"] for path in explore_paths])
rewards_explore = np.concatenate([path["reward"] for path in explore_paths])
returns_explore = a.get_returns(explore_paths, explore = True)

# %%
M = np.array(a.stack_trajectories(explore_paths))
Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })
Z = np.reshape(Z,[1,len(Z)])

# %%
 print("average reward explore: MDP", np.sum(explore_rewards)/num_traj, len(explore_rewards))

# %%
exploit_paths, exploit_rewards = a.sample_paths_exploit(a.env,Z,1000)

# %%
print("average reward exploit: MDP", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))

# %%
def randomize_pendulum(env):
    m = config['pendulum_mass_min'] + np.random.rand()*(config['pendulum_mass_max'] - config['pendulum_mass_min'])
    l = config['pendulum_len_min'] + np.random.rand()*(config['pendulum_len_max'] - config['pendulum_len_min'])
    env.m = m
    env.l = l

# %%
def randomize_hopper(env):
    ts = config['torso_min'] + np.random.rand()*(config['torso_max'] - config['torso_min'])
    f = config['friction_min'] + np.random.rand()*(config['friction_max'] - config['friction_min'])
    
    env.friction = f
    env.torso_size = ts
    env.apply_env_modifications()

# %%
import yaml
cfg_filename = 'hopper-config.yml'
with open(cfg_filename,'r') as ymlfile:
    config = yaml.load(ymlfile)

# %%
env = Randomizer(gym.make('Hopper-v2'), randomize_hopper)
env.unwrapped.__dict__.keys()
env.reset()

# %%
m = config['pendulum_mass_min'] + np.random.rand()*(config['pendulum_mass_max'] - config['pendulum_mass_min'])

# %%
config

# %%
env_id = 'Hopper-v2'
e = gym.make(env_id)

# %%
e.unwrapped.__dict__.keys()

# %%
e.unwrapped.apply_env_modifications()

# %%
a.sim.model.opt
