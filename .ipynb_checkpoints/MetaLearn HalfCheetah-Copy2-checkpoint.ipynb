# %%
# Include Libraries
import numpy as np
import tensorflow as tf
import gym
import tensorflow.contrib.layers as layers
from mujoco_py import load_model_from_xml, MjSim, MjViewer
import policies
import value_functions as vfuncs
import utils_pg as utils

# Environment setup
#env = "CartPole-v0"
#env="InvertedPendulum-v2"
env = "HalfCheetah-v2"

# discrete = isinstance(env.action_space, gym.spaces.Discrete)
# observation_dim = env.observation_space.shape[0]
# action_dim = env.action_space.n if discrete else env.action_space.shape[0]
max_ep_len = 1000
num_traj = 20
#traj_length = max_ep_len*(observation_dim + 2)
latent_size = 100
use_baseline = True

# %%
# Feed forward network (multi-layer-perceptron, or mlp)

def build_mlp(mlp_input,output_size,scope,n_layers,size,output_activation=None):
    '''
    Build a feed forward network
    '''
    Input = mlp_input
    with tf.variable_scope(scope):
        # Dense Layers
        for i in range(n_layers-1):
            dense = tf.layers.dense(inputs = Input, units = size, activation = tf.nn.relu, bias_initializer=tf.constant_initializer(1.0))
            Input = dense
        # Fully Connected Layer
        out = layers.fully_connected(inputs = Input, num_outputs = output_size, activation_fn=output_activation)
    return out

# %%
class MetaLearner():
    def __init__(self, env, max_ep_len, num_traj,latent_size ):
        self.env = gym.make(env)
        self.discrete = isinstance(self.env.action_space, gym.spaces.Discrete)
        self.observation_dim = self.env.observation_space.shape[0]
        self.action_dim = self.env.action_space.n if self.discrete else self.env.action_space.shape[0]
        self.max_ep_len = max_ep_len
        self.num_traj = num_traj
        self.traj_length = self.max_ep_len*(self.observation_dim + 2) # TO Change
        self.use_baseline = True
        self.latent_size = latent_size
        self.feature_size = self.observation_dim + 1 + self.env.action_space.shape[0] # HC
        self.lr = 3e-3
        self.num_layers = 2
        self.layers_size = 32
        self.num_mdps = 10
        self.model = self.env.env.model
        self.sim = MjSim(self.model)
        self.gamma = 0.95
        self.decoder_len = 32

        # build model
        self.ConstructGraph()
    
    def add_placeholders(self):
        self.observation_placeholder_explore = tf.placeholder(tf.float32, shape=(None,self.observation_dim))
        if(self.discrete):
            self.action_placeholder_explore = tf.placeholder(tf.int32, shape=(None))
            self.action_placeholder_exploit = tf.placeholder(tf.int32, shape=(None))
        else:
            self.action_placeholder_explore = tf.placeholder(tf.float32, shape=(None,self.action_dim))
            self.action_placeholder_exploit= tf.placeholder(tf.float32, shape=(None,self.action_dim))

        self.baseline_target_placeholder = tf.placeholder(tf.float32, shape= None)
        self.advantage_placeholder_explore = tf.placeholder(tf.float32, shape=(None))
        
        #self.encoder_input_placeholder = tf.placeholder(tf.float32, shape= (self.num_traj,self.traj_length))
        self.encoder_input_placeholder = tf.placeholder(tf.float32, [None, None, self.feature_size])
        self.decoder_input_placeholder = tf.placeholder(tf.float32, shape= (1,self.latent_size))
        self.sequence_length_placeholder = tf.placeholder(tf.int32, [None, ])
        
        self.observation_placeholder_exploit = tf.placeholder(tf.float32, shape=(None,self.observation_dim))
        #TODO
        self.advantage_placeholder_exploit = tf.placeholder(tf.float32, shape=(None))
        
        
    def build_policy_explore(self, scope = "policy_explore"):
        if (self.discrete):
            self.action_logits = build_mlp(self.observation_placeholder_explore,self.action_dim,scope = scope,n_layers=self.num_layers,size = self.layers_size,output_activation=None)
            self.explore_action = tf.multinomial(self.action_logits,1)
            self.explore_action = tf.squeeze(self.explore_action, axis=1)
            self.explore_logprob = -tf.nn.sparse_softmax_cross_entropy_with_logits(logits = self.action_logits, labels = self.action_placeholder_explore)

        else:   
            action_means = build_mlp(self.observation_placeholder_explore,self.action_dim,scope,n_layers=self.num_layers, size = self.layers_size,output_activation=None)
            init = tf.constant(np.random.rand(1, 2))
            #log_std = tf.get_variable("log_std", [self.action_dim])
            log_std = tf.get_variable(
                'log_std',
                shape=[1, self.action_dim],
                dtype=tf.float32,
                initializer=tf.zeros_initializer(),
                trainable=True
            )
            log_std = tf.log(tf.exp(log_std) + 1.)
            log_std = tf.tile(log_std,
                                   [tf.shape(action_means)[0], 1])
            self.explore_action = tf.random_normal((1,),
                                                   action_means,
                                                   log_std)
            dist = tf.contrib.distributions.MultivariateNormalDiag(action_means, log_std)
            self.explore_logprob = dist.prob(self.action_placeholder_explore, name = 'log_prob')
            #self.explore_action =   action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
            #mvn = tf.contrib.distributions.MultivariateNormalDiag(action_means, tf.exp(log_std))
            #self.explore_logprob =  mvn.log_prob(value = self.action_placeholder_explore, name='log_prob')

    
    
    def build_policy_exploit(self, scope = "policy_exploit"):
        if(self.discrete):
            #self.exploit_action_logits = (tf.matmul(tf.nn.relu(tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W1) + self.d_B1), self.d_W2) + self.d_B2),self.d_W3) + self.d_B3)
            #self.exploit_action_logits = tf.matmul(self.observation_placeholder_exploit,self.d_W3) + self.d_B3
            self.exploit_action_logits = tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W2) + self.d_B2), self.d_W3) + self.d_B3
            self.exploit_action = tf.multinomial(self.exploit_action_logits,1)
            self.exploit_action = tf.squeeze(self.exploit_action, axis=1)
            self.exploit_logprob = -tf.nn.sparse_softmax_cross_entropy_with_logits(logits = self.exploit_action_logits, labels = self.action_placeholder_exploit)
        else:
            action_means = tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W2) + self.d_B2), self.d_W3) + self.d_B3
            init = tf.constant(np.random.rand(1, 2))
            log_std = tf.get_variable("exploit_log_prob", [self.action_dim])
            self.exploit_action = action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
            self.exploit_logprob = utils.gauss_log_prob(mu=action_means, logstd=log_std, x=self.action_placeholder_exploit)
            
#             init = tf.constant(np.random.rand(1, 2))
#             log_std = tf.get_variable("exploit_log_prob", [self.action_dim])
#             self.exploit_action =   action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
#             mvn = tf.contrib.distributions.MultivariateNormalDiag(action_means, tf.exp(log_std))
#             self.exploit_logprob =  mvn.log_prob(value = self.action_placeholder_exploit, name='exploit_log_prob')

        #self.loss_grads_exploit = self.exploit_logprob * self.advantage_placeholder_exploit
        
    def NNEncoder(self, scope = "NNEncoder"):
        self.Z = build_mlp(self.encoder_input_placeholder,self.latent_size,scope = scope,n_layers=3,size = 60,output_activation=None)
    
 

    # input [num_traj, length, features (obs + action + reward) ]
    def LSTMEncoder(self, scope = "LSTMEncoder"):
        self.hidden_size = 64
        initializer = tf.random_uniform_initializer(-1, 1)
        cell = tf.nn.rnn_cell.LSTMCell(self.hidden_size, self.feature_size, initializer=initializer)
        cell_out = tf.contrib.rnn.OutputProjectionWrapper(cell, self.latent_size)
        self.output, _ = tf.nn.dynamic_rnn(cell_out,self.encoder_input_placeholder,self.sequence_length_placeholder,dtype=tf.float32,)
        batch_size = tf.shape(self.output)[0]
        max_length = tf.shape(self.output)[1]
        out_size = int(self.output.get_shape()[2])
        index = tf.range(0, batch_size) * max_length + (self.sequence_length_placeholder - 1)
        flat = tf.reshape(self.output, [-1, out_size])
        self.Z = tf.reduce_mean(tf.gather(flat, index), axis = 0)
        
    
    def Decoder(self, decoder_out_dim, scope):
        return build_mlp(self.decoder_input_placeholder,decoder_out_dim,scope = scope,n_layers=1,size = 64,output_activation=None)
    
    
    def sample_paths_explore(self, env,mdp_num,Test = False, num_episodes = None):
        paths = []
        self.length = []
        episode_rewards = []
        #self.sim.model.opt.gravity[-1] = -5 - mdp_num
        for i in range(self.num_traj):
            pad = False
            state = env.reset()
            new_states,states,new_actions, actions, rewards = [], [], [], [], []
            episode_reward = 0
            for step in range(self.max_ep_len):
                if (pad):
                    states.append([0]*self.observation_dim)
                    if(self.discrete):
                        actions.append(0)
                    else:
                        actions.append([0]*self.action_dim)
                    rewards.append(0)
                else:
                    states.append(state)
                    new_states.append(state)
                    #action = self.sess.run(self.explore_action, feed_dict={self.observation_placeholder_explore : states[-1][None]})[0]
                    action = self.policyfn.sample_action(state) #NEW
                    state, reward, done, info = env.step(action)
                    actions.append(action)
                    new_actions.append(action)
                    rewards.append(reward)
                    episode_reward += reward
                    if (done or step == self.max_ep_len-1):
                        episode_rewards.append(episode_reward)
                        self.length.append(step + 1)
                        pad = True 
                        
            episode_rewards.append(episode_reward)            
            #print("explore",np.array(actions))
            path = {"new_obs" : np.array(new_states),"observation" : np.array(states),
                                "reward" : np.array(rewards),"new_acs" : np.array(new_actions),
                                "action" : np.array(actions)}
            paths.append(path)
        return paths, episode_rewards
    
    def sample_paths_exploit(self, env,Z,mdp_num,Test = False, num_episodes = None):
        #self.sim.model.opt.gravity[-1] = -5 - mdp_num
        
        paths = []
        num = 0
        episode_rewards = []
        for i in range(self.num_traj):
            state = env.reset()
            states, actions, rewards = [], [], []
            episode_reward = 0
            for step in range(self.max_ep_len):
                states.append(state)
                action = self.sess.run(self.exploit_action, feed_dict={self.observation_placeholder_exploit : state[None], self.decoder_input_placeholder: Z})[0]
                state, reward, done, info = env.step(action)
                actions.append(action)
                rewards.append(reward)
                episode_reward += reward
                if (done or step == self.max_ep_len-1):
                    episode_rewards.append(episode_reward)
                    break
            #print("exploit",np.array(actions))
            path = {"observation" : np.array(states),
                                "reward" : np.array(rewards),
                                "action" : np.array(actions)}
            paths.append(path)
 
        #print("exploit success: ", num)
        return paths, episode_rewards
    
    def get_returns(self,paths, explore = False):
        all_returns = []
        m = 0
        for path in paths:
            rewards = path["reward"]
            returns = []
            if(explore):
                length = self.length[m]
            else:
                length = len(rewards)
            for i in range(length):
                path_returns = 0
                k = 0
                for j in range(i,length):
                    path_returns = path_returns + rewards[j]*(self.gamma)**k
                    k = k+1
                returns.append(path_returns)
            all_returns.append(returns)
            m+=1
        returns = np.concatenate(all_returns)
        return returns
    
    def stack_trajectories(self,paths):
        trajectories = []
        for path in paths:
            rewards = path["reward"]
            states = path["observation"]
            action = path["action"]
            
            SAR = []
            for i in range(len(states)):
                SAR.append(list(states[i]) + list(action[i]) + [rewards[i]])
            trajectories.append(SAR)
        return np.array(trajectories)
    
    def addBaseline(self):
        self.baseline = build_mlp(self.observation_placeholder_explore,1,scope = "baseline",n_layers=self.num_layers, size = self.layers_size,output_activation=None)
        self.baseline_loss = tf.losses.mean_squared_error(self.baseline_target_placeholder,self.baseline,scope = "baseline")
        baseline_adam_optimizer =  tf.train.AdamOptimizer(learning_rate = self.lr)
        self.update_baseline_op = baseline_adam_optimizer.minimize(self.baseline_loss)

    def calculate_advantage(self,returns, observations):
        if (self.use_baseline):
            baseline = self.sess.run(self.baseline, {input_placeholder:observations})
            adv = returns - baseline
            adv = (adv - np.mean(adv))/np.std(adv)
        else:
            adv = returns
        return adv
    

        
    def ConstructGraph(self):
        tf.reset_default_graph()
        self.sess = tf.Session()
        
        self.vf = vfuncs.NnValueFunction(session=self.sess,ob_dim=self.observation_dim)
        self.policyfn = policies.GaussianPolicy(self.sess,self.observation_dim, self.action_dim)
        
        self.add_placeholders()
        
#         self.add_placeholders()
        
#         self.build_policy_explore()
#         self.explore_policy_loss = -tf.reduce_sum(self.explore_logprob * self.advantage_placeholder_explore)
#         self.loss_grads_explore = -self.explore_logprob * self.advantage_placeholder_explore
#         self.tvars_explore = tf.trainable_variables()
#         self.gradients_explore = tf.gradients(self.explore_policy_loss,self.tvars_explore)
        
#         #self.addBaseline()
        
#         self.baseline = build_mlp(self.observation_placeholder_explore,1,scope = "baseline",n_layers=1, size = 16,output_activation=None)
#         self.baseline_loss = tf.losses.mean_squared_error(self.baseline_target_placeholder,self.baseline,scope = "baseline")
#         baseline_adam_optimizer =  tf.train.AdamOptimizer(learning_rate = self.lr)
#         self.update_baseline_op = baseline_adam_optimizer.minimize(self.baseline_loss)
        
#         #Encoder LSTM
        self.LSTMEncoder()
        
        
        #decoder weights
        #self.d_W1 = self.Decoder(scope = "W1", decoder_out_dim = self.observation_dim*self.decoder_len)
        self.d_W2 = self.Decoder(scope = "W2", decoder_out_dim = self.observation_dim*self.decoder_len)
        #self.d_W3 = self.Decoder(scope = "W3", decoder_out_dim = self.decoder_len*action_dim)
        self.d_W3 = self.Decoder(scope = "W3", decoder_out_dim = self.decoder_len*self.action_dim)
        
        #self.d_W1 = ((self.d_W1 - (tf.reduce_max(self.d_W1) + tf.reduce_min(self.d_W1))/2)/(tf.reduce_max(self.d_W1) - tf.reduce_min(self.d_W1)))*2 
        #self.d_W2 = ((self.d_W2 - (tf.reduce_max(self.d_W2) + tf.reduce_min(self.d_W2))/2)/(tf.reduce_max(self.d_W2) - tf.reduce_min(self.d_W2)))*2 
        #self.d_W3 = ((self.d_W3 - (tf.reduce_max(self.d_W3) + tf.reduce_min(self.d_W3))/2)/(tf.reduce_max(self.d_W3) - tf.reduce_min(self.d_W3)))*2 
        
        #self.d_W1 = tf.reshape(self.d_W1, [self.observation_dim, self.decoder_len])
        self.d_W2 = tf.reshape(self.d_W2, [self.observation_dim, self.decoder_len])
        #self.d_W3 = tf.reshape(self.d_W3, [self.decoder_len, self.action_dim])
        self.d_W3 = tf.reshape(self.d_W3, [self.decoder_len, self.action_dim])
        
        # decoder output bias
        #self.d_B1 = tf.reshape(self.Decoder(decoder_out_dim = self.decoder_len, scope = "B1"), [self.decoder_len])
        self.d_B2 = tf.reshape(self.Decoder(decoder_out_dim = self.decoder_len, scope = "B2"), [self.decoder_len])
        self.d_B3 = tf.reshape(self.Decoder(decoder_out_dim = self.action_dim, scope = "B3"), [self.action_dim])
        #self.d_B1 = ((self.d_B1 - (tf.reduce_max(self.d_B1) + tf.reduce_min(self.d_B1))/2)/(tf.reduce_max(self.d_B1) - tf.reduce_min(self.d_B1)))*2 
        #self.d_B2 = ((self.d_B2 - (tf.reduce_max(self.d_B2) + tf.reduce_min(self.d_B2))/2)/(tf.reduce_max(self.d_B2) - tf.reduce_min(self.d_B2)))*2 
        
        
        # exploit policy
        self.build_policy_exploit()
        #self.d = [self.d_W1, self.d_B1, self.d_W2, self.d_B2, self.d_W3, self.d_B3]
        self.exploit_policy_loss = -tf.reduce_sum(self.exploit_logprob * self.advantage_placeholder_exploit)
        self.d = [self.d_W3, self.d_B3]
        self.gradients_exploit = tf.gradients(self.exploit_policy_loss,self.d)
        
        # train encoder and decoder
        adam_optimizer_exploit =  tf.train.AdamOptimizer(self.lr*0.3)
        self.output_train_op = adam_optimizer_exploit.minimize(self.exploit_policy_loss)
        # train original network
#         adam_optimizer_explore = tf.train.AdamOptimizer(self.lr)
#         self.input_train_op = adam_optimizer_explore.minimize(self.explore_policy_loss)
        init = tf.global_variables_initializer()
        self.sess.run(init)
    
    def initialize(self):
        self.ConstructGraph()
#         # create tf session
#         self.sess = tf.Session()
        
#         # initiliaze all variables
#         init = tf.global_variables_initializer()
#         self.sess.run(init)
    
    def train_step(self): 
        # sample num_traj*num_MDPs
        for i in range(self.num_mdps):
            explore_paths, explore_rewards = self.sample_paths_explore(self.env,i)
            observations_explore = np.concatenate([path["observation"] for path in explore_paths])
            new_observations_explore = np.concatenate([path["new_obs"] for path in explore_paths])
            new_actions_explore = np.concatenate([path["new_acs"] for path in explore_paths])
            actions_explore = np.concatenate([path["action"] for path in explore_paths])
            rewards_explore = np.concatenate([path["reward"] for path in explore_paths])
            
            vtargs, vpreds, advantages_explore = [], [], []
            for path in explore_paths:
                rew_t = path["reward"]
                return_t = utils.discount(rew_t, self.gamma)
                vpred_t = self.vf.predict(path["observation"])
                adv_t = return_t - vpred_t
                advantages_explore.append(adv_t)
                vtargs.append(return_t)
                vpreds.append(vpred_t)
                
                
            #returns_explore = self.get_returns(explore_paths, explore = True)
            advantages_explore = np.concatenate(advantages_explore)
            advantages_explore = (advantages_explore - advantages_explore.mean()) / (advantages_explore.std() + 1e-8)
            vtarg_n = np.concatenate(vtargs)
            vpred_n = np.concatenate(vpreds)
            #update baseline
            self.vf.fit(new_observations_explore, vtarg_n)
            
            surr_loss, oldmean_na, oldlogstd_a = self.policyfn.update_policy(
                    new_observations_explore, new_actions_explore, advantages_explore, self.lr)
            
            print("average reward explore:", np.mean(explore_rewards))
            
            #print(returns_explore)
#             print("average reward explore: MDP", i, np.sum(explore_rewards)/num_traj, len(explore_rewards))

#             baseline_explore = self.sess.run(self.baseline, {self.observation_placeholder_explore:new_observations_explore})
#             adv = returns_explore - np.squeeze(baseline_explore)
#             advantages_explore = (adv - np.mean(adv))/(np.std(adv) + 1e-12)


#             # update the baseline

#             self.sess.run(self.update_baseline_op, {self.observation_placeholder_explore:new_observations_explore, 
#                                            self.baseline_target_placeholder : returns_explore})

            # calculate explore gradients
    #         grads_explore = self.sess.run(self.gradients_explore, feed_dict={
    #                     self.observation_placeholder_explore : observations_explore,
    #                     self.action_placeholder_explore : actions_explore,
    #                     self.advantage_placeholder_explore : returns_explore})
            #print("explore",grads_explore )
            # form trajectory matrix

            M = np.array(self.stack_trajectories(explore_paths))


            #encoder LSTM
            Z = self.sess.run(self.Z, feed_dict = {self.encoder_input_placeholder: M,self.sequence_length_placeholder: self.length })
            Z = np.reshape(Z,[1,len(Z)])
#             #print("Z",Z)
#             #print(self.sess.run(self.d, feed_dict = {self.decoder_input_placeholder: Z}))
#             #print("d",self.d)
#             # sample paths
#             tvars = tf.trainable_variables()
#             tvars_vals = self.sess.run(tvars[-5:-1])
#             #print(tvars_vals)
            for j in range(10):
                exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z,i)
                # get observations, actions and rewards
                observations_exploit = np.concatenate([path["observation"] for path in exploit_paths])
                actions_exploit = np.concatenate([path["action"] for path in exploit_paths])
                rewards_exploit = np.concatenate([path["reward"] for path in exploit_paths])
                returns_exploit = self.get_returns(exploit_paths)
                print("average reward exploit: MDP", i, np.sum(exploit_rewards) / num_traj, len(exploit_rewards))


#             # exploit grads
#     #         grads_exploit = self.sess.run(self.gradients_exploit,feed_dict={
#     #                     self.observation_placeholder_exploit : observations_exploit,
#     #                     self.action_placeholder_exploit : actions_exploit,
#     #                     self.advantage_placeholder_exploit : returns_exploit,
#     #                     self.decoder_input_placeholder: Z})

            #train encoder and decoder network
                self.sess.run(self.output_train_op, feed_dict={
                                self.observation_placeholder_exploit : observations_exploit,
                                self.action_placeholder_exploit : actions_exploit,
                                self.advantage_placeholder_exploit : returns_exploit,
                                self.decoder_input_placeholder: Z})

            # find advantage for input network
    #         advantage_explore = 0
    #         for i in range(len(grads_exploit)):
    #             l1 = grads_exploit[i]
    #             l2 = grads_explore[i]
    #             advantage_explore = advantage_explore + np.matmul(l1.flatten(), l2.flatten())

            # train input policy
#             self.sess.run(self.input_train_op, feed_dict={
#                             self.observation_placeholder_explore : new_observations_explore,
#                             self.action_placeholder_explore : new_actions_explore,
#                             self.advantage_placeholder_explore : advantages_explore})
    
    def test(self):
        explore_paths, explore_rewards = self.sample_paths_explore(self.env, Test = True)
        M = self.stack_trajectories(explore_paths)
        Z = self.sess.run(self.Z, feed_dict = {self.encoder_input_placeholder: M,self.sequence_length_placeholder: self.length })
        Z = np.reshape(Z,[1,len(Z)])
        # sample paths
        exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z, Test = True)
        print("average reward exploit", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
        
    def train(self):
        self.initialize()
        num_epochs = 200
        for epoch in range(num_epochs):
            print("epoch number: ", epoch)
            self.train_step()

# %%
a = MetaLearner(env, max_ep_len, num_traj, latent_size)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
a.train()
# Out:
# epoch number:  0
# average reward explore: -3662.672117041522
# average reward exploit: MDP 0 -1094.3352855059734 20
# average reward exploit: MDP 0 -923.1838206040175 20
# average reward exploit: MDP 0 -1012.6563000137643 20
# average reward exploit: MDP 0 -1027.7397086157866 20
# average reward exploit: MDP 0 -785.7132634476591 20
# average reward exploit: MDP 0 -727.1258788278433 20
# average reward exploit: MDP 0 -653.2006160224764 20
# average reward exploit: MDP 0 -553.0010214735477 20
# average reward exploit: MDP 0 -557.4145369736119 20
# average reward exploit: MDP 0 -500.3180935135112 20
# average reward explore: -3003.5069068266525
# average reward exploit: MDP 1 -782.798932411737 20
# average reward exploit: MDP 1 -689.9480456156092 20
# average reward exploit: MDP 1 -655.2196221780739 20
# average reward exploit: MDP 1 -700.7474503770436 20
# average reward exploit: MDP 1 -708.5027673316515 20
# average reward exploit: MDP 1 -755.562741896361 20
# average reward exploit: MDP 1 -693.6899605017755 20
# average reward exploit: MDP 1 -772.8385622197768 20
# average reward exploit: MDP 1 -812.2073097242989 20
# average reward exploit: MDP 1 -792.4527803898757 20
# average reward explore: -2543.656809707974
# average reward exploit: MDP 2 -784.361455325791 20
# average reward exploit: MDP 2 -727.7245802193739 20
# average reward exploit: MDP 2 -772.2605968506489 20
# average reward exploit: MDP 2 -748.4273009664353 20
# average reward exploit: MDP 2 -768.6731375236888 20
# average reward exploit: MDP 2 -694.3630761975339 20
# average reward exploit: MDP 2 -680.3736756436635 20
# average reward exploit: MDP 2 -647.7165380039997 20
# average reward exploit: MDP 2 -687.2196803432041 20
# average reward exploit: MDP 2 -801.7571375102799 20
# average reward explore: -2206.2296477037607
# average reward exploit: MDP 3 -602.4589328682812 20
# average reward exploit: MDP 3 -647.7422319817613 20
# average reward exploit: MDP 3 -584.8686921236068 20
# average reward exploit: MDP 3 -572.7126709140335 20
# average reward exploit: MDP 3 -542.5705340515783 20
# average reward exploit: MDP 3 -459.00368086558535 20
# average reward exploit: MDP 3 -465.90003890200126 20
# average reward exploit: MDP 3 -522.543564068962 20
# average reward exploit: MDP 3 -419.58400990797173 20
# average reward exploit: MDP 3 -459.6835954118739 20
# average reward explore: -1942.0121714702975
# average reward exploit: MDP 4 -715.2476535551098 20
# average reward exploit: MDP 4 -717.409556563736 20
# average reward exploit: MDP 4 -661.9139444204667 20
# average reward exploit: MDP 4 -571.1514441776515 20
# average reward exploit: MDP 4 -567.2824618026563 20
# average reward exploit: MDP 4 -613.2299554657901 20
# average reward exploit: MDP 4 -650.4513284745474 20
# average reward exploit: MDP 4 -701.1245043286528 20
# average reward exploit: MDP 4 -710.6186606304991 20
# average reward exploit: MDP 4 -682.6308845817666 20
# average reward explore: -1789.929433563701
# average reward exploit: MDP 5 -869.2631117984463 20
# average reward exploit: MDP 5 -681.4456069530897 20
# average reward exploit: MDP 5 -708.6823690869971 20
# average reward exploit: MDP 5 -615.2865750285508 20
# average reward exploit: MDP 5 -603.030438107945 20
# average reward exploit: MDP 5 -603.0417193809669 20
# average reward exploit: MDP 5 -637.9158192929888 20
# average reward exploit: MDP 5 -647.6911222699475 20
# average reward exploit: MDP 5 -630.8115521302176 20
# average reward exploit: MDP 5 -652.2369319647269 20
# average reward explore: -1607.247518681009
# average reward exploit: MDP 6 -917.9984604995625 20
# average reward exploit: MDP 6 -966.8637200954854 20
# average reward exploit: MDP 6 -1106.2002865316258 20
# average reward exploit: MDP 6 -1189.584855364704 20
# average reward exploit: MDP 6 -1236.131827186406 20
# average reward exploit: MDP 6 -1292.9449952277832 20
# average reward exploit: MDP 6 -1380.2678191638697 20
# average reward exploit: MDP 6 -1321.7728406479164 20
# average reward exploit: MDP 6 -1306.2335693318378 20
# average reward exploit: MDP 6 -1221.8941709609273 20
# average reward explore: -1457.1191242982711
# average reward exploit: MDP 7 -864.3142982837337 20
# average reward exploit: MDP 7 -819.8353922392371 20
# average reward exploit: MDP 7 -787.8069910001972 20
# average reward exploit: MDP 7 -784.5934681959064 20
# average reward exploit: MDP 7 -745.799337945852 20
# average reward exploit: MDP 7 -719.8733721649863 20
# average reward exploit: MDP 7 -701.7568829789702 20
# average reward exploit: MDP 7 -716.9546134437752 20
# average reward exploit: MDP 7 -655.9900506718237 20
# average reward exploit: MDP 7 -668.0585719296648 20
# average reward explore: -1352.0700435957317
# average reward exploit: MDP 8 -652.8505433218218 20
# average reward exploit: MDP 8 -691.040240252403 20
# average reward exploit: MDP 8 -679.3101437566467 20
# average reward exploit: MDP 8 -681.7620675332444 20
# average reward exploit: MDP 8 -676.4179259785525 20
# average reward exploit: MDP 8 -667.7291820675007 20
# average reward exploit: MDP 8 -686.8306750822904 20
# average reward exploit: MDP 8 -695.7563970850883 20
# average reward exploit: MDP 8 -663.710404734804 20
# average reward exploit: MDP 8 -648.6955369202406 20
# average reward explore: -1294.9176783981638
# average reward exploit: MDP 9 -484.99073763695395 20
# average reward exploit: MDP 9 -544.4327728384668 20
# average reward exploit: MDP 9 -514.7091503461227 20
# average reward exploit: MDP 9 -513.1727395588855 20
# average reward exploit: MDP 9 -495.64543506857547 20
# average reward exploit: MDP 9 -452.08083319502373 20
# average reward exploit: MDP 9 -572.8801684023831 20
# average reward exploit: MDP 9 -568.6318488513696 20
# average reward exploit: MDP 9 -552.2465644289224 20
# average reward exploit: MDP 9 -631.5713020727651 20
# epoch number:  1
# average reward explore: -1167.677698330776
# average reward exploit: MDP 0 -469.61058663068826 20
# average reward exploit: MDP 0 -476.0798192760797 20
# average reward exploit: MDP 0 -504.95624161821826 20
# average reward exploit: MDP 0 -470.9955232815547 20
# average reward exploit: MDP 0 -542.2525202246647 20
# average reward exploit: MDP 0 -471.21177371747916 20
# average reward exploit: MDP 0 -524.3368205353964 20
# average reward exploit: MDP 0 -436.733049146517 20
# average reward exploit: MDP 0 -413.00043339064297 20
# average reward exploit: MDP 0 -566.930214780054 20
# average reward explore: -1134.1163503635223
# average reward exploit: MDP 1 -569.7130544073736 20
# average reward exploit: MDP 1 -629.1816396499087 20
# average reward exploit: MDP 1 -566.4337361590973 20
# average reward exploit: MDP 1 -566.2325481646375 20
# average reward exploit: MDP 1 -569.7426021009334 20
# average reward exploit: MDP 1 -525.4232158187167 20
# average reward exploit: MDP 1 -468.48340197958123 20
# average reward exploit: MDP 1 -478.45966830706914 20
# average reward exploit: MDP 1 -546.1783585283546 20
# average reward exploit: MDP 1 -468.5545650721521 20
# average reward explore: -1049.9456716326927
# average reward exploit: MDP 2 -592.6879937040391 20
# average reward exploit: MDP 2 -602.1045062447963 20
# average reward exploit: MDP 2 -551.251672533246 20
# average reward exploit: MDP 2 -581.943298645547 20
# average reward exploit: MDP 2 -476.3987352189382 20
# average reward exploit: MDP 2 -512.1980842058357 20
# average reward exploit: MDP 2 -511.07526115996035 20
# average reward exploit: MDP 2 -464.7027360630872 20
# average reward exploit: MDP 2 -441.8556264984137 20
# average reward exploit: MDP 2 -451.1407376275698 20
# average reward explore: -998.1886649791493
# average reward exploit: MDP 3 -712.129155511672 20
# average reward exploit: MDP 3 -731.7339134327539 20
# average reward exploit: MDP 3 -734.4413108243639 20
# average reward exploit: MDP 3 -692.6644688993291 20
# average reward exploit: MDP 3 -748.974522721999 20
# average reward exploit: MDP 3 -770.287434357631 20
# average reward exploit: MDP 3 -747.9607916207688 20
# average reward exploit: MDP 3 -752.7060277895556 20
# average reward exploit: MDP 3 -766.5354463361748 20
# average reward exploit: MDP 3 -799.0528553338145 20
# average reward explore: -986.3371605993896
# average reward exploit: MDP 4 -634.4451087773404 20
# average reward exploit: MDP 4 -630.1557081425067 20
# average reward exploit: MDP 4 -639.7799678415347 20
# average reward exploit: MDP 4 -620.8005035929831 20
# average reward exploit: MDP 4 -609.0865294138273 20
# average reward exploit: MDP 4 -606.5333750089306 20
# average reward exploit: MDP 4 -589.4726165552904 20
# average reward exploit: MDP 4 -642.9023925933739 20
# average reward exploit: MDP 4 -592.737447206868 20
# average reward exploit: MDP 4 -637.4433559154246 20
# average reward explore: -917.3916115977958
# average reward exploit: MDP 5 -470.189605782103 20
# average reward exploit: MDP 5 -454.46677719301096 20
# average reward exploit: MDP 5 -448.32525021032086 20
# average reward exploit: MDP 5 -499.1548469549043 20
# average reward exploit: MDP 5 -499.6712102341071 20
# average reward exploit: MDP 5 -447.8534640308173 20
# average reward exploit: MDP 5 -420.9335255995411 20
# average reward exploit: MDP 5 -459.4254163862635 20
# average reward exploit: MDP 5 -366.19815553549887 20
# average reward exploit: MDP 5 -392.03444081378234 20
# average reward explore: -931.8216391364543
# average reward exploit: MDP 6 -614.3955064877956 20
# average reward exploit: MDP 6 -605.6966374302078 20
# average reward exploit: MDP 6 -519.7253209176331 20
# average reward exploit: MDP 6 -524.3979798701737 20
# average reward exploit: MDP 6 -470.3444728020063 20
# average reward exploit: MDP 6 -504.50322941507847 20
# average reward exploit: MDP 6 -541.9788537760671 20
# average reward exploit: MDP 6 -506.01980447905845 20
# average reward exploit: MDP 6 -466.15303976323975 20
# average reward exploit: MDP 6 -492.4444800777348 20
# average reward explore: -862.2474137549128
# average reward exploit: MDP 7 -469.6366194884348 20
# average reward exploit: MDP 7 -432.8231411519514 20
# average reward exploit: MDP 7 -419.99513787199203 20
# average reward exploit: MDP 7 -443.3285388950374 20
# average reward exploit: MDP 7 -414.8265758551173 20
# average reward exploit: MDP 7 -498.4075681310866 20
# average reward exploit: MDP 7 -541.1458267401024 20
# average reward exploit: MDP 7 -485.70591798157614 20
# average reward exploit: MDP 7 -513.2679754255603 20
# average reward exploit: MDP 7 -513.7875450311844 20
# average reward explore: -875.1616950718387
# average reward exploit: MDP 8 -521.6297255627198 20
# average reward exploit: MDP 8 -476.12183147986207 20
# average reward exploit: MDP 8 -460.05934867908155 20
# average reward exploit: MDP 8 -370.4229452487523 20
# average reward exploit: MDP 8 -394.1226658182994 20
# average reward exploit: MDP 8 -331.2827690947423 20
# average reward exploit: MDP 8 -295.04232385656854 20
# average reward exploit: MDP 8 -230.09101486604413 20
# average reward exploit: MDP 8 -232.15700668138933 20
# average reward exploit: MDP 8 -269.57362268389363 20
# average reward explore: -832.8035453454322
# average reward exploit: MDP 9 -330.7292233804996 20
# average reward exploit: MDP 9 -276.85525167920144 20
# average reward exploit: MDP 9 -297.74112139218465 20
# average reward exploit: MDP 9 -352.8239371241726 20
# average reward exploit: MDP 9 -318.0958707140063 20
# average reward exploit: MDP 9 -295.26071298227777 20
# average reward exploit: MDP 9 -237.02497803406717 20
# average reward exploit: MDP 9 -293.3333885866233 20
# average reward exploit: MDP 9 -254.34389904653148 20
# average reward exploit: MDP 9 -299.85620499742174 20
# epoch number:  2
# average reward explore: -794.62776629122
# average reward exploit: MDP 0 -291.0738547221903 20
# average reward exploit: MDP 0 -310.66322635365515 20
# average reward exploit: MDP 0 -245.32579048109764 20
# average reward exploit: MDP 0 -326.35774248380346 20
# average reward exploit: MDP 0 -326.00850909822657 20
# average reward exploit: MDP 0 -351.50839036985815 20
# average reward exploit: MDP 0 -383.76434937803344 20
# average reward exploit: MDP 0 -340.79667429518696 20
# average reward exploit: MDP 0 -348.6093886988926 20
# average reward exploit: MDP 0 -344.5226691253389 20
# average reward explore: -785.451160802372
# average reward exploit: MDP 1 -124.87296474450781 20
# average reward exploit: MDP 1 -187.01034867696183 20
# average reward exploit: MDP 1 -172.08096805206782 20
# average reward exploit: MDP 1 -194.5901161684794 20
# average reward exploit: MDP 1 -134.61263733787226 20
# average reward exploit: MDP 1 -234.58145483892105 20
# average reward exploit: MDP 1 -104.65503820730135 20
# average reward exploit: MDP 1 -243.74538154734245 20
# average reward exploit: MDP 1 -130.8983220278355 20
# average reward exploit: MDP 1 -146.39766520694337 20
# average reward explore: -775.0356157387744
# average reward exploit: MDP 2 -448.5786866919972 20
# average reward exploit: MDP 2 -456.05602420929415 20
# average reward exploit: MDP 2 -379.350701755114 20
# average reward exploit: MDP 2 -418.0276038318896 20
# average reward exploit: MDP 2 -375.5335037466926 20
# average reward exploit: MDP 2 -427.4731588535602 20
# average reward exploit: MDP 2 -398.0158478093836 20
# average reward exploit: MDP 2 -391.36052316304693 20
# average reward exploit: MDP 2 -359.12780432264645 20
# average reward exploit: MDP 2 -349.08521197624907 20
# average reward explore: -760.2534867809329
# average reward exploit: MDP 3 -135.8846104820647 20
# average reward exploit: MDP 3 -161.24613929851367 20
# average reward exploit: MDP 3 -142.70874495656787 20
# average reward exploit: MDP 3 -13.053882189030663 20
# average reward exploit: MDP 3 0.8743729989410227 20
# average reward exploit: MDP 3 -24.16809900308218 20
# average reward exploit: MDP 3 50.51323883359175 20
# average reward exploit: MDP 3 91.8022642523261 20
# average reward exploit: MDP 3 -58.2333755147984 20
# average reward exploit: MDP 3 -65.86047286255288 20
# average reward explore: -727.5294541359087
# average reward exploit: MDP 4 206.3131807254183 20
# average reward exploit: MDP 4 2.813617050124961 20
# average reward exploit: MDP 4 115.64959770115811 20
# average reward exploit: MDP 4 26.09850730400794 20
# average reward exploit: MDP 4 -33.07853827735828 20
# average reward exploit: MDP 4 87.5239006378607 20
# average reward exploit: MDP 4 -113.4366350908103 20
# average reward exploit: MDP 4 -71.30354091921879 20
# average reward exploit: MDP 4 -128.27131764702898 20
# average reward exploit: MDP 4 -64.46807252925468 20
# average reward explore: -712.0511738861745
# average reward exploit: MDP 5 -500.87800943108704 20
# average reward exploit: MDP 5 -472.566194466954 20
# average reward exploit: MDP 5 -351.9620544336957 20
# average reward exploit: MDP 5 -272.7930023462782 20
# average reward exploit: MDP 5 -293.57316324745267 20
# average reward exploit: MDP 5 -227.92554893548814 20
# average reward exploit: MDP 5 -144.1469877387258 20
# average reward exploit: MDP 5 -89.07237987399205 20
# average reward exploit: MDP 5 -171.6777840289934 20
# average reward exploit: MDP 5 -125.23818768700998 20
# average reward explore: -720.3972544758655
# average reward exploit: MDP 6 -320.2739835623237 20
# average reward exploit: MDP 6 -258.87673568545165 20
# average reward exploit: MDP 6 -248.7899000900254 20
# average reward exploit: MDP 6 -271.2954522883817 20
# average reward exploit: MDP 6 -269.3138363580087 20
# average reward exploit: MDP 6 -302.89367974693823 20
# average reward exploit: MDP 6 -188.89144275405252 20
# average reward exploit: MDP 6 -40.13053735786067 20
# average reward exploit: MDP 6 -193.08158491232047 20
# average reward exploit: MDP 6 -55.230707726992776 20
# average reward explore: -686.8153983461036
# average reward exploit: MDP 7 -388.017490447521 20
# average reward exploit: MDP 7 -324.0313975615557 20
# average reward exploit: MDP 7 -383.2591672140147 20
# average reward exploit: MDP 7 -313.7633481048682 20
# average reward exploit: MDP 7 -284.45655768436126 20
# average reward exploit: MDP 7 -258.6370821327291 20
# average reward exploit: MDP 7 -340.68767248162715 20
# average reward exploit: MDP 7 -355.5257769747914 20
# average reward exploit: MDP 7 -263.79718229070346 20
# average reward exploit: MDP 7 -226.64350968499147 20
# average reward explore: -679.6698618531042
# average reward exploit: MDP 8 -400.0918713883439 20
# average reward exploit: MDP 8 -235.89454276408787 20
# average reward exploit: MDP 8 -255.45476413003067 20
# average reward exploit: MDP 8 -27.0416269517872 20
# average reward exploit: MDP 8 -47.17393192116606 20
# average reward exploit: MDP 8 52.61617903855007 20
# average reward exploit: MDP 8 -33.741128896211606 20
# average reward exploit: MDP 8 -42.9908913925931 20
# average reward exploit: MDP 8 -0.7802831663365026 20
# average reward exploit: MDP 8 -41.314976151010455 20
# average reward explore: -630.1094843323232
# average reward exploit: MDP 9 -88.47537596169886 20
# average reward exploit: MDP 9 -227.57534097718408 20
# average reward exploit: MDP 9 -243.67396324167999 20
# average reward exploit: MDP 9 -243.90661562744708 20
# average reward exploit: MDP 9 -352.0522056491178 20
# average reward exploit: MDP 9 -478.5716193861484 20
# average reward exploit: MDP 9 -485.57511473628546 20
# average reward exploit: MDP 9 -449.6669167631377 20
# average reward exploit: MDP 9 -328.53048947318365 20
# average reward exploit: MDP 9 -342.7320802677542 20
# epoch number:  3
# average reward explore: -684.9278764264384
# average reward exploit: MDP 0 -59.66195704758803 20
# average reward exploit: MDP 0 94.78476796391028 20
# average reward exploit: MDP 0 23.71134560387805 20
# average reward exploit: MDP 0 24.208684763405913 20
# average reward exploit: MDP 0 2.470835928797436 20
# average reward exploit: MDP 0 13.854073706278314 20
# average reward exploit: MDP 0 -56.71868632740599 20
# average reward exploit: MDP 0 -39.037886012308796 20
# average reward exploit: MDP 0 -57.74602264051161 20
# average reward exploit: MDP 0 -13.59102938965908 20
# average reward explore: -621.6803026478183
# average reward exploit: MDP 1 -412.760936386063 20
# average reward exploit: MDP 1 -387.1624274999833 20
# average reward exploit: MDP 1 -350.14931285776436 20
# average reward exploit: MDP 1 -364.2021723431345 20
# average reward exploit: MDP 1 -301.2604930783712 20
# average reward exploit: MDP 1 -330.6568670042028 20
# average reward exploit: MDP 1 -344.4930769615281 20
# average reward exploit: MDP 1 -373.9298015155656 20
# average reward exploit: MDP 1 -399.80218937217694 20
# average reward exploit: MDP 1 -410.1782202860357 20
# average reward explore: -617.7611594468125
# average reward exploit: MDP 2 -460.8548395552033 20
# average reward exploit: MDP 2 -407.9039475468698 20
# average reward exploit: MDP 2 -358.59744420055864 20
# average reward exploit: MDP 2 -377.98001777233986 20
# average reward exploit: MDP 2 -384.5701548277273 20
# average reward exploit: MDP 2 -375.78882776909677 20
# average reward exploit: MDP 2 -362.7920968582624 20
# average reward exploit: MDP 2 -415.328089407942 20
# average reward exploit: MDP 2 -378.89296121074074 20
# average reward exploit: MDP 2 -405.2020439524377 20
# average reward explore: -647.5296060619896
# average reward exploit: MDP 3 -109.42272142619194 20
# average reward exploit: MDP 3 -78.32462493629833 20
# average reward exploit: MDP 3 -144.3572961012323 20
# average reward exploit: MDP 3 -195.53036285364848 20
# average reward exploit: MDP 3 -199.97337590343997 20
# average reward exploit: MDP 3 -123.22835830749159 20
# average reward exploit: MDP 3 -218.94748357915378 20
# average reward exploit: MDP 3 -156.09152409297158 20
# average reward exploit: MDP 3 -130.11003828707175 20
# average reward exploit: MDP 3 -91.6908506305699 20
# average reward explore: -603.838921901898
# average reward exploit: MDP 4 -467.09100842159125 20
# average reward exploit: MDP 4 -461.9993499529718 20
# average reward exploit: MDP 4 -474.5929225872389 20
# average reward exploit: MDP 4 -477.18169825778705 20
# average reward exploit: MDP 4 -436.8432113886071 20
# average reward exploit: MDP 4 -496.66991633266406 20
# average reward exploit: MDP 4 -456.9683914890212 20
# average reward exploit: MDP 4 -379.34011385215166 20
# average reward exploit: MDP 4 -357.0534110547833 20
# average reward exploit: MDP 4 -381.46781923156794 20
# average reward explore: -628.1088074031699
# average reward exploit: MDP 5 -371.0316508780007 20
# average reward exploit: MDP 5 -378.071428857428 20
# average reward exploit: MDP 5 -350.70265522677704 20
# average reward exploit: MDP 5 -315.58696989422094 20
# average reward exploit: MDP 5 -336.6119347590946 20
# average reward exploit: MDP 5 -349.23346395173826 20
# average reward exploit: MDP 5 -284.59426446934265 20
# average reward exploit: MDP 5 -271.0915703361203 20
# average reward exploit: MDP 5 -274.09396531117864 20
# average reward exploit: MDP 5 -311.17098768659 20
# average reward explore: -602.7541461886412
# average reward exploit: MDP 6 -449.5389502595641 20
# average reward exploit: MDP 6 -460.3806966712303 20
# average reward exploit: MDP 6 -452.27862566909505 20
# average reward exploit: MDP 6 -429.42302595688716 20
# average reward exploit: MDP 6 -434.98817354694773 20
# average reward exploit: MDP 6 -384.7920682787932 20
# average reward exploit: MDP 6 -336.4884830940195 20
# average reward exploit: MDP 6 -339.8952253638744 20
# average reward exploit: MDP 6 -344.13881980058795 20
# average reward exploit: MDP 6 -332.724579133313 20
# average reward explore: -585.9639616235755
# average reward exploit: MDP 7 -281.98473141461943 20
# average reward exploit: MDP 7 -308.06875898981804 20
# average reward exploit: MDP 7 -257.37569507544197 20
# average reward exploit: MDP 7 -221.4124056009337 20
# average reward exploit: MDP 7 -161.83394659237447 20
# average reward exploit: MDP 7 -37.893024502080074 20
# average reward exploit: MDP 7 34.625886958649474 20
# average reward exploit: MDP 7 81.2832572555823 20
# average reward exploit: MDP 7 140.54888492800507 20
# average reward exploit: MDP 7 104.14919131124277 20
# average reward explore: -577.8181903975194
# average reward exploit: MDP 8 -234.6718026570871 20
# average reward exploit: MDP 8 -143.36640536726102 20
# average reward exploit: MDP 8 -121.1244334480075 20
# average reward exploit: MDP 8 -92.80530587344415 20
# average reward exploit: MDP 8 -86.36059897718562 20
# average reward exploit: MDP 8 18.158338576315803 20
# average reward exploit: MDP 8 55.27407648140881 20
# average reward exploit: MDP 8 -106.33648173582603 20
# average reward exploit: MDP 8 -183.8069063784331 20
# average reward exploit: MDP 8 -146.28679106805794 20
# average reward explore: -565.5143053391014
# average reward exploit: MDP 9 9.362719728636815 20
# average reward exploit: MDP 9 111.59908920729826 20
# average reward exploit: MDP 9 54.41655041746306 20
# average reward exploit: MDP 9 63.670331410476365 20
# average reward exploit: MDP 9 -119.81208108603701 20
# average reward exploit: MDP 9 -95.55793991321774 20
# average reward exploit: MDP 9 -169.49766917842865 20
# average reward exploit: MDP 9 -210.7054105363768 20
# average reward exploit: MDP 9 -277.2769178589584 20
# average reward exploit: MDP 9 -154.16742714557284 20
# epoch number:  4
# average reward explore: -578.3969591237083
# average reward exploit: MDP 0 -164.35381146524614 20
# average reward exploit: MDP 0 -255.9621964319747 20
# average reward exploit: MDP 0 -260.1585308172009 20
# average reward exploit: MDP 0 -145.31276910542073 20
# average reward exploit: MDP 0 -130.28285510629794 20
# average reward exploit: MDP 0 -174.22948485992083 20
# average reward exploit: MDP 0 -188.01504169420832 20
# average reward exploit: MDP 0 -195.61342831780948 20
# average reward exploit: MDP 0 -202.6118439387356 20
# average reward exploit: MDP 0 -266.91959736292034 20
# average reward explore: -556.7866913074154
# average reward exploit: MDP 1 -187.08961050610552 20
# average reward exploit: MDP 1 -243.78606726964685 20
# average reward exploit: MDP 1 -264.71706312455893 20
# average reward exploit: MDP 1 -255.85999317713353 20
# average reward exploit: MDP 1 -211.13195431077605 20
# average reward exploit: MDP 1 -260.4093892813913 20
# average reward exploit: MDP 1 -118.49304491621726 20
# average reward exploit: MDP 1 -56.89763102373271 20
# average reward exploit: MDP 1 -20.769101400885383 20
# average reward exploit: MDP 1 -37.45769888480643 20
# average reward explore: -607.4780340145692
# average reward exploit: MDP 2 -355.2623521691879 20
# average reward exploit: MDP 2 -394.8335701870508 20
# average reward exploit: MDP 2 -306.29153628337355 20
# average reward exploit: MDP 2 -354.9371709275282 20
# average reward exploit: MDP 2 -284.869894447573 20
# average reward exploit: MDP 2 -261.22097849866884 20
# average reward exploit: MDP 2 -270.7727750923188 20
# average reward exploit: MDP 2 -312.3777270157712 20
# average reward exploit: MDP 2 -184.45254087847962 20
# average reward exploit: MDP 2 -179.76391384427615 20
# average reward explore: -593.1290755543507
# average reward exploit: MDP 3 -362.8516907164766 20
# average reward exploit: MDP 3 -303.1937929034884 20
# average reward exploit: MDP 3 -307.17078076482346 20
# average reward exploit: MDP 3 -323.29673271005163 20
# average reward exploit: MDP 3 -272.72698582027544 20
# average reward exploit: MDP 3 -283.4368726243052 20
# average reward exploit: MDP 3 -292.70426270596386 20
# average reward exploit: MDP 3 -219.9741667791186 20
# average reward exploit: MDP 3 -288.65020469007806 20
# average reward exploit: MDP 3 -303.9515717932624 20
# average reward explore: -572.2962007682002
# average reward exploit: MDP 4 -136.80661945124248 20
# average reward exploit: MDP 4 -175.30254342065922 20
# average reward exploit: MDP 4 -133.3938364014972 20
# average reward exploit: MDP 4 -106.56969778733969 20
# average reward exploit: MDP 4 -94.73653884430543 20
# average reward exploit: MDP 4 -116.71446833717069 20
# average reward exploit: MDP 4 -141.01414397018468 20
# average reward exploit: MDP 4 -249.3080375393297 20
# average reward exploit: MDP 4 -199.9873421091906 20
# average reward exploit: MDP 4 -246.3970889224157 20
# average reward explore: -564.5478377843383
# average reward exploit: MDP 5 -541.3515878910437 20
# average reward exploit: MDP 5 -412.8025093160892 20
# average reward exploit: MDP 5 -373.2786892776261 20
# average reward exploit: MDP 5 -378.1383471665612 20
# average reward exploit: MDP 5 -349.3931191882599 20
# average reward exploit: MDP 5 -333.4389677669839 20
# average reward exploit: MDP 5 -309.9316544048235 20
# average reward exploit: MDP 5 -339.15385693981443 20
# average reward exploit: MDP 5 -322.4104064181011 20
# average reward exploit: MDP 5 -339.0581640740684 20
# average reward explore: -541.5028853910742
# average reward exploit: MDP 6 -94.15985096238887 20
# average reward exploit: MDP 6 -9.16970581566115 20
# average reward exploit: MDP 6 -97.01076035214571 20
# average reward exploit: MDP 6 -130.96020715787546 20
# average reward exploit: MDP 6 -182.5903631326285 20
# average reward exploit: MDP 6 -135.16253242241567 20
# average reward exploit: MDP 6 -165.81757563206332 20
# average reward exploit: MDP 6 -245.21877546043038 20
# average reward exploit: MDP 6 -272.5750938019535 20
# average reward exploit: MDP 6 -243.97317058586447 20
# average reward explore: -527.4649347154602
# average reward exploit: MDP 7 -273.57769009537463 20
# average reward exploit: MDP 7 -266.39677587229704 20
# average reward exploit: MDP 7 -229.5392939040193 20
# average reward exploit: MDP 7 -288.5108071516205 20
# average reward exploit: MDP 7 -272.6358000885968 20
# average reward exploit: MDP 7 -262.29548691783765 20
# average reward exploit: MDP 7 -240.66066675669194 20
# average reward exploit: MDP 7 -171.1104361303675 20
# average reward exploit: MDP 7 -291.24176608971817 20
# average reward exploit: MDP 7 -236.4736748152555 20
# average reward explore: -544.0097891565841
# average reward exploit: MDP 8 -426.5464533777443 20
# average reward exploit: MDP 8 -392.3724581749329 20
# average reward exploit: MDP 8 -294.2313450720436 20
# average reward exploit: MDP 8 -191.71529808428747 20
# average reward exploit: MDP 8 -229.44825485639345 20
# average reward exploit: MDP 8 -273.3705966393653 20
# average reward exploit: MDP 8 -238.7599836628205 20
# average reward exploit: MDP 8 -117.09149428603268 20
# average reward exploit: MDP 8 -156.54733593992336 20
# average reward exploit: MDP 8 -123.37336312164616 20
# average reward explore: -526.5041612233811
# average reward exploit: MDP 9 140.24683741074506 20
# average reward exploit: MDP 9 49.914494140779766 20
# average reward exploit: MDP 9 73.28323056654486 20
# average reward exploit: MDP 9 80.49237360341121 20
# average reward exploit: MDP 9 224.63906165123086 20
# average reward exploit: MDP 9 83.38085868020887 20
# average reward exploit: MDP 9 171.9634864924787 20
# average reward exploit: MDP 9 329.42781752847674 20
# average reward exploit: MDP 9 267.7196067819299 20
# average reward exploit: MDP 9 277.97987375832156 20
# epoch number:  5
# average reward explore: -524.2089302051279
# average reward exploit: MDP 0 -241.28752678426122 20
# average reward exploit: MDP 0 -232.13699912627922 20
# average reward exploit: MDP 0 -266.304561781419 20
# average reward exploit: MDP 0 -217.51736725759352 20
# average reward exploit: MDP 0 -252.764417503551 20
# average reward exploit: MDP 0 -251.7019151191069 20
# average reward exploit: MDP 0 -242.5793674303753 20
# average reward exploit: MDP 0 -250.93770529683866 20
# average reward exploit: MDP 0 -291.3139893328128 20
# average reward exploit: MDP 0 -250.08356464276284 20
# average reward explore: -505.55404800574127
# average reward exploit: MDP 1 -365.77954829265946 20
# average reward exploit: MDP 1 -502.12387355103374 20
# average reward exploit: MDP 1 -359.74931656004526 20
# average reward exploit: MDP 1 -516.5249738685919 20
# average reward exploit: MDP 1 -509.62414212106916 20
# average reward exploit: MDP 1 -477.4574680967609 20
# average reward exploit: MDP 1 -379.5120643653428 20
# average reward exploit: MDP 1 -313.9177745899566 20
# average reward exploit: MDP 1 -344.53133123661826 20
# average reward exploit: MDP 1 -314.5112590396801 20
# average reward explore: -532.9706164226943
# average reward exploit: MDP 2 -179.29960002382248 20
# average reward exploit: MDP 2 -96.65216431755513 20
# average reward exploit: MDP 2 -86.21526650480652 20
# average reward exploit: MDP 2 -91.21542178379818 20
# average reward exploit: MDP 2 -156.1102899712634 20
# average reward exploit: MDP 2 -82.00999397195037 20
# average reward exploit: MDP 2 -106.15443501715228 20
# average reward exploit: MDP 2 -68.99798928634472 20
# average reward exploit: MDP 2 -146.79951294514333 20
# average reward exploit: MDP 2 -173.1302446073857 20
# average reward explore: -508.9781716671847
# average reward exploit: MDP 3 -566.2594508925351 20
# average reward exploit: MDP 3 -526.1028451094069 20
# average reward exploit: MDP 3 -617.7308884802753 20
# average reward exploit: MDP 3 -557.0912772201374 20
# average reward exploit: MDP 3 -535.4442764217006 20
# average reward exploit: MDP 3 -538.6011562675344 20
# average reward exploit: MDP 3 -555.4485491422504 20
# average reward exploit: MDP 3 -526.6255593041315 20
# average reward exploit: MDP 3 -387.19630068686246 20
# average reward exploit: MDP 3 -296.4304439296081 20
# average reward explore: -514.2866532839746
# average reward exploit: MDP 4 -319.26048724746863 20
# average reward exploit: MDP 4 -306.7911129259189 20
# average reward exploit: MDP 4 -282.4406312612695 20
# average reward exploit: MDP 4 -277.9839291388002 20
# average reward exploit: MDP 4 -258.09042485299017 20
# average reward exploit: MDP 4 -234.5576828946169 20
# average reward exploit: MDP 4 -247.94795807561277 20
# average reward exploit: MDP 4 -231.11888642009177 20
# average reward exploit: MDP 4 -207.65899555345877 20
# average reward exploit: MDP 4 -265.6375814835062 20
# average reward explore: -509.4241032488182
# average reward exploit: MDP 5 -6.492608776316656 20
# average reward exploit: MDP 5 22.42323794316788 20
# average reward exploit: MDP 5 -32.21476383620386 20
# average reward exploit: MDP 5 13.66304056429951 20
# average reward exploit: MDP 5 -80.02068599492125 20
# average reward exploit: MDP 5 -75.73856670928808 20
# average reward exploit: MDP 5 -127.7583513377067 20
# average reward exploit: MDP 5 -162.3443788403268 20
# average reward exploit: MDP 5 -189.64694873797345 20
# average reward exploit: MDP 5 -221.88622082616195 20
# average reward explore: -511.03998158069965
# average reward exploit: MDP 6 -400.3987960835737 20
# average reward exploit: MDP 6 -393.25505906812333 20
# average reward exploit: MDP 6 -374.2137021983891 20
# average reward exploit: MDP 6 -396.09071099854816 20
# average reward exploit: MDP 6 -397.93888674206903 20
# average reward exploit: MDP 6 -460.8698005775873 20
# average reward exploit: MDP 6 -449.91548458493014 20
# average reward exploit: MDP 6 -459.763660737574 20
# average reward exploit: MDP 6 -454.0246255123428 20
# average reward exploit: MDP 6 -449.4003252558483 20
# average reward explore: -486.242256904462
# average reward exploit: MDP 7 16.067453842800923 20
# average reward exploit: MDP 7 35.602292156158384 20
# average reward exploit: MDP 7 -89.28295682262095 20
# average reward exploit: MDP 7 -122.12297810689365 20
# average reward exploit: MDP 7 -32.57711478732191 20
# average reward exploit: MDP 7 -226.17371616697443 20
# average reward exploit: MDP 7 -135.24667708502488 20
# average reward exploit: MDP 7 -179.52241064738905 20
# average reward exploit: MDP 7 -147.31630748783624 20
# average reward exploit: MDP 7 -215.45858742934402 20
# average reward explore: -477.07489758898464
# average reward exploit: MDP 8 -140.41959447664016 20
# average reward exploit: MDP 8 -64.38168701685359 20
# average reward exploit: MDP 8 -133.93236135464645 20
# average reward exploit: MDP 8 13.92846053800412 20
# average reward exploit: MDP 8 26.524268621401575 20
# average reward exploit: MDP 8 172.11991348514715 20
# average reward exploit: MDP 8 238.52653616226266 20
# average reward exploit: MDP 8 164.45319619777746 20
# average reward exploit: MDP 8 -124.67767345392556 20
# average reward exploit: MDP 8 -160.37975450654784 20
# average reward explore: -477.9669058162056
# average reward exploit: MDP 9 -297.60888707739645 20
# average reward exploit: MDP 9 -304.16933547624143 20
# average reward exploit: MDP 9 -317.6650515856875 20
# average reward exploit: MDP 9 -274.03524024566394 20
# average reward exploit: MDP 9 -271.31765537546835 20
# average reward exploit: MDP 9 -262.35093689540656 20
# average reward exploit: MDP 9 -297.9206154363919 20
# average reward exploit: MDP 9 -325.07231895015923 20
# average reward exploit: MDP 9 -289.09745999439644 20
# average reward exploit: MDP 9 -271.3212796178871 20
# epoch number:  6
# average reward explore: -474.3477483622836
# average reward exploit: MDP 0 -281.21245746210354 20
# average reward exploit: MDP 0 -137.35565684524585 20
# average reward exploit: MDP 0 -209.27679531890757 20
# average reward exploit: MDP 0 -240.45926369690864 20
# average reward exploit: MDP 0 -215.98512662820494 20
# average reward exploit: MDP 0 -231.62840726511862 20
# average reward exploit: MDP 0 -241.75940630982805 20
# average reward exploit: MDP 0 -182.92533636317128 20
# average reward exploit: MDP 0 -199.750644413267 20
# average reward exploit: MDP 0 -198.95583599563773 20
# average reward explore: -474.1094755024622
# average reward exploit: MDP 1 40.03097996770724 20
# average reward exploit: MDP 1 96.70620478454036 20
# average reward exploit: MDP 1 54.814303041064115 20
# average reward exploit: MDP 1 39.88487750139926 20
# average reward exploit: MDP 1 197.46756578692685 20
# average reward exploit: MDP 1 54.78755986156267 20
# average reward exploit: MDP 1 -10.697709844311605 20
# average reward exploit: MDP 1 -48.27106483121611 20
# average reward exploit: MDP 1 31.16181210196075 20
# average reward exploit: MDP 1 -111.9301668575512 20
# average reward explore: -475.2153505064454
# average reward exploit: MDP 2 130.13650083980116 20
# average reward exploit: MDP 2 31.015278871977138 20
# average reward exploit: MDP 2 -35.64551211888813 20
# average reward exploit: MDP 2 96.60180929426583 20
# average reward exploit: MDP 2 49.282522007980894 20
# average reward exploit: MDP 2 201.7065705961782 20
# average reward exploit: MDP 2 117.37560742588207 20
# average reward exploit: MDP 2 108.95391264158977 20
# average reward exploit: MDP 2 202.61528506335216 20
# average reward exploit: MDP 2 38.30465291680821 20
# average reward explore: -456.09457264314244
# average reward exploit: MDP 3 -204.34489253809073 20
# average reward exploit: MDP 3 -221.91684802685944 20
# average reward exploit: MDP 3 -237.77942300425352 20
# average reward exploit: MDP 3 -103.0014264598882 20
# average reward exploit: MDP 3 -228.6859217882019 20
# average reward exploit: MDP 3 -169.43709743202905 20
# average reward exploit: MDP 3 -107.02997455452746 20
# average reward exploit: MDP 3 128.35825673985175 20
# average reward exploit: MDP 3 142.78116771081415 20
# average reward exploit: MDP 3 -91.39285160262847 20
# average reward explore: -447.7493738327679
# average reward exploit: MDP 4 53.78887836122321 20
# average reward exploit: MDP 4 27.6338534927906 20
# average reward exploit: MDP 4 107.89149891990193 20
# average reward exploit: MDP 4 169.27476001746035 20
# average reward exploit: MDP 4 87.0863166436701 20
# average reward exploit: MDP 4 -100.93307499085296 20
# average reward exploit: MDP 4 -126.43339621377052 20
# average reward exploit: MDP 4 -207.6806524203073 20
# average reward exploit: MDP 4 -222.4344886378413 20
# average reward exploit: MDP 4 -273.5281637330612 20
# average reward explore: -437.96474394271627
# average reward exploit: MDP 5 -208.66576051062597 20
# average reward exploit: MDP 5 -159.0657285472408 20
# average reward exploit: MDP 5 -122.6967738317743 20
# average reward exploit: MDP 5 -68.1436879218272 20
# average reward exploit: MDP 5 -189.91021840841347 20
# average reward exploit: MDP 5 -168.09483977502418 20
# average reward exploit: MDP 5 -169.2012903279702 20
# average reward exploit: MDP 5 -171.46926049995105 20
# average reward exploit: MDP 5 -144.41519253396933 20
# average reward exploit: MDP 5 -155.76840344042256 20
# average reward explore: -450.515974668538
# average reward exploit: MDP 6 -295.78148211852135 20
# average reward exploit: MDP 6 -275.9696332803052 20
# average reward exploit: MDP 6 -243.26564790485077 20
# average reward exploit: MDP 6 -216.2852340872862 20
# average reward exploit: MDP 6 -125.81750412129256 20
# average reward exploit: MDP 6 -69.90415809689422 20
# average reward exploit: MDP 6 -64.73930737606632 20
# average reward exploit: MDP 6 15.101493463310026 20
# average reward exploit: MDP 6 94.13728378502931 20
# average reward exploit: MDP 6 109.64106077498995 20
# average reward explore: -450.6959463085171
# average reward exploit: MDP 7 575.5780382918892 20
# average reward exploit: MDP 7 515.5782853702581 20
# average reward exploit: MDP 7 247.94815215615145 20
# average reward exploit: MDP 7 130.29544970967265 20
# average reward exploit: MDP 7 -123.09998782404227 20
# average reward exploit: MDP 7 -149.457172101995 20
# average reward exploit: MDP 7 -219.08575143238392 20
# average reward exploit: MDP 7 -104.71838951366131 20
# average reward exploit: MDP 7 -162.32681427964366 20
# average reward exploit: MDP 7 -104.77013100455297 20
# average reward explore: -434.81676527057346
# average reward exploit: MDP 8 -104.20832006155834 20
# average reward exploit: MDP 8 -128.9763996627137 20
# average reward exploit: MDP 8 -148.6904811386117 20
# average reward exploit: MDP 8 -113.24140065752961 20
# average reward exploit: MDP 8 -188.13134930160848 20
# average reward exploit: MDP 8 -187.79435097492575 20
# average reward exploit: MDP 8 -75.64483394191402 20
# average reward exploit: MDP 8 -118.78485013319718 20
# average reward exploit: MDP 8 -200.34521876614193 20
# average reward exploit: MDP 8 -178.2518347454016 20
# average reward explore: -446.4655682643521
# average reward exploit: MDP 9 -261.1794268049195 20
# average reward exploit: MDP 9 -249.85569186826396 20
# average reward exploit: MDP 9 -210.96856487449872 20
# average reward exploit: MDP 9 -231.01020221216692 20
# average reward exploit: MDP 9 -202.66897500314647 20
# average reward exploit: MDP 9 -141.79415494532898 20
# average reward exploit: MDP 9 -145.15054008710786 20
# average reward exploit: MDP 9 -38.58607290644404 20
# average reward exploit: MDP 9 -147.5327296469522 20
# average reward exploit: MDP 9 -12.852369680830725 20
# epoch number:  7
# average reward explore: -416.45379357473183
# average reward exploit: MDP 0 342.11677691743034 20
# average reward exploit: MDP 0 278.55375210819153 20
# average reward exploit: MDP 0 270.44179487495705 20
# average reward exploit: MDP 0 235.55290068017197 20
# average reward exploit: MDP 0 99.0625453867978 20
# average reward exploit: MDP 0 -32.46318332210431 20
# average reward exploit: MDP 0 -111.74574444299128 20
# average reward exploit: MDP 0 -81.72062205053807 20
# average reward exploit: MDP 0 -71.50537345885253 20
# average reward exploit: MDP 0 -109.65460007614907 20
# average reward explore: -425.1849062376541
# average reward exploit: MDP 1 -240.0095687883424 20
# average reward exploit: MDP 1 -256.3030336501407 20
# average reward exploit: MDP 1 -251.66770416466497 20
# average reward exploit: MDP 1 -202.77667544426185 20
# average reward exploit: MDP 1 -236.11721884718372 20
# average reward exploit: MDP 1 -189.52637328218083 20
# average reward exploit: MDP 1 -198.70346211806026 20
# average reward exploit: MDP 1 -188.9964638495714 20
# average reward exploit: MDP 1 -225.99049466908164 20
# average reward exploit: MDP 1 -211.3102991886363 20
# average reward explore: -433.65353998605497
# average reward exploit: MDP 2 -323.8523484868507 20
# average reward exploit: MDP 2 -248.08068095537624 20
# average reward exploit: MDP 2 -194.86165450806018 20
# average reward exploit: MDP 2 -205.8940313260197 20
# average reward exploit: MDP 2 -155.94852831097376 20
# average reward exploit: MDP 2 -146.30677960764555 20
# average reward exploit: MDP 2 -85.90482168867665 20
# average reward exploit: MDP 2 -88.37970343037243 20
# average reward exploit: MDP 2 7.928901941574867 20
# average reward exploit: MDP 2 41.93098743726865 20
# average reward explore: -409.0217211206156
# average reward exploit: MDP 3 250.05240098552548 20
# average reward exploit: MDP 3 155.7339911202857 20
# average reward exploit: MDP 3 182.33672290839158 20
# average reward exploit: MDP 3 288.8255832087125 20
# average reward exploit: MDP 3 201.68327635487384 20
# average reward exploit: MDP 3 137.70273620065194 20
# average reward exploit: MDP 3 84.18399149684194 20
# average reward exploit: MDP 3 30.186152919596275 20
# average reward exploit: MDP 3 50.39244905342804 20
# average reward exploit: MDP 3 119.4480966281221 20
# average reward explore: -404.8957905637093
# average reward exploit: MDP 4 69.11114666936935 20
# average reward exploit: MDP 4 132.34768563102668 20
# average reward exploit: MDP 4 102.99994654815161 20
# average reward exploit: MDP 4 204.7385765548562 20
# average reward exploit: MDP 4 66.45706919773806 20
# average reward exploit: MDP 4 158.31625716633852 20
# average reward exploit: MDP 4 193.63504369163016 20
# average reward exploit: MDP 4 -22.871790038780905 20
# average reward exploit: MDP 4 -21.9968751694678 20
# average reward exploit: MDP 4 -58.3643306226253 20
# average reward explore: -415.5892017622817
# average reward exploit: MDP 5 -217.940914351118 20
# average reward exploit: MDP 5 -172.35615175552965 20
# average reward exploit: MDP 5 -123.17144374647705 20
# average reward exploit: MDP 5 -120.34939294051655 20
# average reward exploit: MDP 5 -135.73160668361507 20
# average reward exploit: MDP 5 -118.39403765406205 20
# average reward exploit: MDP 5 -115.51343841769851 20
# average reward exploit: MDP 5 -39.6500417817837 20
# average reward exploit: MDP 5 -60.53493946203023 20
# average reward exploit: MDP 5 -9.71195231116288 20
# average reward explore: -411.69223313721716
# average reward exploit: MDP 6 -147.53264196975152 20
# average reward exploit: MDP 6 -112.88846837853916 20
# average reward exploit: MDP 6 -157.794894497524 20
# average reward exploit: MDP 6 -133.3763433808337 20
# average reward exploit: MDP 6 -170.58316761741474 20
# average reward exploit: MDP 6 -87.53217268707625 20
# average reward exploit: MDP 6 -83.6804233517561 20
# average reward exploit: MDP 6 -86.42183875069158 20
# average reward exploit: MDP 6 27.31295057794142 20
# average reward exploit: MDP 6 103.6492117420958 20
# average reward explore: -368.50006555443815
# average reward exploit: MDP 7 83.49578541815777 20
# average reward exploit: MDP 7 42.29501646294307 20
# average reward exploit: MDP 7 -101.084426732659 20
# average reward exploit: MDP 7 -152.78784696843834 20
# average reward exploit: MDP 7 -106.26249819602113 20
# average reward exploit: MDP 7 -186.13459909414564 20
# average reward exploit: MDP 7 -181.70080788688605 20
# average reward exploit: MDP 7 -227.19413269271627 20
# average reward exploit: MDP 7 -225.04183054651557 20
# average reward exploit: MDP 7 -1.4970839272807552 20
# average reward explore: -408.43899066432726
# average reward exploit: MDP 8 -29.76370741560956 20
# average reward exploit: MDP 8 -63.997353905402704 20
# average reward exploit: MDP 8 -18.814723521517855 20
# average reward exploit: MDP 8 -64.07736524157869 20
# average reward exploit: MDP 8 113.89941165867204 20
# average reward exploit: MDP 8 -53.33078750631946 20
# average reward exploit: MDP 8 30.452426216366327 20
# average reward exploit: MDP 8 -0.9176233346698488 20
# average reward exploit: MDP 8 -78.94215608685889 20
# average reward exploit: MDP 8 111.21107714386503 20
# average reward explore: -414.1298533487814
# average reward exploit: MDP 9 12.045149886327659 20
# average reward exploit: MDP 9 9.040639934190228 20
# average reward exploit: MDP 9 72.97239841415862 20
# average reward exploit: MDP 9 7.842786909112974 20
# average reward exploit: MDP 9 178.51456592282344 20
# average reward exploit: MDP 9 96.42670060873805 20
# average reward exploit: MDP 9 8.258170313935059 20
# average reward exploit: MDP 9 71.23073159821385 20
# average reward exploit: MDP 9 81.2764954407447 20
# average reward exploit: MDP 9 23.11593575617498 20
# epoch number:  8
# average reward explore: -392.88848348002057
# average reward exploit: MDP 0 -151.0615718489741 20
# average reward exploit: MDP 0 -177.3132214577355 20
# average reward exploit: MDP 0 -164.05575387616278 20
# average reward exploit: MDP 0 -151.92371301510371 20
# average reward exploit: MDP 0 -128.03568578774576 20
# average reward exploit: MDP 0 -137.68398230729974 20
# average reward exploit: MDP 0 -97.36824509150095 20
# average reward exploit: MDP 0 -162.91801576796811 20
# average reward exploit: MDP 0 -84.39231799987468 20
# average reward exploit: MDP 0 -157.93591229471417 20
# average reward explore: -377.92828590866344
# average reward exploit: MDP 1 213.4132559420174 20
# average reward exploit: MDP 1 176.45129885248684 20
# average reward exploit: MDP 1 34.26061062178229 20
# average reward exploit: MDP 1 180.62824342409152 20
# average reward exploit: MDP 1 121.3481074454733 20
# average reward exploit: MDP 1 10.360268651737451 20
# average reward exploit: MDP 1 -54.58471732520354 20
# average reward exploit: MDP 1 -104.93003207655099 20
# average reward exploit: MDP 1 -97.10144790204909 20
# average reward exploit: MDP 1 -12.561392171755987 20
# average reward explore: -399.6463672284271
# average reward exploit: MDP 2 26.167640873690836 20
# average reward exploit: MDP 2 -18.87244782193531 20
# average reward exploit: MDP 2 -1.5619273707491985 20
# average reward exploit: MDP 2 -24.165413195111096 20
# average reward exploit: MDP 2 -24.284659855057033 20
# average reward exploit: MDP 2 3.236050580009882 20
# average reward exploit: MDP 2 -41.82231160185141 20
# average reward exploit: MDP 2 -49.822955054497974 20
# average reward exploit: MDP 2 34.880924689880814 20
# average reward exploit: MDP 2 -58.12488229272683 20
# average reward explore: -383.4343348786594
# average reward exploit: MDP 3 -46.70209580607285 20
# average reward exploit: MDP 3 65.01181096229001 20
# average reward exploit: MDP 3 65.26297569562692 20
# average reward exploit: MDP 3 154.57359784707108 20
# average reward exploit: MDP 3 203.69843726259484 20
# average reward exploit: MDP 3 394.5861785983752 20
# average reward exploit: MDP 3 413.84818324487225 20
# average reward exploit: MDP 3 449.2313645818652 20
# average reward exploit: MDP 3 483.0555743251713 20
# average reward exploit: MDP 3 198.85119866545332 20
# average reward explore: -367.3726259637866
# average reward exploit: MDP 4 -89.85662059837277 20
# average reward exploit: MDP 4 -157.6731077407874 20
# average reward exploit: MDP 4 -87.4258595626745 20
# average reward exploit: MDP 4 -71.82063679584637 20
# average reward exploit: MDP 4 -72.04909671852174 20
# average reward exploit: MDP 4 -78.74843910731394 20
# ...
# average reward exploit: MDP 3 460.9311732781007 20
# average reward explore: 834.0309636726764
# average reward exploit: MDP 4 -600.4839306102637 20
# average reward exploit: MDP 4 -600.4595003413018 20
# average reward exploit: MDP 4 -599.9576720049175 20
# average reward exploit: MDP 4 -608.9945483553591 20
# average reward exploit: MDP 4 -628.8996292350223 20
# average reward exploit: MDP 4 -602.8815085174859 20
# average reward exploit: MDP 4 -624.096502450762 20
# average reward exploit: MDP 4 -629.7565152610883 20
# average reward exploit: MDP 4 -644.5214532979055 20
# average reward exploit: MDP 4 -639.5148164464792 20
# average reward explore: 835.9831936138696
# average reward exploit: MDP 5 538.9261525288496 20
# average reward exploit: MDP 5 461.5179163428735 20
# average reward exploit: MDP 5 516.8325099015626 20
# average reward exploit: MDP 5 485.0784281511991 20
# average reward exploit: MDP 5 487.9343500331132 20
# average reward exploit: MDP 5 398.7475382747252 20
# average reward exploit: MDP 5 538.3662158700474 20
# average reward exploit: MDP 5 488.97562541485013 20
# average reward exploit: MDP 5 523.8234394984016 20
# average reward exploit: MDP 5 489.5602656861335 20
# average reward explore: 844.4643803590232
# average reward exploit: MDP 6 -582.8469652455558 20
# average reward exploit: MDP 6 -613.3829537276526 20
# average reward exploit: MDP 6 -704.8571252026525 20
# average reward exploit: MDP 6 -546.888220136124 20
# average reward exploit: MDP 6 -1102.6395919289384 20
# average reward exploit: MDP 6 -694.7037688670318 20
# average reward exploit: MDP 6 -1248.7471861620236 20
# average reward exploit: MDP 6 -1099.1136245300895 20
# average reward exploit: MDP 6 -1105.0863854218499 20
# average reward exploit: MDP 6 -1170.0180025695634 20
# average reward explore: 865.5112451394391
# average reward exploit: MDP 7 201.56238258195924 20
# average reward exploit: MDP 7 211.45071268125403 20
# average reward exploit: MDP 7 223.71045627475786 20
# average reward exploit: MDP 7 245.40352148887692 20
# average reward exploit: MDP 7 151.3777686361289 20
# average reward exploit: MDP 7 137.44852761911025 20
# average reward exploit: MDP 7 140.87177165763444 20
# average reward exploit: MDP 7 105.10763963159017 20
# average reward exploit: MDP 7 145.1029911465564 20
# average reward exploit: MDP 7 43.89675138654543 20
# average reward explore: 842.4340390854916
# average reward exploit: MDP 8 -2881.914050853172 20
# average reward exploit: MDP 8 -1179.6976370943016 20
# average reward exploit: MDP 8 -662.734108007196 20
# average reward exploit: MDP 8 -430.51586824965415 20
# average reward exploit: MDP 8 -238.69499674350928 20
# average reward exploit: MDP 8 -295.1065862662166 20
# average reward exploit: MDP 8 -357.58919597362853 20
# average reward exploit: MDP 8 -399.74417283572444 20
# average reward exploit: MDP 8 -427.42382779214876 20
# average reward exploit: MDP 8 -424.2974547484907 20
# average reward explore: 890.9487967209279
# average reward exploit: MDP 9 -2783.8942748373524 20
# average reward exploit: MDP 9 -2073.6566065184056 20
# average reward exploit: MDP 9 -2109.010235794616 20
# average reward exploit: MDP 9 -1781.874041561367 20
# average reward exploit: MDP 9 -1537.51005973175 20
# average reward exploit: MDP 9 -1577.4598395361022 20
# average reward exploit: MDP 9 -1607.5936654343318 20
# average reward exploit: MDP 9 -1507.0716527487152 20
# average reward exploit: MDP 9 -1419.0070648370324 20
# average reward exploit: MDP 9 -1427.9640808826098 20
# epoch number:  36
# average reward explore: 879.2766644191564
# average reward exploit: MDP 0 -1073.1605713357676 20
# average reward exploit: MDP 0 -1079.3673932760207 20
# average reward exploit: MDP 0 -996.2373054755795 20
# average reward exploit: MDP 0 -895.4369546826232 20
# average reward exploit: MDP 0 -811.6172933485882 20
# average reward exploit: MDP 0 -743.0658421295784 20
# average reward exploit: MDP 0 -703.2947164832896 20
# average reward exploit: MDP 0 -664.3551492643004 20
# average reward exploit: MDP 0 -613.3962015367126 20
# average reward exploit: MDP 0 -553.1832668116717 20
# average reward explore: 855.9687459516878
# average reward exploit: MDP 1 -349.46193992628537 20
# average reward exploit: MDP 1 -312.68673866332495 20
# average reward exploit: MDP 1 -288.6589491614135 20
# average reward exploit: MDP 1 -252.99469640136954 20
# average reward exploit: MDP 1 -222.85559259078536 20
# average reward exploit: MDP 1 -180.7470813417189 20
# average reward exploit: MDP 1 -145.71757480021785 20
# average reward exploit: MDP 1 -117.61001197526828 20
# average reward exploit: MDP 1 -81.85560489903929 20
# average reward exploit: MDP 1 -59.30696129533923 20
# average reward explore: 863.2900349372187
# average reward exploit: MDP 2 -1208.1909212071052 20
# average reward exploit: MDP 2 -1202.8429582451924 20
# average reward exploit: MDP 2 -1184.0956644260593 20
# average reward exploit: MDP 2 -1129.4274825325379 20
# average reward exploit: MDP 2 -1031.7944212859284 20
# average reward exploit: MDP 2 -904.7161522191598 20
# average reward exploit: MDP 2 -881.2745468484638 20
# average reward exploit: MDP 2 -727.1300588272672 20
# average reward exploit: MDP 2 -613.2429189502388 20
# average reward exploit: MDP 2 -474.8209500631554 20
# average reward explore: 854.5763717684207
# average reward exploit: MDP 3 149.82815870143205 20
# average reward exploit: MDP 3 149.19869364769232 20
# average reward exploit: MDP 3 158.78973451354364 20
# average reward exploit: MDP 3 151.7696796300116 20
# average reward exploit: MDP 3 166.5987162751197 20
# average reward exploit: MDP 3 174.46020184388286 20
# average reward exploit: MDP 3 181.1117299963579 20
# average reward exploit: MDP 3 185.19745662870932 20
# average reward exploit: MDP 3 192.36064036165385 20
# average reward exploit: MDP 3 206.05359672035578 20
# average reward explore: 837.7567999622522
# average reward exploit: MDP 4 -163.68779898482393 20
# average reward exploit: MDP 4 -166.1025185035949 20
# average reward exploit: MDP 4 -155.85363769425516 20
# average reward exploit: MDP 4 -153.58552108400744 20
# average reward exploit: MDP 4 -145.99968582417503 20
# average reward exploit: MDP 4 -131.48865655587673 20
# average reward exploit: MDP 4 -125.60744167513799 20
# average reward exploit: MDP 4 -111.53135157330378 20
# average reward exploit: MDP 4 -120.88987289749852 20
# average reward exploit: MDP 4 -93.67605556220693 20
# average reward explore: 796.9755914253975
# average reward exploit: MDP 5 -47.97114418472043 20
# average reward exploit: MDP 5 -13.610198364520523 20
# average reward exploit: MDP 5 -14.259543335460894 20
# average reward exploit: MDP 5 -0.544026175536662 20
# average reward exploit: MDP 5 12.710408125590357 20
# average reward exploit: MDP 5 49.08249370319894 20
# average reward exploit: MDP 5 12.501197325858342 20
# average reward exploit: MDP 5 58.62839219444538 20
# average reward exploit: MDP 5 92.5042745644834 20
# average reward exploit: MDP 5 86.28141013146212 20
# average reward explore: 796.5457432634679
# average reward exploit: MDP 6 -1655.387175557651 20
# average reward exploit: MDP 6 -1924.3650888144355 20
# average reward exploit: MDP 6 -926.0747662522687 20
# average reward exploit: MDP 6 -1047.6870454993116 20
# average reward exploit: MDP 6 -656.8426895381347 20
# average reward exploit: MDP 6 -370.34026178991064 20
# average reward exploit: MDP 6 -176.4765664799025 20
# average reward exploit: MDP 6 -157.3139013030864 20
# average reward exploit: MDP 6 -178.8600363708842 20
# average reward exploit: MDP 6 -175.24103006374975 20
# average reward explore: 823.5394627233807
# average reward exploit: MDP 7 -421.3976390919869 20
# average reward exploit: MDP 7 -405.54644567178076 20
# average reward exploit: MDP 7 -398.05872143611776 20
# average reward exploit: MDP 7 -370.78826026580543 20
# average reward exploit: MDP 7 -329.4720532452674 20
# average reward exploit: MDP 7 -347.1184388127058 20
# average reward exploit: MDP 7 -326.9903903012045 20
# average reward exploit: MDP 7 -283.2873261701186 20
# average reward exploit: MDP 7 -307.49381851161695 20
# average reward exploit: MDP 7 -269.95672919007814 20
# average reward explore: 838.3498741285588
# average reward exploit: MDP 8 126.23890871185635 20
# average reward exploit: MDP 8 119.07186845689714 20
# average reward exploit: MDP 8 128.48588673819248 20
# average reward exploit: MDP 8 115.20391424069369 20
# average reward exploit: MDP 8 126.54952851005851 20
# average reward exploit: MDP 8 140.69467717751812 20
# average reward exploit: MDP 8 149.43187036768228 20
# average reward exploit: MDP 8 141.75612810081043 20
# average reward exploit: MDP 8 166.76653577341997 20
# average reward exploit: MDP 8 147.81061783938196 20
# average reward explore: 869.1548505095814
# average reward exploit: MDP 9 136.69564885168964 20
# average reward exploit: MDP 9 126.0297021124821 20
# average reward exploit: MDP 9 129.2607525130084 20
# average reward exploit: MDP 9 136.20903035968524 20
# average reward exploit: MDP 9 134.240743742196 20
# average reward exploit: MDP 9 141.46997380777222 20
# average reward exploit: MDP 9 138.84614906157194 20
# average reward exploit: MDP 9 142.83629947938516 20
# average reward exploit: MDP 9 144.57639726181583 20
# average reward exploit: MDP 9 147.52834093840764 20
# epoch number:  37
# average reward explore: 872.8877187849688
# average reward exploit: MDP 0 -34.3594125848028 20
# average reward exploit: MDP 0 -34.56739724749609 20
# average reward exploit: MDP 0 -29.40573693478887 20
# average reward exploit: MDP 0 -11.135509332806723 20
# average reward exploit: MDP 0 -0.6207772285391062 20
# average reward exploit: MDP 0 0.4553471663991429 20
# average reward exploit: MDP 0 21.885037957285956 20
# average reward exploit: MDP 0 33.49533450652684 20
# average reward exploit: MDP 0 45.78590227468932 20
# average reward exploit: MDP 0 65.65068124154324 20
# average reward explore: 868.9577790427047
# average reward exploit: MDP 1 -379.589997225313 20
# average reward exploit: MDP 1 -406.3606640086425 20
# average reward exploit: MDP 1 -368.96584287510854 20
# average reward exploit: MDP 1 -347.6867011104193 20
# average reward exploit: MDP 1 -319.2296921236597 20
# average reward exploit: MDP 1 -299.5608765717887 20
# average reward exploit: MDP 1 -299.354988960206 20
# average reward exploit: MDP 1 -265.25884971619655 20
# average reward exploit: MDP 1 -229.01745085413125 20
# average reward exploit: MDP 1 -215.19053767829033 20
# average reward explore: 844.7577631718493
# average reward exploit: MDP 2 157.26945946473748 20
# average reward exploit: MDP 2 175.97050163700965 20
# average reward exploit: MDP 2 172.50462819111257 20
# average reward exploit: MDP 2 193.7152219223823 20
# average reward exploit: MDP 2 193.6932166146481 20
# average reward exploit: MDP 2 223.52964424120438 20
# average reward exploit: MDP 2 239.48781693767347 20
# average reward exploit: MDP 2 216.28837203140665 20
# average reward exploit: MDP 2 273.90464097627944 20
# average reward exploit: MDP 2 300.6516599656623 20
# average reward explore: 870.0678612859363
# average reward exploit: MDP 3 61.020172558691115 20
# average reward exploit: MDP 3 47.512488053274886 20
# average reward exploit: MDP 3 55.053458177208256 20
# average reward exploit: MDP 3 49.250156418872855 20
# average reward exploit: MDP 3 67.71689243452782 20
# average reward exploit: MDP 3 54.435585691722096 20
# average reward exploit: MDP 3 53.2154046358102 20
# average reward exploit: MDP 3 41.92907350605438 20
# average reward exploit: MDP 3 75.83092045945921 20
# average reward exploit: MDP 3 48.6767240304675 20
# average reward explore: 887.3288024927072
# average reward exploit: MDP 4 130.28552197150364 20
# average reward exploit: MDP 4 158.27938259116473 20
# average reward exploit: MDP 4 154.91440761829102 20
# average reward exploit: MDP 4 141.86410143836775 20
# average reward exploit: MDP 4 187.72552832907996 20
# average reward exploit: MDP 4 193.28535060459726 20
# average reward exploit: MDP 4 149.8125393054884 20
# average reward exploit: MDP 4 194.73789199274333 20
# average reward exploit: MDP 4 230.51843605042328 20
# average reward exploit: MDP 4 155.25120122771864 20
# average reward explore: 892.5132992919068
# average reward exploit: MDP 5 -71.83656176747365 20
# average reward exploit: MDP 5 -310.97601100112536 20
# average reward exploit: MDP 5 56.647203760261945 20
# average reward exploit: MDP 5 233.08482778437445 20
# average reward exploit: MDP 5 257.52035496703667 20
# average reward exploit: MDP 5 430.8289442567499 20
# average reward exploit: MDP 5 332.0322624958201 20
# average reward exploit: MDP 5 523.2896266312603 20
# average reward exploit: MDP 5 522.044530411247 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-bde7b6456197> in <module>()
# ----> 1 a.train()
#
# <ipython-input-62-4bae5ac3000e> in train(self)
#     441         for epoch in range(num_epochs):
#     442             print("epoch number: ", epoch)
# --> 443             self.train_step()
#     444
#
# <ipython-input-62-4bae5ac3000e> in train_step(self)
#     391 #             #print(tvars_vals)
#     392             for j in range(10):
# --> 393                 exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z,i)
#     394                 # get observations, actions and rewards
#     395                 observations_exploit = np.concatenate([path["observation"] for path in exploit_paths])
#
# <ipython-input-62-4bae5ac3000e> in sample_paths_exploit(self, env, Z, mdp_num, Test, num_episodes)
#     177             for step in range(self.max_ep_len):
#     178                 states.append(state)
# --> 179                 action = self.sess.run(self.exploit_action, feed_dict={self.observation_placeholder_exploit : state[None], self.decoder_input_placeholder: Z})[0]
#     180                 state, reward, done, info = env.step(action)
#     181                 actions.append(action)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
explore_paths, explore_rewards = a.sample_paths_explore(a.env,1)

# %%
print("average reward explore:", np.mean(explore_rewards))
M = a.stack_trajectories(explore_paths)
# Out:
# average reward explore: 188.03284965532836

# %%
Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })

# %%
Z = np.reshape(Z,[1,len(Z)])

# %%
exploit_paths, exploit_rewards = a.sample_paths_exploit(a.env,Z,1)

# %%
print("average reward exploit", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
# Out:
# average reward exploit 562.4916582849902 400

# %%
a.num_traj = 400

# %%
a.sim.model.opt.gravity[-1] = -15

# %%
observations_explore = np.concatenate([path["observation"] for path in explore_paths])
new_observations_explore = np.concatenate([path["new_obs"] for path in explore_paths])
new_actions_explore = np.concatenate([path["new_acs"] for path in explore_paths])
actions_explore = np.concatenate([path["action"] for path in explore_paths])
rewards_explore = np.concatenate([path["reward"] for path in explore_paths])
returns_explore = a.get_returns(explore_paths, explore = True)

# %%
M = np.array(a.stack_trajectories(explore_paths))
Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })
Z = np.reshape(Z,[1,len(Z)])

# %%
 print("average reward explore: MDP", np.sum(explore_rewards)/num_traj, len(explore_rewards))

# %%
exploit_paths, exploit_rewards = a.sample_paths_exploit(a.env,Z,1000)

# %%
print("average reward exploit: MDP", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))

# %%
def randomize_pendulum(env):
    m = config['pendulum_mass_min'] + np.random.rand()*(config['pendulum_mass_max'] - config['pendulum_mass_min'])
    l = config['pendulum_len_min'] + np.random.rand()*(config['pendulum_len_max'] - config['pendulum_len_min'])
    env.m = m
    env.l = l

# %%
def randomize_hopper(env):
    ts = config['torso_min'] + np.random.rand()*(config['torso_max'] - config['torso_min'])
    f = config['friction_min'] + np.random.rand()*(config['friction_max'] - config['friction_min'])
    
    env.friction = f
    env.torso_size = ts
    env.apply_env_modifications()

# %%
import yaml
cfg_filename = 'hopper-config.yml'
with open(cfg_filename,'r') as ymlfile:
    config = yaml.load(ymlfile)

# %%
env = Randomizer(gym.make('Hopper-v2'), randomize_hopper)
env.unwrapped.__dict__.keys()
env.reset()

# %%
m = config['pendulum_mass_min'] + np.random.rand()*(config['pendulum_mass_max'] - config['pendulum_mass_min'])

# %%
config

# %%
env_id = 'Hopper-v2'
e = gym.make(env_id)

# %%
e.unwrapped.__dict__.keys()

# %%
e.unwrapped.apply_env_modifications()
