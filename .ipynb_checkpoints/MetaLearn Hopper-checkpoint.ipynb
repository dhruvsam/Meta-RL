# %%
# Include Libraries
import numpy as np
import tensorflow as tf
import gym
import tensorflow.contrib.layers as layers
from mujoco_py import load_model_from_xml, MjSim, MjViewer
import policies
import value_functions as vfuncs
import utils_pg as utils

# Environment setup
#env = "CartPole-v0"
#env="InvertedPendulum-v2"
env = "Hopper-v2"

# discrete = isinstance(env.action_space, gym.spaces.Discrete)
# observation_dim = env.observation_space.shape[0]
# action_dim = env.action_space.n if discrete else env.action_space.shape[0]
max_ep_len = 1000
num_traj = 20
#traj_length = max_ep_len*(observation_dim + 2)
latent_size = 100
use_baseline = True

# %%
# Feed forward network (multi-layer-perceptron, or mlp)

def build_mlp(mlp_input,output_size,scope,n_layers,size,output_activation=None):
    '''
    Build a feed forward network
    '''
    Input = mlp_input
    with tf.variable_scope(scope):
        # Dense Layers
        for i in range(n_layers-1):
            dense = tf.layers.dense(inputs = Input, units = size, activation = tf.nn.relu, bias_initializer=tf.constant_initializer(1.0))
            Input = dense
        # Fully Connected Layer
        out = layers.fully_connected(inputs = Input, num_outputs = output_size, activation_fn=output_activation)
    return out

# %%
class MetaLearner():
    def __init__(self, env, max_ep_len, num_traj,latent_size ):
        self.env = gym.make(env)
        self.discrete = isinstance(self.env.action_space, gym.spaces.Discrete)
        self.observation_dim = self.env.observation_space.shape[0]
        self.action_dim = self.env.action_space.n if self.discrete else self.env.action_space.shape[0]
        self.max_ep_len = max_ep_len
        self.num_traj = num_traj
        self.traj_length = self.max_ep_len*(self.observation_dim + 2) # TO Change
        self.use_baseline = True
        self.latent_size = latent_size
        self.feature_size = self.observation_dim + 1 + self.env.action_space.shape[0] # HC
        self.lr = 3e-3
        self.num_layers = 2
        self.layers_size = 32
        self.num_mdps = 10
        self.model = self.env.env.model
        self.sim = MjSim(self.model)
        self.gamma = 0.95
        self.decoder_len = 32

        # build model
        self.ConstructGraph()
    
    def add_placeholders(self):
        self.observation_placeholder_explore = tf.placeholder(tf.float32, shape=(None,self.observation_dim))
        if(self.discrete):
            self.action_placeholder_explore = tf.placeholder(tf.int32, shape=(None))
            self.action_placeholder_exploit = tf.placeholder(tf.int32, shape=(None))
        else:
            self.action_placeholder_explore = tf.placeholder(tf.float32, shape=(None,self.action_dim))
            self.action_placeholder_exploit= tf.placeholder(tf.float32, shape=(None,self.action_dim))

        self.baseline_target_placeholder = tf.placeholder(tf.float32, shape= None)
        self.advantage_placeholder_explore = tf.placeholder(tf.float32, shape=(None))
        
        #self.encoder_input_placeholder = tf.placeholder(tf.float32, shape= (self.num_traj,self.traj_length))
        self.encoder_input_placeholder = tf.placeholder(tf.float32, [None, None, self.feature_size])
        self.decoder_input_placeholder = tf.placeholder(tf.float32, shape= (1,self.latent_size))
        self.sequence_length_placeholder = tf.placeholder(tf.int32, [None, ])
        
        self.observation_placeholder_exploit = tf.placeholder(tf.float32, shape=(None,self.observation_dim))
        #TODO
        self.advantage_placeholder_exploit = tf.placeholder(tf.float32, shape=(None))
        
        
    def build_policy_explore(self, scope = "policy_explore"):
        if (self.discrete):
            self.action_logits = build_mlp(self.observation_placeholder_explore,self.action_dim,scope = scope,n_layers=self.num_layers,size = self.layers_size,output_activation=None)
            self.explore_action = tf.multinomial(self.action_logits,1)
            self.explore_action = tf.squeeze(self.explore_action, axis=1)
            self.explore_logprob = -tf.nn.sparse_softmax_cross_entropy_with_logits(logits = self.action_logits, labels = self.action_placeholder_explore)

        else:   
            action_means = build_mlp(self.observation_placeholder_explore,self.action_dim,scope,n_layers=self.num_layers, size = self.layers_size,output_activation=None)
            init = tf.constant(np.random.rand(1, 2))
            #log_std = tf.get_variable("log_std", [self.action_dim])
            log_std = tf.get_variable(
                'log_std',
                shape=[1, self.action_dim],
                dtype=tf.float32,
                initializer=tf.zeros_initializer(),
                trainable=True
            )
            log_std = tf.log(tf.exp(log_std) + 1.)
            log_std = tf.tile(log_std,
                                   [tf.shape(action_means)[0], 1])
            self.explore_action = tf.random_normal((1,),
                                                   action_means,
                                                   log_std)
            dist = tf.contrib.distributions.MultivariateNormalDiag(action_means, log_std)
            self.explore_logprob = dist.prob(self.action_placeholder_explore, name = 'log_prob')
            #self.explore_action =   action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
            #mvn = tf.contrib.distributions.MultivariateNormalDiag(action_means, tf.exp(log_std))
            #self.explore_logprob =  mvn.log_prob(value = self.action_placeholder_explore, name='log_prob')

    
    
    def build_policy_exploit(self, scope = "policy_exploit"):
        if(self.discrete):
            #self.exploit_action_logits = (tf.matmul(tf.nn.relu(tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W1) + self.d_B1), self.d_W2) + self.d_B2),self.d_W3) + self.d_B3)
            #self.exploit_action_logits = tf.matmul(self.observation_placeholder_exploit,self.d_W3) + self.d_B3
            self.exploit_action_logits = tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W2) + self.d_B2), self.d_W3) + self.d_B3
            self.exploit_action = tf.multinomial(self.exploit_action_logits,1)
            self.exploit_action = tf.squeeze(self.exploit_action, axis=1)
            self.exploit_logprob = -tf.nn.sparse_softmax_cross_entropy_with_logits(logits = self.exploit_action_logits, labels = self.action_placeholder_exploit)
        else:
            action_means = tf.matmul(tf.nn.relu(tf.matmul(self.observation_placeholder_exploit,self.d_W2) + self.d_B2), self.d_W3) + self.d_B3
            init = tf.constant(np.random.rand(1, 2))
            log_std = tf.get_variable("exploit_log_prob", [self.action_dim])
            self.exploit_action = action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
            self.exploit_logprob = utils.gauss_log_prob(mu=action_means, logstd=log_std, x=self.action_placeholder_exploit)
            
#             init = tf.constant(np.random.rand(1, 2))
#             log_std = tf.get_variable("exploit_log_prob", [self.action_dim])
#             self.exploit_action =   action_means + tf.multiply(tf.exp(log_std),tf.random_normal(shape = (self.action_dim,1),mean=0,stddev=1))
#             mvn = tf.contrib.distributions.MultivariateNormalDiag(action_means, tf.exp(log_std))
#             self.exploit_logprob =  mvn.log_prob(value = self.action_placeholder_exploit, name='exploit_log_prob')

        #self.loss_grads_exploit = self.exploit_logprob * self.advantage_placeholder_exploit
        
    def NNEncoder(self, scope = "NNEncoder"):
        self.Z = build_mlp(self.encoder_input_placeholder,self.latent_size,scope = scope,n_layers=3,size = 60,output_activation=None)
    
 

    # input [num_traj, length, features (obs + action + reward) ]
    def LSTMEncoder(self, scope = "LSTMEncoder"):
        self.hidden_size = 64
        initializer = tf.random_uniform_initializer(-1, 1)
        cell = tf.nn.rnn_cell.LSTMCell(self.hidden_size, self.feature_size, initializer=initializer)
        cell_out = tf.contrib.rnn.OutputProjectionWrapper(cell, self.latent_size)
        self.output, _ = tf.nn.dynamic_rnn(cell_out,self.encoder_input_placeholder,self.sequence_length_placeholder,dtype=tf.float32,)
        batch_size = tf.shape(self.output)[0]
        max_length = tf.shape(self.output)[1]
        out_size = int(self.output.get_shape()[2])
        index = tf.range(0, batch_size) * max_length + (self.sequence_length_placeholder - 1)
        flat = tf.reshape(self.output, [-1, out_size])
        self.Z = tf.reduce_mean(tf.gather(flat, index), axis = 0)
        
    
    def Decoder(self, decoder_out_dim, scope):
        return build_mlp(self.decoder_input_placeholder,decoder_out_dim,scope = scope,n_layers=1,size = 64,output_activation=None)
    
    
    def sample_paths_explore(self, env,mdp_num,Test = False, num_episodes = None):
        paths = []
        self.length = []
        episode_rewards = []
        self.sim.model.opt.gravity[-1] = -5 - mdp_num
        for i in range(self.num_traj):
            pad = False
            state = env.reset()
            new_states,states,new_actions, actions, rewards,new_rewards = [], [], [], [], [],[]
            episode_reward = 0
            for step in range(self.max_ep_len):
                if (pad):
                    states.append([0]*self.observation_dim)
                    if(self.discrete):
                        actions.append(0)
                    else:
                        actions.append([0]*self.action_dim)
                    rewards.append(0)
                else:
                    states.append(state)
                    new_states.append(state)
                    #action = self.sess.run(self.explore_action, feed_dict={self.observation_placeholder_explore : states[-1][None]})[0]
                    action = self.policyfn.sample_action(state) #NEW
                    state, reward, done, info = env.step(action)
                    actions.append(action)
                    new_actions.append(action)
                    rewards.append(reward)
                    new_rewards.append(reward)
                    episode_reward += reward
                    if (done or step == self.max_ep_len-1):
                        self.length.append(step + 1)
                        pad = True 
                        
            episode_rewards.append(episode_reward)            
            #print("explore",np.array(actions))
            path = {"new_obs" : np.array(new_states),"observation" : np.array(states),
                                "reward" : np.array(rewards),"new_acs" : np.array(new_actions),
                                "action" : np.array(actions),"new_rewards":np.array(new_rewards)}
            paths.append(path)
        return paths, episode_rewards
    
    def sample_paths_exploit(self, env,Z,mdp_num,Test = False, num_episodes = None):
        self.sim.model.opt.gravity[-1] = -5 - mdp_num
        
        paths = []
        num = 0
        episode_rewards = []
        for i in range(self.num_traj):
            state = env.reset()
            states, actions, rewards = [], [], []
            episode_reward = 0
            for step in range(self.max_ep_len):
                states.append(state)
                action = self.sess.run(self.exploit_action, feed_dict={self.observation_placeholder_exploit : state[None], self.decoder_input_placeholder: Z})[0]
                state, reward, done, info = env.step(action)
                actions.append(action)
                rewards.append(reward)
                episode_reward += reward
                if (done or step == self.max_ep_len-1):
                    episode_rewards.append(episode_reward)
                    break
            #print("exploit",np.array(actions))
            path = {"observation" : np.array(states),
                                "reward" : np.array(rewards),
                                "action" : np.array(actions)}
            paths.append(path)
 
        #print("exploit success: ", num)
        return paths, episode_rewards
    
    def get_returns(self,paths, explore = False):
        all_returns = []
        m = 0
        for path in paths:
            rewards = path["reward"]
            returns = []
            if(explore):
                length = self.length[m]
            else:
                length = len(rewards)
            for i in range(length):
                path_returns = 0
                k = 0
                for j in range(i,length):
                    path_returns = path_returns + rewards[j]*(self.gamma)**k
                    k = k+1
                returns.append(path_returns)
            all_returns.append(returns)
            m+=1
        returns = np.concatenate(all_returns)
        return returns
    
    def stack_trajectories(self,paths):
        trajectories = []
        for path in paths:
            rewards = path["reward"]
            states = path["observation"]
            action = path["action"]
            
            SAR = []
            for i in range(len(states)):
                SAR.append(list(states[i]) + list(action[i]) + [rewards[i]])
            trajectories.append(SAR)
        return np.array(trajectories)
    
    def addBaseline(self):
        self.baseline = build_mlp(self.observation_placeholder_explore,1,scope = "baseline",n_layers=self.num_layers, size = self.layers_size,output_activation=None)
        self.baseline_loss = tf.losses.mean_squared_error(self.baseline_target_placeholder,self.baseline,scope = "baseline")
        baseline_adam_optimizer =  tf.train.AdamOptimizer(learning_rate = self.lr)
        self.update_baseline_op = baseline_adam_optimizer.minimize(self.baseline_loss)

    def calculate_advantage(self,returns, observations):
        if (self.use_baseline):
            baseline = self.sess.run(self.baseline, {input_placeholder:observations})
            adv = returns - baseline
            adv = (adv - np.mean(adv))/np.std(adv)
        else:
            adv = returns
        return adv
    

        
    def ConstructGraph(self):
        tf.reset_default_graph()
        self.sess = tf.Session()
        
        self.vf = vfuncs.NnValueFunction(session=self.sess,ob_dim=self.observation_dim)
        self.policyfn = policies.GaussianPolicy(self.sess,self.observation_dim, self.action_dim)
        
        self.add_placeholders()
        
#         self.add_placeholders()
        
#         self.build_policy_explore()
#         self.explore_policy_loss = -tf.reduce_sum(self.explore_logprob * self.advantage_placeholder_explore)
#         self.loss_grads_explore = -self.explore_logprob * self.advantage_placeholder_explore
#         self.tvars_explore = tf.trainable_variables()
#         self.gradients_explore = tf.gradients(self.explore_policy_loss,self.tvars_explore)
        
#         #self.addBaseline()
        
#         self.baseline = build_mlp(self.observation_placeholder_explore,1,scope = "baseline",n_layers=1, size = 16,output_activation=None)
#         self.baseline_loss = tf.losses.mean_squared_error(self.baseline_target_placeholder,self.baseline,scope = "baseline")
#         baseline_adam_optimizer =  tf.train.AdamOptimizer(learning_rate = self.lr)
#         self.update_baseline_op = baseline_adam_optimizer.minimize(self.baseline_loss)
        
#         #Encoder LSTM
        self.LSTMEncoder()
        
        
        #decoder weights
        #self.d_W1 = self.Decoder(scope = "W1", decoder_out_dim = self.observation_dim*self.decoder_len)
        self.d_W2 = self.Decoder(scope = "W2", decoder_out_dim = self.observation_dim*self.decoder_len)
        #self.d_W3 = self.Decoder(scope = "W3", decoder_out_dim = self.decoder_len*action_dim)
        self.d_W3 = self.Decoder(scope = "W3", decoder_out_dim = self.decoder_len*self.action_dim)
        
        #self.d_W1 = ((self.d_W1 - (tf.reduce_max(self.d_W1) + tf.reduce_min(self.d_W1))/2)/(tf.reduce_max(self.d_W1) - tf.reduce_min(self.d_W1)))*2 
        #self.d_W2 = ((self.d_W2 - (tf.reduce_max(self.d_W2) + tf.reduce_min(self.d_W2))/2)/(tf.reduce_max(self.d_W2) - tf.reduce_min(self.d_W2)))*2 
        #self.d_W3 = ((self.d_W3 - (tf.reduce_max(self.d_W3) + tf.reduce_min(self.d_W3))/2)/(tf.reduce_max(self.d_W3) - tf.reduce_min(self.d_W3)))*2 
        
        #self.d_W1 = tf.reshape(self.d_W1, [self.observation_dim, self.decoder_len])
        self.d_W2 = tf.reshape(self.d_W2, [self.observation_dim, self.decoder_len])
        #self.d_W3 = tf.reshape(self.d_W3, [self.decoder_len, self.action_dim])
        self.d_W3 = tf.reshape(self.d_W3, [self.decoder_len, self.action_dim])
        
        # decoder output bias
        #self.d_B1 = tf.reshape(self.Decoder(decoder_out_dim = self.decoder_len, scope = "B1"), [self.decoder_len])
        self.d_B2 = tf.reshape(self.Decoder(decoder_out_dim = self.decoder_len, scope = "B2"), [self.decoder_len])
        self.d_B3 = tf.reshape(self.Decoder(decoder_out_dim = self.action_dim, scope = "B3"), [self.action_dim])
        #self.d_B1 = ((self.d_B1 - (tf.reduce_max(self.d_B1) + tf.reduce_min(self.d_B1))/2)/(tf.reduce_max(self.d_B1) - tf.reduce_min(self.d_B1)))*2 
        #self.d_B2 = ((self.d_B2 - (tf.reduce_max(self.d_B2) + tf.reduce_min(self.d_B2))/2)/(tf.reduce_max(self.d_B2) - tf.reduce_min(self.d_B2)))*2 
        
        
        # exploit policy
        self.build_policy_exploit()
        #self.d = [self.d_W1, self.d_B1, self.d_W2, self.d_B2, self.d_W3, self.d_B3]
        self.exploit_policy_loss = -tf.reduce_sum(self.exploit_logprob * self.advantage_placeholder_exploit)
        self.d = [self.d_W3, self.d_B3]
        self.gradients_exploit = tf.gradients(self.exploit_policy_loss,self.d)
        
        # train encoder and decoder
        adam_optimizer_exploit =  tf.train.AdamOptimizer(self.lr*0.3)
        self.output_train_op = adam_optimizer_exploit.minimize(self.exploit_policy_loss)
        # train original network
#         adam_optimizer_explore = tf.train.AdamOptimizer(self.lr)
#         self.input_train_op = adam_optimizer_explore.minimize(self.explore_policy_loss)
        init = tf.global_variables_initializer()
        self.sess.run(init)
    
    def initialize(self):
        self.ConstructGraph()
#         # create tf session
#         self.sess = tf.Session()
        
#         # initiliaze all variables
#         init = tf.global_variables_initializer()
#         self.sess.run(init)
    
    def train_step(self): 
        # sample num_traj*num_MDPs
        for i in range(self.num_mdps):
            explore_paths, explore_rewards = self.sample_paths_explore(self.env,10*np.random.rand())
            observations_explore = np.concatenate([path["observation"] for path in explore_paths])
            new_observations_explore = np.concatenate([path["new_obs"] for path in explore_paths])
            new_actions_explore = np.concatenate([path["new_acs"] for path in explore_paths])
            actions_explore = np.concatenate([path["action"] for path in explore_paths])
            rewards_explore = np.concatenate([path["reward"] for path in explore_paths])
            
            vtargs, vpreds, advantages_explore = [], [], []
            for path in explore_paths:
                rew_t = path["new_rewards"]
                return_t = utils.discount(rew_t, self.gamma)
                vpred_t = self.vf.predict(path["new_obs"])
                adv_t = return_t - vpred_t
                advantages_explore.append(adv_t)
                vtargs.append(return_t)
                vpreds.append(vpred_t)
                
                
            #returns_explore = self.get_returns(explore_paths, explore = True)
            advantages_explore = np.concatenate(advantages_explore)
            advantages_explore = (advantages_explore - advantages_explore.mean()) / (advantages_explore.std() + 1e-8)
            vtarg_n = np.concatenate(vtargs)
            vpred_n = np.concatenate(vpreds)
            #update baseline
            #print(advantages_explore.shape,new_observations_explore.shape)
            self.vf.fit(new_observations_explore, vtarg_n)
            
            surr_loss, oldmean_na, oldlogstd_a = self.policyfn.update_policy(
                    new_observations_explore, new_actions_explore, advantages_explore, self.lr)
            
            print("average reward explore:", np.mean(explore_rewards))
            
            #print(returns_explore)
#             print("average reward explore: MDP", i, np.sum(explore_rewards)/num_traj, len(explore_rewards))

#             baseline_explore = self.sess.run(self.baseline, {self.observation_placeholder_explore:new_observations_explore})
#             adv = returns_explore - np.squeeze(baseline_explore)
#             advantages_explore = (adv - np.mean(adv))/(np.std(adv) + 1e-12)


#             # update the baseline

#             self.sess.run(self.update_baseline_op, {self.observation_placeholder_explore:new_observations_explore, 
#                                            self.baseline_target_placeholder : returns_explore})

            # calculate explore gradients
    #         grads_explore = self.sess.run(self.gradients_explore, feed_dict={
    #                     self.observation_placeholder_explore : observations_explore,
    #                     self.action_placeholder_explore : actions_explore,
    #                     self.advantage_placeholder_explore : returns_explore})
            #print("explore",grads_explore )
            # form trajectory matrix

            M = np.array(self.stack_trajectories(explore_paths))


            #encoder LSTM
            Z = self.sess.run(self.Z, feed_dict = {self.encoder_input_placeholder: M,self.sequence_length_placeholder: self.length })
            Z = np.reshape(Z,[1,len(Z)])
#             #print("Z",Z)
#             #print(self.sess.run(self.d, feed_dict = {self.decoder_input_placeholder: Z}))
#             #print("d",self.d)
#             # sample paths
#             tvars = tf.trainable_variables()
#             tvars_vals = self.sess.run(tvars[-5:-1])
#             #print(tvars_vals)
            for j in range(10):
                exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z,10*np.random.rand())
                # get observations, actions and rewards
                observations_exploit = np.concatenate([path["observation"] for path in exploit_paths])
                actions_exploit = np.concatenate([path["action"] for path in exploit_paths])
                rewards_exploit = np.concatenate([path["reward"] for path in exploit_paths])
                returns_exploit = self.get_returns(exploit_paths)
                print("average reward exploit: MDP", i, np.sum(exploit_rewards) / num_traj, len(exploit_rewards))


#             # exploit grads
#     #         grads_exploit = self.sess.run(self.gradients_exploit,feed_dict={
#     #                     self.observation_placeholder_exploit : observations_exploit,
#     #                     self.action_placeholder_exploit : actions_exploit,
#     #                     self.advantage_placeholder_exploit : returns_exploit,
#     #                     self.decoder_input_placeholder: Z})

            #train encoder and decoder network
                self.sess.run(self.output_train_op, feed_dict={
                                self.observation_placeholder_exploit : observations_exploit,
                                self.action_placeholder_exploit : actions_exploit,
                                self.advantage_placeholder_exploit : returns_exploit,
                                self.decoder_input_placeholder: Z})

            # find advantage for input network
    #         advantage_explore = 0
    #         for i in range(len(grads_exploit)):
    #             l1 = grads_exploit[i]
    #             l2 = grads_explore[i]
    #             advantage_explore = advantage_explore + np.matmul(l1.flatten(), l2.flatten())

            # train input policy
#             self.sess.run(self.input_train_op, feed_dict={
#                             self.observation_placeholder_explore : new_observations_explore,
#                             self.action_placeholder_explore : new_actions_explore,
#                             self.advantage_placeholder_explore : advantages_explore})
    
    def test(self):
        explore_paths, explore_rewards = self.sample_paths_explore(self.env, Test = True)
        M = self.stack_trajectories(explore_paths)
        Z = self.sess.run(self.Z, feed_dict = {self.encoder_input_placeholder: M,self.sequence_length_placeholder: self.length })
        Z = np.reshape(Z,[1,len(Z)])
        # sample paths
        exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z, Test = True)
        print("average reward exploit", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
        
    def train(self):
        self.initialize()
        num_epochs = 200
        for epoch in range(num_epochs):
            print("epoch number: ", epoch)
            self.train_step()

# %%
a = MetaLearner(env, max_ep_len, num_traj, latent_size)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
a.train()
# Out:
# epoch number:  0
# average reward explore: 28.170619892816614
# average reward exploit: MDP 0 31.914395718928073 20
# average reward exploit: MDP 0 62.82781149449869 20
# average reward exploit: MDP 0 50.643726090773676 20
# average reward exploit: MDP 0 52.813951758847075 20
# average reward exploit: MDP 0 54.60915002274434 20
# average reward exploit: MDP 0 60.17411719875082 20
# average reward exploit: MDP 0 68.87978534891036 20
# average reward exploit: MDP 0 78.1526570588571 20
# average reward exploit: MDP 0 72.96218068589374 20
# average reward exploit: MDP 0 67.3822658643837 20
# average reward explore: 42.317980030223566
# average reward exploit: MDP 1 60.26339791594768 20
# average reward exploit: MDP 1 56.38519248925555 20
# average reward exploit: MDP 1 61.461082184795885 20
# average reward exploit: MDP 1 66.08101130647945 20
# average reward exploit: MDP 1 66.8969520600822 20
# average reward exploit: MDP 1 65.79469469916972 20
# average reward exploit: MDP 1 67.52985774760852 20
# average reward exploit: MDP 1 72.5377332912932 20
# average reward exploit: MDP 1 72.32283007775494 20
# average reward exploit: MDP 1 74.44817725398448 20
# average reward explore: 59.8897232287256
# average reward exploit: MDP 2 61.308378778033116 20
# average reward exploit: MDP 2 64.00896012304958 20
# average reward exploit: MDP 2 63.31676272500977 20
# average reward exploit: MDP 2 60.23255160626635 20
# average reward exploit: MDP 2 58.32952661291098 20
# average reward exploit: MDP 2 61.30125173430046 20
# average reward exploit: MDP 2 61.779669568004735 20
# average reward exploit: MDP 2 61.007344738707864 20
# average reward exploit: MDP 2 59.337022053165015 20
# average reward exploit: MDP 2 60.610534832104534 20
# average reward explore: 66.18303896707616
# average reward exploit: MDP 3 46.10867075666148 20
# average reward exploit: MDP 3 44.239423003256995 20
# average reward exploit: MDP 3 45.53804766683958 20
# average reward exploit: MDP 3 48.696942557639886 20
# average reward exploit: MDP 3 51.5977378624161 20
# average reward exploit: MDP 3 47.74476029201583 20
# average reward exploit: MDP 3 51.343302187457695 20
# average reward exploit: MDP 3 55.93058266403737 20
# average reward exploit: MDP 3 59.804135841553126 20
# average reward exploit: MDP 3 66.58064763485243 20
# average reward explore: 118.7042262672719
# average reward exploit: MDP 4 45.33061203695484 20
# average reward exploit: MDP 4 51.89314145036877 20
# average reward exploit: MDP 4 55.52834141277644 20
# average reward exploit: MDP 4 56.83751676270789 20
# average reward exploit: MDP 4 67.21702061618842 20
# average reward exploit: MDP 4 66.54375859829835 20
# average reward exploit: MDP 4 74.63450483312307 20
# average reward exploit: MDP 4 73.69569924099403 20
# average reward exploit: MDP 4 72.35299317098907 20
# average reward exploit: MDP 4 72.3433947820564 20
# average reward explore: 127.39865543588789
# average reward exploit: MDP 5 75.42458753140781 20
# average reward exploit: MDP 5 63.70398100146358 20
# average reward exploit: MDP 5 65.14600764907827 20
# average reward exploit: MDP 5 72.67069177857994 20
# average reward exploit: MDP 5 77.39347023406576 20
# average reward exploit: MDP 5 79.25038615829848 20
# average reward exploit: MDP 5 82.15541033553122 20
# average reward exploit: MDP 5 80.3082463149527 20
# average reward exploit: MDP 5 82.77816147092935 20
# average reward exploit: MDP 5 82.80562095852996 20
# average reward explore: 107.12492555721374
# average reward exploit: MDP 6 86.22020158949894 20
# average reward exploit: MDP 6 77.39281259760894 20
# average reward exploit: MDP 6 73.99795282544281 20
# average reward exploit: MDP 6 78.43898182884686 20
# average reward exploit: MDP 6 93.2393440959327 20
# average reward exploit: MDP 6 93.38870010041683 20
# average reward exploit: MDP 6 99.00361530362231 20
# average reward exploit: MDP 6 101.59239392908783 20
# average reward exploit: MDP 6 97.9559514238059 20
# average reward exploit: MDP 6 121.31176834832561 20
# average reward explore: 108.25861847511798
# average reward exploit: MDP 7 104.52432275176082 20
# average reward exploit: MDP 7 118.51908461263318 20
# average reward exploit: MDP 7 103.18064616709815 20
# average reward exploit: MDP 7 122.09712304806494 20
# average reward exploit: MDP 7 153.25572720669942 20
# average reward exploit: MDP 7 235.84661775062332 20
# average reward exploit: MDP 7 191.8217629650624 20
# average reward exploit: MDP 7 170.3626718510232 20
# average reward exploit: MDP 7 139.53595155946346 20
# average reward exploit: MDP 7 131.56086313779795 20
# average reward explore: 103.16834002713433
# average reward exploit: MDP 8 206.9609663380505 20
# average reward exploit: MDP 8 228.3021676208363 20
# average reward exploit: MDP 8 278.9960796050015 20
# average reward exploit: MDP 8 400.9332654198724 20
# average reward exploit: MDP 8 296.5811979891513 20
# average reward exploit: MDP 8 246.4699468817966 20
# average reward exploit: MDP 8 247.7308377809498 20
# average reward exploit: MDP 8 243.70585556583518 20
# average reward exploit: MDP 8 298.0234167415819 20
# average reward exploit: MDP 8 243.61422681319215 20
# average reward explore: 105.05682593958977
# average reward exploit: MDP 9 367.825614212792 20
# average reward exploit: MDP 9 333.36966269352627 20
# average reward exploit: MDP 9 365.3399114406444 20
# average reward exploit: MDP 9 367.87574967175743 20
# average reward exploit: MDP 9 324.8677941237208 20
# average reward exploit: MDP 9 273.3031446459934 20
# average reward exploit: MDP 9 268.8708120410514 20
# average reward exploit: MDP 9 255.8868280664458 20
# average reward exploit: MDP 9 232.0976206044853 20
# average reward exploit: MDP 9 233.17524965031163 20
# epoch number:  1
# average reward explore: 120.31096351549414
# average reward exploit: MDP 0 438.61576523013025 20
# average reward exploit: MDP 0 495.8850510567253 20
# average reward exploit: MDP 0 505.7385278905087 20
# average reward exploit: MDP 0 483.60411959061105 20
# average reward exploit: MDP 0 443.17055265257324 20
# average reward exploit: MDP 0 389.16033837997816 20
# average reward exploit: MDP 0 307.1221712322 20
# average reward exploit: MDP 0 223.89438453679253 20
# average reward exploit: MDP 0 203.00074460443128 20
# average reward exploit: MDP 0 195.91156297114588 20
# average reward explore: 128.17237567195292
# average reward exploit: MDP 1 199.2393732501975 20
# average reward exploit: MDP 1 202.1299478506043 20
# average reward exploit: MDP 1 193.01067867215363 20
# average reward exploit: MDP 1 226.89538189363037 20
# average reward exploit: MDP 1 233.9084527402287 20
# average reward exploit: MDP 1 225.80710640685433 20
# average reward exploit: MDP 1 246.50020676858017 20
# average reward exploit: MDP 1 304.1935975450053 20
# average reward exploit: MDP 1 393.23604133974055 20
# average reward exploit: MDP 1 438.9755042576283 20
# average reward explore: 136.99530956486618
# average reward exploit: MDP 2 370.67834095368113 20
# average reward exploit: MDP 2 383.37571253669654 20
# average reward exploit: MDP 2 354.2994857168152 20
# average reward exploit: MDP 2 323.0571175619187 20
# average reward exploit: MDP 2 203.60857328548548 20
# average reward exploit: MDP 2 134.6425750668498 20
# average reward exploit: MDP 2 101.9322423532494 20
# average reward exploit: MDP 2 97.9082199895551 20
# average reward exploit: MDP 2 87.34874996347011 20
# average reward exploit: MDP 2 71.76258899202836 20
# average reward explore: 141.41353039268353
# average reward exploit: MDP 3 68.54359182043525 20
# average reward exploit: MDP 3 59.18715182675301 20
# average reward exploit: MDP 3 57.550279126954635 20
# average reward exploit: MDP 3 54.73239356427119 20
# average reward exploit: MDP 3 59.887684138277585 20
# average reward exploit: MDP 3 52.78065435262058 20
# average reward exploit: MDP 3 53.1479724607269 20
# average reward exploit: MDP 3 53.252774463716285 20
# average reward exploit: MDP 3 48.511756336530986 20
# average reward exploit: MDP 3 52.19345435293485 20
# average reward explore: 143.27137768333193
# average reward exploit: MDP 4 51.581747340160156 20
# average reward exploit: MDP 4 51.497403816981034 20
# average reward exploit: MDP 4 53.557275806807695 20
# average reward exploit: MDP 4 56.03245740514641 20
# average reward exploit: MDP 4 68.88501086568766 20
# average reward exploit: MDP 4 72.88147005450877 20
# average reward exploit: MDP 4 77.68547900914012 20
# average reward exploit: MDP 4 85.20741123226767 20
# average reward exploit: MDP 4 86.40620079585884 20
# average reward exploit: MDP 4 87.45895003232837 20
# average reward explore: 145.98720285510072
# average reward exploit: MDP 5 105.45789048164973 20
# average reward exploit: MDP 5 103.01736988434081 20
# average reward exploit: MDP 5 105.17577760254558 20
# average reward exploit: MDP 5 101.52456296367052 20
# average reward exploit: MDP 5 90.9269567591885 20
# average reward exploit: MDP 5 90.93021958476808 20
# average reward exploit: MDP 5 78.47681268541625 20
# average reward exploit: MDP 5 76.88972726772367 20
# average reward exploit: MDP 5 73.92149973047407 20
# average reward exploit: MDP 5 87.4630209148943 20
# average reward explore: 164.7718515942167
# average reward exploit: MDP 6 60.69560612403789 20
# average reward exploit: MDP 6 59.51886915895217 20
# average reward exploit: MDP 6 74.813936165702 20
# average reward exploit: MDP 6 88.87808570832745 20
# average reward exploit: MDP 6 95.41012010372991 20
# average reward exploit: MDP 6 97.0941681933765 20
# average reward exploit: MDP 6 95.8308951330234 20
# average reward exploit: MDP 6 104.14315562517928 20
# average reward exploit: MDP 6 107.96916784729187 20
# average reward exploit: MDP 6 98.83525000508219 20
# average reward explore: 162.34038249192662
# average reward exploit: MDP 7 175.2507390023822 20
# average reward exploit: MDP 7 174.24621553520564 20
# average reward exploit: MDP 7 167.87899862593267 20
# average reward exploit: MDP 7 176.32146169734537 20
# average reward exploit: MDP 7 165.27317529281078 20
# average reward exploit: MDP 7 156.29212326164 20
# average reward exploit: MDP 7 195.587389955755 20
# average reward exploit: MDP 7 198.7623087166845 20
# average reward exploit: MDP 7 190.59766876361215 20
# average reward exploit: MDP 7 171.98586470371367 20
# average reward explore: 158.59440708176754
# average reward exploit: MDP 8 97.21228220269003 20
# average reward exploit: MDP 8 82.32002619562522 20
# average reward exploit: MDP 8 65.35085033571214 20
# average reward exploit: MDP 8 62.59351671719928 20
# average reward exploit: MDP 8 60.545259830076006 20
# average reward exploit: MDP 8 63.84174896720084 20
# average reward exploit: MDP 8 69.67037073117595 20
# average reward exploit: MDP 8 60.931184360989015 20
# average reward exploit: MDP 8 69.5634843317147 20
# average reward exploit: MDP 8 60.81255365087785 20
# average reward explore: 136.80828611381818
# average reward exploit: MDP 9 87.69476678582772 20
# average reward exploit: MDP 9 86.25450642681004 20
# average reward exploit: MDP 9 80.85517797509445 20
# average reward exploit: MDP 9 75.99185935901535 20
# average reward exploit: MDP 9 67.83772493664131 20
# average reward exploit: MDP 9 66.49225961323992 20
# average reward exploit: MDP 9 70.06380434162648 20
# average reward exploit: MDP 9 66.4478193927148 20
# average reward exploit: MDP 9 69.1655805871126 20
# average reward exploit: MDP 9 72.74992151447563 20
# epoch number:  2
# average reward explore: 148.40630242735307
# average reward exploit: MDP 0 62.71753649432445 20
# average reward exploit: MDP 0 61.738146180023065 20
# average reward exploit: MDP 0 61.27851418718577 20
# average reward exploit: MDP 0 59.13534389616141 20
# average reward exploit: MDP 0 49.25124843935234 20
# average reward exploit: MDP 0 20.2555490113752 20
# average reward exploit: MDP 0 15.146590066897478 20
# average reward exploit: MDP 0 13.078415535413466 20
# average reward exploit: MDP 0 7.7750026770984295 20
# average reward exploit: MDP 0 4.043356025855756 20
# average reward explore: 146.49148028517317
# average reward exploit: MDP 1 13.155230307873714 20
# average reward exploit: MDP 1 8.33481333984782 20
# average reward exploit: MDP 1 9.850663438838016 20
# average reward exploit: MDP 1 11.208257571380544 20
# average reward exploit: MDP 1 7.9481481057450525 20
# average reward exploit: MDP 1 17.601944355278086 20
# average reward exploit: MDP 1 14.500391666278642 20
# average reward exploit: MDP 1 18.301034887304088 20
# average reward exploit: MDP 1 17.745141544358724 20
# average reward exploit: MDP 1 13.540644418229054 20
# average reward explore: 145.7247063604164
# average reward exploit: MDP 2 38.777351155363725 20
# average reward exploit: MDP 2 57.391879969201284 20
# average reward exploit: MDP 2 64.06789495427387 20
# average reward exploit: MDP 2 55.4822763875312 20
# average reward exploit: MDP 2 61.73718135341686 20
# average reward exploit: MDP 2 74.70326121879253 20
# average reward exploit: MDP 2 33.39446060559083 20
# average reward exploit: MDP 2 44.09482929686098 20
# average reward exploit: MDP 2 55.0678891348029 20
# average reward exploit: MDP 2 59.55972248133266 20
# average reward explore: 161.0789854017073
# average reward exploit: MDP 3 79.23031171836304 20
# average reward exploit: MDP 3 82.57513479700432 20
# average reward exploit: MDP 3 80.93870134903472 20
# average reward exploit: MDP 3 101.19640694895085 20
# average reward exploit: MDP 3 52.481675510927495 20
# average reward exploit: MDP 3 56.8618449099053 20
# average reward exploit: MDP 3 70.37621576430335 20
# average reward exploit: MDP 3 64.01105204661175 20
# average reward exploit: MDP 3 45.558121845763836 20
# average reward exploit: MDP 3 91.63237921380143 20
# average reward explore: 137.38816842185855
# average reward exploit: MDP 4 111.43485259244376 20
# average reward exploit: MDP 4 114.07818832699016 20
# average reward exploit: MDP 4 147.40558487249328 20
# average reward exploit: MDP 4 160.60865532707172 20
# average reward exploit: MDP 4 118.43135574997468 20
# average reward exploit: MDP 4 130.8072148735051 20
# average reward exploit: MDP 4 129.97359859348902 20
# average reward exploit: MDP 4 119.30996338798994 20
# average reward exploit: MDP 4 110.16852456872775 20
# average reward exploit: MDP 4 94.74019919095326 20
# average reward explore: 163.31787075562454
# average reward exploit: MDP 5 100.62261515106871 20
# average reward exploit: MDP 5 87.08817345554971 20
# average reward exploit: MDP 5 104.48656904864951 20
# average reward exploit: MDP 5 110.22934734531671 20
# average reward exploit: MDP 5 108.78720034455519 20
# average reward exploit: MDP 5 109.15485348737461 20
# average reward exploit: MDP 5 99.24576903941848 20
# average reward exploit: MDP 5 89.39777959083384 20
# average reward exploit: MDP 5 70.703997276612 20
# average reward exploit: MDP 5 54.984495194286396 20
# average reward explore: 167.91873529010985
# average reward exploit: MDP 6 28.41733464274011 20
# average reward exploit: MDP 6 16.126623787722437 20
# average reward exploit: MDP 6 19.823269068252237 20
# average reward exploit: MDP 6 15.302422781855906 20
# average reward exploit: MDP 6 14.294409268360212 20
# average reward exploit: MDP 6 12.037127088981471 20
# average reward exploit: MDP 6 9.165147378723097 20
# average reward exploit: MDP 6 12.596835516064242 20
# average reward exploit: MDP 6 4.176496360583345 20
# average reward exploit: MDP 6 6.461026988990019 20
# average reward explore: 174.8462113507551
# average reward exploit: MDP 7 20.665744366140125 20
# average reward exploit: MDP 7 18.75415469433593 20
# average reward exploit: MDP 7 15.366703724396135 20
# average reward exploit: MDP 7 17.080026082044018 20
# average reward exploit: MDP 7 18.38875564493814 20
# average reward exploit: MDP 7 16.06414073966155 20
# average reward exploit: MDP 7 15.529097566891215 20
# average reward exploit: MDP 7 20.13819672622336 20
# average reward exploit: MDP 7 23.010858063034952 20
# average reward exploit: MDP 7 20.878504697279066 20
# average reward explore: 161.70423954334234
# average reward exploit: MDP 8 45.86465670856374 20
# average reward exploit: MDP 8 41.8373550703247 20
# average reward exploit: MDP 8 40.501814809118756 20
# average reward exploit: MDP 8 43.97307503262401 20
# average reward exploit: MDP 8 43.24074037608386 20
# average reward exploit: MDP 8 48.811906171285436 20
# average reward exploit: MDP 8 52.13514683765585 20
# average reward exploit: MDP 8 51.75463879211701 20
# average reward exploit: MDP 8 57.74893198185699 20
# average reward exploit: MDP 8 59.78715671441792 20
# average reward explore: 171.06526262710014
# average reward exploit: MDP 9 40.760508037804584 20
# average reward exploit: MDP 9 44.58634783824649 20
# average reward exploit: MDP 9 46.57809745567313 20
# average reward exploit: MDP 9 46.70683727423334 20
# average reward exploit: MDP 9 49.865323222387694 20
# average reward exploit: MDP 9 56.00314241035786 20
# average reward exploit: MDP 9 59.94592000753412 20
# average reward exploit: MDP 9 64.7791997329783 20
# average reward exploit: MDP 9 67.25339061082158 20
# average reward exploit: MDP 9 72.12328902487253 20
# epoch number:  3
# average reward explore: 157.12206379952744
# average reward exploit: MDP 0 97.36541631599383 20
# average reward exploit: MDP 0 93.19267065955873 20
# average reward exploit: MDP 0 94.99821672743144 20
# average reward exploit: MDP 0 95.755312864754 20
# average reward exploit: MDP 0 94.02585529086927 20
# average reward exploit: MDP 0 93.41987546296231 20
# average reward exploit: MDP 0 94.82918382441449 20
# average reward exploit: MDP 0 93.63139786764876 20
# average reward exploit: MDP 0 95.04210612193825 20
# average reward exploit: MDP 0 90.51305801561344 20
# average reward explore: 160.97037610331523
# average reward exploit: MDP 1 97.47001091110283 20
# average reward exploit: MDP 1 99.50159412134897 20
# average reward exploit: MDP 1 103.9059527504013 20
# average reward exploit: MDP 1 104.46042921231783 20
# average reward exploit: MDP 1 105.77573278147915 20
# average reward exploit: MDP 1 110.92501614198538 20
# average reward exploit: MDP 1 113.3827431077651 20
# average reward exploit: MDP 1 116.30815643339693 20
# average reward exploit: MDP 1 130.96220533893631 20
# average reward exploit: MDP 1 144.19097256843668 20
# average reward explore: 157.67880381648686
# average reward exploit: MDP 2 138.82648141713327 20
# average reward exploit: MDP 2 145.9834251705975 20
# average reward exploit: MDP 2 154.47814549563333 20
# average reward exploit: MDP 2 185.5267593752847 20
# average reward exploit: MDP 2 195.93581660026229 20
# average reward exploit: MDP 2 183.34420306651145 20
# average reward exploit: MDP 2 217.94968800718908 20
# average reward exploit: MDP 2 169.6857670597264 20
# average reward exploit: MDP 2 174.71843556273097 20
# average reward exploit: MDP 2 167.1879150357912 20
# average reward explore: 160.75914633266285
# average reward exploit: MDP 3 22.381106377305816 20
# average reward exploit: MDP 3 20.775165997946687 20
# average reward exploit: MDP 3 20.708686152049005 20
# average reward exploit: MDP 3 20.073870576411004 20
# average reward exploit: MDP 3 19.761088073073218 20
# average reward exploit: MDP 3 19.646113879088166 20
# average reward exploit: MDP 3 19.663741505316562 20
# average reward exploit: MDP 3 19.433168494388035 20
# average reward exploit: MDP 3 19.641496104787613 20
# average reward exploit: MDP 3 19.46817858713439 20
# average reward explore: 159.9128691736317
# average reward exploit: MDP 4 21.571339720678527 20
# average reward exploit: MDP 4 21.621305422872645 20
# average reward exploit: MDP 4 20.82627199072567 20
# average reward exploit: MDP 4 21.118550140600572 20
# average reward exploit: MDP 4 21.23560344309018 20
# average reward exploit: MDP 4 21.289471650671146 20
# average reward exploit: MDP 4 21.334830169407773 20
# average reward exploit: MDP 4 20.885873780195844 20
# average reward exploit: MDP 4 21.118263074635806 20
# average reward exploit: MDP 4 20.882606258908645 20
# average reward explore: 159.22308318499967
# average reward exploit: MDP 5 23.862892145982887 20
# average reward exploit: MDP 5 24.10620195500557 20
# average reward exploit: MDP 5 25.06889762316241 20
# average reward exploit: MDP 5 24.365808147285907 20
# average reward exploit: MDP 5 23.35142501186764 20
# average reward exploit: MDP 5 23.252787791693663 20
# average reward exploit: MDP 5 27.270047142098925 20
# average reward exploit: MDP 5 24.54858369182762 20
# average reward exploit: MDP 5 23.698361675383136 20
# average reward exploit: MDP 5 25.90364659124225 20
# average reward explore: 176.28162117509154
# average reward exploit: MDP 6 19.67512305911861 20
# average reward exploit: MDP 6 23.125525184562026 20
# average reward exploit: MDP 6 23.282982200597374 20
# average reward exploit: MDP 6 21.36023904322234 20
# average reward exploit: MDP 6 20.842738887233644 20
# average reward exploit: MDP 6 20.714136275468224 20
# average reward exploit: MDP 6 25.48081621609368 20
# average reward exploit: MDP 6 21.479079387117274 20
# average reward exploit: MDP 6 24.763619586906593 20
# average reward exploit: MDP 6 23.95848136028782 20
# average reward explore: 166.8393548907287
# average reward exploit: MDP 7 25.49751867162265 20
# average reward exploit: MDP 7 28.97072151195769 20
# average reward exploit: MDP 7 24.499673039391094 20
# average reward exploit: MDP 7 25.492709429099236 20
# average reward exploit: MDP 7 23.738927278285637 20
# average reward exploit: MDP 7 26.356824513201538 20
# average reward exploit: MDP 7 33.06229896931845 20
# average reward exploit: MDP 7 29.17186627547415 20
# average reward exploit: MDP 7 30.86770809578229 20
# average reward exploit: MDP 7 29.5064281781886 20
# average reward explore: 164.1352026575624
# average reward exploit: MDP 8 28.643004192299195 20
# average reward exploit: MDP 8 29.828580613667537 20
# average reward exploit: MDP 8 32.99174333373094 20
# average reward exploit: MDP 8 38.265201489690035 20
# average reward exploit: MDP 8 33.17923986437408 20
# average reward exploit: MDP 8 36.29179460655801 20
# average reward exploit: MDP 8 34.886739267518124 20
# average reward exploit: MDP 8 38.642064872756734 20
# average reward exploit: MDP 8 37.7002752280206 20
# average reward exploit: MDP 8 46.136147062188954 20
# average reward explore: 170.23407762646428
# average reward exploit: MDP 9 41.04324608069546 20
# average reward exploit: MDP 9 38.542673506761105 20
# average reward exploit: MDP 9 50.9157787004367 20
# average reward exploit: MDP 9 60.723165737904914 20
# average reward exploit: MDP 9 48.667395043395906 20
# average reward exploit: MDP 9 51.714367903937294 20
# average reward exploit: MDP 9 57.62590923475526 20
# average reward exploit: MDP 9 50.808901473456366 20
# average reward exploit: MDP 9 73.94289194100774 20
# average reward exploit: MDP 9 69.71944727254623 20
# epoch number:  4
# average reward explore: 153.02086492076234
# average reward exploit: MDP 0 50.96171754167768 20
# average reward exploit: MDP 0 52.032580094428226 20
# average reward exploit: MDP 0 56.08817244738066 20
# average reward exploit: MDP 0 61.54544676917087 20
# average reward exploit: MDP 0 63.67077744163303 20
# average reward exploit: MDP 0 55.17601498163756 20
# average reward exploit: MDP 0 66.74368408650288 20
# average reward exploit: MDP 0 70.84573470746108 20
# average reward exploit: MDP 0 84.73488700645939 20
# average reward exploit: MDP 0 85.81439942180779 20
# average reward explore: 145.00129829490524
# average reward exploit: MDP 1 125.39099050504826 20
# average reward exploit: MDP 1 124.7043071553995 20
# average reward exploit: MDP 1 188.353603405202 20
# average reward exploit: MDP 1 126.32990129247901 20
# average reward exploit: MDP 1 225.45552542712358 20
# average reward exploit: MDP 1 330.8547843406811 20
# average reward exploit: MDP 1 387.03597553522275 20
# average reward exploit: MDP 1 411.64180837618295 20
# average reward exploit: MDP 1 366.7976042081689 20
# average reward exploit: MDP 1 309.69855539962197 20
# average reward explore: 165.90713547503964
# average reward exploit: MDP 2 245.73845438690765 20
# average reward exploit: MDP 2 254.388453650156 20
# average reward exploit: MDP 2 234.2755625297048 20
# average reward exploit: MDP 2 217.06907044807082 20
# average reward exploit: MDP 2 184.1979972957631 20
# average reward exploit: MDP 2 161.40024502704574 20
# average reward exploit: MDP 2 176.05706852252771 20
# average reward exploit: MDP 2 187.00610976156858 20
# average reward exploit: MDP 2 170.871324092878 20
# average reward exploit: MDP 2 184.56103322306114 20
# average reward explore: 151.53197137029855
# average reward exploit: MDP 3 221.1866680343935 20
# average reward exploit: MDP 3 226.84655266397152 20
# average reward exploit: MDP 3 235.70299047859103 20
# average reward exploit: MDP 3 194.8448881494883 20
# average reward exploit: MDP 3 209.94625723673963 20
# average reward exploit: MDP 3 183.63528658048196 20
# average reward exploit: MDP 3 169.41878512245782 20
# average reward exploit: MDP 3 173.37649800455483 20
# average reward exploit: MDP 3 157.8052310754712 20
# average reward exploit: MDP 3 155.2162358756917 20
# average reward explore: 165.62858989530835
# average reward exploit: MDP 4 134.5595891779091 20
# average reward exploit: MDP 4 138.2967260886786 20
# average reward exploit: MDP 4 142.4935680510243 20
# average reward exploit: MDP 4 152.03210624411906 20
# average reward exploit: MDP 4 158.4952694011985 20
# average reward exploit: MDP 4 153.9556499297061 20
# average reward exploit: MDP 4 175.5362459838215 20
# average reward exploit: MDP 4 194.30017638453458 20
# average reward exploit: MDP 4 219.7449114123051 20
# average reward exploit: MDP 4 225.05724911639646 20
# average reward explore: 172.93359094216734
# average reward exploit: MDP 5 233.6135918062293 20
# average reward exploit: MDP 5 239.79444114912798 20
# average reward exploit: MDP 5 210.14749210701763 20
# average reward exploit: MDP 5 175.22579683075804 20
# average reward exploit: MDP 5 196.39619559497007 20
# average reward exploit: MDP 5 190.7093161203045 20
# average reward exploit: MDP 5 159.54814901595472 20
# average reward exploit: MDP 5 195.87492563997745 20
# average reward exploit: MDP 5 176.66607964073336 20
# average reward exploit: MDP 5 177.00537436993253 20
# average reward explore: 176.23561561199637
# average reward exploit: MDP 6 129.85074545004886 20
# average reward exploit: MDP 6 147.61791748420788 20
# average reward exploit: MDP 6 113.82664987871719 20
# average reward exploit: MDP 6 103.46961851816452 20
# average reward exploit: MDP 6 121.02633319682134 20
# average reward exploit: MDP 6 107.66942930239354 20
# average reward exploit: MDP 6 100.5183097560966 20
# average reward exploit: MDP 6 130.69065320907805 20
# average reward exploit: MDP 6 157.21434863052372 20
# average reward exploit: MDP 6 157.71016662516095 20
# average reward explore: 166.7515769236391
# average reward exploit: MDP 7 173.13202263394422 20
# average reward exploit: MDP 7 177.0388388878389 20
# average reward exploit: MDP 7 205.25703009867183 20
# average reward exploit: MDP 7 211.49138341010013 20
# average reward exploit: MDP 7 206.4441257031761 20
# average reward exploit: MDP 7 204.27904616254108 20
# average reward exploit: MDP 7 200.43719034292423 20
# average reward exploit: MDP 7 197.80901993701553 20
# average reward exploit: MDP 7 200.97638073509083 20
# average reward exploit: MDP 7 197.61749438479308 20
# average reward explore: 177.6624259224492
# average reward exploit: MDP 8 191.0505672195568 20
# average reward exploit: MDP 8 190.80109354731238 20
# average reward exploit: MDP 8 191.04997999755668 20
# average reward exploit: MDP 8 189.1485297469447 20
# average reward exploit: MDP 8 187.43281976351108 20
# average reward exploit: MDP 8 168.3090544054024 20
# average reward exploit: MDP 8 145.85490263678568 20
# average reward exploit: MDP 8 140.5731411698192 20
# average reward exploit: MDP 8 110.31517404698181 20
# average reward exploit: MDP 8 112.03207378661007 20
# average reward explore: 174.13160912995937
# average reward exploit: MDP 9 124.32038375050377 20
# average reward exploit: MDP 9 128.8770728085787 20
# average reward exploit: MDP 9 121.4609150464972 20
# average reward exploit: MDP 9 128.86544081387325 20
# average reward exploit: MDP 9 142.18053183123362 20
# average reward exploit: MDP 9 141.81991101232148 20
# average reward exploit: MDP 9 146.81042426991348 20
# average reward exploit: MDP 9 154.0046344110865 20
# average reward exploit: MDP 9 151.20608939672567 20
# average reward exploit: MDP 9 149.03936595106273 20
# epoch number:  5
# average reward explore: 165.22318308508147
# average reward exploit: MDP 0 107.48482854608542 20
# average reward exploit: MDP 0 108.18375596398582 20
# average reward exploit: MDP 0 102.76926943504832 20
# average reward exploit: MDP 0 100.50243907597084 20
# average reward exploit: MDP 0 100.13643311272025 20
# average reward exploit: MDP 0 95.37136890282521 20
# average reward exploit: MDP 0 92.89306971810817 20
# average reward exploit: MDP 0 89.41872023107112 20
# average reward exploit: MDP 0 90.47975434689009 20
# average reward exploit: MDP 0 87.40809821335476 20
# average reward explore: 162.07400684139526
# average reward exploit: MDP 1 83.03288701635735 20
# average reward exploit: MDP 1 83.12845306044674 20
# average reward exploit: MDP 1 80.733464708778 20
# average reward exploit: MDP 1 80.06499973786944 20
# average reward exploit: MDP 1 74.5490691799944 20
# average reward exploit: MDP 1 73.93999345589444 20
# average reward exploit: MDP 1 73.44526216581664 20
# average reward exploit: MDP 1 75.3781270201858 20
# average reward exploit: MDP 1 75.6227471567887 20
# average reward exploit: MDP 1 72.95373021510713 20
# average reward explore: 158.24879566099
# average reward exploit: MDP 2 75.36952224889906 20
# average reward exploit: MDP 2 78.21473239854734 20
# average reward exploit: MDP 2 80.18051288284016 20
# average reward exploit: MDP 2 80.04354646897926 20
# average reward exploit: MDP 2 83.19799616489829 20
# average reward exploit: MDP 2 84.09995280039797 20
# average reward exploit: MDP 2 86.55411453833105 20
# average reward exploit: MDP 2 87.45287434986989 20
# average reward exploit: MDP 2 89.68206530256163 20
# average reward exploit: MDP 2 88.62083717272246 20
# average reward explore: 173.4333367402403
# average reward exploit: MDP 3 87.3417099438579 20
# average reward exploit: MDP 3 90.9180408529995 20
# average reward exploit: MDP 3 91.87243413539642 20
# average reward exploit: MDP 3 86.66938027000324 20
# average reward exploit: MDP 3 88.24316998131788 20
# average reward exploit: MDP 3 90.40254284530276 20
# average reward exploit: MDP 3 87.25849268377573 20
# average reward exploit: MDP 3 92.54079172135633 20
# average reward exploit: MDP 3 91.16992221671973 20
# average reward exploit: MDP 3 92.35810209290119 20
# average reward explore: 170.07618257201722
# average reward exploit: MDP 4 90.96902306927392 20
# average reward exploit: MDP 4 94.8282853231581 20
# average reward exploit: MDP 4 96.52515053404426 20
# average reward exploit: MDP 4 94.17889989953287 20
# average reward exploit: MDP 4 93.87408834415136 20
# average reward exploit: MDP 4 94.84424231488391 20
# average reward exploit: MDP 4 98.5544050649145 20
# average reward exploit: MDP 4 96.72705390515205 20
# average reward exploit: MDP 4 97.14347138047962 20
# average reward exploit: MDP 4 94.4209818689175 20
# average reward explore: 168.3231831911206
# average reward exploit: MDP 5 98.32358120102023 20
# average reward exploit: MDP 5 94.33513952603373 20
# average reward exploit: MDP 5 97.27784605008848 20
# average reward exploit: MDP 5 99.74731959419148 20
# average reward exploit: MDP 5 102.507721691077 20
# average reward exploit: MDP 5 97.24028204815393 20
# average reward exploit: MDP 5 104.24835677296646 20
# average reward exploit: MDP 5 104.08110406522167 20
# average reward exploit: MDP 5 103.62517347242574 20
# average reward exploit: MDP 5 107.98883587273812 20
# average reward explore: 176.05128726215074
# average reward exploit: MDP 6 106.2724517431662 20
# average reward exploit: MDP 6 109.20482755786091 20
# average reward exploit: MDP 6 111.49365056163512 20
# average reward exploit: MDP 6 132.48039858150668 20
# average reward exploit: MDP 6 125.39964970724608 20
# average reward exploit: MDP 6 139.418720154798 20
# average reward exploit: MDP 6 158.82109384309393 20
# average reward exploit: MDP 6 164.59866337999284 20
# average reward exploit: MDP 6 159.51801255293844 20
# average reward exploit: MDP 6 178.91302706734973 20
# average reward explore: 179.5699847329016
# average reward exploit: MDP 7 177.787977283094 20
# average reward exploit: MDP 7 178.47578105990797 20
# average reward exploit: MDP 7 185.70457552067896 20
# average reward exploit: MDP 7 190.99512407709145 20
# average reward exploit: MDP 7 198.75246528615645 20
# average reward exploit: MDP 7 190.83129012635948 20
# average reward exploit: MDP 7 191.20911529405538 20
# average reward exploit: MDP 7 197.18077161747016 20
# average reward exploit: MDP 7 196.2223083624145 20
# average reward exploit: MDP 7 194.44682115674175 20
# average reward explore: 181.54559184699923
# average reward exploit: MDP 8 190.01236660594026 20
# average reward exploit: MDP 8 193.74564851598691 20
# average reward exploit: MDP 8 193.69718234849643 20
# average reward exploit: MDP 8 194.6900003093902 20
# average reward exploit: MDP 8 195.643316323518 20
# average reward exploit: MDP 8 190.1633829873035 20
# average reward exploit: MDP 8 191.76209125406095 20
# average reward exploit: MDP 8 189.91888026967257 20
# average reward exploit: MDP 8 188.62449073052375 20
# average reward exploit: MDP 8 183.34811631268548 20
# average reward explore: 180.51311738972063
# average reward exploit: MDP 9 176.94008806466974 20
# average reward exploit: MDP 9 182.32556999444768 20
# average reward exploit: MDP 9 175.70696522223986 20
# average reward exploit: MDP 9 178.86499285526446 20
# average reward exploit: MDP 9 179.93634208597751 20
# average reward exploit: MDP 9 172.1474849054686 20
# average reward exploit: MDP 9 163.1489067848699 20
# average reward exploit: MDP 9 166.4098211543165 20
# average reward exploit: MDP 9 162.29909186877293 20
# average reward exploit: MDP 9 148.7137873903528 20
# epoch number:  6
# average reward explore: 167.10556076767298
# average reward exploit: MDP 0 215.66079965458465 20
# average reward exploit: MDP 0 208.56077248258822 20
# average reward exploit: MDP 0 203.73825383017314 20
# average reward exploit: MDP 0 229.36364665703059 20
# average reward exploit: MDP 0 214.92334940646407 20
# average reward exploit: MDP 0 193.30310357175435 20
# average reward exploit: MDP 0 189.03315331662924 20
# average reward exploit: MDP 0 195.8969854389242 20
# average reward exploit: MDP 0 192.39688070767036 20
# average reward exploit: MDP 0 190.55577165669587 20
# average reward explore: 163.88142311765418
# average reward exploit: MDP 1 165.2556202463135 20
# average reward exploit: MDP 1 161.3927264268985 20
# average reward exploit: MDP 1 167.67429346280144 20
# average reward exploit: MDP 1 166.83497041042094 20
# average reward exploit: MDP 1 169.85921363967697 20
# average reward exploit: MDP 1 164.05604692433303 20
# average reward exploit: MDP 1 163.97698341869005 20
# average reward exploit: MDP 1 158.9033906518352 20
# average reward exploit: MDP 1 159.79181736005415 20
# average reward exploit: MDP 1 161.6017515870014 20
# average reward explore: 161.14714737594846
# average reward exploit: MDP 2 132.51650482852477 20
# average reward exploit: MDP 2 139.5340273785908 20
# average reward exploit: MDP 2 145.21145740955632 20
# average reward exploit: MDP 2 120.96756478486932 20
# average reward exploit: MDP 2 145.92136600101747 20
# average reward exploit: MDP 2 147.53402354694782 20
# average reward exploit: MDP 2 139.31370640529678 20
# average reward exploit: MDP 2 140.57275518105357 20
# average reward exploit: MDP 2 141.51114465218325 20
# average reward exploit: MDP 2 148.45692248883148 20
# average reward explore: 169.79998523089014
# average reward exploit: MDP 3 120.17514479829393 20
# average reward exploit: MDP 3 112.57995204882442 20
# average reward exploit: MDP 3 111.599269455591 20
# average reward exploit: MDP 3 114.36661476584939 20
# average reward exploit: MDP 3 117.2275792046593 20
# average reward exploit: MDP 3 132.6686020871012 20
# average reward exploit: MDP 3 129.34327986783268 20
# average reward exploit: MDP 3 137.41676168810895 20
# average reward exploit: MDP 3 141.9692827158323 20
# average reward exploit: MDP 3 155.0621791041161 20
# average reward explore: 169.40380669938128
# average reward exploit: MDP 4 155.81502720396992 20
# average reward exploit: MDP 4 164.45642358403538 20
# average reward exploit: MDP 4 178.1873964476278 20
# average reward exploit: MDP 4 166.2447624221014 20
# average reward exploit: MDP 4 182.16225022708 20
# average reward exploit: MDP 4 171.6832220921653 20
# average reward exploit: MDP 4 173.66048439025278 20
# average reward exploit: MDP 4 176.86322411336405 20
# average reward exploit: MDP 4 182.64263382059727 20
# average reward exploit: MDP 4 189.80446409466282 20
# average reward explore: 167.0224863565978
# average reward exploit: MDP 5 189.06361100270408 20
# average reward exploit: MDP 5 196.67984067390802 20
# average reward exploit: MDP 5 197.817196843765 20
# average reward exploit: MDP 5 201.66125980004534 20
# average reward exploit: MDP 5 204.69739847838125 20
# average reward exploit: MDP 5 207.86999829261094 20
# average reward exploit: MDP 5 206.0494281216075 20
# average reward exploit: MDP 5 210.18827764934468 20
# average reward exploit: MDP 5 198.84532041664687 20
# average reward exploit: MDP 5 187.1637863265334 20
# average reward explore: 171.89435067927678
# average reward exploit: MDP 6 213.2830245919306 20
# average reward exploit: MDP 6 199.58542906878404 20
# average reward exploit: MDP 6 211.2667597718924 20
# average reward exploit: MDP 6 196.6339011112332 20
# average reward exploit: MDP 6 202.78238075822622 20
# average reward exploit: MDP 6 203.1014413636669 20
# average reward exploit: MDP 6 200.37712599344576 20
# average reward exploit: MDP 6 205.06025733862595 20
# average reward exploit: MDP 6 200.32446775287775 20
# average reward exploit: MDP 6 199.3448656583727 20
# average reward explore: 174.1514101765608
# average reward exploit: MDP 7 195.1471364120762 20
# average reward exploit: MDP 7 175.28077755499734 20
# average reward exploit: MDP 7 161.79200197055448 20
# average reward exploit: MDP 7 83.4613907513697 20
# average reward exploit: MDP 7 30.16866694376024 20
# average reward exploit: MDP 7 36.0106646678015 20
# average reward exploit: MDP 7 28.974131753081082 20
# average reward exploit: MDP 7 28.336812313534416 20
# average reward exploit: MDP 7 28.56824468787662 20
# average reward exploit: MDP 7 30.280302814721573 20
# average reward explore: 172.6102824903525
# average reward exploit: MDP 8 31.630040472306668 20
# average reward exploit: MDP 8 35.07254275913455 20
# average reward exploit: MDP 8 32.6501735883885 20
# average reward exploit: MDP 8 33.03973263071485 20
# average reward exploit: MDP 8 34.868305226519304 20
# average reward exploit: MDP 8 34.201165677107305 20
# average reward exploit: MDP 8 34.8210415011399 20
# average reward exploit: MDP 8 34.409179205621584 20
# average reward exploit: MDP 8 35.397095590577734 20
# average reward exploit: MDP 8 43.95490711076648 20
# average reward explore: 177.3187790053869
# average reward exploit: MDP 9 38.33089320677828 20
# average reward exploit: MDP 9 35.54290913031655 20
# average reward exploit: MDP 9 40.20950110424939 20
# average reward exploit: MDP 9 51.81353549631873 20
# average reward exploit: MDP 9 39.29563067416878 20
# average reward exploit: MDP 9 41.900578937322976 20
# average reward exploit: MDP 9 68.01237445916388 20
# average reward exploit: MDP 9 53.985492707988406 20
# average reward exploit: MDP 9 65.54942289798663 20
# average reward exploit: MDP 9 87.23929695901141 20
# epoch number:  7
# average reward explore: 166.38333135749411
# average reward exploit: MDP 0 205.3170773637903 20
# average reward exploit: MDP 0 207.28183198549414 20
# average reward exploit: MDP 0 178.58606498307694 20
# average reward exploit: MDP 0 206.62523708658918 20
# average reward exploit: MDP 0 215.91800870206248 20
# average reward exploit: MDP 0 206.25035214748155 20
# average reward exploit: MDP 0 201.15403624104897 20
# average reward exploit: MDP 0 185.20087742542216 20
# average reward exploit: MDP 0 192.45816944077347 20
# average reward exploit: MDP 0 184.47789797010972 20
# average reward explore: 162.71834753644916
# average reward exploit: MDP 1 174.81183507356826 20
# average reward exploit: MDP 1 193.01488184681816 20
# average reward exploit: MDP 1 205.64715718153911 20
# average reward exploit: MDP 1 215.648499319783 20
# average reward exploit: MDP 1 201.8874599670226 20
# average reward exploit: MDP 1 196.88418398467985 20
# average reward exploit: MDP 1 213.4632427964993 20
# average reward exploit: MDP 1 192.81907816369608 20
# average reward exploit: MDP 1 199.4845490634004 20
# average reward exploit: MDP 1 200.3691721670219 20
# average reward explore: 158.7994247108933
# average reward exploit: MDP 2 209.5645848704276 20
# average reward exploit: MDP 2 205.45286756658112 20
# average reward exploit: MDP 2 205.24181826778923 20
# average reward exploit: MDP 2 200.55674697144292 20
# average reward exploit: MDP 2 201.49530929811658 20
# average reward exploit: MDP 2 196.40679725548006 20
# average reward exploit: MDP 2 200.02907196241463 20
# average reward exploit: MDP 2 199.81046212980831 20
# average reward exploit: MDP 2 201.95175261663806 20
# average reward exploit: MDP 2 204.6961258631868 20
# average reward explore: 164.8253668418785
# average reward exploit: MDP 3 210.71560794774692 20
# average reward exploit: MDP 3 213.87493636927735 20
# average reward exploit: MDP 3 191.2006628326617 20
# average reward exploit: MDP 3 194.91315955958368 20
# average reward exploit: MDP 3 204.63740132321553 20
# average reward exploit: MDP 3 204.79697716893932 20
# average reward exploit: MDP 3 194.50658628157663 20
# average reward exploit: MDP 3 197.05178725459243 20
# average reward exploit: MDP 3 186.72710212395873 20
# average reward exploit: MDP 3 186.9290110592714 20
# average reward explore: 167.5530679147592
# average reward exploit: MDP 4 195.5672115567215 20
# average reward exploit: MDP 4 196.91636132524576 20
# average reward exploit: MDP 4 193.4764712108156 20
# average reward exploit: MDP 4 187.21496763059082 20
# average reward exploit: MDP 4 176.08109577011413 20
# average reward exploit: MDP 4 171.14043403272765 20
# average reward exploit: MDP 4 160.9747884874726 20
# average reward exploit: MDP 4 159.89180128289442 20
# average reward exploit: MDP 4 157.03578971141872 20
# average reward exploit: MDP 4 152.2542744991848 20
# average reward explore: 163.20733079861367
# average reward exploit: MDP 5 159.95913417436861 20
# average reward exploit: MDP 5 179.48629589663284 20
# average reward exploit: MDP 5 165.23976733061255 20
# average reward exploit: MDP 5 167.2367006967551 20
# average reward exploit: MDP 5 176.75458148048807 20
# average reward exploit: MDP 5 169.12467425869465 20
# average reward exploit: MDP 5 184.43465963052353 20
# average reward exploit: MDP 5 189.4013326500979 20
# average reward exploit: MDP 5 193.6861280028154 20
# average reward exploit: MDP 5 183.23742396146605 20
# average reward explore: 163.1958327273446
# average reward exploit: MDP 6 152.62564991926408 20
# average reward exploit: MDP 6 142.12672700194386 20
# average reward exploit: MDP 6 144.45233603359134 20
# average reward exploit: MDP 6 147.86009134574687 20
# average reward exploit: MDP 6 139.00276731388885 20
# average reward exploit: MDP 6 149.37720134376826 20
# average reward exploit: MDP 6 152.11198716830003 20
# average reward exploit: MDP 6 162.7018174898094 20
# average reward exploit: MDP 6 161.1832382518057 20
# average reward exploit: MDP 6 165.16336144975406 20
# average reward explore: 168.93088083190986
# average reward exploit: MDP 7 153.47217002312576 20
# average reward exploit: MDP 7 153.22328081069605 20
# average reward exploit: MDP 7 148.67659487568608 20
# average reward exploit: MDP 7 151.55999101110382 20
# average reward exploit: MDP 7 151.06903304106118 20
# average reward exploit: MDP 7 157.32602256388626 20
# average reward exploit: MDP 7 163.33613109505504 20
# average reward exploit: MDP 7 171.23424649055374 20
# average reward exploit: MDP 7 174.9488822948964 20
# average reward exploit: MDP 7 177.0935797399268 20
# average reward explore: 172.63069484361787
# average reward exploit: MDP 8 181.0271633510925 20
# average reward exploit: MDP 8 180.144796278873 20
# average reward exploit: MDP 8 180.25762600914115 20
# average reward exploit: MDP 8 180.69052559856905 20
# average reward exploit: MDP 8 175.1066625960043 20
# average reward exploit: MDP 8 173.81614217230288 20
# average reward exploit: MDP 8 172.9284478342417 20
# average reward exploit: MDP 8 172.54249745594797 20
# average reward exploit: MDP 8 171.0266980115076 20
# average reward exploit: MDP 8 174.14346208783664 20
# average reward explore: 178.81050772126878
# average reward exploit: MDP 9 153.80411338462426 20
# average reward exploit: MDP 9 160.83830947861097 20
# average reward exploit: MDP 9 167.27360693262332 20
# average reward exploit: MDP 9 177.07915713440246 20
# average reward exploit: MDP 9 176.61446173036157 20
# average reward exploit: MDP 9 180.90067551026277 20
# average reward exploit: MDP 9 178.33688107945267 20
# average reward exploit: MDP 9 181.58326614639628 20
# average reward exploit: MDP 9 178.62206718697348 20
# average reward exploit: MDP 9 182.39863140350107 20
# epoch number:  8
# average reward explore: 169.68448860707682
# average reward exploit: MDP 0 148.1089132408344 20
# average reward exploit: MDP 0 146.91867717190877 20
# average reward exploit: MDP 0 126.56804098822377 20
# average reward exploit: MDP 0 131.94132751636693 20
# average reward exploit: MDP 0 138.7364302985102 20
# average reward exploit: MDP 0 130.20283005581828 20
# average reward exploit: MDP 0 131.38825292807786 20
# average reward exploit: MDP 0 131.66031683399197 20
# average reward exploit: MDP 0 119.20031208992548 20
# average reward exploit: MDP 0 131.50380088294324 20
# average reward explore: 163.13477976161846
# average reward exploit: MDP 1 128.63093872592506 20
# average reward exploit: MDP 1 140.0536528344872 20
# average reward exploit: MDP 1 131.42587155573196 20
# average reward exploit: MDP 1 122.71325973698947 20
# average reward exploit: MDP 1 125.44135641721186 20
# average reward exploit: MDP 1 136.28527478376793 20
# average reward exploit: MDP 1 128.2061871010379 20
# average reward exploit: MDP 1 128.08341977380576 20
# average reward exploit: MDP 1 133.27913518614048 20
# average reward exploit: MDP 1 138.0997430067742 20
# average reward explore: 160.3065785100113
# average reward exploit: MDP 2 172.85633796312857 20
# average reward exploit: MDP 2 168.2243544139953 20
# average reward exploit: MDP 2 175.10537136816876 20
# average reward exploit: MDP 2 159.19753537934048 20
# average reward exploit: MDP 2 181.36271642657147 20
# average reward exploit: MDP 2 180.19988263566918 20
# average reward exploit: MDP 2 174.56853681882896 20
# average reward exploit: MDP 2 178.04854469369346 20
# average reward exploit: MDP 2 176.15930908084442 20
# average reward exploit: MDP 2 183.81848431154577 20
# average reward explore: 166.70006804522086
# average reward exploit: MDP 3 186.0353568871578 20
# average reward exploit: MDP 3 178.4580086895932 20
# average reward exploit: MDP 3 188.23262216903763 20
# average reward exploit: MDP 3 169.5638579802988 20
# average reward exploit: MDP 3 179.75483423735986 20
# average reward exploit: MDP 3 179.71056194777938 20
# average reward exploit: MDP 3 184.33314934255077 20
# average reward exploit: MDP 3 183.9021544711678 20
# average reward exploit: MDP 3 190.76144191171915 20
# average reward exploit: MDP 3 183.62620656447282 20
# average reward explore: 175.151024802118
# average reward exploit: MDP 4 176.71231634917368 20
# average reward exploit: MDP 4 176.01223243429598 20
# average reward exploit: MDP 4 188.06941913103805 20
# average reward exploit: MDP 4 183.07847612537915 20
# average reward exploit: MDP 4 186.09545177293106 20
# average reward exploit: MDP 4 180.23917668087012 20
# average reward exploit: MDP 4 188.3279579498236 20
# average reward exploit: MDP 4 179.31394261983976 20
# average reward exploit: MDP 4 184.9572029348814 20
# average reward exploit: MDP 4 188.46996453195408 20
# average reward explore: 178.33958865878543
# average reward exploit: MDP 5 187.88661773951839 20
# average reward exploit: MDP 5 185.60041731150002 20
# average reward exploit: MDP 5 179.2789955425937 20
# average reward exploit: MDP 5 179.6954883920411 20
# average reward exploit: MDP 5 181.54441956848592 20
# average reward exploit: MDP 5 174.89111047424154 20
# average reward exploit: MDP 5 171.4080590590335 20
# average reward exploit: MDP 5 179.7705375989553 20
# ...
# average reward exploit: MDP 4 108.84325304647432 20
# average reward exploit: MDP 4 112.92777332352202 20
# average reward exploit: MDP 4 99.80652414695605 20
# average reward exploit: MDP 4 101.12237534950734 20
# average reward exploit: MDP 4 107.22613602042448 20
# average reward exploit: MDP 4 110.33446422410896 20
# average reward exploit: MDP 4 104.60641674518872 20
# average reward exploit: MDP 4 96.88711100339624 20
# average reward explore: 173.63737191972467
# average reward exploit: MDP 5 100.51969480674384 20
# average reward exploit: MDP 5 108.65390085275574 20
# average reward exploit: MDP 5 96.97833223680477 20
# average reward exploit: MDP 5 101.97916290949082 20
# average reward exploit: MDP 5 103.75928970805664 20
# average reward exploit: MDP 5 112.88888465092987 20
# average reward exploit: MDP 5 112.96310388182576 20
# average reward exploit: MDP 5 114.91800230533379 20
# average reward exploit: MDP 5 111.02298428148742 20
# average reward exploit: MDP 5 118.41282843646438 20
# average reward explore: 176.25136009831036
# average reward exploit: MDP 6 118.75240203886251 20
# average reward exploit: MDP 6 117.36017202266916 20
# average reward exploit: MDP 6 128.58489523590714 20
# average reward exploit: MDP 6 122.34821329224405 20
# average reward exploit: MDP 6 122.64090552607999 20
# average reward exploit: MDP 6 128.38951996792449 20
# average reward exploit: MDP 6 132.06594902332535 20
# average reward exploit: MDP 6 125.29527368912684 20
# average reward exploit: MDP 6 129.59090132444527 20
# average reward exploit: MDP 6 140.05737435697367 20
# average reward explore: 171.88139913124854
# average reward exploit: MDP 7 135.1358337034218 20
# average reward exploit: MDP 7 139.06031399171394 20
# average reward exploit: MDP 7 152.32185239105956 20
# average reward exploit: MDP 7 143.6048169280562 20
# average reward exploit: MDP 7 142.93518054133557 20
# average reward exploit: MDP 7 129.0313710129625 20
# average reward exploit: MDP 7 144.9910908604014 20
# average reward exploit: MDP 7 144.3402696797188 20
# average reward exploit: MDP 7 145.75477706632324 20
# average reward exploit: MDP 7 151.08438985578636 20
# average reward explore: 179.50148760340304
# average reward exploit: MDP 8 147.3835777918342 20
# average reward exploit: MDP 8 142.57350842304172 20
# average reward exploit: MDP 8 146.68627356529143 20
# average reward exploit: MDP 8 146.05659176153426 20
# average reward exploit: MDP 8 137.64353972298935 20
# average reward exploit: MDP 8 145.21854484640977 20
# average reward exploit: MDP 8 144.15292071760155 20
# average reward exploit: MDP 8 130.38018878352432 20
# average reward exploit: MDP 8 131.78330579084047 20
# average reward exploit: MDP 8 132.3625713999515 20
# average reward explore: 172.2294237740456
# average reward exploit: MDP 9 144.37027758732683 20
# average reward exploit: MDP 9 142.60863947502475 20
# average reward exploit: MDP 9 140.5233258946541 20
# average reward exploit: MDP 9 147.3074371874656 20
# average reward exploit: MDP 9 138.35642686736014 20
# average reward exploit: MDP 9 149.46437836491674 20
# average reward exploit: MDP 9 139.65665337547836 20
# average reward exploit: MDP 9 149.64913336283917 20
# average reward exploit: MDP 9 140.63896843819063 20
# average reward exploit: MDP 9 149.39280919934188 20
# epoch number:  13
# average reward explore: 170.01051898793986
# average reward exploit: MDP 0 223.7701820492051 20
# average reward exploit: MDP 0 239.65054002125535 20
# average reward exploit: MDP 0 255.1872083227949 20
# average reward exploit: MDP 0 252.38616228547318 20
# average reward exploit: MDP 0 257.6467603262567 20
# average reward exploit: MDP 0 291.1384314181091 20
# average reward exploit: MDP 0 236.35911768629498 20
# average reward exploit: MDP 0 243.1983769240344 20
# average reward exploit: MDP 0 253.86893356709842 20
# average reward exploit: MDP 0 241.04892996062003 20
# average reward explore: 157.01612483059435
# average reward exploit: MDP 1 197.883969109094 20
# average reward exploit: MDP 1 182.24926312671784 20
# average reward exploit: MDP 1 188.1134662252458 20
# average reward exploit: MDP 1 186.58475243328948 20
# average reward exploit: MDP 1 178.55673588979096 20
# average reward exploit: MDP 1 164.18901749646818 20
# average reward exploit: MDP 1 177.46770428088482 20
# average reward exploit: MDP 1 152.0652887616034 20
# average reward exploit: MDP 1 166.47453468503247 20
# average reward exploit: MDP 1 135.72195848674838 20
# average reward explore: 160.0185524568705
# average reward exploit: MDP 2 187.025928669348 20
# average reward exploit: MDP 2 172.2004076982512 20
# average reward exploit: MDP 2 197.68249701426058 20
# average reward exploit: MDP 2 192.3673629588021 20
# average reward exploit: MDP 2 200.9021380761952 20
# average reward exploit: MDP 2 190.9840806393185 20
# average reward exploit: MDP 2 220.42210177212033 20
# average reward exploit: MDP 2 189.8124337294356 20
# average reward exploit: MDP 2 205.66930228206496 20
# average reward exploit: MDP 2 215.17872454402504 20
# average reward explore: 163.86636194433558
# average reward exploit: MDP 3 184.6968977136715 20
# average reward exploit: MDP 3 177.70324131119497 20
# average reward exploit: MDP 3 196.53731713194094 20
# average reward exploit: MDP 3 173.0014688616942 20
# average reward exploit: MDP 3 163.74009063012403 20
# average reward exploit: MDP 3 175.53382162606846 20
# average reward exploit: MDP 3 173.81534938287572 20
# average reward exploit: MDP 3 169.16046216525137 20
# average reward exploit: MDP 3 170.26617891395344 20
# average reward exploit: MDP 3 167.89838057423535 20
# average reward explore: 178.12488095753915
# average reward exploit: MDP 4 164.2551446352115 20
# average reward exploit: MDP 4 155.46549128943866 20
# average reward exploit: MDP 4 157.67645635015015 20
# average reward exploit: MDP 4 160.76371117589113 20
# average reward exploit: MDP 4 179.7838935388772 20
# average reward exploit: MDP 4 175.1534651420226 20
# average reward exploit: MDP 4 163.3055259650645 20
# average reward exploit: MDP 4 166.1037981094159 20
# average reward exploit: MDP 4 164.58384314050306 20
# average reward exploit: MDP 4 154.42852301486852 20
# average reward explore: 177.03191266412367
# average reward exploit: MDP 5 161.40101534350453 20
# average reward exploit: MDP 5 165.37265227144533 20
# average reward exploit: MDP 5 162.64789631138825 20
# average reward exploit: MDP 5 179.60840148059265 20
# average reward exploit: MDP 5 173.24067508114575 20
# average reward exploit: MDP 5 184.53537947668588 20
# average reward exploit: MDP 5 183.31209702131034 20
# average reward exploit: MDP 5 196.5425352074025 20
# average reward exploit: MDP 5 190.48910367238406 20
# average reward exploit: MDP 5 191.8899577062686 20
# average reward explore: 172.88326984516817
# average reward exploit: MDP 6 193.93997563538557 20
# average reward exploit: MDP 6 195.1121917158778 20
# average reward exploit: MDP 6 209.03746685999354 20
# average reward exploit: MDP 6 211.65809351298276 20
# average reward exploit: MDP 6 204.40738515282945 20
# average reward exploit: MDP 6 213.88326385483134 20
# average reward exploit: MDP 6 209.13273493024485 20
# average reward exploit: MDP 6 218.4753593598628 20
# average reward exploit: MDP 6 218.74505893905325 20
# average reward exploit: MDP 6 213.33299800264558 20
# average reward explore: 183.15727726118953
# average reward exploit: MDP 7 214.17979707033373 20
# average reward exploit: MDP 7 211.6419533591545 20
# average reward exploit: MDP 7 208.05689245098347 20
# average reward exploit: MDP 7 210.66203104996754 20
# average reward exploit: MDP 7 203.01976994828937 20
# average reward exploit: MDP 7 198.63406855022467 20
# average reward exploit: MDP 7 205.25467678770337 20
# average reward exploit: MDP 7 200.52718019217028 20
# average reward exploit: MDP 7 194.81636835155743 20
# average reward exploit: MDP 7 202.25132910290682 20
# average reward explore: 184.0648814925239
# average reward exploit: MDP 8 187.44361013056735 20
# average reward exploit: MDP 8 179.04334874040325 20
# average reward exploit: MDP 8 157.32455281243776 20
# average reward exploit: MDP 8 158.27001305944688 20
# average reward exploit: MDP 8 168.80281646258044 20
# average reward exploit: MDP 8 104.78225590229783 20
# average reward exploit: MDP 8 142.3790217925236 20
# average reward exploit: MDP 8 122.72129904381788 20
# average reward exploit: MDP 8 149.680192957109 20
# average reward exploit: MDP 8 187.83702824363098 20
# average reward explore: 178.01057216650275
# average reward exploit: MDP 9 189.2658485220117 20
# average reward exploit: MDP 9 146.98644635599385 20
# average reward exploit: MDP 9 130.6808451615633 20
# average reward exploit: MDP 9 171.19364277894073 20
# average reward exploit: MDP 9 145.4561345236289 20
# average reward exploit: MDP 9 173.44109171288366 20
# average reward exploit: MDP 9 165.39868824396802 20
# average reward exploit: MDP 9 112.31283668132457 20
# average reward exploit: MDP 9 144.5573009190519 20
# average reward exploit: MDP 9 129.10181937315275 20
# epoch number:  14
# average reward explore: 171.5263089856492
# average reward exploit: MDP 0 86.19266376421604 20
# average reward exploit: MDP 0 73.82537949684607 20
# average reward exploit: MDP 0 81.00905750406534 20
# average reward exploit: MDP 0 83.34537977277783 20
# average reward exploit: MDP 0 114.18465009165868 20
# average reward exploit: MDP 0 95.12299957221212 20
# average reward exploit: MDP 0 98.15693318022973 20
# average reward exploit: MDP 0 79.7528311416864 20
# average reward exploit: MDP 0 65.92943886298316 20
# average reward exploit: MDP 0 73.1127578495573 20
# average reward explore: 160.1922692340291
# average reward exploit: MDP 1 52.40192162596669 20
# average reward exploit: MDP 1 50.79863385302608 20
# average reward exploit: MDP 1 84.42623617794607 20
# average reward exploit: MDP 1 83.2304318043126 20
# average reward exploit: MDP 1 96.16715229816927 20
# average reward exploit: MDP 1 57.75346501881266 20
# average reward exploit: MDP 1 37.667652961655435 20
# average reward exploit: MDP 1 68.51339416793653 20
# average reward exploit: MDP 1 68.38717916643688 20
# average reward exploit: MDP 1 39.19631452190188 20
# average reward explore: 162.06549924349878
# average reward exploit: MDP 2 139.46772940392347 20
# average reward exploit: MDP 2 146.16596255416735 20
# average reward exploit: MDP 2 139.14751934541 20
# average reward exploit: MDP 2 97.2990849722202 20
# average reward exploit: MDP 2 126.9924805648748 20
# average reward exploit: MDP 2 130.21003684238107 20
# average reward exploit: MDP 2 108.32242303126046 20
# average reward exploit: MDP 2 70.51674994572889 20
# average reward exploit: MDP 2 112.85444142713663 20
# average reward exploit: MDP 2 112.6139065122087 20
# average reward explore: 166.10914499117217
# average reward exploit: MDP 3 49.16519507558361 20
# average reward exploit: MDP 3 44.86203621341377 20
# average reward exploit: MDP 3 49.04649568670489 20
# average reward exploit: MDP 3 39.202770605983254 20
# average reward exploit: MDP 3 80.35438739550987 20
# average reward exploit: MDP 3 58.85988668735014 20
# average reward exploit: MDP 3 65.59438590747084 20
# average reward exploit: MDP 3 113.17810986673535 20
# average reward exploit: MDP 3 112.22326338913874 20
# average reward exploit: MDP 3 131.34969718628568 20
# average reward explore: 178.18199346806415
# average reward exploit: MDP 4 127.89512288669255 20
# average reward exploit: MDP 4 120.31530809588699 20
# average reward exploit: MDP 4 127.12595750617803 20
# average reward exploit: MDP 4 158.52371780038825 20
# average reward exploit: MDP 4 151.62215724033814 20
# average reward exploit: MDP 4 140.5422352838147 20
# average reward exploit: MDP 4 180.84900381690667 20
# average reward exploit: MDP 4 144.55052316229822 20
# average reward exploit: MDP 4 194.08765943713237 20
# average reward exploit: MDP 4 158.01608250969886 20
# average reward explore: 182.602728723569
# average reward exploit: MDP 5 171.53110360175475 20
# average reward exploit: MDP 5 149.4432439679676 20
# average reward exploit: MDP 5 180.72551934289595 20
# average reward exploit: MDP 5 191.1810426718943 20
# average reward exploit: MDP 5 215.71866002619012 20
# average reward exploit: MDP 5 210.40624599161924 20
# average reward exploit: MDP 5 189.49023620694658 20
# average reward exploit: MDP 5 213.84937742683687 20
# average reward exploit: MDP 5 207.03867664921282 20
# average reward exploit: MDP 5 198.3534951647511 20
# average reward explore: 182.4847111014091
# average reward exploit: MDP 6 204.26780315364368 20
# average reward exploit: MDP 6 205.86233416086966 20
# average reward exploit: MDP 6 205.5524162814845 20
# average reward exploit: MDP 6 207.58542306508352 20
# average reward exploit: MDP 6 212.2039813626664 20
# average reward exploit: MDP 6 204.67202557040636 20
# average reward exploit: MDP 6 206.85155859957672 20
# average reward exploit: MDP 6 205.105025604672 20
# average reward exploit: MDP 6 208.41434293474563 20
# average reward exploit: MDP 6 203.1449648457177 20
# average reward explore: 185.0047903932587
# average reward exploit: MDP 7 197.40764329747668 20
# average reward exploit: MDP 7 195.02566159460568 20
# average reward exploit: MDP 7 198.53448076722844 20
# average reward exploit: MDP 7 197.0157677252447 20
# average reward exploit: MDP 7 196.61745976993925 20
# average reward exploit: MDP 7 192.86294794670494 20
# average reward exploit: MDP 7 197.5710438056621 20
# average reward exploit: MDP 7 195.07201755886143 20
# average reward exploit: MDP 7 196.67154587798308 20
# average reward exploit: MDP 7 191.630581768327 20
# average reward explore: 197.17210692799773
# average reward exploit: MDP 8 232.9749044005069 20
# average reward exploit: MDP 8 229.9127207063429 20
# average reward exploit: MDP 8 229.68535147921912 20
# average reward exploit: MDP 8 208.9344894608028 20
# average reward exploit: MDP 8 219.24603505857948 20
# average reward exploit: MDP 8 189.22140201156802 20
# average reward exploit: MDP 8 197.45169451056688 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-bde7b6456197> in <module>()
# ----> 1 a.train()
#
# <ipython-input-49-fb36fe994242> in train(self)
#     443         for epoch in range(num_epochs):
#     444             print("epoch number: ", epoch)
# --> 445             self.train_step()
#     446
#
# <ipython-input-49-fb36fe994242> in train_step(self)
#     393 #             #print(tvars_vals)
#     394             for j in range(10):
# --> 395                 exploit_paths, exploit_rewards = self.sample_paths_exploit(self.env,Z,i)
#     396                 # get observations, actions and rewards
#     397                 observations_exploit = np.concatenate([path["observation"] for path in exploit_paths])
#
# <ipython-input-49-fb36fe994242> in sample_paths_exploit(self, env, Z, mdp_num, Test, num_episodes)
#     179                 states.append(state)
#     180                 action = self.sess.run(self.exploit_action, feed_dict={self.observation_placeholder_exploit : state[None], self.decoder_input_placeholder: Z})[0]
# --> 181                 state, reward, done, info = env.step(action)
#     182                 actions.append(action)
#     183                 rewards.append(reward)
#
# /anaconda3/lib/python3.6/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      29     def step(self, action):
#      30         assert self._episode_started_at is not None, "Cannot call env.step() before calling reset()"
# ---> 31         observation, reward, done, info = self.env.step(action)
#      32         self._elapsed_steps += 1
#      33
#
# /anaconda3/lib/python3.6/site-packages/gym/envs/mujoco/hopper.py in step(self, a)
#      10     def step(self, a):
#      11         posbefore = self.sim.data.qpos[0]
# ---> 12         self.do_simulation(a, self.frame_skip)
#      13         posafter, height, ang = self.sim.data.qpos[0:3]
#      14         alive_bonus = 1.0
#
# /anaconda3/lib/python3.6/site-packages/gym/envs/mujoco/mujoco_env.py in do_simulation(self, ctrl, n_frames)
#      98         self.sim.data.ctrl[:] = ctrl
#      99         for _ in range(n_frames):
# --> 100             self.sim.step()
#     101
#     102     def render(self, mode='human'):
#
# KeyboardInterrupt:

# %%
a.lr = 3e-3
num_epochs = 50
for epoch in range(num_epochs):
        print("epoch number: ", epoch)
        a.train_step()
# Out:
# epoch number:  0
# average reward explore: 210.21803166108037
# average reward exploit: MDP 0 1.2102014499978386 20
# average reward exploit: MDP 0 0.453440734965816 20
# average reward exploit: MDP 0 0.4610745693248276 20
# average reward exploit: MDP 0 0.9814852631956976 20
# average reward exploit: MDP 0 0.6795388032283648 20
# average reward exploit: MDP 0 0.6245450751715281 20
# average reward exploit: MDP 0 1.4510826378393429 20
# average reward exploit: MDP 0 1.810710538956704 20
# average reward exploit: MDP 0 1.130289546216216 20
# average reward exploit: MDP 0 2.4941984260498913 20
# average reward explore: 527.9931821043476
# average reward exploit: MDP 1 1.028904755019719 20
# average reward exploit: MDP 1 1.0591985770693284 20
# average reward exploit: MDP 1 1.6336284834311225 20
# average reward exploit: MDP 1 1.8515118683949563 20
# average reward exploit: MDP 1 1.4947950404341592 20
# average reward exploit: MDP 1 0.9785628041426131 20
# average reward exploit: MDP 1 1.0039998948866873 20
# average reward exploit: MDP 1 1.486470202349492 20
# average reward exploit: MDP 1 1.7977226179924923 20
# average reward exploit: MDP 1 0.6227341653734858 20
# average reward explore: 554.2324148275004
# average reward exploit: MDP 2 45.35622677379159 20
# average reward exploit: MDP 2 38.81308811129065 20
# average reward exploit: MDP 2 37.30136640936697 20
# average reward exploit: MDP 2 36.78488864599487 20
# average reward exploit: MDP 2 44.75422482747794 20
# average reward exploit: MDP 2 49.792718081690126 20
# average reward exploit: MDP 2 43.653124003498775 20
# average reward exploit: MDP 2 40.146227967231816 20
# average reward exploit: MDP 2 42.324151762642025 20
# average reward exploit: MDP 2 48.373684105061876 20
# average reward explore: 768.2356926711453
# average reward exploit: MDP 3 12.469242103073766 20
# average reward exploit: MDP 3 21.201498529828235 20
# average reward exploit: MDP 3 34.04215268053034 20
# average reward exploit: MDP 3 44.07560421631739 20
# average reward exploit: MDP 3 36.49899501263032 20
# average reward exploit: MDP 3 41.623485951379735 20
# average reward exploit: MDP 3 33.10548745037384 20
# average reward exploit: MDP 3 61.83925436616406 20
# average reward exploit: MDP 3 42.838033593801086 20
# average reward exploit: MDP 3 43.5421268677848 20
# average reward explore: 618.3788488175849
# average reward exploit: MDP 4 38.349722384322334 20
# average reward exploit: MDP 4 47.72637759031075 20
# average reward exploit: MDP 4 39.97070955551275 20
# average reward exploit: MDP 4 34.80289451278355 20
# average reward exploit: MDP 4 35.67931659456859 20
# average reward exploit: MDP 4 39.26446909124873 20
# average reward exploit: MDP 4 41.20515163521558 20
# average reward exploit: MDP 4 29.45994643313448 20
# average reward exploit: MDP 4 37.76558232337898 20
# average reward exploit: MDP 4 47.21393952828329 20
# average reward explore: 563.3970479378804
# average reward exploit: MDP 5 36.55245446716324 20
# average reward exploit: MDP 5 37.97927178164908 20
# average reward exploit: MDP 5 38.75760678826772 20
# average reward exploit: MDP 5 39.69929709803863 20
# average reward exploit: MDP 5 40.63190676076929 20
# average reward exploit: MDP 5 41.8639676746054 20
# average reward exploit: MDP 5 42.75055715498571 20
# average reward exploit: MDP 5 40.47793601782583 20
# average reward exploit: MDP 5 41.47584374835586 20
# average reward exploit: MDP 5 45.31507460661042 20
# average reward explore: 447.15754922119305
# average reward exploit: MDP 6 40.910267400253424 20
# average reward exploit: MDP 6 40.85910987761755 20
# average reward exploit: MDP 6 43.807156744336126 20
# average reward exploit: MDP 6 40.88836362126574 20
# average reward exploit: MDP 6 41.71305141071981 20
# average reward exploit: MDP 6 40.40543179119144 20
# average reward exploit: MDP 6 42.0512845525047 20
# average reward exploit: MDP 6 40.35423080465458 20
# average reward exploit: MDP 6 42.912366199238434 20
# average reward exploit: MDP 6 41.753094924463014 20
# average reward explore: 398.2909670039165
# average reward exploit: MDP 7 42.67352536810234 20
# average reward exploit: MDP 7 39.688819205232576 20
# average reward exploit: MDP 7 40.61254700850756 20
# average reward exploit: MDP 7 40.64352519408642 20
# average reward exploit: MDP 7 40.13351104635456 20
# average reward exploit: MDP 7 42.048940863507376 20
# average reward exploit: MDP 7 40.86373351573692 20
# average reward exploit: MDP 7 40.850427745086236 20
# average reward exploit: MDP 7 40.149886384369 20
# average reward exploit: MDP 7 42.45905792507783 20
# average reward explore: 475.04755299137594
# average reward exploit: MDP 8 39.49410745295269 20
# average reward exploit: MDP 8 38.737521067100595 20
# average reward exploit: MDP 8 38.339267812691546 20
# average reward exploit: MDP 8 39.13709959669351 20
# average reward exploit: MDP 8 41.40355214491667 20
# average reward exploit: MDP 8 39.694559072326854 20
# average reward exploit: MDP 8 41.465201460082675 20
# average reward exploit: MDP 8 40.78425011386183 20
# average reward exploit: MDP 8 38.764546560050334 20
# average reward exploit: MDP 8 37.07685878722466 20
# average reward explore: 511.8761030405507
# average reward exploit: MDP 9 39.262549125552304 20
# average reward exploit: MDP 9 40.2886583915796 20
# average reward exploit: MDP 9 40.255585584357796 20
# average reward exploit: MDP 9 39.159018151815715 20
# average reward exploit: MDP 9 42.8739549261596 20
# average reward exploit: MDP 9 44.90912574113394 20
# average reward exploit: MDP 9 44.21988127595089 20
# average reward exploit: MDP 9 48.74654339200316 20
# average reward exploit: MDP 9 48.07150643141274 20
# average reward exploit: MDP 9 48.003695480121465 20
# epoch number:  1
# average reward explore: 187.3424865791689
# average reward exploit: MDP 0 1.6071665619534248 20
# average reward exploit: MDP 0 1.6586698578603685 20
# average reward exploit: MDP 0 1.6406650328857608 20
# average reward exploit: MDP 0 1.5714600279873538 20
# average reward exploit: MDP 0 1.557572763064098 20
# average reward exploit: MDP 0 1.5754220231247504 20
# average reward exploit: MDP 0 1.6065044434071172 20
# average reward exploit: MDP 0 1.572101958168106 20
# average reward exploit: MDP 0 1.5873301107028603 20
# average reward exploit: MDP 0 1.5675968128902316 20
# average reward explore: 224.46159876038627
# average reward exploit: MDP 1 1.2360191855336669 20
# average reward exploit: MDP 1 1.3327475953816335 20
# average reward exploit: MDP 1 1.2695451187487488 20
# average reward exploit: MDP 1 1.3509980877925813 20
# average reward exploit: MDP 1 1.3557816920174517 20
# average reward exploit: MDP 1 1.2942317760924429 20
# average reward exploit: MDP 1 1.2790117451401921 20
# average reward exploit: MDP 1 1.3455226004279635 20
# average reward exploit: MDP 1 1.3246058180527276 20
# average reward exploit: MDP 1 1.3290860267025173 20
# average reward explore: 368.48453542057075
# average reward exploit: MDP 2 0.9732702901589375 20
# average reward exploit: MDP 2 0.9020917485687736 20
# average reward exploit: MDP 2 0.9056490342226657 20
# average reward exploit: MDP 2 0.9171498464698594 20
# average reward exploit: MDP 2 0.946938361196821 20
# average reward exploit: MDP 2 0.8896321903747723 20
# average reward exploit: MDP 2 0.898219778831917 20
# average reward exploit: MDP 2 0.9563673700661273 20
# average reward exploit: MDP 2 0.915379105512369 20
# average reward exploit: MDP 2 0.9426796731832375 20
# average reward explore: 421.6735248573157
# average reward exploit: MDP 3 0.6209298241878478 20
# average reward exploit: MDP 3 0.6272411345837199 20
# average reward exploit: MDP 3 0.6994833428102855 20
# average reward exploit: MDP 3 0.7017865943323625 20
# average reward exploit: MDP 3 0.6420343426454758 20
# average reward exploit: MDP 3 0.6990322650287326 20
# average reward exploit: MDP 3 0.6362139196450582 20
# average reward exploit: MDP 3 0.5571381173822326 20
# average reward exploit: MDP 3 0.6165126636232097 20
# average reward exploit: MDP 3 0.6522900922258115 20
# average reward explore: 507.5309393450181
# average reward exploit: MDP 4 0.6524905740124339 20
# average reward exploit: MDP 4 1.2992103648125324 20
# average reward exploit: MDP 4 0.7168376477817795 20
# average reward exploit: MDP 4 0.7658337943242985 20
# average reward exploit: MDP 4 2.484050371016623 20
# average reward exploit: MDP 4 1.1296879207758512 20
# average reward exploit: MDP 4 0.8873610744341616 20
# average reward exploit: MDP 4 2.640860515662589 20
# average reward exploit: MDP 4 1.892341254804031 20
# average reward exploit: MDP 4 0.6151933375807191 20
# average reward explore: 408.90876026130803
# average reward exploit: MDP 5 0.9620166050930704 20
# average reward exploit: MDP 5 1.0893781696267157 20
# average reward exploit: MDP 5 1.3744874584530453 20
# average reward exploit: MDP 5 0.6693206634728739 20
# average reward exploit: MDP 5 1.95903062017022 20
# average reward exploit: MDP 5 1.455284422400464 20
# average reward exploit: MDP 5 0.6530484610954044 20
# average reward exploit: MDP 5 1.2788438626498153 20
# average reward exploit: MDP 5 2.088974852083587 20
# average reward exploit: MDP 5 1.472029407726338 20
# average reward explore: 496.7743838206603
# average reward exploit: MDP 6 0.7208058948727898 20
# average reward exploit: MDP 6 0.9969632769076637 20
# average reward exploit: MDP 6 1.5613579126256885 20
# average reward exploit: MDP 6 0.7319661465892877 20
# average reward exploit: MDP 6 1.170060604405784 20
# average reward exploit: MDP 6 0.959735887637579 20
# average reward exploit: MDP 6 1.0949078922246502 20
# average reward exploit: MDP 6 0.665935393921361 20
# average reward exploit: MDP 6 0.7224347703557655 20
# average reward exploit: MDP 6 1.1916459481276882 20
# average reward explore: 560.83177410549
# average reward exploit: MDP 7 35.96114190657053 20
# average reward exploit: MDP 7 38.65943280023701 20
# average reward exploit: MDP 7 36.858244311670916 20
# average reward exploit: MDP 7 39.35559465071036 20
# average reward exploit: MDP 7 42.74796265863761 20
# average reward exploit: MDP 7 42.65677647693173 20
# average reward exploit: MDP 7 44.115936542385676 20
# average reward exploit: MDP 7 47.59096999430825 20
# average reward exploit: MDP 7 43.00881149471632 20
# average reward exploit: MDP 7 44.91641935754999 20
# average reward explore: 584.2284748398282
# average reward exploit: MDP 8 49.252600621873455 20
# average reward exploit: MDP 8 43.08980971440415 20
# average reward exploit: MDP 8 42.14061926573731 20
# average reward exploit: MDP 8 43.71535646484376 20
# average reward exploit: MDP 8 48.648959594015246 20
# average reward exploit: MDP 8 52.154525350505274 20
# average reward exploit: MDP 8 49.68230639717207 20
# average reward exploit: MDP 8 60.57433976630536 20
# average reward exploit: MDP 8 58.34897096182076 20
# average reward exploit: MDP 8 61.68172358406476 20
# average reward explore: 523.9644693335007
# average reward exploit: MDP 9 17.634390294633043 20
# average reward exploit: MDP 9 14.253786408675193 20
# average reward exploit: MDP 9 11.454393851427108 20
# average reward exploit: MDP 9 17.444192490846433 20
# average reward exploit: MDP 9 4.954888782762203 20
# average reward exploit: MDP 9 9.59544061345232 20
# average reward exploit: MDP 9 4.311710525591815 20
# average reward exploit: MDP 9 6.1282622745368975 20
# average reward exploit: MDP 9 5.291729946659444 20
# average reward exploit: MDP 9 4.344199840491533 20
# epoch number:  2
# average reward explore: 166.51293745202935
# average reward exploit: MDP 0 3.291072641243756 20
# average reward exploit: MDP 0 3.2827448200418936 20
# average reward exploit: MDP 0 3.2760842042958935 20
# average reward exploit: MDP 0 3.370587846554785 20
# average reward exploit: MDP 0 3.3281549272111626 20
# average reward exploit: MDP 0 3.3409302070024722 20
# average reward exploit: MDP 0 3.397078679090285 20
# average reward exploit: MDP 0 3.4473695256757226 20
# average reward exploit: MDP 0 3.4312552471329583 20
# average reward exploit: MDP 0 3.6273028111492414 20
# average reward explore: 424.2098759127086
# average reward exploit: MDP 1 0.8551244920188056 20
# average reward exploit: MDP 1 0.7866624341324824 20
# average reward exploit: MDP 1 0.7656073293688106 20
# average reward exploit: MDP 1 0.759600740019564 20
# average reward exploit: MDP 1 0.7258384560868669 20
# average reward exploit: MDP 1 0.7742385716969317 20
# average reward exploit: MDP 1 0.8057164765948903 20
# average reward exploit: MDP 1 0.7635167431744527 20
# average reward exploit: MDP 1 0.8559445987520748 20
# average reward exploit: MDP 1 0.8134960062631673 20
# average reward explore: 487.7946099854936
# average reward exploit: MDP 2 0.9831821749836488 20
# average reward exploit: MDP 2 1.039617967472647 20
# average reward exploit: MDP 2 0.9914239644263173 20
# average reward exploit: MDP 2 1.0357848040949826 20
# average reward exploit: MDP 2 1.003581943461252 20
# average reward exploit: MDP 2 0.9917704837103438 20
# average reward exploit: MDP 2 1.0311939372217078 20
# average reward exploit: MDP 2 0.989308512076007 20
# average reward exploit: MDP 2 1.0259178506653275 20
# average reward exploit: MDP 2 1.0431770286593185 20
# average reward explore: 380.4163956973323
# average reward exploit: MDP 3 1.5256245781816855 20
# average reward exploit: MDP 3 1.623480350230711 20
# average reward exploit: MDP 3 1.523007487342331 20
# average reward exploit: MDP 3 1.5459120260478 20
# average reward exploit: MDP 3 1.5643730941424117 20
# average reward exploit: MDP 3 1.5902131858811859 20
# average reward exploit: MDP 3 1.5917367289158335 20
# average reward exploit: MDP 3 1.5984490787820262 20
# average reward exploit: MDP 3 1.675614943826958 20
# average reward exploit: MDP 3 1.6564881523002608 20
# average reward explore: 382.53261970863167
# average reward exploit: MDP 4 1.2527642902286409 20
# average reward exploit: MDP 4 1.2524964955248195 20
# average reward exploit: MDP 4 1.2217161834812251 20
# average reward exploit: MDP 4 1.2346937357751977 20
# average reward exploit: MDP 4 1.2536193335941375 20
# average reward exploit: MDP 4 1.244417642896042 20
# average reward exploit: MDP 4 1.2247791998443027 20
# average reward exploit: MDP 4 1.2369055874788704 20
# average reward exploit: MDP 4 1.2707091889835478 20
# average reward exploit: MDP 4 1.2582372886056734 20
# average reward explore: 433.10654267732906
# average reward exploit: MDP 5 1.585772190367599 20
# average reward exploit: MDP 5 1.5172778643778013 20
# average reward exploit: MDP 5 1.5674219225687915 20
# average reward exploit: MDP 5 1.5093931365256639 20
# average reward exploit: MDP 5 1.5429745925985738 20
# average reward exploit: MDP 5 1.5001032841219588 20
# average reward exploit: MDP 5 1.4836830432338453 20
# average reward exploit: MDP 5 1.5593386534081524 20
# average reward exploit: MDP 5 1.4875253126698431 20
# average reward exploit: MDP 5 1.507287150948433 20
# average reward explore: 353.14740167517385
# average reward exploit: MDP 6 1.6018338776479912 20
# average reward exploit: MDP 6 1.7325299916974077 20
# average reward exploit: MDP 6 1.6587573015614587 20
# average reward exploit: MDP 6 1.6805132712703983 20
# average reward exploit: MDP 6 1.6296441021054922 20
# average reward exploit: MDP 6 1.6788517909697425 20
# average reward exploit: MDP 6 1.615629566604402 20
# average reward exploit: MDP 6 1.6309277705501288 20
# average reward exploit: MDP 6 1.6637328478138265 20
# average reward exploit: MDP 6 1.6903107049559167 20
# average reward explore: 334.41848652371425
# average reward exploit: MDP 7 2.1696979905102873 20
# average reward exploit: MDP 7 2.1599282207685575 20
# average reward exploit: MDP 7 2.178943366681508 20
# average reward exploit: MDP 7 2.135335273706649 20
# average reward exploit: MDP 7 2.1606675653595855 20
# average reward exploit: MDP 7 2.2465562990752126 20
# average reward exploit: MDP 7 2.163765528111026 20
# average reward exploit: MDP 7 2.222088273232613 20
# average reward exploit: MDP 7 2.199152135031568 20
# average reward exploit: MDP 7 2.220317007782688 20
# average reward explore: 339.0904777394263
# average reward exploit: MDP 8 1.6588746593164334 20
# average reward exploit: MDP 8 1.7030542174467453 20
# average reward exploit: MDP 8 1.6520959109412356 20
# average reward exploit: MDP 8 1.6489450678068664 20
# average reward exploit: MDP 8 1.6181990456430833 20
# average reward exploit: MDP 8 1.6412226316143013 20
# average reward exploit: MDP 8 1.6046408739138247 20
# average reward exploit: MDP 8 1.626659736884977 20
# average reward exploit: MDP 8 1.6655139603641587 20
# average reward exploit: MDP 8 1.6477683475364 20
# average reward explore: 304.7402545747844
# average reward exploit: MDP 9 2.227368659687058 20
# average reward exploit: MDP 9 2.321578114189489 20
# average reward exploit: MDP 9 2.3200186059686567 20
# average reward exploit: MDP 9 2.3949725851399597 20
# average reward exploit: MDP 9 2.394715133217125 20
# average reward exploit: MDP 9 2.436658314724491 20
# average reward exploit: MDP 9 2.4280427411122627 20
# average reward exploit: MDP 9 2.365473188044566 20
# average reward exploit: MDP 9 2.43380922705365 20
# average reward exploit: MDP 9 2.401722032051028 20
# epoch number:  3
# average reward explore: 169.6350110264886
# average reward exploit: MDP 0 1.6400464883268522 20
# average reward exploit: MDP 0 1.8321292551815058 20
# average reward exploit: MDP 0 1.6451016185255996 20
# average reward exploit: MDP 0 1.9103526700646682 20
# average reward exploit: MDP 0 1.7174099616282994 20
# average reward exploit: MDP 0 2.1370213293939146 20
# average reward exploit: MDP 0 1.819549388835044 20
# average reward exploit: MDP 0 1.469480682007362 20
# average reward exploit: MDP 0 1.8258458032351068 20
# average reward exploit: MDP 0 1.8046657084381206 20
# average reward explore: 159.30675700069006
# average reward exploit: MDP 1 2.4268073633930602 20
# average reward exploit: MDP 1 2.5402566873495127 20
# average reward exploit: MDP 1 2.4519620311807246 20
# average reward exploit: MDP 1 2.491312027823432 20
# average reward exploit: MDP 1 2.1844342085523025 20
# average reward exploit: MDP 1 2.5668819932624727 20
# average reward exploit: MDP 1 2.5661397441826197 20
# average reward exploit: MDP 1 2.3233425493085327 20
# average reward exploit: MDP 1 2.513070203871781 20
# average reward exploit: MDP 1 2.5699598626202933 20
# average reward explore: 159.29905952959888
# average reward exploit: MDP 2 36.02551906730598 20
# average reward exploit: MDP 2 15.960814122264832 20
# average reward exploit: MDP 2 6.486445854811845 20
# average reward exploit: MDP 2 5.79236658331212 20
# average reward exploit: MDP 2 16.659297588837063 20
# average reward exploit: MDP 2 10.10828059574451 20
# average reward exploit: MDP 2 5.6086714785574205 20
# average reward exploit: MDP 2 18.84046440884936 20
# average reward exploit: MDP 2 23.5713855489324 20
# average reward exploit: MDP 2 36.986882617772906 20
# average reward explore: 272.18981202714787
# average reward exploit: MDP 3 2.9814568556085286 20
# average reward exploit: MDP 3 2.8652696911014157 20
# average reward exploit: MDP 3 3.026368772651183 20
# average reward exploit: MDP 3 2.9465062475618082 20
# average reward exploit: MDP 3 3.0132475788557374 20
# average reward exploit: MDP 3 2.9638538901208937 20
# average reward exploit: MDP 3 2.8898526559861955 20
# average reward exploit: MDP 3 2.879428805738215 20
# average reward exploit: MDP 3 2.977446432994872 20
# average reward exploit: MDP 3 2.98738624013673 20
# average reward explore: 356.7908167044919
# average reward exploit: MDP 4 2.942729181220018 20
# average reward exploit: MDP 4 3.0402681529830926 20
# average reward exploit: MDP 4 2.9898163907808137 20
# average reward exploit: MDP 4 2.9248350062468105 20
# average reward exploit: MDP 4 3.0563376867021264 20
# average reward exploit: MDP 4 7.494836180101923 20
# average reward exploit: MDP 4 2.8983377211126684 20
# average reward exploit: MDP 4 3.0485201632169376 20
# average reward exploit: MDP 4 2.8431312927795824 20
# average reward exploit: MDP 4 2.837204812376519 20
# average reward explore: 376.6836385564558
# average reward exploit: MDP 5 1.4698049526781622 20
# average reward exploit: MDP 5 1.435099716272785 20
# average reward exploit: MDP 5 1.5491392598441631 20
# average reward exploit: MDP 5 1.5289400178482482 20
# average reward exploit: MDP 5 1.4925966288853008 20
# average reward exploit: MDP 5 1.4805603550228317 20
# average reward exploit: MDP 5 1.474907575034381 20
# average reward exploit: MDP 5 1.4681135017278837 20
# average reward exploit: MDP 5 1.4784938882814997 20
# average reward exploit: MDP 5 1.5023228463725626 20
# average reward explore: 357.9530918727746
# average reward exploit: MDP 6 1.9944271620098835 20
# average reward exploit: MDP 6 1.8870761608147273 20
# average reward exploit: MDP 6 1.9807852535646877 20
# average reward exploit: MDP 6 1.8604897596834344 20
# average reward exploit: MDP 6 1.941512322877615 20
# average reward exploit: MDP 6 1.9292617597160753 20
# average reward exploit: MDP 6 2.0004858152114045 20
# average reward exploit: MDP 6 2.0135399108913887 20
# average reward exploit: MDP 6 1.982562707577508 20
# average reward exploit: MDP 6 2.0273918798085813 20
# average reward explore: 287.58259938410083
# average reward exploit: MDP 7 2.1690760491517294 20
# average reward exploit: MDP 7 2.192587019668263 20
# average reward exploit: MDP 7 2.104805242317323 20
# average reward exploit: MDP 7 2.264306339768816 20
# average reward exploit: MDP 7 2.2538641200925906 20
# average reward exploit: MDP 7 2.276872644201881 20
# average reward exploit: MDP 7 2.2087864085671494 20
# average reward exploit: MDP 7 2.2135301709949937 20
# average reward exploit: MDP 7 2.1974129084632725 20
# average reward exploit: MDP 7 2.2169299258105903 20
# average reward explore: 330.7886891845341
# average reward exploit: MDP 8 1.7514266219233328 20
# average reward exploit: MDP 8 1.7798914485436632 20
# average reward exploit: MDP 8 1.786121918956259 20
# average reward exploit: MDP 8 1.8000153084081956 20
# average reward exploit: MDP 8 1.7183551564026083 20
# average reward exploit: MDP 8 1.7323359477388593 20
# average reward exploit: MDP 8 1.8618913028890893 20
# average reward exploit: MDP 8 1.7362177980393494 20
# average reward exploit: MDP 8 1.7672795832526584 20
# average reward exploit: MDP 8 1.746550297016323 20
# average reward explore: 311.8125558392209
# average reward exploit: MDP 9 1.5042683227149822 20
# average reward exploit: MDP 9 1.502479433281573 20
# average reward exploit: MDP 9 1.4787371737727508 20
# average reward exploit: MDP 9 1.524423973301961 20
# average reward exploit: MDP 9 1.4659687098575354 20
# average reward exploit: MDP 9 1.4982727802258307 20
# average reward exploit: MDP 9 1.4383128823215314 20
# average reward exploit: MDP 9 1.457981213884955 20
# average reward exploit: MDP 9 1.5013838487463698 20
# average reward exploit: MDP 9 1.5017010463816054 20
# epoch number:  4
# average reward explore: 166.7732739874472
# average reward exploit: MDP 0 2.1193200972527473 20
# average reward exploit: MDP 0 1.9948527648448704 20
# average reward exploit: MDP 0 2.0476353272237304 20
# average reward exploit: MDP 0 2.1499721500404907 20
# average reward exploit: MDP 0 2.039864396759804 20
# average reward exploit: MDP 0 2.0336927005999383 20
# average reward exploit: MDP 0 1.9244253537217269 20
# average reward exploit: MDP 0 1.97332743454783 20
# average reward exploit: MDP 0 2.1292950229209735 20
# average reward exploit: MDP 0 2.1928113593838066 20
# average reward explore: 159.9362839256183
# average reward exploit: MDP 1 2.9938231087830984 20
# average reward exploit: MDP 1 2.999153392468384 20
# average reward exploit: MDP 1 2.9104457449029337 20
# average reward exploit: MDP 1 2.934325384585566 20
# average reward exploit: MDP 1 2.893797052782499 20
# average reward exploit: MDP 1 2.938711132005845 20
# average reward exploit: MDP 1 2.949141249113901 20
# average reward exploit: MDP 1 2.9462507977981196 20
# average reward exploit: MDP 1 2.966109015281459 20
# average reward exploit: MDP 1 2.948474643020819 20
# average reward explore: 189.80739612464504
# average reward exploit: MDP 2 2.926472803086464 20
# average reward exploit: MDP 2 2.8232052810732475 20
# average reward exploit: MDP 2 2.819348701403034 20
# average reward exploit: MDP 2 3.0895381261852806 20
# average reward exploit: MDP 2 2.938695655355035 20
# average reward exploit: MDP 2 3.0979958126901086 20
# average reward exploit: MDP 2 4.433991293088231 20
# average reward exploit: MDP 2 3.2516076100999505 20
# average reward exploit: MDP 2 3.1154451297774024 20
# average reward exploit: MDP 2 12.465237483791846 20
# average reward explore: 318.78468950778426
# average reward exploit: MDP 3 3.5350988310958136 20
# average reward exploit: MDP 3 3.6663260768444994 20
# average reward exploit: MDP 3 3.584839821388921 20
# average reward exploit: MDP 3 3.5699091287596003 20
# average reward exploit: MDP 3 3.6371803273935273 20
# average reward exploit: MDP 3 3.6447581065710617 20
# average reward exploit: MDP 3 3.6041301355734943 20
# average reward exploit: MDP 3 3.691541391704945 20
# average reward exploit: MDP 3 3.758966877638823 20
# average reward exploit: MDP 3 3.6907696860359787 20
# average reward explore: 323.8184537140886
# average reward exploit: MDP 4 3.5606912040046894 20
# average reward exploit: MDP 4 3.574777047873757 20
# average reward exploit: MDP 4 3.403125997536732 20
# average reward exploit: MDP 4 3.5566032539101053 20
# average reward exploit: MDP 4 3.3834263741079207 20
# average reward exploit: MDP 4 3.3619894270478445 20
# average reward exploit: MDP 4 3.511480233629831 20
# average reward exploit: MDP 4 3.4149560002468275 20
# average reward exploit: MDP 4 3.441350477792862 20
# average reward exploit: MDP 4 3.3447540304983128 20
# average reward explore: 342.3038140197932
# average reward exploit: MDP 5 2.3451874150980387 20
# average reward exploit: MDP 5 2.2958163434104217 20
# average reward exploit: MDP 5 2.305713690001167 20
# average reward exploit: MDP 5 2.2358238324216275 20
# average reward exploit: MDP 5 2.321048256171623 20
# average reward exploit: MDP 5 2.2905110954139842 20
# average reward exploit: MDP 5 2.3416156092194536 20
# average reward exploit: MDP 5 2.3000127655649196 20
# average reward exploit: MDP 5 2.322802796725919 20
# average reward exploit: MDP 5 2.337615426999576 20
# average reward explore: 320.465749201884
# average reward exploit: MDP 6 2.102848061464498 20
# average reward exploit: MDP 6 2.174637383128263 20
# average reward exploit: MDP 6 2.1618169742827438 20
# average reward exploit: MDP 6 2.077782779460052 20
# average reward exploit: MDP 6 2.0752984967908388 20
# average reward exploit: MDP 6 2.2312221781126906 20
# average reward exploit: MDP 6 2.1490754189206926 20
# average reward exploit: MDP 6 2.0577479083051258 20
# average reward exploit: MDP 6 2.124646455899116 20
# average reward exploit: MDP 6 2.0157312956549847 20
# average reward explore: 327.0960379950047
# average reward exploit: MDP 7 1.3588296961619966 20
# average reward exploit: MDP 7 1.3889032428064572 20
# average reward exploit: MDP 7 1.2920458302943072 20
# average reward exploit: MDP 7 1.274413996360398 20
# average reward exploit: MDP 7 1.3714735260299715 20
# average reward exploit: MDP 7 1.194045008225744 20
# average reward exploit: MDP 7 1.2864416432747052 20
# average reward exploit: MDP 7 1.2572358764683946 20
# average reward exploit: MDP 7 1.5119616453035607 20
# average reward exploit: MDP 7 1.3004548465628536 20
# average reward explore: 337.82658586186756
# average reward exploit: MDP 8 1.7289056122921846 20
# average reward exploit: MDP 8 1.7533773469665401 20
# average reward exploit: MDP 8 1.7096734251837216 20
# average reward exploit: MDP 8 1.656609324604937 20
# average reward exploit: MDP 8 1.6784224285274374 20
# average reward exploit: MDP 8 1.7303006295716614 20
# average reward exploit: MDP 8 1.7529016793164698 20
# average reward exploit: MDP 8 1.740010306196623 20
# average reward exploit: MDP 8 1.7820387182373192 20
# average reward exploit: MDP 8 1.7419300661992985 20
# average reward explore: 316.1571068791501
# average reward exploit: MDP 9 1.6476095749118198 20
# average reward exploit: MDP 9 1.6130843296644166 20
# average reward exploit: MDP 9 1.6166446046475584 20
# average reward exploit: MDP 9 1.626447994344715 20
# average reward exploit: MDP 9 1.640330746081942 20
# average reward exploit: MDP 9 1.6282910137274176 20
# average reward exploit: MDP 9 1.6687056156845235 20
# average reward exploit: MDP 9 1.6693503726973034 20
# average reward exploit: MDP 9 1.6293245602549864 20
# average reward exploit: MDP 9 1.608842989112923 20
# epoch number:  5
# average reward explore: 240.14177490694948
# average reward exploit: MDP 0 2.487441261457434 20
# average reward exploit: MDP 0 2.390006525118639 20
# average reward exploit: MDP 0 2.34559513652068 20
# average reward exploit: MDP 0 2.432572173599519 20
# average reward exploit: MDP 0 2.3140831376675277 20
# average reward exploit: MDP 0 2.3409132737082805 20
# average reward exploit: MDP 0 2.3435620578551744 20
# average reward exploit: MDP 0 2.4948060598405153 20
# average reward exploit: MDP 0 2.388007242030798 20
# average reward exploit: MDP 0 2.440804408624153 20
# average reward explore: 296.9464209458197
# average reward exploit: MDP 1 3.7426099301557065 20
# average reward exploit: MDP 1 3.7898733965493507 20
# average reward exploit: MDP 1 3.7617689863279025 20
# average reward exploit: MDP 1 3.7932433957771097 20
# average reward exploit: MDP 1 3.945585395074442 20
# average reward exploit: MDP 1 3.882059675225687 20
# average reward exploit: MDP 1 3.756418286168509 20
# average reward exploit: MDP 1 3.8379148547707027 20
# average reward exploit: MDP 1 3.8293910518102123 20
# average reward exploit: MDP 1 3.9597301831206573 20
# average reward explore: 311.99659095336267
# average reward exploit: MDP 2 2.4302919171292565 20
# average reward exploit: MDP 2 2.428643518171074 20
# average reward exploit: MDP 2 2.443833686864608 20
# average reward exploit: MDP 2 2.399983087315735 20
# average reward exploit: MDP 2 2.5062643450176734 20
# average reward exploit: MDP 2 2.4180916362471505 20
# average reward exploit: MDP 2 2.5198814665998217 20
# average reward exploit: MDP 2 2.4910494798535665 20
# average reward exploit: MDP 2 2.3989413062864156 20
# average reward exploit: MDP 2 2.3966523456301507 20
# average reward explore: 335.3398121796462
# average reward exploit: MDP 3 2.1856981103116317 20
# average reward exploit: MDP 3 2.17497598628972 20
# average reward exploit: MDP 3 2.1403808277441962 20
# average reward exploit: MDP 3 2.156122538679066 20
# average reward exploit: MDP 3 2.1753630384371236 20
# average reward exploit: MDP 3 2.194306608585388 20
# average reward exploit: MDP 3 2.0853487260697676 20
# average reward exploit: MDP 3 2.1450685067245607 20
# average reward exploit: MDP 3 2.086649048987475 20
# average reward exploit: MDP 3 2.1452030547422045 20
# average reward explore: 343.88371713329394
# average reward exploit: MDP 4 2.986216926492455 20
# average reward exploit: MDP 4 3.094074635107108 20
# average reward exploit: MDP 4 3.0445620041240247 20
# average reward exploit: MDP 4 3.1582317647207194 20
# average reward exploit: MDP 4 3.123678009245228 20
# average reward exploit: MDP 4 3.0853542115521693 20
# average reward exploit: MDP 4 3.230802150402826 20
# average reward exploit: MDP 4 3.1385054153757825 20
# average reward exploit: MDP 4 3.210638889899484 20
# average reward exploit: MDP 4 3.239313796728806 20
# average reward explore: 414.9216541651452
# average reward exploit: MDP 5 1.768858050895055 20
# average reward exploit: MDP 5 2.553979183585675 20
# average reward exploit: MDP 5 1.8493253970983559 20
# average reward exploit: MDP 5 3.784780623800345 20
# average reward exploit: MDP 5 2.0990238218520854 20
# average reward exploit: MDP 5 1.8529194436649223 20
# average reward exploit: MDP 5 1.8040369805543839 20
# average reward exploit: MDP 5 1.776162518340333 20
# average reward exploit: MDP 5 1.832502633359954 20
# average reward exploit: MDP 5 1.8113958091341786 20
# average reward explore: 478.4085905367864
# average reward exploit: MDP 6 1.5419269317405035 20
# average reward exploit: MDP 6 15.596525327999606 20
# average reward exploit: MDP 6 8.95798589013998 20
# average reward exploit: MDP 6 12.065263150298213 20
# average reward exploit: MDP 6 7.556955624482917 20
# average reward exploit: MDP 6 37.111630777504885 20
# average reward exploit: MDP 6 35.52007707742034 20
# average reward exploit: MDP 6 74.11112555423395 20
# average reward exploit: MDP 6 59.158836596273396 20
# average reward exploit: MDP 6 46.536582728145795 20
# average reward explore: 447.854047069904
# average reward exploit: MDP 7 1.074623256021947 20
# average reward exploit: MDP 7 1.059755591258337 20
# average reward exploit: MDP 7 1.9801069392078314 20
# average reward exploit: MDP 7 1.0779821992374745 20
# average reward exploit: MDP 7 1.1005716891956656 20
# average reward exploit: MDP 7 0.9398399640395848 20
# average reward exploit: MDP 7 1.129840344569317 20
# average reward exploit: MDP 7 1.0981231558918463 20
# average reward exploit: MDP 7 1.0483459298594033 20
# average reward exploit: MDP 7 3.0810575505862596 20
# average reward explore: 479.4157047499792
# average reward exploit: MDP 8 62.67847022172174 20
# average reward exploit: MDP 8 65.20663291327337 20
# average reward exploit: MDP 8 71.09333213882671 20
# average reward exploit: MDP 8 71.2913953906008 20
# average reward exploit: MDP 8 70.45150227878206 20
# average reward exploit: MDP 8 73.27549264144338 20
# average reward exploit: MDP 8 77.27906893510436 20
# average reward exploit: MDP 8 88.98848202780218 20
# average reward exploit: MDP 8 97.47604995884781 20
# average reward exploit: MDP 8 87.27866740216307 20
# average reward explore: 495.5990284194425
# average reward exploit: MDP 9 20.38862433010374 20
# average reward exploit: MDP 9 22.077216988779412 20
# average reward exploit: MDP 9 22.523367773751854 20
# average reward exploit: MDP 9 23.487766451758453 20
# average reward exploit: MDP 9 24.09179129343089 20
# average reward exploit: MDP 9 37.202614366173705 20
# average reward exploit: MDP 9 31.72998691533694 20
# average reward exploit: MDP 9 48.98214812092432 20
# average reward exploit: MDP 9 52.92493657926849 20
# average reward exploit: MDP 9 53.614368219538925 20
# epoch number:  6
# average reward explore: 194.9523024613585
# average reward exploit: MDP 0 43.25874818638217 20
# average reward exploit: MDP 0 56.15548733544739 20
# average reward exploit: MDP 0 46.82735025538089 20
# average reward exploit: MDP 0 56.46956778350277 20
# average reward exploit: MDP 0 56.17843339960486 20
# average reward exploit: MDP 0 22.511503168935995 20
# average reward exploit: MDP 0 2.3490682225514274 20
# average reward exploit: MDP 0 2.001773042263584 20
# average reward exploit: MDP 0 1.59877810325225 20
# average reward exploit: MDP 0 1.5694522704905356 20
# average reward explore: 337.74934517273397
# average reward exploit: MDP 1 0.9639275485928691 20
# average reward exploit: MDP 1 0.9818908021512838 20
# average reward exploit: MDP 1 0.9496811025720397 20
# average reward exploit: MDP 1 0.9451886607031689 20
# average reward exploit: MDP 1 0.9372781261861463 20
# average reward exploit: MDP 1 0.8710131267898404 20
# average reward exploit: MDP 1 0.9466511403871498 20
# average reward exploit: MDP 1 0.8620920204411476 20
# average reward exploit: MDP 1 0.8748568731439296 20
# average reward exploit: MDP 1 0.8835392112351539 20
# average reward explore: 396.96549164026374
# average reward exploit: MDP 2 0.6156241979636763 20
# average reward exploit: MDP 2 0.6455743937138562 20
# average reward exploit: MDP 2 0.6631390001104357 20
# average reward exploit: MDP 2 0.6702504097433739 20
# average reward exploit: MDP 2 0.6779076421220731 20
# average reward exploit: MDP 2 0.6428934530525774 20
# average reward exploit: MDP 2 0.6532354312649471 20
# average reward exploit: MDP 2 0.6483747260801758 20
# average reward exploit: MDP 2 0.6311777123886513 20
# average reward exploit: MDP 2 0.6427194099599267 20
# average reward explore: 413.2016385251574
# average reward exploit: MDP 3 0.9828892659174923 20
# average reward exploit: MDP 3 0.9484442881491064 20
# average reward exploit: MDP 3 0.9451510975931589 20
# average reward exploit: MDP 3 0.9480641049814788 20
# average reward exploit: MDP 3 0.9790434489804598 20
# average reward exploit: MDP 3 0.9687972833050524 20
# average reward exploit: MDP 3 0.9562879767331018 20
# average reward exploit: MDP 3 0.9431277393969053 20
# average reward exploit: MDP 3 0.9097141865242293 20
# average reward exploit: MDP 3 0.9616582401195053 20
# average reward explore: 467.49574755521706
# average reward exploit: MDP 4 0.27736901011894954 20
# average reward exploit: MDP 4 0.28396851181495025 20
# average reward exploit: MDP 4 0.20779109366856474 20
# average reward exploit: MDP 4 0.22466187843192192 20
# average reward exploit: MDP 4 0.17864440855841818 20
# average reward exploit: MDP 4 0.2511995156843473 20
# average reward exploit: MDP 4 0.20868330265709084 20
# average reward exploit: MDP 4 0.20076530716468294 20
# average reward exploit: MDP 4 0.2337800574128858 20
# average reward exploit: MDP 4 0.208455789499752 20
# average reward explore: 346.62383397573365
# average reward exploit: MDP 5 0.644958957099319 20
# average reward exploit: MDP 5 0.672889864366312 20
# average reward exploit: MDP 5 0.6637599935714971 20
# average reward exploit: MDP 5 0.6562553109372441 20
# average reward exploit: MDP 5 0.6277752143595017 20
# average reward exploit: MDP 5 0.6582530252999834 20
# average reward exploit: MDP 5 0.6268020419453507 20
# average reward exploit: MDP 5 0.7386882244241886 20
# average reward exploit: MDP 5 0.6957981594470609 20
# average reward exploit: MDP 5 0.7048402923246815 20
# average reward explore: 358.97829002642897
# average reward exploit: MDP 6 0.1178658786094722 20
# average reward exploit: MDP 6 0.14507357575051721 20
# average reward exploit: MDP 6 0.09933973905180984 20
# average reward exploit: MDP 6 0.12574828289717566 20
# average reward exploit: MDP 6 0.14100572886252388 20
# average reward exploit: MDP 6 0.0973790209994307 20
# average reward exploit: MDP 6 0.11357495082185701 20
# average reward exploit: MDP 6 0.12845202831426333 20
# average reward exploit: MDP 6 0.1146222927248283 20
# average reward exploit: MDP 6 0.11205149430416887 20
# average reward explore: 432.0032788034323
# average reward exploit: MDP 7 0.021968187101488307 20
# average reward exploit: MDP 7 0.055962414075313584 20
# average reward exploit: MDP 7 0.04868025700256974 20
# average reward exploit: MDP 7 0.04270117263424149 20
# average reward exploit: MDP 7 -0.009533592439776157 20
# average reward exploit: MDP 7 -0.050994945014275685 20
# average reward exploit: MDP 7 -0.035967804562427354 20
# average reward exploit: MDP 7 0.008836929294388705 20
# average reward exploit: MDP 7 0.038173011727066816 20
# average reward exploit: MDP 7 0.046009904264740775 20
# average reward explore: 419.5917577283156
# average reward exploit: MDP 8 -0.11595820524719753 20
# average reward exploit: MDP 8 -0.0630942748910914 20
# average reward exploit: MDP 8 -0.06521229665885402 20
# average reward exploit: MDP 8 -0.06500547195527363 20
# average reward exploit: MDP 8 -0.03857087165509283 20
# average reward exploit: MDP 8 0.007577448456250743 20
# average reward exploit: MDP 8 0.14518724840049663 20
# average reward exploit: MDP 8 0.1697163042508683 20
# average reward exploit: MDP 8 0.2698220592630392 20
# average reward exploit: MDP 8 0.3557507065142974 20
# average reward explore: 601.5689300333331
# average reward exploit: MDP 9 0.062378592015347026 20
# average reward exploit: MDP 9 0.07047417601254763 20
# average reward exploit: MDP 9 0.1407094514921397 20
# average reward exploit: MDP 9 0.14384585462884056 20
# average reward exploit: MDP 9 0.21345161389038325 20
# average reward exploit: MDP 9 0.2593033890321473 20
# average reward exploit: MDP 9 0.2917993014428252 20
# average reward exploit: MDP 9 0.35621670540642497 20
# average reward exploit: MDP 9 0.38511574380769636 20
# average reward exploit: MDP 9 0.39360160365330066 20
# epoch number:  7
# average reward explore: 173.72254911326564
# average reward exploit: MDP 0 1.5618464642831271 20
# average reward exploit: MDP 0 1.5593335605759646 20
# average reward exploit: MDP 0 1.577955465817659 20
# average reward exploit: MDP 0 1.5412994987143045 20
# average reward exploit: MDP 0 1.5363065756626015 20
# average reward exploit: MDP 0 1.4005781414216925 20
# average reward exploit: MDP 0 1.532221968128368 20
# average reward exploit: MDP 0 1.5806354730580805 20
# average reward exploit: MDP 0 1.5080813586680486 20
# average reward exploit: MDP 0 1.4461660777018224 20
# average reward explore: 281.616307537588
# average reward exploit: MDP 1 1.5339644656860847 20
# average reward exploit: MDP 1 1.5194677830821406 20
# average reward exploit: MDP 1 1.567189324380149 20
# average reward exploit: MDP 1 1.5073926726129534 20
# average reward exploit: MDP 1 1.5912644312993294 20
# average reward exploit: MDP 1 1.528931602217131 20
# average reward exploit: MDP 1 1.551374138316878 20
# average reward exploit: MDP 1 1.530635188266118 20
# average reward exploit: MDP 1 1.5527163134327613 20
# average reward exploit: MDP 1 1.5492452141652693 20
# average reward explore: 470.8772704807328
# average reward exploit: MDP 2 0.8806734491151664 20
# average reward exploit: MDP 2 0.9012820237118093 20
# average reward exploit: MDP 2 0.8945251605555326 20
# average reward exploit: MDP 2 0.9011680027313005 20
# average reward exploit: MDP 2 0.9179284031148454 20
# average reward exploit: MDP 2 0.9138995839082588 20
# average reward exploit: MDP 2 0.9325984774604545 20
# average reward exploit: MDP 2 0.908902825828925 20
# average reward exploit: MDP 2 0.9677216911309268 20
# average reward exploit: MDP 2 0.9352068545707535 20
# average reward explore: 463.32830841198074
# average reward exploit: MDP 3 1.2063134128616841 20
# average reward exploit: MDP 3 1.2422765773124773 20
# average reward exploit: MDP 3 1.2074425125411552 20
# average reward exploit: MDP 3 1.2452307674168446 20
# average reward exploit: MDP 3 1.2203598486726093 20
# average reward exploit: MDP 3 1.2355500799744388 20
# average reward exploit: MDP 3 1.2746015386143759 20
# average reward exploit: MDP 3 1.2806859365011802 20
# average reward exploit: MDP 3 1.304001899234302 20
# average reward exploit: MDP 3 1.2554677626432904 20
# average reward explore: 412.4223886744538
# average reward exploit: MDP 4 1.6243700531051188 20
# average reward exploit: MDP 4 1.6805583815329572 20
# average reward exploit: MDP 4 1.7545495385549021 20
# average reward exploit: MDP 4 1.6812349895741867 20
# average reward exploit: MDP 4 1.714189653305579 20
# average reward exploit: MDP 4 1.6340835569545853 20
# average reward exploit: MDP 4 1.7716763065219971 20
# average reward exploit: MDP 4 1.734883170322334 20
# average reward exploit: MDP 4 1.7266156876719219 20
# average reward exploit: MDP 4 1.7543126721679072 20
# average reward explore: 450.38404283095207
# average reward exploit: MDP 5 0.7485747389503835 20
# average reward exploit: MDP 5 0.6952514283511276 20
# average reward exploit: MDP 5 0.673971686402865 20
# average reward exploit: MDP 5 0.725550218956973 20
# average reward exploit: MDP 5 0.7487655098395538 20
# average reward exploit: MDP 5 0.6972706527694621 20
# average reward exploit: MDP 5 0.666582891623931 20
# average reward exploit: MDP 5 0.7646707720224771 20
# average reward exploit: MDP 5 0.7433034940631693 20
# average reward exploit: MDP 5 0.7856491255975689 20
# average reward explore: 572.8581567765026
# average reward exploit: MDP 6 0.4992917040396395 20
# average reward exploit: MDP 6 0.5489108417409839 20
# average reward exploit: MDP 6 0.5331754993426999 20
# average reward exploit: MDP 6 0.5131252312244188 20
# average reward exploit: MDP 6 0.5045543500761684 20
# average reward exploit: MDP 6 0.5526519742780088 20
# average reward exploit: MDP 6 0.5449652887609583 20
# average reward exploit: MDP 6 0.5462445131842245 20
# average reward exploit: MDP 6 0.532194048398356 20
# average reward exploit: MDP 6 0.5853709574029153 20
# average reward explore: 517.8332971771988
# average reward exploit: MDP 7 0.709021195955358 20
# average reward exploit: MDP 7 0.7150329306351336 20
# average reward exploit: MDP 7 0.7279618645573026 20
# average reward exploit: MDP 7 0.769196962506437 20
# average reward exploit: MDP 7 0.7367327538240147 20
# average reward exploit: MDP 7 0.6637097950255529 20
# average reward exploit: MDP 7 0.808208993259646 20
# average reward exploit: MDP 7 0.8273297910379729 20
# average reward exploit: MDP 7 0.8248359637863688 20
# average reward exploit: MDP 7 0.9067067811617265 20
# average reward explore: 626.8653653755548
# average reward exploit: MDP 8 1.053705143336497 20
# average reward exploit: MDP 8 1.1193652739634796 20
# average reward exploit: MDP 8 1.5590871659005672 20
# average reward exploit: MDP 8 1.0697134064833906 20
# average reward exploit: MDP 8 1.0592591602662673 20
# average reward exploit: MDP 8 1.3176366710427876 20
# average reward exploit: MDP 8 1.6018779626548274 20
# average reward exploit: MDP 8 1.4087320944972626 20
# average reward exploit: MDP 8 1.8152543721008674 20
# average reward exploit: MDP 8 1.9102441115099587 20
# average reward explore: 664.1499957360722
# average reward exploit: MDP 9 6.896599307176807 20
# average reward exploit: MDP 9 6.650978885661568 20
# average reward exploit: MDP 9 9.191916199744986 20
# average reward exploit: MDP 9 6.311765125082006 20
# average reward exploit: MDP 9 6.489358842553408 20
# average reward exploit: MDP 9 11.220267885039318 20
# average reward exploit: MDP 9 11.045900630875032 20
# average reward exploit: MDP 9 8.667331004191228 20
# average reward exploit: MDP 9 6.954767240987262 20
# average reward exploit: MDP 9 11.75641683894477 20
# epoch number:  8
# average reward explore: 180.1657041875949
# average reward exploit: MDP 0 2.056609789330477 20
# average reward exploit: MDP 0 2.0831023703940232 20
# average reward exploit: MDP 0 1.964513274838578 20
# average reward exploit: MDP 0 1.9783724544481707 20
# average reward exploit: MDP 0 1.8852777967827172 20
# average reward exploit: MDP 0 1.9695131542122648 20
# average reward exploit: MDP 0 1.9079175044643972 20
# average reward exploit: MDP 0 1.9679326955440728 20
# average reward exploit: MDP 0 1.9136233847027886 20
# average reward exploit: MDP 0 1.890502140131821 20
# average reward explore: 361.41366179182535
# average reward exploit: MDP 1 2.253594061660679 20
# average reward exploit: MDP 1 2.1698958572976954 20
# average reward exploit: MDP 1 2.138725620186573 20
# average reward exploit: MDP 1 2.266656653617969 20
# average reward exploit: MDP 1 2.2249262466641158 20
# average reward exploit: MDP 1 2.2446679685051607 20
# average reward exploit: MDP 1 2.3432667268875607 20
# average reward exploit: MDP 1 2.487752931368436 20
# average reward exploit: MDP 1 2.365456692417247 20
# average reward exploit: MDP 1 2.5235495630708016 20
# average reward explore: 583.3419723297354
# average reward exploit: MDP 2 1.9400829843597258 20
# average reward exploit: MDP 2 2.0047172191244633 20
# average reward exploit: MDP 2 2.207766479801304 20
# average reward exploit: MDP 2 2.2977339135910038 20
# average reward exploit: MDP 2 2.373682497482968 20
# average reward exploit: MDP 2 2.4817942423838146 20
# average reward exploit: MDP 2 2.4546804334686945 20
# average reward exploit: MDP 2 2.2488154236541247 20
# average reward exploit: MDP 2 2.484132145242984 20
# average reward exploit: MDP 2 2.4476625945711223 20
# average reward explore: 656.4624904269442
# average reward exploit: MDP 3 1.293706434882642 20
# average reward exploit: MDP 3 1.2268515079748248 20
# average reward exploit: MDP 3 1.3784467404848981 20
# average reward exploit: MDP 3 1.2903580673765345 20
# average reward exploit: MDP 3 1.2867606771791862 20
# average reward exploit: MDP 3 1.369288177205525 20
# average reward exploit: MDP 3 1.5331109521288786 20
# average reward exploit: MDP 3 1.5095922332091818 20
# average reward exploit: MDP 3 1.6013260819287918 20
# average reward exploit: MDP 3 1.7014924288138034 20
# average reward explore: 600.4434641897599
# average reward exploit: MDP 4 1.789579881430845 20
# average reward exploit: MDP 4 1.7155351180253327 20
# average reward exploit: MDP 4 1.67696369915327 20
# average reward exploit: MDP 4 5.202383965162639 20
# average reward exploit: MDP 4 8.469935682232517 20
# average reward exploit: MDP 4 14.299191669068918 20
# average reward exploit: MDP 4 9.793096361665594 20
# average reward exploit: MDP 4 13.040372644892532 20
# average reward exploit: MDP 4 17.911175949721127 20
# average reward exploit: MDP 4 20.882697437897377 20
# average reward explore: 536.6624470852636
# average reward exploit: MDP 5 1.1704920040549978 20
# average reward exploit: MDP 5 1.275352453373764 20
# average reward exploit: MDP 5 1.1300809705063712 20
# average reward exploit: MDP 5 1.1076390474541493 20
# average reward exploit: MDP 5 1.0391851129284322 20
# ...
# average reward exploit: MDP 0 3.5467589562818476 20
# average reward exploit: MDP 0 3.3624253844867007 20
# average reward exploit: MDP 0 3.825957091557295 20
# average reward exploit: MDP 0 3.2945435376699743 20
# average reward exploit: MDP 0 2.975307054888103 20
# average reward exploit: MDP 0 2.9968801566734755 20
# average reward exploit: MDP 0 3.485983878903235 20
# average reward exploit: MDP 0 2.892345359530355 20
# average reward exploit: MDP 0 3.024575290061288 20
# average reward exploit: MDP 0 3.274556418248809 20
# average reward explore: 159.8929011818811
# average reward exploit: MDP 1 15.755909773172055 20
# average reward exploit: MDP 1 6.459677861295799 20
# average reward exploit: MDP 1 6.326945179477517 20
# average reward exploit: MDP 1 6.535212452712837 20
# average reward exploit: MDP 1 10.234237772485054 20
# average reward exploit: MDP 1 6.324275369365862 20
# average reward exploit: MDP 1 11.607573010315384 20
# average reward exploit: MDP 1 6.353007465055471 20
# average reward exploit: MDP 1 11.689713451125117 20
# average reward exploit: MDP 1 6.063221851777921 20
# average reward explore: 179.13400293224518
# average reward exploit: MDP 2 7.283573321268159 20
# average reward exploit: MDP 2 7.515962993947317 20
# average reward exploit: MDP 2 7.317408720668564 20
# average reward exploit: MDP 2 7.109692877977149 20
# average reward exploit: MDP 2 7.237779775013206 20
# average reward exploit: MDP 2 7.082417970047105 20
# average reward exploit: MDP 2 7.316651444370622 20
# average reward exploit: MDP 2 7.163715581490815 20
# average reward exploit: MDP 2 6.911067839242409 20
# average reward exploit: MDP 2 6.904722976274016 20
# average reward explore: 321.48088784121046
# average reward exploit: MDP 3 3.594561917430396 20
# average reward exploit: MDP 3 3.597236456925058 20
# average reward exploit: MDP 3 3.556722097241446 20
# average reward exploit: MDP 3 3.4329620005670973 20
# average reward exploit: MDP 3 3.6214028374592475 20
# average reward exploit: MDP 3 3.507898572941497 20
# average reward exploit: MDP 3 6.59765479989281 20
# average reward exploit: MDP 3 3.4947671629763293 20
# average reward exploit: MDP 3 3.575195941120884 20
# average reward exploit: MDP 3 3.386362131526598 20
# average reward explore: 441.10868940220024
# average reward exploit: MDP 4 3.0643173566512134 20
# average reward exploit: MDP 4 3.0351566207950165 20
# average reward exploit: MDP 4 3.0164973177391334 20
# average reward exploit: MDP 4 3.092224841927853 20
# average reward exploit: MDP 4 3.0332987785537573 20
# average reward exploit: MDP 4 3.040669905783284 20
# average reward exploit: MDP 4 2.96685183820712 20
# average reward exploit: MDP 4 3.041309648900779 20
# average reward exploit: MDP 4 3.028125555875528 20
# average reward exploit: MDP 4 3.1792746016050564 20
# average reward explore: 409.24988669176594
# average reward exploit: MDP 5 2.2260448935206125 20
# average reward exploit: MDP 5 2.188025696658999 20
# average reward exploit: MDP 5 4.448928327856931 20
# average reward exploit: MDP 5 8.95066866663212 20
# average reward exploit: MDP 5 20.823312336055242 20
# average reward exploit: MDP 5 14.655686137686164 20
# average reward exploit: MDP 5 18.453179103635136 20
# average reward exploit: MDP 5 19.682394153918388 20
# average reward exploit: MDP 5 16.689479931967547 20
# average reward exploit: MDP 5 15.623894665791372 20
# average reward explore: 417.2735445240157
# average reward exploit: MDP 6 3.1955181022227426 20
# average reward exploit: MDP 6 3.174282209166379 20
# average reward exploit: MDP 6 3.111515158821596 20
# average reward exploit: MDP 6 3.1504553276924536 20
# average reward exploit: MDP 6 3.168897872828827 20
# average reward exploit: MDP 6 3.1495580748110488 20
# average reward exploit: MDP 6 3.1309308915900464 20
# average reward exploit: MDP 6 3.216585636905523 20
# average reward exploit: MDP 6 3.1418154680178825 20
# average reward exploit: MDP 6 3.235139303215695 20
# average reward explore: 430.7743829784593
# average reward exploit: MDP 7 3.0516413076369524 20
# average reward exploit: MDP 7 3.1706733261249287 20
# average reward exploit: MDP 7 3.0967925849915834 20
# average reward exploit: MDP 7 4.635245807689111 20
# average reward exploit: MDP 7 3.1858040743875824 20
# average reward exploit: MDP 7 3.2169963061792286 20
# average reward exploit: MDP 7 3.1599947784904368 20
# average reward exploit: MDP 7 3.2398893065757632 20
# average reward exploit: MDP 7 3.372783051269092 20
# average reward exploit: MDP 7 3.3842376855181144 20
# average reward explore: 344.24214390558626
# average reward exploit: MDP 8 3.003881087279281 20
# average reward exploit: MDP 8 3.033039169862197 20
# average reward exploit: MDP 8 3.0994154367323796 20
# average reward exploit: MDP 8 3.001458012609007 20
# average reward exploit: MDP 8 2.9530395884976737 20
# average reward exploit: MDP 8 3.0107008719903527 20
# average reward exploit: MDP 8 3.0687795487392173 20
# average reward exploit: MDP 8 2.9926643079858977 20
# average reward exploit: MDP 8 3.1755292312073853 20
# average reward exploit: MDP 8 2.992924600987851 20
# average reward explore: 465.37704273993313
# average reward exploit: MDP 9 3.625313764703062 20
# average reward exploit: MDP 9 3.8367369982121695 20
# average reward exploit: MDP 9 3.6882473385858296 20
# average reward exploit: MDP 9 3.822055470682499 20
# average reward exploit: MDP 9 3.997032037355203 20
# average reward exploit: MDP 9 3.981398219772564 20
# average reward exploit: MDP 9 4.064084779017768 20
# average reward exploit: MDP 9 4.084305462758982 20
# average reward exploit: MDP 9 4.202676534912624 20
# average reward exploit: MDP 9 4.284998068655673 20
# epoch number:  12
# average reward explore: 160.10120592211192
# average reward exploit: MDP 0 33.05688169377059 20
# average reward exploit: MDP 0 33.17575064567708 20
# average reward exploit: MDP 0 32.19537554334944 20
# average reward exploit: MDP 0 47.69291892706782 20
# average reward exploit: MDP 0 46.5228074952784 20
# average reward exploit: MDP 0 52.191633107281746 20
# average reward exploit: MDP 0 36.576825980914116 20
# average reward exploit: MDP 0 50.33729915408842 20
# average reward exploit: MDP 0 76.7828162339115 20
# average reward exploit: MDP 0 70.50354426526775 20
# average reward explore: 153.6092262138237
# average reward exploit: MDP 1 44.46755072541984 20
# average reward exploit: MDP 1 45.82841970402755 20
# average reward exploit: MDP 1 41.58752281694681 20
# average reward exploit: MDP 1 67.81641791351204 20
# average reward exploit: MDP 1 23.144508072776993 20
# average reward exploit: MDP 1 15.046942935712162 20
# average reward exploit: MDP 1 23.106706236656148 20
# average reward exploit: MDP 1 13.852586138353155 20
# average reward exploit: MDP 1 35.155247889299645 20
# average reward exploit: MDP 1 15.928306948497994 20
# average reward explore: 164.91068956700798
# average reward exploit: MDP 2 10.05587736350558 20
# average reward exploit: MDP 2 10.056258657922346 20
# average reward exploit: MDP 2 10.673594917020562 20
# average reward exploit: MDP 2 9.722749630400637 20
# average reward exploit: MDP 2 11.247265069437058 20
# average reward exploit: MDP 2 10.500792115827355 20
# average reward exploit: MDP 2 10.728209038992691 20
# average reward exploit: MDP 2 16.070551486159825 20
# average reward exploit: MDP 2 11.085777870110256 20
# average reward exploit: MDP 2 10.138041577078065 20
# average reward explore: 315.344734295095
# average reward exploit: MDP 3 5.266677264645744 20
# average reward exploit: MDP 3 5.254213742722652 20
# average reward exploit: MDP 3 6.232447868653324 20
# average reward exploit: MDP 3 6.262016943338068 20
# average reward exploit: MDP 3 5.688390103099753 20
# average reward exploit: MDP 3 6.915053619319235 20
# average reward exploit: MDP 3 6.44326584528018 20
# average reward exploit: MDP 3 6.290007407361169 20
# average reward exploit: MDP 3 6.169691381208115 20
# average reward exploit: MDP 3 6.407962174764284 20
# average reward explore: 417.8533201138679
# average reward exploit: MDP 4 7.70993720113489 20
# average reward exploit: MDP 4 10.115708530848098 20
# average reward exploit: MDP 4 7.877846004380899 20
# average reward exploit: MDP 4 8.803160653030783 20
# average reward exploit: MDP 4 8.411863963867365 20
# average reward exploit: MDP 4 8.558672875765195 20
# average reward exploit: MDP 4 7.610590467452331 20
# average reward exploit: MDP 4 7.795608294717503 20
# average reward exploit: MDP 4 7.782469187915045 20
# average reward exploit: MDP 4 7.773233407622568 20
# average reward explore: 370.0257827723957
# average reward exploit: MDP 5 5.222046503089437 20
# average reward exploit: MDP 5 5.547863084974584 20
# average reward exploit: MDP 5 5.679566107055392 20
# average reward exploit: MDP 5 5.621649231590384 20
# average reward exploit: MDP 5 5.859667023073365 20
# average reward exploit: MDP 5 5.614730688605818 20
# average reward exploit: MDP 5 5.940451605276356 20
# average reward exploit: MDP 5 6.150500679585624 20
# average reward exploit: MDP 5 5.985345423568423 20
# average reward exploit: MDP 5 6.247662467224542 20
# average reward explore: 378.3159082763248
# average reward exploit: MDP 6 6.669285568125288 20
# average reward exploit: MDP 6 6.791535074984823 20
# average reward exploit: MDP 6 6.911210369124956 20
# average reward exploit: MDP 6 6.864432680955881 20
# average reward exploit: MDP 6 7.080993574828938 20
# average reward exploit: MDP 6 6.779011964918324 20
# average reward exploit: MDP 6 6.735197696654874 20
# average reward exploit: MDP 6 6.671507657884431 20
# average reward exploit: MDP 6 7.02575270462264 20
# average reward exploit: MDP 6 6.987767271843326 20
# average reward explore: 430.3127908421011
# average reward exploit: MDP 7 32.21508649720912 20
# average reward exploit: MDP 7 30.839813201663823 20
# average reward exploit: MDP 7 33.18770591695902 20
# average reward exploit: MDP 7 40.90403935493351 20
# average reward exploit: MDP 7 25.497552252735765 20
# average reward exploit: MDP 7 24.202776364959583 20
# average reward exploit: MDP 7 30.163085627225268 20
# average reward exploit: MDP 7 19.205709480899284 20
# average reward exploit: MDP 7 7.813283722334612 20
# average reward exploit: MDP 7 7.85135799063367 20
# average reward explore: 423.4513402375657
# average reward exploit: MDP 8 2.8774642627878113 20
# average reward exploit: MDP 8 2.6637471333042346 20
# average reward exploit: MDP 8 2.7539418544100607 20
# average reward exploit: MDP 8 2.674322274885024 20
# average reward exploit: MDP 8 2.75994443538744 20
# average reward exploit: MDP 8 2.5086487148768453 20
# average reward exploit: MDP 8 2.7364066169255086 20
# average reward exploit: MDP 8 2.8315445561498342 20
# average reward exploit: MDP 8 2.882389774780622 20
# average reward exploit: MDP 8 2.9301497842873028 20
# average reward explore: 443.65373804521477
# average reward exploit: MDP 9 3.442657147069 20
# average reward exploit: MDP 9 3.500857011840575 20
# average reward exploit: MDP 9 3.657555198726425 20
# average reward exploit: MDP 9 9.980167540192136 20
# average reward exploit: MDP 9 20.087333515952686 20
# average reward exploit: MDP 9 30.639725458345293 20
# average reward exploit: MDP 9 73.89833450140125 20
# average reward exploit: MDP 9 72.2559054861809 20
# average reward exploit: MDP 9 62.56630988748731 20
# average reward exploit: MDP 9 50.76501392395414 20
# epoch number:  13
# average reward explore: 166.895341249448
# average reward exploit: MDP 0 37.447671062891345 20
# average reward exploit: MDP 0 38.21509055318456 20
# average reward exploit: MDP 0 22.81593016301142 20
# average reward exploit: MDP 0 37.059889640135665 20
# average reward exploit: MDP 0 14.237996243723313 20
# average reward exploit: MDP 0 21.254101950543678 20
# average reward exploit: MDP 0 23.72563113367319 20
# average reward exploit: MDP 0 14.762469090496708 20
# average reward exploit: MDP 0 24.038407459492596 20
# average reward exploit: MDP 0 13.65288939232613 20
# average reward explore: 158.18516197106564
# average reward exploit: MDP 1 8.143978766826976 20
# average reward exploit: MDP 1 8.990577769224096 20
# average reward exploit: MDP 1 10.315881237869432 20
# average reward exploit: MDP 1 9.215526538582996 20
# average reward exploit: MDP 1 12.54977551695015 20
# average reward exploit: MDP 1 8.516419522182186 20
# average reward exploit: MDP 1 12.771716946929988 20
# average reward exploit: MDP 1 12.236235706099007 20
# average reward exploit: MDP 1 13.547916578259763 20
# average reward exploit: MDP 1 14.400347786757948 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-fff9c5bce224> in <module>()
#       3 for epoch in range(num_epochs):
#       4         print("epoch number: ", epoch)
# ----> 5         a.train_step()
#
# <ipython-input-49-fb36fe994242> in train_step(self)
#     326         # sample num_traj*num_MDPs
#     327         for i in range(self.num_mdps):
# --> 328             explore_paths, explore_rewards = self.sample_paths_explore(self.env,i)
#     329             observations_explore = np.concatenate([path["observation"] for path in explore_paths])
#     330             new_observations_explore = np.concatenate([path["new_obs"] for path in explore_paths])
#
# <ipython-input-49-fb36fe994242> in sample_paths_explore(self, env, mdp_num, Test, num_episodes)
#     146                     new_states.append(state)
#     147                     #action = self.sess.run(self.explore_action, feed_dict={self.observation_placeholder_explore : states[-1][None]})[0]
# --> 148                     action = self.policyfn.sample_action(state) #NEW
#     149                     state, reward, done, info = env.step(action)
#     150                     actions.append(action)
#
# ~/AA290/Meta-RL/policies.py in sample_action(self, ob)
#     163
#     164     def sample_action(self, ob):
# --> 165         return self.sess.run(self.sampled_ac, feed_dict={self.ob_no: ob[None]})
#     166
#     167
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
explore_paths, explore_rewards = a.sample_paths_explore(a.env,1)

# %%
print("average reward explore:", np.mean(explore_rewards), len(explore_rewards))
M = a.stack_trajectories(explore_paths)
# Out:
# average reward explore: 427.84420643869714 40

# %%
Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })

# %%
Z = np.reshape(Z,[1,len(Z)])

# %%
exploit_paths, exploit_rewards = a.sample_paths_exploit(a.env,Z,1)

# %%
print("average reward exploit", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
# Out:
# average reward exploit 22.049929724727424 20

# %%
a.num_traj = 20

# %%
for i in range(10):
    maxrev2 = 0
    maxrev1 = 0
    traj = np.random.rand()*(i+1)
    
    for i in range(4):
        explore_paths, explore_rewards = a.sample_paths_explore(a.env,traj)
        #print("average reward explore:", np.mean(explore_rewards))
        M = a.stack_trajectories(explore_paths)
        Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })
        Z = np.reshape(Z,[1,len(Z)])
        exploit_paths, explore_rewards = a.sample_paths_exploit(a.env,Z,traj)
        if(np.mean(explore_rewards) > maxrev1):
            maxrev1 = np.mean(explore_rewards) / num_traj
        if(np.mean(exploit_rewards)>maxrev2):
            maxrev2 = np.mean(exploit_rewards) / num_traj
    print("gravity:", a.sim.model.opt.gravity)
    print("average reward explore", maxrev1)
    print("average reward exploit", maxrev2)
# Out:
# gravity: [ 0.         0.        -5.4325712]
# average reward explore 3.5619071147766848
# average reward exploit 2.7301699712255383
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-730f26c155e6> in <module>()
#       5
#       6     for i in range(4):
# ----> 7         explore_paths, explore_rewards = a.sample_paths_explore(a.env,traj)
#       8         #print("average reward explore:", np.mean(explore_rewards))
#       9         M = a.stack_trajectories(explore_paths)
#
# <ipython-input-49-fb36fe994242> in sample_paths_explore(self, env, mdp_num, Test, num_episodes)
#     143                     rewards.append(0)
#     144                 else:
# --> 145                     states.append(state)
#     146                     new_states.append(state)
#     147                     #action = self.sess.run(self.explore_action, feed_dict={self.observation_placeholder_explore : states[-1][None]})[0]
#
# KeyboardInterrupt:

# %%
explore_paths, explore_rewards = a.sample_paths_explore(a.env,5)
observations_explore = np.concatenate([path["observation"] for path in explore_paths])
new_observations_explore = np.concatenate([path["new_obs"] for path in explore_paths])
new_actions_explore = np.concatenate([path["new_acs"] for path in explore_paths])
actions_explore = np.concatenate([path["action"] for path in explore_paths])
rewards_explore = np.concatenate([path["reward"] for path in explore_paths])
returns_explore = a.get_returns(explore_paths, explore = True)

# %%
M = np.array(a.stack_trajectories(explore_paths))
Z = a.sess.run(a.Z, feed_dict = {a.encoder_input_placeholder: M,a.sequence_length_placeholder: a.length })
Z = np.reshape(Z,[1,len(Z)])

# %%
 print("average reward explore: MDP", np.sum(explore_rewards)/num_traj, len(explore_rewards))
# Out:
# average reward explore: MDP 20488.85105031593 800

# %%
exploit_paths, exploit_rewards = a.sample_paths_exploit(a.env,Z,5)

# %%
print("average reward exploit: MDP", np.sum(exploit_rewards) / num_traj, len(exploit_rewards))
# Out:
# average reward exploit: MDP 644.4290518284578 400

# %%
def randomize_pendulum(env):
    m = config['pendulum_mass_min'] + np.random.rand()*(config['pendulum_mass_max'] - config['pendulum_mass_min'])
    l = config['pendulum_len_min'] + np.random.rand()*(config['pendulum_len_max'] - config['pendulum_len_min'])
    env.m = m
    env.l = l

# %%
def randomize_hopper(env):
    ts = config['torso_min'] + np.random.rand()*(config['torso_max'] - config['torso_min'])
    f = config['friction_min'] + np.random.rand()*(config['friction_max'] - config['friction_min'])
    
    env.friction = f
    env.torso_size = ts
    env.apply_env_modifications()

# %%
import yaml
cfg_filename = 'hopper-config.yml'
with open(cfg_filename,'r') as ymlfile:
    config = yaml.load(ymlfile)

# %%
env = Randomizer(gym.make('Hopper-v2'), randomize_hopper)
env.unwrapped.__dict__.keys()
env.reset()

# %%
m = config['pendulum_mass_min'] + np.random.rand()*(config['pendulum_mass_max'] - config['pendulum_mass_min'])

# %%
config

# %%
env_id = 'Hopper-v2'
e = gym.make(env_id)

# %%
e.unwrapped.__dict__.keys()

# %%
e.unwrapped.apply_env_modifications()

# %%
a.sim.model.opt
